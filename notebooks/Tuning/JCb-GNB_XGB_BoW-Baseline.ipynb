# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'gnb'
FEATURE_IMPORTANCE_ORDERING = 'xgb'
PREPROCESSING = 'Baseline'
TUNER = 'jiaochengb'
FEATURE_ENGINEERING = 'bow'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle
from scipy.sparse import load_npz 

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/Research - Internet Addiction Part 1/PrivatePackages" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/Research - Internet Addiction Part 1/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
else:
    py_file_location = '../../PrivatePackages'
    home_directory = '../../'

sys.path.append(os.path.abspath(py_file_location))

from Tuners import JiaoChengB

import pandas as pd

# %%
## Parameters that are same for every script

SEED = 2608

TASK_TYPE = 'Classification' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = True # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from xgboost import XGBClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'var_smoothing': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    }

tuning_order = [
    'features',
    'var_smoothing'
]

default_hyperparameter_values = {'var_smoothing': 1, 'features': 0}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_x = load_npz(home_directory + f'data/curated/baseline/train_{FEATURE_ENGINEERING}_x.npz')
val_x = load_npz(home_directory + f'data/curated/baseline/val_{FEATURE_ENGINEERING}_x.npz')
test_x = load_npz(home_directory + f'data/curated/baseline/test_{FEATURE_ENGINEERING}_x.npz')

with open(home_directory + 'data/curated/baseline/train_y.pkl', 'rb') as f:
    train_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/val_y.pkl', 'rb') as f:
    val_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/test_y.pkl', 'rb') as f:
    test_y = pickle.load(f)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = JiaoChengB.JiaoChengB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'xgboost.sklearn.XGBClassifier'>, which is a Classification model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# FEATURE_INDEX: 0 (var_smoothing) ROUND 1
#
# Round 1
# Hyperparameter: features (index: 1)
# Trained and Tested combination 1 of 904: (5, 0), taking 5.53 seconds to get val score of 0.7881
#         Current best combo: (5, 0) with val score 0.7881
# Trained and Tested combination 2 of 904: (5, 1), taking 6.54 seconds to get val score of 0.7844
#         Current best combo: (5, 0) with val score 0.7881
# Trained and Tested combination 3 of 904: (5, 2), taking 6.05 seconds to get val score of 0.7907
#         Current best combo: (5, 2) with val score 0.7907
# Trained and Tested combination 4 of 904: (5, 3), taking 5.52 seconds to get val score of 0.79
#         Current best combo: (5, 2) with val score 0.7907
# Trained and Tested combination 5 of 904: (5, 4), taking 7.44 seconds to get val score of 0.7941
#         Current best combo: (5, 4) with val score 0.7941
# Trained and Tested combination 6 of 904: (5, 5), taking 5.83 seconds to get val score of 0.7996
#         Current best combo: (5, 5) with val score 0.7996
# Trained and Tested combination 7 of 904: (5, 6), taking 6.63 seconds to get val score of 0.797
#         Current best combo: (5, 5) with val score 0.7996
# Trained and Tested combination 8 of 904: (5, 7), taking 7.21 seconds to get val score of 0.8078
#         Current best combo: (5, 7) with val score 0.8078
# Trained and Tested combination 9 of 904: (5, 8), taking 9.51 seconds to get val score of 0.8004
#         Current best combo: (5, 7) with val score 0.8078
# Trained and Tested combination 10 of 904: (5, 9), taking 7.21 seconds to get val score of 0.8048
#         Current best combo: (5, 7) with val score 0.8078
# Trained and Tested combination 11 of 904: (5, 10), taking 5.77 seconds to get val score of 0.8026
#         Current best combo: (5, 7) with val score 0.8078
# Trained and Tested combination 12 of 904: (5, 11), taking 7.02 seconds to get val score of 0.8007
#         Current best combo: (5, 7) with val score 0.8078
# Trained and Tested combination 13 of 904: (5, 12), taking 6.72 seconds to get val score of 0.8026
#         Current best combo: (5, 7) with val score 0.8078
# Trained and Tested combination 14 of 904: (5, 13), taking 7.32 seconds to get val score of 0.8056
#         Current best combo: (5, 7) with val score 0.8078
# Trained and Tested combination 15 of 904: (5, 14), taking 5.58 seconds to get val score of 0.807
#         Current best combo: (5, 7) with val score 0.8078
# Trained and Tested combination 16 of 904: (5, 15), taking 5.23 seconds to get val score of 0.8111
#         Current best combo: (5, 15) with val score 0.8111
# Trained and Tested combination 17 of 904: (5, 16), taking 6.29 seconds to get val score of 0.8159
#         Current best combo: (5, 16) with val score 0.8159
# Trained and Tested combination 18 of 904: (5, 17), taking 5.38 seconds to get val score of 0.8185
#         Current best combo: (5, 17) with val score 0.8185
# Trained and Tested combination 19 of 904: (5, 18), taking 4.68 seconds to get val score of 0.813
#         Current best combo: (5, 17) with val score 0.8185
# Trained and Tested combination 20 of 904: (5, 19), taking 9.62 seconds to get val score of 0.81
#         Current best combo: (5, 17) with val score 0.8185
# Trained and Tested combination 21 of 904: (5, 20), taking 5.2 seconds to get val score of 0.8089
#         Current best combo: (5, 17) with val score 0.8185
# Trained and Tested combination 22 of 904: (5, 21), taking 6.05 seconds to get val score of 0.8148
#         Current best combo: (5, 17) with val score 0.8185
# Trained and Tested combination 23 of 904: (5, 22), taking 5.63 seconds to get val score of 0.8219
#         Current best combo: (5, 22) with val score 0.8219
# Trained and Tested combination 24 of 904: (5, 23), taking 5.33 seconds to get val score of 0.8204
#         Current best combo: (5, 22) with val score 0.8219
# Trained and Tested combination 25 of 904: (5, 24), taking 5.31 seconds to get val score of 0.8148
#         Current best combo: (5, 22) with val score 0.8219
# Trained and Tested combination 26 of 904: (5, 25), taking 6.14 seconds to get val score of 0.8185
#         Current best combo: (5, 22) with val score 0.8219
# Trained and Tested combination 27 of 904: (5, 26), taking 5.82 seconds to get val score of 0.817
#         Current best combo: (5, 22) with val score 0.8219
# Trained and Tested combination 28 of 904: (5, 27), taking 4.41 seconds to get val score of 0.8174
#         Current best combo: (5, 22) with val score 0.8219
# Trained and Tested combination 29 of 904: (5, 28), taking 2.36 seconds to get val score of 0.8159
#         Current best combo: (5, 22) with val score 0.8219
# Trained and Tested combination 30 of 904: (5, 29), taking 2.93 seconds to get val score of 0.8226
#         Current best combo: (5, 29) with val score 0.8226
# Trained and Tested combination 31 of 904: (5, 30), taking 4.63 seconds to get val score of 0.82
#         Current best combo: (5, 29) with val score 0.8226
# Trained and Tested combination 32 of 904: (5, 31), taking 4.61 seconds to get val score of 0.8215
#         Current best combo: (5, 29) with val score 0.8226
# Trained and Tested combination 33 of 904: (5, 32), taking 4.28 seconds to get val score of 0.8256
#         Current best combo: (5, 32) with val score 0.8256
# Trained and Tested combination 34 of 904: (5, 33), taking 5.86 seconds to get val score of 0.8226
#         Current best combo: (5, 32) with val score 0.8256
# Trained and Tested combination 35 of 904: (5, 34), taking 4.33 seconds to get val score of 0.8219
#         Current best combo: (5, 32) with val score 0.8256
# Trained and Tested combination 36 of 904: (5, 35), taking 4.14 seconds to get val score of 0.8274
#         Current best combo: (5, 35) with val score 0.8274
# Trained and Tested combination 37 of 904: (5, 36), taking 4.81 seconds to get val score of 0.8226
#         Current best combo: (5, 35) with val score 0.8274
# Trained and Tested combination 38 of 904: (5, 37), taking 6.38 seconds to get val score of 0.8226
#         Current best combo: (5, 35) with val score 0.8274
# Trained and Tested combination 39 of 904: (5, 38), taking 4.69 seconds to get val score of 0.8256
#         Current best combo: (5, 35) with val score 0.8274
# Trained and Tested combination 40 of 904: (5, 39), taking 3.89 seconds to get val score of 0.8289
#         Current best combo: (5, 39) with val score 0.8289
# Trained and Tested combination 41 of 904: (5, 40), taking 4.35 seconds to get val score of 0.8352
#         Current best combo: (5, 40) with val score 0.8352
# Trained and Tested combination 42 of 904: (5, 41), taking 4.9 seconds to get val score of 0.8278
#         Current best combo: (5, 40) with val score 0.8352
# Trained and Tested combination 43 of 904: (5, 42), taking 4.62 seconds to get val score of 0.8296
#         Current best combo: (5, 40) with val score 0.8352
# Trained and Tested combination 44 of 904: (5, 43), taking 3.69 seconds to get val score of 0.8337
#         Current best combo: (5, 40) with val score 0.8352
# Trained and Tested combination 45 of 904: (5, 44), taking 4.02 seconds to get val score of 0.8274
#         Current best combo: (5, 40) with val score 0.8352
# Trained and Tested combination 46 of 904: (5, 45), taking 3.89 seconds to get val score of 0.83
#         Current best combo: (5, 40) with val score 0.8352
# Trained and Tested combination 47 of 904: (5, 46), taking 4.65 seconds to get val score of 0.8341
#         Current best combo: (5, 40) with val score 0.8352
# Trained and Tested combination 48 of 904: (5, 47), taking 3.84 seconds to get val score of 0.8356
#         Current best combo: (5, 47) with val score 0.8356
# Trained and Tested combination 49 of 904: (5, 48), taking 3.83 seconds to get val score of 0.8322
#         Current best combo: (5, 47) with val score 0.8356
# Trained and Tested combination 50 of 904: (5, 49), taking 3.76 seconds to get val score of 0.8311
#         Current best combo: (5, 47) with val score 0.8356
# Trained and Tested combination 51 of 904: (5, 50), taking 4.65 seconds to get val score of 0.8363
#         Current best combo: (5, 50) with val score 0.8363
# Trained and Tested combination 52 of 904: (5, 51), taking 4.11 seconds to get val score of 0.8356
#         Current best combo: (5, 50) with val score 0.8363
# Trained and Tested combination 53 of 904: (5, 52), taking 3.61 seconds to get val score of 0.837
#         Current best combo: (5, 52) with val score 0.837
# Trained and Tested combination 54 of 904: (5, 53), taking 3.93 seconds to get val score of 0.837
#         Current best combo: (5, 52) with val score 0.837
# Trained and Tested combination 55 of 904: (5, 54), taking 3.45 seconds to get val score of 0.833
#         Current best combo: (5, 52) with val score 0.837
# Trained and Tested combination 56 of 904: (5, 55), taking 5.03 seconds to get val score of 0.8367
#         Current best combo: (5, 52) with val score 0.837
# Trained and Tested combination 57 of 904: (5, 56), taking 4.42 seconds to get val score of 0.8296
#         Current best combo: (5, 52) with val score 0.837
# Trained and Tested combination 58 of 904: (5, 57), taking 4.31 seconds to get val score of 0.8367
#         Current best combo: (5, 52) with val score 0.837
# Trained and Tested combination 59 of 904: (5, 58), taking 3.24 seconds to get val score of 0.8326
#         Current best combo: (5, 52) with val score 0.837
# Trained and Tested combination 60 of 904: (5, 59), taking 3.88 seconds to get val score of 0.8267
#         Current best combo: (5, 52) with val score 0.837
# Trained and Tested combination 61 of 904: (5, 60), taking 4.59 seconds to get val score of 0.8385
#         Current best combo: (5, 60) with val score 0.8385
# Trained and Tested combination 62 of 904: (5, 61), taking 5.22 seconds to get val score of 0.8333
#         Current best combo: (5, 60) with val score 0.8385
# Trained and Tested combination 63 of 904: (5, 62), taking 5.98 seconds to get val score of 0.8315
#         Current best combo: (5, 60) with val score 0.8385
# Trained and Tested combination 64 of 904: (5, 63), taking 5.44 seconds to get val score of 0.8319
#         Current best combo: (5, 60) with val score 0.8385
# Trained and Tested combination 65 of 904: (5, 64), taking 10.7 seconds to get val score of 0.8326
#         Current best combo: (5, 60) with val score 0.8385
# Trained and Tested combination 66 of 904: (5, 65), taking 4.58 seconds to get val score of 0.8356
#         Current best combo: (5, 60) with val score 0.8385
# Trained and Tested combination 67 of 904: (5, 66), taking 5.61 seconds to get val score of 0.8344
#         Current best combo: (5, 60) with val score 0.8385
# Trained and Tested combination 68 of 904: (5, 67), taking 5.52 seconds to get val score of 0.8356
#         Current best combo: (5, 60) with val score 0.8385
# Trained and Tested combination 69 of 904: (5, 68), taking 4.39 seconds to get val score of 0.8367
#         Current best combo: (5, 60) with val score 0.8385
# Trained and Tested combination 70 of 904: (5, 69), taking 2.89 seconds to get val score of 0.8378
#         Current best combo: (5, 60) with val score 0.8385
# Trained and Tested combination 71 of 904: (5, 70), taking 2.05 seconds to get val score of 0.8411
#         Current best combo: (5, 70) with val score 0.8411
# Trained and Tested combination
, UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: var_smoothing (index: 0)
#
# Trained and Tested combination 114 of 904: (0, 80), taking 5.65 seconds to get val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448
# Trained and Tested combination 115 of 904: (1, 80), taking 5.74 seconds to get val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448
# Trained and Tested combination 116 of 904: (2, 80), taking 5.27 seconds to get val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448
# Trained and Tested combination 117 of 904: (3, 80), taking 4.86 seconds to get val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448
# Trained and Tested combination 118 of 904: (4, 80), taking 6.74 seconds to get val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448
# Already Trained and Tested combination (5, 80), which had val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 118 of 904 combinations so far
# Trained and Tested combination 119 of 904: (6, 80), taking 8.53 seconds to get val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448
# Trained and Tested combination 120 of 904: (7, 80), taking 7.88 seconds to get val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448
#
# Best combo after this hyperparameter: (5, 80) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 0 (var_smoothing) ROUND 2
#
# Round 2
# Hyperparameter: features (index: 1)
#
# Already Trained and Tested combination (5, 0), which had val score of 0.7881
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 1), which had val score of 0.7844
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 2), which had val score of 0.7907
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 3), which had val score of 0.79
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 4), which had val score of 0.7941
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 5), which had val score of 0.7996
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 6), which had val score of 0.797
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 7), which had val score of 0.8078
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 8), which had val score of 0.8004
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 9), which had val score of 0.8048
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 10), which had val score of 0.8026
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 11), which had val score of 0.8007
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 12), which had val score of 0.8026
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 13), which had val score of 0.8056
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 14), which had val score of 0.807
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 15), which had val score of 0.8111
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 16), which had val score of 0.8159
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 17), which had val score of 0.8185
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 18), which had val score of 0.813
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 19), which had val score of 0.81
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 20), which had val score of 0.8089
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 21), which had val score of 0.8148
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 22), which had val score of 0.8219
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 23), which had val score of 0.8204
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 24), which had val score of 0.8148
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 25), which had val score of 0.8185
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 26), which had val score of 0.817
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 27), which had val score of 0.8174
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 28), which had val score of 0.8159
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 29), which had val score of 0.8226
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 30), which had val score of 0.82
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 31), which had val score of 0.8215
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 32), which had val score of 0.8256
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 33), which had val score of 0.8226
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 34), which had val score of 0.8219
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 35), which had val score of 0.8274
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 36), which had val score of 0.8226
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 37), which had val score of 0.8226
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 38), which had val score of 0.8256
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 39), which had val score of 0.8289
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 40), which had val score of 0.8352
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 41), which had val score of 0.8278
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 42), which had val score of 0.8296
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 43), which had val score of 0.8337
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 44), which had val score of 0.8274
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 45), which had val score of 0.83
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 46), which had val score of 0.8341
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 47), which had val score of 0.8356
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 48), which had val score of 0.8322
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 49), which had val score of 0.8311
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 50), which had val score of 0.8363
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 51), which had val score of 0.8356
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 52), which had val score of 0.837
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 53), which had val score of 0.837
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 54), which had val score of 0.833
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 55), which had val score of 0.8367
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 56), which had val score of 0.8296
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 57), which had val score of 0.8367
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 58), which had val score of 0.8326
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 59), which had val score of 0.8267
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 60), which had val score of 0.8385
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 61), which had val score of 0.8333
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 62), which had val score of 0.8315
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 63), which had val score of 0.8319
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 64), which had val score of 0.8326
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 65), which had val score of 0.8356
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 66), which had val score of 0.8344
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 67), which had val score of 0.8356
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 68), which had val score of 0.8367
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 69), which had val score of 0.8378
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 70), which had val score of 0.8411
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 71), which had val score of 0.8359
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 72), which had val score of 0.8389
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 73), which had val score of 0.8367
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 74), which had val score of 0.833
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 75), which had val score of 0.8378
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 76), which had val score of 0.83
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 77), which had val score of 0.8374
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 78), which had val score of 0.8393
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 79), which had val score of 0.8374
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 80), which had val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 81), which had val score of 0.8348
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 82), which had val score of 0.8341
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 83), which had val score of 0.8356
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 84), which had val score of 0.84
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 85), which had val score of 0.8378
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 86), which had val score of 0.8337
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 87), which had val score of 0.8422
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 88), which had val score of 0.8385
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 89), which had val score of 0.8363
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 90), which had val score of 0.8426
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 91), which had val score of 0.8352
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 92), which had val score of 0.8389
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 93), which had val score of 0.8381
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 94), which had val score of 0.8381
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 95), which had val score of 0.8367
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 96), which had val score of 0.8389
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 97), which had val score of 0.837
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 98), which had val score of 0.8419
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 99), which had val score of 0.837
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 100), which had val score of 0.837
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 101), which had val score of 0.8344
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 102), which had val score of 0.8404
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 103), which had val score of 0.8352
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 104), which had val score of 0.8311
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 105), which had val score of 0.8359
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 106), which had val score of 0.8359
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 107), which had val score of 0.84
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 108), which had val score of 0.8411
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 109), which had val score of 0.8419
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 110), which had val score of 0.8381
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 111), which had val score of 0.8381
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 112), which had val score of 0.833
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
#
# Best combo after this hyperparameter: (5, 80) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: var_smoothing (index: 0)
#
# Already Trained and Tested combination (0, 80), which had val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (1, 80), which had val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (2, 80), which had val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (3, 80), which had val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (4, 80), which had val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (5, 80), which had val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (6, 80), which had val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
# Already Trained and Tested combination (7, 80), which had val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 120 of 904 combinations so far
#
# Best combo after this hyperparameter: (5, 80) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 1 (features) ROUND 1
#
# Round 1
# Hyperparameter: var_smoothing (index: 0)
#
# Trained and Tested combination 121 of 904: (0, 0), taking 3.67 seconds to get val score of 0.7881
#         Current best combo: (5, 80) with val score 0.8448
# Trained and Tested combination 122 of 904: (1, 0), taking 2.43 seconds to get val score of 0.7881
#         Current best combo: (5, 80) with val score 0.8448
# Trained and Tested combination 123 of 904: (2, 0), taking 3.15 seconds to get val score of 0.7881
#         Current best combo: (5, 80) with val score 0.8448
# Trained and Tested combination 124 of 904: (3, 0), taking 2.15 seconds to get val score of 0.7881
#         Current best combo: (5, 80) with val score 0.8448
# Trained and Tested combination 125 of 904: (4, 0), taking 2.08 seconds to get val score of 0.7881
#         Current best combo: (5, 80) with val score 0.8448
# Already Trained and Tested combination (5, 0), which had val score of 0.7881
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 125 of 904 combinations so far
# Trained and Tested combination 126 of 904: (6, 0), taking 1.56 seconds to get val score of 0.7881
#         Current best combo: (5, 80) with val score 0.8448
# Trained and Tested combination 127 of 904: (7, 0), taking 2.53 seconds to get val score of 0.7881
#         Current best combo: (5, 80) with val score 0.8448
#
# Best combo after this hyperparameter: (5, 80) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: features (index: 1)
#
# Already Trained and Tested combination (5, 0), which had val score of 0.7881
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 1), which had val score of 0.7844
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 2), which had val score of 0.7907
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 3), which had val score of 0.79
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 4), which had val score of 0.7941
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 5), which had val score of 0.7996
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 6), which had val score of 0.797
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 7), which had val score of 0.8078
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 8), which had val score of 0.8004
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 9), which had val score of 0.8048
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 10), which had val score of 0.8026
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 11), which had val score of 0.8007
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 12), which had val score of 0.8026
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 13), which had val score of 0.8056
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 14), which had val score of 0.807
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 15), which had val score of 0.8111
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 16), which had val score of 0.8159
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 17), which had val score of 0.8185
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 18), which had val score of 0.813
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 19), which had val score of 0.81
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 20), which had val score of 0.8089
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 21), which had val score of 0.8148
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# ...
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 52), which had val score of 0.837
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 53), which had val score of 0.837
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 54), which had val score of 0.833
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 55), which had val score of 0.8367
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 56), which had val score of 0.8296
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 57), which had val score of 0.8367
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 58), which had val score of 0.8326
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 59), which had val score of 0.8267
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 60), which had val score of 0.8385
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 61), which had val score of 0.8333
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 62), which had val score of 0.8315
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 63), which had val score of 0.8319
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 64), which had val score of 0.8326
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 65), which had val score of 0.8356
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 66), which had val score of 0.8344
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 67), which had val score of 0.8356
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 68), which had val score of 0.8367
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 69), which had val score of 0.8378
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 70), which had val score of 0.8411
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 71), which had val score of 0.8359
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 72), which had val score of 0.8389
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 73), which had val score of 0.8367
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 74), which had val score of 0.833
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 75), which had val score of 0.8378
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 76), which had val score of 0.83
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 77), which had val score of 0.8374
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 78), which had val score of 0.8393
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 79), which had val score of 0.8374
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 80), which had val score of 0.8448
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 81), which had val score of 0.8348
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 82), which had val score of 0.8341
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 83), which had val score of 0.8356
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 84), which had val score of 0.84
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 85), which had val score of 0.8378
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 86), which had val score of 0.8337
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 87), which had val score of 0.8422
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 88), which had val score of 0.8385
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 89), which had val score of 0.8363
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 90), which had val score of 0.8426
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 91), which had val score of 0.8352
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 92), which had val score of 0.8389
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 93), which had val score of 0.8381
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 94), which had val score of 0.8381
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 95), which had val score of 0.8367
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 96), which had val score of 0.8389
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 97), which had val score of 0.837
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 98), which had val score of 0.8419
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 99), which had val score of 0.837
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 100), which had val score of 0.837
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 101), which had val score of 0.8344
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 102), which had val score of 0.8404
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 103), which had val score of 0.8352
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 104), which had val score of 0.8311
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 105), which had val score of 0.8359
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 106), which had val score of 0.8359
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 107), which had val score of 0.84
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 108), which had val score of 0.8411
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 109), which had val score of 0.8419
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 110), which had val score of 0.8381
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 111), which had val score of 0.8381
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
# Already Trained and Tested combination (5, 112), which had val score of 0.833
#         Current best combo: (5, 80) with val score 0.8448.
#         Has trained 127 of 904 combinations so far
#
# Best combo after this hyperparameter: (5, 80) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.8448148148148148
# Max Test Score:
#  0.845185
# Max Combo Index:
#  (5, 80) out of [8, 113] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'var_smoothing': 1, 'features': 80}
# Max Combo Features:
#  (29667, 59920, 41191, 9639, 11997, 14175, 66664, 7149, 6603, 32996, 3710, 4587, 14700, 25279, 27675, 67128, 66157, 67050, 68180, 7075, 59749, 20338, 28574, 35861, 36130, 3061, 22106, 11721, 13444, 9404, 14989, 567, 27004, 6826, 36615, 34203, 16127, 6771, 4193, 37572, 66519, 2160, 27889, 1762, 36120, 67094, 35137, 36623, 3677, 3863, 67659, 2359, 63650, 112, 67892, 37744, 60303, 68047, 9072, 17942, 9372, 27745, 6450, 13095, 5563, 40128, 2491, 34703, 13142, 57787, 64230, 49708, 4501, 17577, 44387, 13454, 59415, 6308, 23378, 43389, 13877, 56288, 12469, 67781, 50832, 66239, 47800, 52938, 66841, 5607, 3414, 52187, 32465, 45854, 65820, 8584, 31185, 2038, 1574, 3094, 500, 29750, 50043, 13792, 42802, 23414, 27046, 62724, 389, 13727, 1651, 67637, 2688, 67361, 23131, 9050, 16198, 17050, 44471, 15432, 3403, 29971, 1663, 39524, 10971, 16331, 16037, 41662, 34860, 30159, 15118, 17674, 39435, 26704, 2567, 67494, 6882, 12746, 7300, 58670, 29441, 36203, 14524, 68147, 18304, 29592, 48456, 6638, 15998, 29601, 898, 43055, 18791, 51366, 1120, 11229, 5082, 51794, 2522, 49870, 30337, 35352, 11926, 21109, 14423, 1774, 19240, 48631, 58751, 43307, 18584, 2060, 111, 3315, 10330, 4875, 710, 17607, 31239, 27581, 1629, 16422, 22771, 66508, 20178, 16474, 13010, 8973, 25246, 3072, 15022, 4083, 3907, 25175, 1429, 38537, 3039, 11893, 67825, 50463, 17566, 66797, 2436, 46601, 7001, 12924, 11786, 22655, 2215, 58438, 12206, 20544, 67106, 60336, 1142, 9726, 64229, 775, 14637, 5401, 14361, 39106, 18484, 34377, 16564, 10842, 55893, 1441