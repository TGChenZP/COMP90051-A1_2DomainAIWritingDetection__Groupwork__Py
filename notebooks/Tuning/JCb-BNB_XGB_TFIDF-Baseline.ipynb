# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'bnb'
FEATURE_IMPORTANCE_ORDERING = 'xgb'
PREPROCESSING = 'Baseline'
TUNER = 'jiaochengb'
FEATURE_ENGINEERING = 'tfidf'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle
from scipy.sparse import load_npz 

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/Research - Internet Addiction Part 1/PrivatePackages" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/Research - Internet Addiction Part 1/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
else:
    py_file_location = '../../PrivatePackages'
    home_directory = '../../'

sys.path.append(os.path.abspath(py_file_location))

from Tuners import JiaoChengB

import pandas as pd

# %%
## Parameters that are same for every script

SEED = 2608

TASK_TYPE = 'Classification' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = True # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.naive_bayes import BernoulliNB as clf

# what values to try for each hyperparameter
parameter_choices = parameter_choices = {
    'alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
    'fit_prior': (False, True)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {}

tuning_order = [
    'features',
    'alpha',
    'fit_prior'
]

default_hyperparameter_values = {'fit_prior': True, 'alpha': 1, 'features': 0}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_x = load_npz(home_directory + f'data/curated/baseline/train_{FEATURE_ENGINEERING}_x.npz')
val_x = load_npz(home_directory + f'data/curated/baseline/val_{FEATURE_ENGINEERING}_x.npz')
test_x = load_npz(home_directory + f'data/curated/baseline/test_{FEATURE_ENGINEERING}_x.npz')

with open(home_directory + 'data/curated/baseline/train_y.pkl', 'rb') as f:
    train_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/val_y.pkl', 'rb') as f:
    val_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/test_y.pkl', 'rb') as f:
    test_y = pickle.load(f)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = JiaoChengB.JiaoChengB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'sklearn.naive_bayes.BernoulliNB'>, which is a Classification model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# FEATURE_INDEX: 0 (alpha) ROUND 1
#
# Round 1
# Hyperparameter: features (index: 2)
# Trained and Tested combination 1 of 1302: (4, 1, 0), taking 0.01 seconds to get val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 2 of 1302: (4, 1, 1), taking 0.02 seconds to get val score of 0.7615
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 3 of 1302: (4, 1, 2), taking 0.01 seconds to get val score of 0.7674
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 4 of 1302: (4, 1, 3), taking 0.01 seconds to get val score of 0.7648
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 5 of 1302: (4, 1, 4), taking 0.01 seconds to get val score of 0.7704
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 6 of 1302: (4, 1, 5), taking 0.01 seconds to get val score of 0.7693
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 7 of 1302: (4, 1, 6), taking 0.03 seconds to get val score of 0.7
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 8 of 1302: (4, 1, 7), taking 0.01 seconds to get val score of 0.7052
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 9 of 1302: (4, 1, 8), taking 0.01 seconds to get val score of 0.7085
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 10 of 1302: (4, 1, 9), taking 0.02 seconds to get val score of 0.7722
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 11 of 1302: (4, 1, 10), taking 0.03 seconds to get val score of 0.7207
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 12 of 1302: (4, 1, 11), taking 0.01 seconds to get val score of 0.7193
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 13 of 1302: (4, 1, 12), taking 0.01 seconds to get val score of 0.7219
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 14 of 1302: (4, 1, 13), taking 0.02 seconds to get val score of 0.7041
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 15 of 1302: (4, 1, 14), taking 0.02 seconds to get val score of 0.6922
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 16 of 1302: (4, 1, 15), taking 0.01 seconds to get val score of 0.6811
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 17 of 1302: (4, 1, 16), taking 0.01 seconds to get val score of 0.6759
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 18 of 1302: (4, 1, 17), taking 0.02 seconds to get val score of 0.6844
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 19 of 1302: (4, 1, 18), taking 0.02 seconds to get val score of 0.6852
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 20 of 1302: (4, 1, 19), taking 0.01 seconds to get val score of 0.6767
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 21 of 1302: (4, 1, 20), taking 0.05 seconds to get val score of 0.6574
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 22 of 1302: (4, 1, 21), taking 0.01 seconds to get val score of 0.6481
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 23 of 1302: (4, 1, 22), taking 0.02 seconds to get val score of 0.6367
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 24 of 1302: (4, 1, 23), taking 0.01 seconds to get val score of 0.6322
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 25 of 1302: (4, 1, 24), taking 0.01 seconds to get val score of 0.6452
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 26 of 1302: (4, 1, 25), taking 0.01 seconds to get val score of 0.6407
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 27 of 1302: (4, 1, 26), taking 0.01 seconds to get val score of 0.6374
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 28 of 1302: (4, 1, 27), taking 0.01 seconds to get val score of 0.6463
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 29 of 1302: (4, 1, 28), taking 0.02 seconds to get val score of 0.6404
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 30 of 1302: (4, 1, 29), taking 0.04 seconds to get val score of 0.6348
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 31 of 1302: (4, 1, 30), taking 0.02 seconds to get val score of 0.6341
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 32 of 1302: (4, 1, 31), taking 0.02 seconds to get val score of 0.6352
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 33 of 1302: (4, 1, 32), taking 0.03 seconds to get val score of 0.627
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 34 of 1302: (4, 1, 33), taking 0.03 seconds to get val score of 0.6178
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 35 of 1302: (4, 1, 34), taking 0.02 seconds to get val score of 0.62
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 36 of 1302: (4, 1, 35), taking 0.02 seconds to get val score of 0.6189
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 37 of 1302: (4, 1, 36), taking 0.01 seconds to get val score of 0.6174
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 38 of 1302: (4, 1, 37), taking 0.01 seconds to get val score of 0.6122
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 39 of 1302: (4, 1, 38), taking 0.02 seconds to get val score of 0.6085
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 40 of 1302: (4, 1, 39), taking 0.02 seconds to get val score of 0.6019
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 41 of 1302: (4, 1, 40), taking 0.06 seconds to get val score of 0.6048
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 42 of 1302: (4, 1, 41), taking 0.02 seconds to get val score of 0.6019
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 43 of 1302: (4, 1, 42), taking 0.02 seconds to get val score of 0.5981
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 44 of 1302: (4, 1, 43), taking 0.02 seconds to get val score of 0.5996
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 45 of 1302: (4, 1, 44), taking 0.01 seconds to get val score of 0.5967
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 46 of 1302: (4, 1, 45), taking 0.04 seconds to get val score of 0.5944
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 47 of 1302: (4, 1, 46), taking 0.02 seconds to get val score of 0.5981
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 48 of 1302: (4, 1, 47), taking 0.02 seconds to get val score of 0.5959
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 49 of 1302: (4, 1, 48), taking 0.02 seconds to get val score of 0.5952
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 50 of 1302: (4, 1, 49), taking 0.02 seconds to get val score of 0.5996
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 51 of 1302: (4, 1, 50), taking 0.02 seconds to get val score of 0.6011
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 52 of 1302: (4, 1, 51), taking 0.02 seconds to get val score of 0.6007
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 53 of 1302: (4, 1, 52), taking 0.02 seconds to get val score of 0.6022
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 54 of 1302: (4, 1, 53), taking 0.02 seconds to get val score of 0.6
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 55 of 1302: (4, 1, 54), taking 0.02 seconds to get val score of 0.5952
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 56 of 1302: (4, 1, 55), taking 0.06 seconds to get val score of 0.5978
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 57 of 1302: (4, 1, 56), taking 0.02 seconds to get val score of 0.5978
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 58 of 1302: (4, 1, 57), taking 0.04 seconds to get val score of 0.5967
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 59 of 1302: (4, 1, 58), taking 0.02 seconds to get val score of 0.5978
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 60 of 1302: (4, 1, 59), taking 0.02 seconds to get val score of 0.5956
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 61 of 1302: (4, 1, 60), taking 0.05 seconds to get val score of 0.5922
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 62 of 1302: (4, 1, 61), taking 0.04 seconds to get val score of 0.5926
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 63 of 1302: (4, 1, 62), taking 0.02 seconds to get val score of 0.593
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 64 of 1302: (4, 1, 63), taking 0.02 seconds to get val score of 0.5922
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 65 of 1302: (4, 1, 64), taking 0.02 seconds to get val score of 0.5904
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 66 of 1302: (4, 1, 65), taking 0.02 seconds to get val score of 0.5907
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 67 of 1302: (4, 1, 66), taking 0.02 seconds to get val score of 0.5904
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 68 of 1302: (4, 1, 67), taking 0.02 seconds to get val score of 0.5893
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 69 of 1302: (4, 1, 68), taking 0.02 seconds to get val score of 0.5867
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 70 of 1302: (4, 1, 69), taking 0.02 seconds to get val score of 0.5863
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 71 of 1302: (4, 1, 70), taking 0.02 seconds to get val score of 0.5863
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 72 of 1302: (4, 1, 71), taking 0.05 seconds to get val score of 0.5878
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 73 of 1302: (4, 1, 72), taking 0.05 seconds to get val score of 0.5859
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 74 of 1302: (4, 1, 73), taking 0.02 seconds to get val score of 0.5867
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 75 of 1302: (4, 1, 74), taking 0.05 seconds to get val score of 0.5874
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 76 of 1302: (4, 1, 75), taking 0.03 seconds to get val score of 0.5863
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 77 of 1302: (4, 1, 76), taking 0.04 seconds to get val score of 0.5874
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 78 of 1302: (4, 1, 77), taking 0.02 seconds to get val score of 0.5859
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 79 of 1302: (4, 1, 78), taking 0.02 seconds to get val score of 0.587
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 80 of 1302: (4, 1, 79), taking 0.02 seconds to get val score of 0.5841
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 81 of 1302: (4, 1, 80), taking 0.02 seconds to get val score of 0.5856
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 82 of 1302: (4, 1, 81), taking 0.02 seconds to get val score of 0.5841
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 83 of 1302: (4, 1, 82), taking 0.02 seconds to get val score of 0.5833
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 84 of 1302: (4, 1, 83), taking 0.03 seconds to get val score of 0.5837
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 85 of 1302: (4, 1, 84), taking 0.02 seconds to get val score of 0.5837
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 86 of 1302: (4, 1, 85), taking 0.02 seconds to get val score of 0.5826
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 87 of 1302: (4, 1, 86), taking 0.03 seconds to get val score of 0.583
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 88 of 1302: (4, 1, 87), taking 0.03 seconds to get val score of 0.583
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 89 of 1302: (4, 1, 88), taking 0.02 seconds to get val score of 0.5807
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 90 of 1302: (4, 1, 89), taking 0.03 seconds to get val score of 0.5822
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 91 of 1302: (4, 1, 90), taking 0.02 seconds to get val score of 0.5822
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 92 of 1302: (4, 1, 91), taking 0.02 seconds to get val score of 0.5819
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 93 of 1302: (4, 1, 92), taking 0.03 seconds to get val score of 0.5815
#         Current best combo: (4, 1, 0) with val score 0.7781
#
# Best combo after this hyperparameter: (4, 1, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: alpha (index: 0)
#
# Trained and Tested combination 94 of 1302: (0, 1, 0), taking 0.01 seconds to get val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 95 of 1302: (1, 1, 0), taking 0.01 seconds to get val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 96 of 1302: (2, 1, 0), taking 0.01 seconds to get val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 97 of 1302: (3, 1, 0), taking 0.01 seconds to get val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781
# Already Trained and Tested combination (4, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 97 of 1302 combinations so far
# Trained and Tested combination 98 of 1302: (5, 1, 0), taking 0.01 seconds to get val score of 0.7767
#         Current best combo: (4, 1, 0) with val score 0.7781
# Trained and Tested combination 99 of 1302: (6, 1, 0), taking 0.01 seconds to get val score of 0.7752
#         Current best combo: (4, 1, 0) with val score 0.7781
#
# Best combo after this hyperparameter: (4, 1, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: fit_prior (index: 1)
#
# Trained and Tested combination 100 of 1302: (4, 0, 0), taking 0.02 seconds to get val score of 0.7544
#         Current best combo: (4, 1, 0) with val score 0.7781
# Already Trained and Tested combination (4, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
#
# Best combo after this hyperparameter: (4, 1, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 0 (alpha) ROUND 2
#
# Round 2
# Hyperparameter: features (index: 2)
#
# Already Trained and Tested combination (4, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 1), which had val score of 0.7615
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 2), which had val score of 0.7674
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 3), which had val score of 0.7648
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 4), which had val score of 0.7704
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 5), which had val score of 0.7693
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 6), which had val score of 0.7
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 7), which had val score of 0.7052
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 8), which had val score of 0.7085
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 9), which had val score of 0.7722
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 10), which had val score of 0.7207
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 11), which had val score of 0.7193
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 12), which had val score of 0.7219
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 13), which had val score of 0.7041
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 14), which had val score of 0.6922
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 15), which had val score of 0.6811
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 16), which had val score of 0.6759
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 17), which had val score of 0.6844
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 18), which had val score of 0.6852
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 19), which had val score of 0.6767
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 20), which had val score of 0.6574
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 21), which had val score of 0.6481
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 22), which had val score of 0.6367
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 23), which had val score of 0.6322
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 24), which had val score of 0.6452
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 25), which had val score of 0.6407
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 26), which had val score of 0.6374
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 27), which had val score of 0.6463
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 28), which had val score of 0.6404
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 29), which had val score of 0.6348
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 30), which had val score of 0.6341
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 31), which had val score of 0.6352
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 32), which had val score of 0.627
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 33), which had val score of 0.6178
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 34), which had val score of 0.62
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 35), which had val score of 0.6189
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 36), which had val score of 0.6174
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 37), which had val score of 0.6122
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 38), which had val score of 0.6085
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 39), which had val score of 0.6019
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 40), which had val score of 0.6048
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 41), which had val score of 0.6019
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 42), which had val score of 0.5981
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 43), which had val score of 0.5996
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 44), which had val score of 0.5967
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 45), which had val score of 0.5944
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 46), which had val score of 0.5981
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 47), which had val score of 0.5959
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 48), which had val score of 0.5952
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 49), which had val score of 0.5996
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 50), which had val score of 0.6011
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 51), which had val score of 0.6007
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 52), which had val score of 0.6022
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 53), which had val score of 0.6
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 54), which had val score of 0.5952
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 55), which had val score of 0.5978
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 56), which had val score of 0.5978
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 57), which had val score of 0.5967
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 58), which had val score of 0.5978
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 59), which had val score of 0.5956
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 60), which had val score of 0.5922
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 61), which had val score of 0.5926
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 62), which had val score of 0.593
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 63), which had val score of 0.5922
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 64), which had val score of 0.5904
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 65), which had val score of 0.5907
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 66), which had val score of 0.5904
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 67), which had val score of 0.5893
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 68), which had val score of 0.5867
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 69), which had val score of 0.5863
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 70), which had val score of 0.5863
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 71), which had val score of 0.5878
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 72), which had val score of 0.5859
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 73), which had val score of 0.5867
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 74), which had val score of 0.5874
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 75), which had val score of 0.5863
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 76), which had val score of 0.5874
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 77), which had val score of 0.5859
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 78), which had val score of 0.587
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 79), which had val score of 0.5841
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 80), which had val score of 0.5856
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 81), which had val score of 0.5841
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 82), which had val score of 0.5833
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 83), which had val score of 0.5837
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 84), which had val score of 0.5837
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 85), which had val score of 0.5826
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 86), which had val score of 0.583
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 87), which had val score of 0.583
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 88), which had val score of 0.5807
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 89), which had val score of 0.5822
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 90), which had val score of 0.5822
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 91), which had val score of 0.5819
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 92), which had val score of 0.5815
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
#
# Best combo after this hyperparameter: (4, 1, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: alpha (index: 0)
#
# Already Trained and Tested combination (0, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (1, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (2, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (3, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (5, 1, 0), which had val score of 0.7767
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (6, 1, 0), which had val score of 0.7752
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
#
# Best combo after this hyperparameter: (4, 1, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: fit_prior (index: 1)
#
# Already Trained and Tested combination (4, 0, 0), which had val score of 0.7544
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
#
# Best combo after this hyperparameter: (4, 1, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 1 (fit_prior) ROUND 1
#
# Round 1
# Hyperparameter: alpha (index: 0)
#
# Already Trained and Tested combination (0, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (1, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (2, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (3, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (5, 1, 0), which had val score of 0.7767
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (6, 1, 0), which had val score of 0.7752
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
#
# Best combo after this hyperparameter: (4, 1, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: fit_prior (index: 1)
#
# Already Trained and Tested combination (4, 0, 0), which had val score of 0.7544
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
#
# Best combo after this hyperparameter: (4, 1, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: features (index: 2)
#
# Already Trained and Tested combination (4, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 1), which had val score of 0.7615
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 2), which had val score of 0.7674
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 3), which had val score of 0.7648
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 4), which had val score of 0.7704
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 5), which had val score of 0.7693
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 6), which had val score of 0.7
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 7), which had val score of 0.7052
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 8), which had val score of 0.7085
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 9), which had val score of 0.7722
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 10), which had val score of 0.7207
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 11), which had val score of 0.7193
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 12), which had val score of 0.7219
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 13), which had val score of 0.7041
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 14), which had val score of 0.6922
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 15), which had val score of 0.6811
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 16), which had val score of 0.6759
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 17), which had val score of 0.6844
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 18), which had val score of 0.6852
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 19), which had val score of 0.6767
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 20), which had val score of 0.6574
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 21), which had val score of 0.6481
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 22), which had val score of 0.6367
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 23), which had val score of 0.6322
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 24), which had val score of 0.6452
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 25), which had val score of 0.6407
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 26), which had val score of 0.6374
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 27), which had val score of 0.6463
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 28), which had val score of 0.6404
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 29), which had val score of 0.6348
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 30), which had val score of 0.6341
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 31), which had val score of 0.6352
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 32), which had val score of 0.627
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 33), which had val score of 0.6178
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 34), which had val score of 0.62
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 35), which had val score of 0.6189
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 36), which had val score of 0.6174
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 37), which had val score of 0.6122
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 38), which had val score of 0.6085
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 39), which had val score of 0.6019
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 40), which had val score of 0.6048
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 41), which had val score of 0.6019
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 42), which had val score of 0.5981
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 43), which had val score of 0.5996
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# ...
# Already Trained and Tested combination (4, 1, 21), which had val score of 0.6481
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 22), which had val score of 0.6367
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 23), which had val score of 0.6322
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 24), which had val score of 0.6452
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 25), which had val score of 0.6407
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 26), which had val score of 0.6374
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 27), which had val score of 0.6463
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 28), which had val score of 0.6404
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 29), which had val score of 0.6348
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 30), which had val score of 0.6341
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 31), which had val score of 0.6352
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 32), which had val score of 0.627
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 33), which had val score of 0.6178
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 34), which had val score of 0.62
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 35), which had val score of 0.6189
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 36), which had val score of 0.6174
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 37), which had val score of 0.6122
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 38), which had val score of 0.6085
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 39), which had val score of 0.6019
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 40), which had val score of 0.6048
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 41), which had val score of 0.6019
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 42), which had val score of 0.5981
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 43), which had val score of 0.5996
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 44), which had val score of 0.5967
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 45), which had val score of 0.5944
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 46), which had val score of 0.5981
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 47), which had val score of 0.5959
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 48), which had val score of 0.5952
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 49), which had val score of 0.5996
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 50), which had val score of 0.6011
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 51), which had val score of 0.6007
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 52), which had val score of 0.6022
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 53), which had val score of 0.6
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 54), which had val score of 0.5952
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 55), which had val score of 0.5978
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 56), which had val score of 0.5978
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 57), which had val score of 0.5967
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 58), which had val score of 0.5978
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 59), which had val score of 0.5956
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 60), which had val score of 0.5922
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 61), which had val score of 0.5926
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 62), which had val score of 0.593
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 63), which had val score of 0.5922
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 64), which had val score of 0.5904
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 65), which had val score of 0.5907
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 66), which had val score of 0.5904
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 67), which had val score of 0.5893
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 68), which had val score of 0.5867
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 69), which had val score of 0.5863
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 70), which had val score of 0.5863
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 71), which had val score of 0.5878
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 72), which had val score of 0.5859
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 73), which had val score of 0.5867
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 74), which had val score of 0.5874
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 75), which had val score of 0.5863
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 76), which had val score of 0.5874
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 77), which had val score of 0.5859
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 78), which had val score of 0.587
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 79), which had val score of 0.5841
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 80), which had val score of 0.5856
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 81), which had val score of 0.5841
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 82), which had val score of 0.5833
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 83), which had val score of 0.5837
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 84), which had val score of 0.5837
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 85), which had val score of 0.5826
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 86), which had val score of 0.583
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 87), which had val score of 0.583
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 88), which had val score of 0.5807
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 89), which had val score of 0.5822
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 90), which had val score of 0.5822
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 91), which had val score of 0.5819
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 92), which had val score of 0.5815
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
#
# Best combo after this hyperparameter: (4, 1, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: alpha (index: 0)
#
# Already Trained and Tested combination (0, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (1, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (2, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (3, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (4, 1, 0), which had val score of 0.7781
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (5, 1, 0), which had val score of 0.7767
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
# Already Trained and Tested combination (6, 1, 0), which had val score of 0.7752
#         Current best combo: (4, 1, 0) with val score 0.7781.
#         Has trained 100 of 1302 combinations so far
#
# Best combo after this hyperparameter: (4, 1, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.7781481481481481
# Max Test Score:
#  0.78037
# Max Combo Index:
#  (4, 1, 0) out of [7, 2, 93] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'alpha': 1, 'fit_prior': True, 'features': 0}
# Max Combo Features:
#  (3414, 29667, 887, 14524, 6603, 67869, 15936, 63974, 66808, 3426)
# % Combos Checked: 100 out of 1302 which is 7.680492%
