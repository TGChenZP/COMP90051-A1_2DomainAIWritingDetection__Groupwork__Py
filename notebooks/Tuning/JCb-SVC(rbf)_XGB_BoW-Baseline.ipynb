# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'svc(rbf)'
FEATURE_IMPORTANCE_ORDERING = 'xgb'
PREPROCESSING = 'Baseline'
TUNER = 'jiaochengb'
FEATURE_ENGINEERING = 'bow'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os
import pickle
from scipy.sparse import load_npz

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/PrivatePackages" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
else:
    py_file_location = '../../PrivatePackages'
    home_directory = '../../'

sys.path.append(os.path.abspath(py_file_location))

from Tuners import JiaoChengB

import pandas as pd

# %%
## Parameters that are same for every script

SEED = 2608

TASK_TYPE = 'Classification' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = True # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import SVC as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'decision_function_shape': 'ovr',
                                    'random_state': 42,
                                    'kernel': 'rbf'
                                    }

tuning_order = [
    'features',
    'C',
    'max_iter',
    'gamma',
    'tol',
]

default_hyperparameter_values = {'C': 1, 'tol': 0.001, 'max_iter': 800, 'gamma': 'auto', 'features': 0}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_x = load_npz(home_directory + f'data/curated/baseline/train_{FEATURE_ENGINEERING}_x.npz')
val_x = load_npz(home_directory + f'data/curated/baseline/val_{FEATURE_ENGINEERING}_x.npz')
test_x = load_npz(home_directory + f'data/curated/baseline/test_{FEATURE_ENGINEERING}_x.npz')

with open(home_directory + 'data/curated/baseline/train_y.pkl', 'rb') as f:
    train_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/val_y.pkl', 'rb') as f:
    val_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/test_y.pkl', 'rb') as f:
    test_y = pickle.load(f)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = JiaoChengB.JiaoChengB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.SVC'>, which is a Classification model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# FEATURE_INDEX: 0 (C) ROUND 1
#
# Round 1
# Hyperparameter: features (index: 4)
#
# Trained and Tested combination 1 of 48816: (4, 1, 4, 0, 0), taking 0.65 seconds to get val score of 0.3804
#         Current best combo: (4, 1, 4, 0, 0) with val score 0.3804
# Trained and Tested combination 2 of 48816: (4, 1, 4, 0, 1), taking 0.59 seconds to get val score of 0.3933
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 3 of 48816: (4, 1, 4, 0, 2), taking 0.78 seconds to get val score of 0.3433
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 4 of 48816: (4, 1, 4, 0, 3), taking 1.0 seconds to get val score of 0.3126
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 5 of 48816: (4, 1, 4, 0, 4), taking 0.67 seconds to get val score of 0.2748
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 6 of 48816: (4, 1, 4, 0, 5), taking 0.7 seconds to get val score of 0.2604
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 7 of 48816: (4, 1, 4, 0, 6), taking 0.71 seconds to get val score of 0.2604
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 8 of 48816: (4, 1, 4, 0, 7), taking 0.74 seconds to get val score of 0.2544
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 9 of 48816: (4, 1, 4, 0, 8), taking 0.77 seconds to get val score of 0.2548
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 10 of 48816: (4, 1, 4, 0, 9), taking 0.84 seconds to get val score of 0.2578
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 11 of 48816: (4, 1, 4, 0, 10), taking 1.28 seconds to get val score of 0.2559
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 12 of 48816: (4, 1, 4, 0, 11), taking 0.93 seconds to get val score of 0.2478
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 13 of 48816: (4, 1, 4, 0, 12), taking 0.91 seconds to get val score of 0.2559
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 14 of 48816: (4, 1, 4, 0, 13), taking 0.93 seconds to get val score of 0.2481
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 15 of 48816: (4, 1, 4, 0, 14), taking 0.98 seconds to get val score of 0.2556
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 16 of 48816: (4, 1, 4, 0, 15), taking 1.01 seconds to get val score of 0.2659
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 17 of 48816: (4, 1, 4, 0, 16), taking 1.57 seconds to get val score of 0.2559
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 18 of 48816: (4, 1, 4, 0, 17), taking 1.14 seconds to get val score of 0.2537
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 19 of 48816: (4, 1, 4, 0, 18), taking 1.18 seconds to get val score of 0.2707
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 20 of 48816: (4, 1, 4, 0, 19), taking 1.22 seconds to get val score of 0.2585
#         Current best combo: (4, 1, 4, 0, 1) with val score 0.3933
# Trained and Tested combination 21 of 48816: (4, 1, 4, 0, 20), taking 1.8 seconds to get val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 22 of 48816: (4, 1, 4, 0, 21), taking 1.44 seconds to get val score of 0.26
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 23 of 48816: (4, 1, 4, 0, 22), taking 1.47 seconds to get val score of 0.2648
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 24 of 48816: (4, 1, 4, 0, 23), taking 1.57 seconds to get val score of 0.2607
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 25 of 48816: (4, 1, 4, 0, 24), taking 1.78 seconds to get val score of 0.3041
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 26 of 48816: (4, 1, 4, 0, 25), taking 1.8 seconds to get val score of 0.3096
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 27 of 48816: (4, 1, 4, 0, 26), taking 2.73 seconds to get val score of 0.2841
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 28 of 48816: (4, 1, 4, 0, 27), taking 1.94 seconds to get val score of 0.2704
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 29 of 48816: (4, 1, 4, 0, 28), taking 1.98 seconds to get val score of 0.2744
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 30 of 48816: (4, 1, 4, 0, 29), taking 2.7 seconds to get val score of 0.2737
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 31 of 48816: (4, 1, 4, 0, 30), taking 2.19 seconds to get val score of 0.2796
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 32 of 48816: (4, 1, 4, 0, 31), taking 2.34 seconds to get val score of 0.2689
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 107 of 48816: (4, 1, 4, 0, 106), taking 9.84 seconds to get val score of 0.3219
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 108 of 48816: (4, 1, 4, 0, 107), taking 10.07 seconds to get val score of 0.3244
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 109 of 48816: (4, 1, 4, 0, 108), taking 10.0 seconds to get val score of 0.3137
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 110 of 48816: (4, 1, 4, 0, 109), taking 9.31 seconds to get val score of 0.3344
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 111 of 48816: (4, 1, 4, 0, 110), taking 9.66 seconds to get val score of 0.3259
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 112 of 48816: (4, 1, 4, 0, 111), taking 9.64 seconds to get val score of 0.3622
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 113 of 48816: (4, 1, 4, 0, 112), taking 9.59 seconds to get val score of 0.3204
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
#
# Best combo after this hyperparameter: (4, 1, 4, 0, 20) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: C (index: 0)
#
# Trained and Tested combination 114 of 48816: (0, 1, 4, 0, 20), taking 1.37 seconds to get val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 115 of 48816: (1, 1, 4, 0, 20), taking 1.31 seconds to get val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 116 of 48816: (2, 1, 4, 0, 20), taking 1.31 seconds to get val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 117 of 48816: (3, 1, 4, 0, 20), taking 1.85 seconds to get val score of 0.2633
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Already Trained and Tested combination (4, 1, 4, 0, 20), which had val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 117 of 48816 combinations so far
# Trained and Tested combination 118 of 48816: (5, 1, 4, 0, 20), taking 1.34 seconds to get val score of 0.2626
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
#
# Best combo after this hyperparameter: (4, 1, 4, 0, 20) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_iter (index: 2)
#
# Trained and Tested combination 119 of 48816: (4, 1, 0, 0, 20), taking 0.07 seconds to get val score of 0.2807
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 120 of 48816: (4, 1, 1, 0, 20), taking 0.15 seconds to get val score of 0.2633
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 121 of 48816: (4, 1, 2, 0, 20), taking 0.24 seconds to get val score of 0.2637
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 122 of 48816: (4, 1, 3, 0, 20), taking 0.58 seconds to get val score of 0.2719
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Already Trained and Tested combination (4, 1, 4, 0, 20), which had val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 122 of 48816 combinations so far
# Trained and Tested combination 123 of 48816: (4, 1, 5, 0, 20), taking 3.87 seconds to get val score of 0.2726
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
#
# Best combo after this hyperparameter: (4, 1, 4, 0, 20) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: gamma (index: 3)
#
# Already Trained and Tested combination (4, 1, 4, 0, 20), which had val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 123 of 48816 combinations so far
# Trained and Tested combination 124 of 48816: (4, 1, 4, 1, 20), taking 1.33 seconds to get val score of 0.393
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
#
# Best combo after this hyperparameter: (4, 1, 4, 0, 20) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: tol (index: 1)
#
# Trained and Tested combination 125 of 48816: (4, 0, 4, 0, 20), taking 1.31 seconds to get val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Already Trained and Tested combination (4, 1, 4, 0, 20), which had val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 125 of 48816 combinations so far
# Trained and Tested combination 126 of 48816: (4, 2, 4, 0, 20), taking 1.87 seconds to get val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 127 of 48816: (4, 3, 4, 0, 20), taking 1.33 seconds to get val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 128 of 48816: (4, 4, 4, 0, 20), taking 1.34 seconds to get val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
# Trained and Tested combination 129 of 48816: (4, 5, 4, 0, 20), taking 0.01 seconds to get val score of 0.2222
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563
#
# Best combo after this hyperparameter: (4, 1, 4, 0, 20) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 0 (C) ROUND 2
#
# Round 2
# Hyperparameter: features (index: 4)
#
# Already Trained and Tested combination (4, 1, 4, 0, 0), which had val score of 0.3804
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 1), which had val score of 0.3933
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 2), which had val score of 0.3433
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 3), which had val score of 0.3126
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 4), which had val score of 0.2748
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 5), which had val score of 0.2604
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 6), which had val score of 0.2604
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 7), which had val score of 0.2544
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 8), which had val score of 0.2548
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 9), which had val score of 0.2578
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 10), which had val score of 0.2559
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 11), which had val score of 0.2478
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 12), which had val score of 0.2559
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 13), which had val score of 0.2481
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 14), which had val score of 0.2556
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 15), which had val score of 0.2659
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 16), which had val score of 0.2559
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 17), which had val score of 0.2537
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 18), which had val score of 0.2707
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 19), which had val score of 0.2585
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 20), which had val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 21), which had val score of 0.26
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 22), which had val score of 0.2648
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 23), which had val score of 0.2607
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 24), which had val score of 0.3041
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 25), which had val score of 0.3096
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 26), which had val score of 0.2841
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 27), which had val score of 0.2704
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 28), which had val score of 0.2744
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 29), which had val score of 0.2737
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 30), which had val score of 0.2796
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 31), which had val score of 0.2689
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 32), which had val score of 0.2926
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 33), which had val score of 0.2737
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 34), which had val score of 0.2941
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 35), which had val score of 0.273
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 36), which had val score of 0.2889
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 37), which had val score of 0.2689
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 38), which had val score of 0.2915
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 39), which had val score of 0.3004
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 40), which had val score of 0.307
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 41), which had val score of 0.2819
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 42), which had val score of 0.2948
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 43), which had val score of 0.2867
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 44), which had val score of 0.3567
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 45), which had val score of 0.3026
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 46), which had val score of 0.3156
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 47), which had val score of 0.3207
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 48), which had val score of 0.3341
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 49), which had val score of 0.327
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 50), which had val score of 0.3233
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 51), which had val score of 0.2993
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 52), which had val score of 0.3115
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 53), which had val score of 0.307
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 54), which had val score of 0.3326
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 55), which had val score of 0.3119
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 56), which had val score of 0.3356
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 57), which had val score of 0.3174
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 58), which had val score of 0.3067
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 59), which had val score of 0.3093
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 60), which had val score of 0.3459
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 61), which had val score of 0.3348
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 62), which had val score of 0.3648
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 63), which had val score of 0.3367
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 64), which had val score of 0.3333
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 65), which had val score of 0.3511
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 66), which had val score of 0.3319
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 67), which had val score of 0.3515
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 68), which had val score of 0.3837
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 69), which had val score of 0.3578
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 70), which had val score of 0.3589
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 71), which had val score of 0.3259
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 72), which had val score of 0.3711
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 73), which had val score of 0.3393
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 74), which had val score of 0.3019
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 75), which had val score of 0.3307
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 76), which had val score of 0.347
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 77), which had val score of 0.3256
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 78), which had val score of 0.3352
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 79), which had val score of 0.3244
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 80), which had val score of 0.3556
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 81), which had val score of 0.3722
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 82), which had val score of 0.3463
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 83), which had val score of 0.32
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 84), which had val score of 0.3315
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 85), which had val score of 0.3407
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 86), which had val score of 0.3122
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 87), which had val score of 0.3378
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 88), which had val score of 0.3315
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 89), which had val score of 0.3226
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 90), which had val score of 0.3556
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 91), which had val score of 0.3433
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 92), which had val score of 0.33
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 93), which had val score of 0.3493
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 94), which had val score of 0.34
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 95), which had val score of 0.3267
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 96), which had val score of 0.3485
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 97), which had val score of 0.3237
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 98), which had val score of 0.3263
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 99), which had val score of 0.3615
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 100), which had val score of 0.333
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 101), which had val score of 0.3307
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 102), which had val score of 0.3422
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 103), which had val score of 0.3256
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 104), which had val score of 0.3311
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 105), which had val score of 0.3193
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 106), which had val score of 0.3219
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 107), which had val score of 0.3244
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 108), which had val score of 0.3137
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 109), which had val score of 0.3344
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 110), which had val score of 0.3259
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 111), which had val score of 0.3622
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 112), which had val score of 0.3204
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 129 of 48816 combinations so far
#
# ...
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 62), which had val score of 0.3648
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 63), which had val score of 0.3367
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 64), which had val score of 0.3333
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 65), which had val score of 0.3511
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 66), which had val score of 0.3319
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 67), which had val score of 0.3515
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 68), which had val score of 0.3837
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 69), which had val score of 0.3578
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 70), which had val score of 0.3589
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 71), which had val score of 0.3259
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 72), which had val score of 0.3711
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 73), which had val score of 0.3393
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 74), which had val score of 0.3019
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 75), which had val score of 0.3307
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 76), which had val score of 0.347
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 77), which had val score of 0.3256
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 78), which had val score of 0.3352
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 79), which had val score of 0.3244
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 80), which had val score of 0.3556
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 81), which had val score of 0.3722
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 82), which had val score of 0.3463
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 83), which had val score of 0.32
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 84), which had val score of 0.3315
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 85), which had val score of 0.3407
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 86), which had val score of 0.3122
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 87), which had val score of 0.3378
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 88), which had val score of 0.3315
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 89), which had val score of 0.3226
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 90), which had val score of 0.3556
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 91), which had val score of 0.3433
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 92), which had val score of 0.33
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 93), which had val score of 0.3493
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 94), which had val score of 0.34
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 95), which had val score of 0.3267
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 96), which had val score of 0.3485
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 97), which had val score of 0.3237
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 98), which had val score of 0.3263
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 99), which had val score of 0.3615
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 100), which had val score of 0.333
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 101), which had val score of 0.3307
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 102), which had val score of 0.3422
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 103), which had val score of 0.3256
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 104), which had val score of 0.3311
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 105), which had val score of 0.3193
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 106), which had val score of 0.3219
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 107), which had val score of 0.3244
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 108), which had val score of 0.3137
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 109), which had val score of 0.3344
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 110), which had val score of 0.3259
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 111), which had val score of 0.3622
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 112), which had val score of 0.3204
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
#
# Best combo after this hyperparameter: (4, 1, 4, 0, 20) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: C (index: 0)
#
# Already Trained and Tested combination (0, 1, 4, 0, 20), which had val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (1, 1, 4, 0, 20), which had val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (2, 1, 4, 0, 20), which had val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (3, 1, 4, 0, 20), which had val score of 0.2633
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 20), which had val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (5, 1, 4, 0, 20), which had val score of 0.2626
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
#
# Best combo after this hyperparameter: (4, 1, 4, 0, 20) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_iter (index: 2)
#
# Already Trained and Tested combination (4, 1, 0, 0, 20), which had val score of 0.2807
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 1, 0, 20), which had val score of 0.2633
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 2, 0, 20), which had val score of 0.2637
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 3, 0, 20), which had val score of 0.2719
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0, 20), which had val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 5, 0, 20), which had val score of 0.2726
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
#
# Best combo after this hyperparameter: (4, 1, 4, 0, 20) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: gamma (index: 3)
#
# Already Trained and Tested combination (4, 1, 4, 0, 20), which had val score of 0.4563
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 4, 1, 20), which had val score of 0.393
#         Current best combo: (4, 1, 4, 0, 20) with val score 0.4563.
#         Has trained 145 of 48816 combinations so far
#
# Best combo after this hyperparameter: (4, 1, 4, 0, 20) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.4562962962962963
# Max Test Score:
#  0.461111
# Max Combo Index:
#  (4, 1, 4, 0, 20) out of [6, 6, 6, 2, 113] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 1, 'tol': 0.001, 'max_iter': 800, 'gamma': 'auto', 'features': 20}
# Max Combo Features:
#  (29667, 59920, 41191, 9639, 11997, 14175, 66664, 7149, 6603, 32996, 3710, 4587, 14700, 25279, 27675, 67128, 66157, 67050, 68180, 7075, 59749, 20338, 28574, 35861, 36130, 3061, 22106, 11721, 13444, 9404, 14989, 567, 27004, 6826, 36615, 34203, 16127, 6771, 4193, 37572, 66519, 2160, 27889, 1762, 36120, 67094, 35137, 36623, 3677, 3863, 67659, 2359, 63650, 112, 67892, 37744, 60303, 68047, 9072, 17942, 9372, 27745, 6450, 13095, 5563, 40128, 2491, 34703, 13142, 57787, 64230, 49708, 4501, 17577, 44387, 13454, 59415, 6308, 23378, 43389, 13877, 56288, 12469, 67781, 50832, 66239, 47800, 52938, 66841, 5607, 3414, 52187, 32465, 45854, 65820, 8584, 31185, 2038, 1574, 3094, 500, 29750, 50043, 13792, 42802, 23414, 27046, 62724, 389, 13727, 1651, 67637, 2688, 67361, 23131, 9050, 16198, 17050, 44471, 15432, 3403, 29971, 1663, 39524, 10971, 16331, 16037, 41662, 34860, 30159, 15118, 17674, 39435, 26704, 2567, 67494, 6882, 12746, 7300, 58670, 29441, 36203, 14524, 68147, 18304, 29592, 48456, 6638, 15998, 29601, 898, 43055, 18791, 51366, 1120, 11229, 5082, 51794, 2522, 49870, 30337, 35352, 11926, 21109, 14423, 1774, 19240, 48631, 58751, 43307, 18584, 2060, 111, 3315, 10330, 4875, 710, 17607, 31239, 27581, 1629, 16422, 22771, 66508, 20178, 16474, 13010, 8973, 25246, 3072, 15022, 4083, 3907, 25175, 1429, 38537, 3039, 11893, 67825, 50463, 17566, 66797, 2436, 46601, 7001, 12924, 11786, 22655, 2215, 58438)
# % Combos Checked: 145 out of 48816 which is 0.297034%
