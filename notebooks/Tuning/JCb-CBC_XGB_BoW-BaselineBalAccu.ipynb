# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'cbc'
FEATURE_IMPORTANCE_ORDERING = 'xgb'
PREPROCESSING = 'Baseline'
TUNER = 'jiaochengb-balaccu'
FEATURE_ENGINEERING = 'bow'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
from scipy.sparse import load_npz

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/PrivatePackages" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
else:
    py_file_location = '../../PrivatePackages'
    home_directory = '../../'

sys.path.append(os.path.abspath(py_file_location))

from Tuners import JiaoChengB_BalAccu

import pandas as pd
# Out:
# Collecting catboost
#   Downloading catboost-1.2.3-cp310-cp310-manylinux2014_x86_64.whl (98.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.3

# %%
## Parameters that are same for every script

SEED = 2608

TASK_TYPE = 'Classification' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = True # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from catboost import CatBoostClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {

    'n_estimators': (25, 50, 100, 200),
    'max_depth': (2, 4, 8, 16),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bylevel': (0.4, 0.55, 0.7, 0.85, 1),
    'reg_lambda': (0.01, 0.1, 1),
    'learning_rate': (0.001, 0.01, 0.1, 1),

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
      'random_state': 19260817,
      'verbose': False,
      'max_bin': 64
      }

# what order to tune hyperparameters in (JiaoCheng specific)
tuning_order = ['features',
                'max_depth',
                'colsample_bylevel',
                'subsample',
                'n_estimators',
                'reg_lambda',
                'learning_rate']

# what order to tune hyperparameters in (JiaoCheng specific)
default_hyperparameter_values = {
                                'features': 0,
                                'n_estimators': 50,
                                'max_depth': 4,
                                'subsample': 0.7,
                                'colsample_bylevel': 0.7,
                                'learning_rate': 0.01,
                                'reg_lambda': 0.01
                                }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_x = load_npz(home_directory + f'data/curated/baseline/train_{FEATURE_ENGINEERING}_x.npz')
val_x = load_npz(home_directory + f'data/curated/baseline/val_{FEATURE_ENGINEERING}_x.npz')
test_x = load_npz(home_directory + f'data/curated/baseline/test_{FEATURE_ENGINEERING}_x.npz')

with open(home_directory + 'data/curated/baseline/train_y.pkl', 'rb') as f:
    train_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/val_y.pkl', 'rb') as f:
    val_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/test_y.pkl', 'rb') as f:
    test_y = pickle.load(f)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = JiaoChengB_BalAccu.JiaoChengB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'catboost.core.CatBoostClassifier'>, which is a Classification model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# Successfully read in tuning result of 176 rows, for 176.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# FEATURE_INDEX: 0 (features) ROUND 1
#
# Round 1
# Hyperparameter: features (index: 6)
#
# As new Best Combo (1, 1, 2, 2, 0, 1, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 0), which had val score of 0.5856
#         Current best combo: (1, 1, 2, 2, 0, 1, 0) with val score 0.5856.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 1), which had val score of 0.5849
#         Current best combo: (1, 1, 2, 2, 0, 1, 0) with val score 0.5856.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (1, 1, 2, 2, 0, 1, 2) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 2), which had val score of 0.5858
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.5858.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 3), which had val score of 0.5839
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.5858.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 4), which had val score of 0.5838
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.5858.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 5), which had val score of 0.5855
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.5858.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 6), which had val score of 0.5856
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.5858.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 7), which had val score of 0.5851
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.5858.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 8), which had val score of 0.5851
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.5858.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 9), which had val score of 0.5738
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.5858.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (1, 1, 2, 2, 0, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 10), which had val score of 0.5879
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 11), which had val score of 0.5846
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 12), which had val score of 0.5718
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 13), which had val score of 0.5756
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 14), which had val score of 0.58
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 15), which had val score of 0.5812
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 16), which had val score of 0.5806
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 17), which had val score of 0.5799
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 18), which had val score of 0.563
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 19), which had val score of 0.5767
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 20), which had val score of 0.565
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 21), which had val score of 0.5814
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 22), which had val score of 0.5787
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 23), which had val score of 0.5727
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 24), which had val score of 0.5727
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 25), which had val score of 0.5755
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 26), which had val score of 0.571
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 27), which had val score of 0.5743
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 28), which had val score of 0.5769
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 29), which had val score of 0.5798
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 30), which had val score of 0.558
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 31), which had val score of 0.5658
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 32), which had val score of 0.5515
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 33), which had val score of 0.5581
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 34), which had val score of 0.5627
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 35), which had val score of 0.5502
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 36), which had val score of 0.566
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 37), which had val score of 0.5551
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 38), which had val score of 0.5531
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 39), which had val score of 0.5593
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 40), which had val score of 0.5711
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 41), which had val score of 0.559
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 42), which had val score of 0.5627
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 43), which had val score of 0.5579
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 44), which had val score of 0.5527
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 45), which had val score of 0.5562
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 46), which had val score of 0.5543
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 47), which had val score of 0.5619
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 48), which had val score of 0.5573
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 49), which had val score of 0.5515
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 50), which had val score of 0.5654
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 51), which had val score of 0.5529
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 52), which had val score of 0.5586
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 53), which had val score of 0.552
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 54), which had val score of 0.5555
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 55), which had val score of 0.5545
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 56), which had val score of 0.5605
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 57), which had val score of 0.5546
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 58), which had val score of 0.5574
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 59), which had val score of 0.5602
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 60), which had val score of 0.5587
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 61), which had val score of 0.557
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 62), which had val score of 0.5492
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 63), which had val score of 0.5523
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 64), which had val score of 0.5465
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 65), which had val score of 0.5485
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 66), which had val score of 0.5464
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 67), which had val score of 0.552
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 68), which had val score of 0.5575
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 69), which had val score of 0.5499
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 70), which had val score of 0.55
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 71), which had val score of 0.5464
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 72), which had val score of 0.5586
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 73), which had val score of 0.5502
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 74), which had val score of 0.5496
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 75), which had val score of 0.5435
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 76), which had val score of 0.5474
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 77), which had val score of 0.5487
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 78), which had val score of 0.5549
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 79), which had val score of 0.5529
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 80), which had val score of 0.5474
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 81), which had val score of 0.5456
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 82), which had val score of 0.5501
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 83), which had val score of 0.5419
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 84), which had val score of 0.5463
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 85), which had val score of 0.5533
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 86), which had val score of 0.5532
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 87), which had val score of 0.5501
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 88), which had val score of 0.5382
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 89), which had val score of 0.5529
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 90), which had val score of 0.5492
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 91), which had val score of 0.5543
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 92), which had val score of 0.541
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 93), which had val score of 0.5513
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 94), which had val score of 0.549
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 95), which had val score of 0.5604
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 96), which had val score of 0.5568
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 97), which had val score of 0.5407
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 98), which had val score of 0.5417
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 99), which had val score of 0.559
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 100), which had val score of 0.5494
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 101), which had val score of 0.5475
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 102), which had val score of 0.5443
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 103), which had val score of 0.5411
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 104), which had val score of 0.5437
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 105), which had val score of 0.5451
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 106), which had val score of 0.5479
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 107), which had val score of 0.5399
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 108), which had val score of 0.5475
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 109), which had val score of 0.543
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 110), which had val score of 0.5414
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 111), which had val score of 0.5439
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 112), which had val score of 0.5452
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 1, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (1, 0, 2, 2, 0, 1, 10), which had val score of 0.5027
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 10), which had val score of 0.5879
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 0, 1, 10), which had val score of 0.5873
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.5879.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (1, 3, 2, 2, 0, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 2, 2, 0, 1, 10), which had val score of 0.5973
#         Current best combo: (1, 3, 2, 2, 0, 1, 10) with val score 0.5973.
#         Has trained 176 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 0, 1, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: colsample_bylevel (index: 3)
#
# Already Trained and Tested combination (1, 3, 2, 0, 0, 1, 10), which had val score of 0.5882
#         Current best combo: (1, 3, 2, 2, 0, 1, 10) with val score 0.5973.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 2, 1, 0, 1, 10), which had val score of 0.592
#         Current best combo: (1, 3, 2, 2, 0, 1, 10) with val score 0.5973.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 0, 1, 10), which had val score of 0.5973
#         Current best combo: (1, 3, 2, 2, 0, 1, 10) with val score 0.5973.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 2, 3, 0, 1, 10), which had val score of 0.5904
#         Current best combo: (1, 3, 2, 2, 0, 1, 10) with val score 0.5973.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (1, 3, 2, 4, 0, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 2, 4, 0, 1, 10), which had val score of 0.6048
#         Current best combo: (1, 3, 2, 4, 0, 1, 10) with val score 0.6048.
#         Has trained 176 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 4, 0, 1, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: subsample (index: 2)
#
# As new Best Combo (1, 3, 0, 4, 0, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 0, 4, 0, 1, 10), which had val score of 0.6074
#         Current best combo: (1, 3, 0, 4, 0, 1, 10) with val score 0.6074.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 1, 4, 0, 1, 10), which had val score of 0.6029
#         Current best combo: (1, 3, 0, 4, 0, 1, 10) with val score 0.6074.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 2, 4, 0, 1, 10), which had val score of 0.6048
#         Current best combo: (1, 3, 0, 4, 0, 1, 10) with val score 0.6074.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 3, 4, 0, 1, 10), which had val score of 0.6029
#         Current best combo: (1, 3, 0, 4, 0, 1, 10) with val score 0.6074.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 4, 4, 0, 1, 10), which had val score of 0.5999
#         Current best combo: (1, 3, 0, 4, 0, 1, 10) with val score 0.6074.
#         Has trained 176 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 0, 4, 0, 1, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: n_estimators (index: 0)
#
# As new Best Combo (0, 3, 0, 4, 0, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 3, 0, 4, 0, 1, 10), which had val score of 0.6075
#         Current best combo: (0, 3, 0, 4, 0, 1, 10) with val score 0.6075.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 0, 1, 10), which had val score of 0.6074
#         Current best combo: (0, 3, 0, 4, 0, 1, 10) with val score 0.6075.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (2, 3, 0, 4, 0, 1, 10), which had val score of 0.6012
#         Current best combo: (0, 3, 0, 4, 0, 1, 10) with val score 0.6075.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (3, 3, 0, 4, 0, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 0, 4, 0, 1, 10), which had val score of 0.6079
#         Current best combo: (3, 3, 0, 4, 0, 1, 10) with val score 0.6079.
#         Has trained 176 of 542400 combinations so far
#
# Best combo after this hyperparameter: (3, 3, 0, 4, 0, 1, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: reg_lambda (index: 4)
#
# Already Trained and Tested combination (3, 3, 0, 4, 0, 1, 10), which had val score of 0.6079
#         Current best combo: (3, 3, 0, 4, 0, 1, 10) with val score 0.6079.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 1, 1, 10), which had val score of 0.606
#         Current best combo: (3, 3, 0, 4, 0, 1, 10) with val score 0.6079.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (3, 3, 0, 4, 2, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 0, 4, 2, 1, 10), which had val score of 0.6081
#         Current best combo: (3, 3, 0, 4, 2, 1, 10) with val score 0.6081.
#         Has trained 176 of 542400 combinations so far
#
# Best combo after this hyperparameter: (3, 3, 0, 4, 2, 1, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: learning_rate (index: 5)
#
# Already Trained and Tested combination (3, 3, 0, 4, 2, 0, 10), which had val score of 0.6071
#         Current best combo: (3, 3, 0, 4, 2, 1, 10) with val score 0.6081.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 1, 10), which had val score of 0.6081
#         Current best combo: (3, 3, 0, 4, 2, 1, 10) with val score 0.6081.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (3, 3, 0, 4, 2, 2, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 10), which had val score of 0.655
#         Current best combo: (3, 3, 0, 4, 2, 2, 10) with val score 0.655.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 3, 10), which had val score of 0.6505
#         Current best combo: (3, 3, 0, 4, 2, 2, 10) with val score 0.655.
#         Has trained 176 of 542400 combinations so far
#
# Best combo after this hyperparameter: (3, 3, 0, 4, 2, 2, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 0 (features) ROUND 2
#
# Round 2
# Hyperparameter: features (index: 6)
#
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 0), which had val score of 0.6069
#         Current best combo: (3, 3, 0, 4, 2, 2, 10) with val score 0.655.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 1), which had val score of 0.6129
#         Current best combo: (3, 3, 0, 4, 2, 2, 10) with val score 0.655.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 2), which had val score of 0.6131
#         Current best combo: (3, 3, 0, 4, 2, 2, 10) with val score 0.655.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 3), which had val score of 0.6142
#         Current best combo: (3, 3, 0, 4, 2, 2, 10) with val score 0.655.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 4), which had val score of 0.6256
#         Current best combo: (3, 3, 0, 4, 2, 2, 10) with val score 0.655.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 5), which had val score of 0.634
#         Current best combo: (3, 3, 0, 4, 2, 2, 10) with val score 0.655.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 6), which had val score of 0.6331
#         Current best combo: (3, 3, 0, 4, 2, 2, 10) with val score 0.655.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 7), which had val score of 0.6413
#         Current best combo: (3, 3, 0, 4, 2, 2, 10) with val score 0.655.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 8), which had val score of 0.6464
#         Current best combo: (3, 3, 0, 4, 2, 2, 10) with val score 0.655.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (3, 3, 0, 4, 2, 2, 9) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 9), which had val score of 0.6585
#         Current best combo: (3, 3, 0, 4, 2, 2, 9) with val score 0.6585.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 10), which had val score of 0.655
#         Current best combo: (3, 3, 0, 4, 2, 2, 9) with val score 0.6585.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 11), which had val score of 0.6507
#         Current best combo: (3, 3, 0, 4, 2, 2, 9) with val score 0.6585.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 12), which had val score of 0.6442
#         Current best combo: (3, 3, 0, 4, 2, 2, 9) with val score 0.6585.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 13), which had val score of 0.6517
#         Current best combo: (3, 3, 0, 4, 2, 2, 9) with val score 0.6585.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 14), which had val score of 0.6569
#         Current best combo: (3, 3, 0, 4, 2, 2, 9) with val score 0.6585.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (3, 3, 0, 4, 2, 2, 15) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 15), which had val score of 0.6607
#         Current best combo: (3, 3, 0, 4, 2, 2, 15) with val score 0.6607.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 16), which had val score of 0.6592
#         Current best combo: (3, 3, 0, 4, 2, 2, 15) with val score 0.6607.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 17), which had val score of 0.6585
#         Current best combo: (3, 3, 0, 4, 2, 2, 15) with val score 0.6607.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (3, 3, 0, 4, 2, 2, 18) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 18), which had val score of 0.6652
#         Current best combo: (3, 3, 0, 4, 2, 2, 18) with val score 0.6652.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 19), which had val score of 0.6617
#         Current best combo: (3, 3, 0, 4, 2, 2, 18) with val score 0.6652.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (3, 3, 0, 4, 2, 2, 20) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 20), which had val score of 0.6665
#         Current best combo: (3, 3, 0, 4, 2, 2, 20) with val score 0.6665.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (3, 3, 0, 4, 2, 2, 21) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 21), which had val score of 0.6695
#         Current best combo: (3, 3, 0, 4, 2, 2, 21) with val score 0.6695.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (3, 3, 0, 4, 2, 2, 22) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 22), which had val score of 0.6729
#         Current best combo: (3, 3, 0, 4, 2, 2, 22) with val score 0.6729.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 23), which had val score of 0.6667
#         Current best combo: (3, 3, 0, 4, 2, 2, 22) with val score 0.6729.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (3, 3, 0, 4, 2, 2, 24) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 24), which had val score of 0.6732
#         Current best combo: (3, 3, 0, 4, 2, 2, 24) with val score 0.6732.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 25), which had val score of 0.6661
#         Current best combo: (3, 3, 0, 4, 2, 2, 24) with val score 0.6732.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (3, 3, 0, 4, 2, 2, 26) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 26), which had val score of 0.6842
#         Current best combo: (3, 3, 0, 4, 2, 2, 26) with val score 0.6842.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 27), which had val score of 0.6806
#         Current best combo: (3, 3, 0, 4, 2, 2, 26) with val score 0.6842.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (3, 3, 0, 4, 2, 2, 28) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 28), which had val score of 0.6888
#         Current best combo: (3, 3, 0, 4, 2, 2, 28) with val score 0.6888.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 29), which had val score of 0.67
#         Current best combo: (3, 3, 0, 4, 2, 2, 28) with val score 0.6888.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 30), which had val score of 0.6775
#         Current best combo: (3, 3, 0, 4, 2, 2, 28) with val score 0.6888.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 31), which had val score of 0.6779
#         Current best combo: (3, 3, 0, 4, 2, 2, 28) with val score 0.6888.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 32), which had val score of 0.6801
#         Current best combo: (3, 3, 0, 4, 2, 2, 28) with val score 0.6888.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 33), which had val score of 0.6824
#         Current best combo: (3, 3, 0, 4, 2, 2, 28) with val score 0.6888.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (3, 3, 0, 4, 2, 2, 34) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 34), which had val score of 0.6937
#         Current best combo: (3, 3, 0, 4, 2, 2, 34) with val score 0.6937.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 35), which had val score of 0.6799
#         Current best combo: (3, 3, 0, 4, 2, 2, 34) with val score 0.6937.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 36), which had val score of 0.6868
#         Current best combo: (3, 3, 0, 4, 2, 2, 34) with val score 0.6937.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (3, 3, 0, 4, 2, 2, 37) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 37), which had val score of 0.6942
#         Current best combo: (3, 3, 0, 4, 2, 2, 37) with val score 0.6942.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 38), which had val score of 0.6935
#         Current best combo: (3, 3, 0, 4, 2, 2, 37) with val score 0.6942.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 39), which had val score of 0.6938
#         Current best combo: (3, 3, 0, 4, 2, 2, 37) with val score 0.6942.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 40), which had val score of 0.6913
#         Current best combo: (3, 3, 0, 4, 2, 2, 37) with val score 0.6942.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 41), which had val score of 0.6783
#         Current best combo: (3, 3, 0, 4, 2, 2, 37) with val score 0.6942.
#         Has trained 176 of 542400 combinations so far
# As new Best Combo (3, 3, 0, 4, 2, 2, 42) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 42), which had val score of 0.6943
#         Current best combo: (3, 3, 0, 4, 2, 2, 42) with val score 0.6943.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 43), which had val score of 0.6875
#         Current best combo: (3, 3, 0, 4, 2, 2, 42) with val score 0.6943.
#         Has trained 176 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 44), which had val score of 0.6833
#         Current best combo: (3, 3, 0, 4, 2, 2, 42) with val score 0.6943.
#         Has trained 176 of 542400 combinations so far
