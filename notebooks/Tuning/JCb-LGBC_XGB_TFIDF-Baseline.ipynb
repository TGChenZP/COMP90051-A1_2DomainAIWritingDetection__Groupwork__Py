# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'lgbc'
FEATURE_IMPORTANCE_ORDERING = 'xgb'
PREPROCESSING = 'Baseline'
TUNER = 'jiaochengb'
FEATURE_ENGINEERING = 'tfidf'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os
import pickle
from scipy.sparse import load_npz

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/PrivatePackages" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
else:
    py_file_location = '../../PrivatePackages'
    home_directory = '../../'

sys.path.append(os.path.abspath(py_file_location))

from Tuners import JiaoChengB

import pandas as pd

# %%
## Parameters that are same for every script

SEED = 2608

TASK_TYPE = 'Classification' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = True # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from lightgbm import LGBMClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
    'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'reg_alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 19260817,
                                    'n_jobs': -1,
                                    'warnings': 'none'
                                    }

tuning_order = [
    'features',
    'max_depth',
    'subsample',
    'colsample_bytree',
    'n_estimators',
    'reg_alpha',
    'learning_rate',
]

default_hyperparameter_values = {'n_estimators': 100, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.01, 'learning_rate': 0.01, 'features': 0}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_x = load_npz(home_directory + f'data/curated/baseline/train_{FEATURE_ENGINEERING}_x.npz')
val_x = load_npz(home_directory + f'data/curated/baseline/val_{FEATURE_ENGINEERING}_x.npz')
test_x = load_npz(home_directory + f'data/curated/baseline/test_{FEATURE_ENGINEERING}_x.npz')

with open(home_directory + 'data/curated/baseline/train_y.pkl', 'rb') as f:
    train_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/val_y.pkl', 'rb') as f:
    val_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/test_y.pkl', 'rb') as f:
    test_y = pickle.load(f)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = JiaoChengB.JiaoChengB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'lightgbm.sklearn.LGBMClassifier'>, which is a Classification model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#         Has trained 486 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 486 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 87), which had val score of 0.8593
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 486 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 88), which had val score of 0.8641
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 486 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 89), which had val score of 0.8622
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 486 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 90), which had val score of 0.8633
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 486 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 91), which had val score of 0.8611
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 486 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 92), which had val score of 0.8644
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 486 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 2 (subsample) ROUND 1
#
# Round 1
# Hyperparameter: subsample (index: 2)
#
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 2800, number of negative: 9800
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004549 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1459
# [LightGBM] [Info] Number of data points in the train set: 12600, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.222222 -> initscore=-1.252763
# [LightGBM] [Info] Start training from score -1.252763
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Trained and Tested combination 487 of 2929500: (2, 2, 0, 2, 3, 2, 0), taking 0.22 seconds to get val score of 0.777
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 2800, number of negative: 9800
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001277 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1459
# [LightGBM] [Info] Number of data points in the train set: 12600, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.222222 -> initscore=-1.252763
# [LightGBM] [Info] Start training from score -1.252763
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Trained and Tested combination 488 of 2929500: (2, 2, 1, 2, 3, 2, 0), taking 0.17 seconds to get val score of 0.777
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689
# Already Trained and Tested combination (2, 2, 2, 2, 3, 2, 0), which had val score of 0.777
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 488 of 2929500 combinations so far
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 2800, number of negative: 9800
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001181 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1459
# [LightGBM] [Info] Number of data points in the train set: 12600, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.222222 -> initscore=-1.252763
# [LightGBM] [Info] Start training from score -1.252763
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Trained and Tested combination 489 of 2929500: (2, 2, 3, 2, 3, 2, 0), taking 0.2 seconds to get val score of 0.777
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 2800, number of negative: 9800
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001123 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1459
# [LightGBM] [Info] Number of data points in the train set: 12600, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.222222 -> initscore=-1.252763
# [LightGBM] [Info] Start training from score -1.252763
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Trained and Tested combination 490 of 2929500: (2, 2, 4, 2, 3, 2, 0), taking 0.17 seconds to get val score of 0.777
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: colsample_bytree (index: 3)
#
# Already Trained and Tested combination (5, 4, 2, 0, 4, 4, 86), which had val score of 0.8656
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 1, 4, 4, 86), which had val score of 0.8659
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 3, 4, 4, 86), which had val score of 0.8652
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 4, 4, 4, 86), which had val score of 0.8619
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 4, 2, 2, 4, 4, 86), which had val score of 0.8193
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (1, 4, 2, 2, 4, 4, 86), which had val score of 0.8274
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (2, 4, 2, 2, 4, 4, 86), which had val score of 0.8456
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 4, 4, 86), which had val score of 0.8526
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (4, 4, 2, 2, 4, 4, 86), which had val score of 0.8637
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: reg_alpha (index: 5)
#
# Already Trained and Tested combination (5, 4, 2, 2, 4, 0, 86), which had val score of 0.8519
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 1, 86), which had val score of 0.8563
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 2, 86), which had val score of 0.8522
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 3, 86), which had val score of 0.8533
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 5, 86), which had val score of 0.8448
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: learning_rate (index: 4)
#
# Already Trained and Tested combination (5, 4, 2, 2, 0, 4, 86), which had val score of 0.7778
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 1, 4, 86), which had val score of 0.7778
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 2, 4, 86), which had val score of 0.7778
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 3, 4, 86), which had val score of 0.8467
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: features (index: 6)
#
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 0), which had val score of 0.7793
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 1), which had val score of 0.7785
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 2), which had val score of 0.7826
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 3), which had val score of 0.78
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 4), which had val score of 0.7793
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 5), which had val score of 0.7859
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 6), which had val score of 0.7863
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 7), which had val score of 0.7878
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 8), which had val score of 0.7944
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 9), which had val score of 0.8067
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 10), which had val score of 0.8033
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 11), which had val score of 0.8056
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 12), which had val score of 0.813
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 13), which had val score of 0.813
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 14), which had val score of 0.8189
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 15), which had val score of 0.8167
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 16), which had val score of 0.8148
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 17), which had val score of 0.8156
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 18), which had val score of 0.817
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 19), which had val score of 0.8193
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 20), which had val score of 0.8207
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 21), which had val score of 0.8233
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 22), which had val score of 0.8204
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 23), which had val score of 0.8237
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 24), which had val score of 0.8278
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 25), which had val score of 0.8315
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 26), which had val score of 0.827
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 27), which had val score of 0.8352
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 28), which had val score of 0.8352
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 29), which had val score of 0.8422
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 30), which had val score of 0.8352
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 31), which had val score of 0.8352
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 32), which had val score of 0.8359
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 33), which had val score of 0.8378
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 34), which had val score of 0.8437
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 35), which had val score of 0.8404
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 36), which had val score of 0.843
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 37), which had val score of 0.8422
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 38), which had val score of 0.8422
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 39), which had val score of 0.8452
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 40), which had val score of 0.85
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 41), which had val score of 0.85
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 42), which had val score of 0.8537
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 43), which had val score of 0.8459
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 44), which had val score of 0.8481
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 45), which had val score of 0.85
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 46), which had val score of 0.8496
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 47), which had val score of 0.8593
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 48), which had val score of 0.8467
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 49), which had val score of 0.8519
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 50), which had val score of 0.8533
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 51), which had val score of 0.8574
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 52), which had val score of 0.8574
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 53), which had val score of 0.8604
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 54), which had val score of 0.857
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 55), which had val score of 0.8567
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 56), which had val score of 0.8552
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 57), which had val score of 0.8637
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 58), which had val score of 0.8563
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 59), which had val score of 0.8656
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 60), which had val score of 0.8637
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 61), which had val score of 0.8593
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 62), which had val score of 0.8633
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 63), which had val score of 0.857
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 64), which had val score of 0.8637
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 65), which had val score of 0.8578
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 66), which had val score of 0.8648
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 67), which had val score of 0.86
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 68), which had val score of 0.8648
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 69), which had val score of 0.8641
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 70), which had val score of 0.8619
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 71), which had val score of 0.8633
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 72), which had val score of 0.8626
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 73), which had val score of 0.8633
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 74), which had val score of 0.8615
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 75), which had val score of 0.8659
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 76), which had val score of 0.8611
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 77), which had val score of 0.8633
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 78), which had val score of 0.8589
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 79), which had val score of 0.8641
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 80), which had val score of 0.8637
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 81), which had val score of 0.8615
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 82), which had val score of 0.8626
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 83), which had val score of 0.8604
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 84), which had val score of 0.8641
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 85), which had val score of 0.8648
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 87), which had val score of 0.8593
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 88), which had val score of 0.8641
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 89), which had val score of 0.8622
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 90), which had val score of 0.8633
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 91), which had val score of 0.8611
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 92), which had val score of 0.8644
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (5, 0, 2, 2, 4, 4, 86), which had val score of 0.8489
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 1, 2, 2, 4, 4, 86), which had val score of 0.8556
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 4, 86), which had val score of 0.8641
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 2, 2, 4, 4, 86), which had val score of 0.8619
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 5, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 6, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 2 (subsample) ROUND 2
#
# Round 2
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (5, 4, 0, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 1, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 3, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 4, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: colsample_bytree (index: 3)
#
# Already Trained and Tested combination (5, 4, 2, 0, 4, 4, 86), which had val score of 0.8656
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 1, 4, 4, 86), which had val score of 0.8659
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 3, 4, 4, 86), which had val score of 0.8652
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 4, 4, 4, 86), which had val score of 0.8619
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 4, 2, 2, 4, 4, 86), which had val score of 0.8193
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (1, 4, 2, 2, 4, 4, 86), which had val score of 0.8274
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (2, 4, 2, 2, 4, 4, 86), which had val score of 0.8456
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 4, 4, 86), which had val score of 0.8526
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (4, 4, 2, 2, 4, 4, 86), which had val score of 0.8637
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: reg_alpha (index: 5)
#
# Already Trained and Tested combination (5, 4, 2, 2, 4, 0, 86), which had val score of 0.8519
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 1, 86), which had val score of 0.8563
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 2, 86), which had val score of 0.8522
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 3, 86), which had val score of 0.8533
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 5, 86), which had val score of 0.8448
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: learning_rate (index: 4)
#
# Already Trained and Tested combination (5, 4, 2, 2, 0, 4, 86), which had val score of 0.7778
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 1, 4, 86), which had val score of 0.7778
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 2, 4, 86), which had val score of 0.7778
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 3, 4, 86), which had val score of 0.8467
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: features (index: 6)
#
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 0), which had val score of 0.7793
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 1), which had val score of 0.7785
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 2), which had val score of 0.7826
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 3), which had val score of 0.78
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 4), which had val score of 0.7793
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 5), which had val score of 0.7859
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 6), which had val score of 0.7863
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 7), which had val score of 0.7878
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 8), which had val score of 0.7944
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 9), which had val score of 0.8067
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 10), which had val score of 0.8033
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 11), which had val score of 0.8056
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 12), which had val score of 0.813
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 13), which had val score of 0.813
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 14), which had val score of 0.8189
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 15), which had val score of 0.8167
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 16), which had val score of 0.8148
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 17), which had val score of 0.8156
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 18), which had val score of 0.817
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 490 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 19), which had val score of 0.8193
# ...
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 74), which had val score of 0.8615
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 75), which had val score of 0.8659
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 76), which had val score of 0.8611
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 77), which had val score of 0.8633
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 78), which had val score of 0.8589
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 79), which had val score of 0.8641
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 80), which had val score of 0.8637
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 81), which had val score of 0.8615
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 82), which had val score of 0.8626
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 83), which had val score of 0.8604
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 84), which had val score of 0.8641
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 85), which had val score of 0.8648
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 87), which had val score of 0.8593
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 88), which had val score of 0.8641
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 89), which had val score of 0.8622
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 90), which had val score of 0.8633
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 91), which had val score of 0.8611
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 92), which had val score of 0.8644
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (5, 0, 2, 2, 4, 4, 86), which had val score of 0.8489
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 1, 2, 2, 4, 4, 86), which had val score of 0.8556
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 4, 86), which had val score of 0.8641
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 2, 2, 4, 4, 86), which had val score of 0.8619
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 5, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 6, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (5, 4, 0, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 1, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 3, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 4, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: colsample_bytree (index: 3)
#
# Already Trained and Tested combination (5, 4, 2, 0, 4, 4, 86), which had val score of 0.8656
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 1, 4, 4, 86), which had val score of 0.8659
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 3, 4, 4, 86), which had val score of 0.8652
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 4, 4, 4, 86), which had val score of 0.8619
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 4, 2, 2, 4, 4, 86), which had val score of 0.8193
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (1, 4, 2, 2, 4, 4, 86), which had val score of 0.8274
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (2, 4, 2, 2, 4, 4, 86), which had val score of 0.8456
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 4, 4, 86), which had val score of 0.8526
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (4, 4, 2, 2, 4, 4, 86), which had val score of 0.8637
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: reg_alpha (index: 5)
#
# Already Trained and Tested combination (5, 4, 2, 2, 4, 0, 86), which had val score of 0.8519
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 1, 86), which had val score of 0.8563
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 2, 86), which had val score of 0.8522
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 3, 86), which had val score of 0.8533
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 4, 86), which had val score of 0.8689
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 5, 86), which had val score of 0.8448
#         Current best combo: (5, 4, 2, 2, 4, 4, 86) with val score 0.8689.
#         Has trained 507 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 4, 2, 2, 4, 4, 86) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.8688888888888889
# Max Test Score:
#  0.87
# Max Combo Index:
#  (5, 4, 2, 2, 4, 4, 86) out of [6, 7, 5, 5, 5, 6, 93] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 800, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.1, 'reg_alpha': 1, 'features': 86}
# Max Combo Features:
#  (3414, 29667, 887, 14524, 6603, 67869, 15936, 63974, 66808, 3426, 66664, 29750, 41191, 55340, 12469, 67858, 66575, 65072, 16037, 1740, 13507, 2688, 2215, 52187, 23378, 6233, 10403, 37744, 14712, 32284, 1674, 45854, 3216, 2359, 30255, 34377, 8995, 5290, 15598, 6860, 3403, 46916, 17969, 13664, 32363, 36120, 40128, 36203, 51794, 55739, 3907, 15310, 11612, 9426, 567, 44892, 22090, 30337, 18791, 24916, 31782, 50216, 50215, 35702, 7824, 11463, 42186, 52031, 55970, 49708, 6092, 16198, 40946, 11229, 50463, 33791, 13877, 21818, 67106, 24711, 62981, 45306, 19094, 57360, 10927, 48377, 4654, 8387, 13044, 5192, 31387, 2181, 38937, 6276, 42062, 36443, 21494, 4522, 16137, 775, 67394, 8778, 68147, 1396, 3995, 27108, 67483, 599, 2325, 11358, 5027, 1275, 60996, 200, 8670, 67659, 1663, 6826, 2038, 14989, 5563, 7910, 13802, 6308, 62561, 3863, 28574, 8973, 67781, 12746, 112, 1219, 58670, 4587, 6882, 68058, 66841, 43634, 21109, 42225, 16422, 66519, 4631, 14637, 12935, 21486, 8200, 2522, 2491, 24897, 29971, 67361, 19494, 1629, 10500, 67991, 13980, 7690, 42802, 67715, 31538, 35098, 49870, 7194, 44224, 3621, 23830, 66239, 9748, 3644, 4017, 7933, 46987, 15432, 11293, 55573, 2082, 34542, 753, 47462, 7625, 3094, 40333, 41027, 8530, 9105, 36130, 665, 54450, 63408, 7041, 20921, 3360, 7365, 26712, 13727, 34703, 10716, 2414, 7476, 13454, 11347, 2104, 41268, 50294, 3973, 1961, 60910, 39435, 17673, 13350, 7311, 5071, 2006, 4742, 4083, 742, 13230, 7399, 22771, 32440, 3072, 51366, 22478, 444, 68047, 3940, 886, 4875, 2832, 67128, 36530, 8050, 23837, 63142, 6716, 25175, 6450, 38996, 2654, 3061, 478, 30264, 37833, 55177, 9737, 29835, 1751