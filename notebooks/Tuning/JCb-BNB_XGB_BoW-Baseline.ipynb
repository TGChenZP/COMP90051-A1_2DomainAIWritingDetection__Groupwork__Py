# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'bnb'
FEATURE_IMPORTANCE_ORDERING = 'xgb'
PREPROCESSING = 'Baseline'
TUNER = 'jiaochengb'
FEATURE_ENGINEERING = 'bow'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle
from scipy.sparse import load_npz 

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/Research - Internet Addiction Part 1/PrivatePackages" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/Research - Internet Addiction Part 1/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
else:
    py_file_location = '../../PrivatePackages'
    home_directory = '../../'

sys.path.append(os.path.abspath(py_file_location))

from Tuners import JiaoChengB

import pandas as pd

# %%
## Parameters that are same for every script

SEED = 2608

TASK_TYPE = 'Classification' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = True # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.naive_bayes import BernoulliNB as clf

# what values to try for each hyperparameter
parameter_choices = parameter_choices = {
    'alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
    'fit_prior': (False, True)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {}

tuning_order = [
    'features',
    'alpha',
    'fit_prior'
]

default_hyperparameter_values = {'fit_prior': True, 'alpha': 1, 'features': 0}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_x = load_npz(home_directory + f'data/curated/baseline/train_{FEATURE_ENGINEERING}_x.npz')
val_x = load_npz(home_directory + f'data/curated/baseline/val_{FEATURE_ENGINEERING}_x.npz')
test_x = load_npz(home_directory + f'data/curated/baseline/test_{FEATURE_ENGINEERING}_x.npz')

with open(home_directory + 'data/curated/baseline/train_y.pkl', 'rb') as f:
    train_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/val_y.pkl', 'rb') as f:
    val_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/test_y.pkl', 'rb') as f:
    test_y = pickle.load(f)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = JiaoChengB.JiaoChengB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'sklearn.naive_bayes.BernoulliNB'>, which is a Classification model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# FEATURE_INDEX: 0 (alpha) ROUND 1
#
# Round 1
# Hyperparameter: features (index: 2)
#
# Trained and Tested combination 1 of 1582: (4, 1, 0), taking 0.01 seconds to get val score of 0.7678
#         Current best combo: (4, 1, 0) with val score 0.7678
# Trained and Tested combination 2 of 1582: (4, 1, 1), taking 0.01 seconds to get val score of 0.767
#         Current best combo: (4, 1, 0) with val score 0.7678
# Trained and Tested combination 3 of 1582: (4, 1, 2), taking 0.02 seconds to get val score of 0.7648
#         Current best combo: (4, 1, 0) with val score 0.7678
# Trained and Tested combination 4 of 1582: (4, 1, 3), taking 0.01 seconds to get val score of 0.7707
#         Current best combo: (4, 1, 3) with val score 0.7707
# Trained and Tested combination 5 of 1582: (4, 1, 4), taking 0.01 seconds to get val score of 0.7656
#         Current best combo: (4, 1, 3) with val score 0.7707
# Trained and Tested combination 6 of 1582: (4, 1, 5), taking 0.01 seconds to get val score of 0.7722
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 7 of 1582: (4, 1, 6), taking 0.01 seconds to get val score of 0.7685
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 8 of 1582: (4, 1, 7), taking 0.02 seconds to get val score of 0.7685
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 9 of 1582: (4, 1, 8), taking 0.01 seconds to get val score of 0.7656
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 10 of 1582: (4, 1, 9), taking 0.01 seconds to get val score of 0.767
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 11 of 1582: (4, 1, 10), taking 0.01 seconds to get val score of 0.7685
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 12 of 1582: (4, 1, 11), taking 0.01 seconds to get val score of 0.7652
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 13 of 1582: (4, 1, 12), taking 0.02 seconds to get val score of 0.7604
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 14 of 1582: (4, 1, 13), taking 0.01 seconds to get val score of 0.7615
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 15 of 1582: (4, 1, 14), taking 0.01 seconds to get val score of 0.707
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 16 of 1582: (4, 1, 15), taking 0.02 seconds to get val score of 0.7104
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 17 of 1582: (4, 1, 16), taking 0.05 seconds to get val score of 0.6867
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 18 of 1582: (4, 1, 17), taking 0.02 seconds to get val score of 0.6656
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 19 of 1582: (4, 1, 18), taking 0.01 seconds to get val score of 0.6648
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 20 of 1582: (4, 1, 19), taking 0.01 seconds to get val score of 0.6611
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 21 of 1582: (4, 1, 20), taking 0.01 seconds to get val score of 0.6578
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 22 of 1582: (4, 1, 21), taking 0.02 seconds to get val score of 0.6641
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 23 of 1582: (4, 1, 22), taking 0.01 seconds to get val score of 0.6559
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 24 of 1582: (4, 1, 23), taking 0.01 seconds to get val score of 0.6567
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 25 of 1582: (4, 1, 24), taking 0.02 seconds to get val score of 0.6596
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 26 of 1582: (4, 1, 25), taking 0.02 seconds to get val score of 0.6589
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 27 of 1582: (4, 1, 26), taking 0.01 seconds to get val score of 0.6537
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 28 of 1582: (4, 1, 27), taking 0.01 seconds to get val score of 0.6433
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 29 of 1582: (4, 1, 28), taking 0.01 seconds to get val score of 0.6444
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 30 of 1582: (4, 1, 29), taking 0.02 seconds to get val score of 0.6411
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 31 of 1582: (4, 1, 30), taking 0.02 seconds to get val score of 0.6448
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 32 of 1582: (4, 1, 31), taking 0.03 seconds to get val score of 0.6415
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 33 of 1582: (4, 1, 32), taking 0.02 seconds to get val score of 0.63
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 34 of 1582: (4, 1, 33), taking 0.01 seconds to get val score of 0.6352
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 35 of 1582: (4, 1, 34), taking 0.01 seconds to get val score of 0.637
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 36 of 1582: (4, 1, 35), taking 0.01 seconds to get val score of 0.6359
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 37 of 1582: (4, 1, 36), taking 0.01 seconds to get val score of 0.6341
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 38 of 1582: (4, 1, 37), taking 0.02 seconds to get val score of 0.6326
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 39 of 1582: (4, 1, 38), taking 0.02 seconds to get val score of 0.6244
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 40 of 1582: (4, 1, 39), taking 0.02 seconds to get val score of 0.6185
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 41 of 1582: (4, 1, 40), taking 0.06 seconds to get val score of 0.6174
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 42 of 1582: (4, 1, 41), taking 0.01 seconds to get val score of 0.62
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 43 of 1582: (4, 1, 42), taking 0.02 seconds to get val score of 0.6204
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 44 of 1582: (4, 1, 43), taking 0.01 seconds to get val score of 0.6226
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 45 of 1582: (4, 1, 44), taking 0.02 seconds to get val score of 0.6185
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 46 of 1582: (4, 1, 45), taking 0.01 seconds to get val score of 0.6193
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 47 of 1582: (4, 1, 46), taking 0.02 seconds to get val score of 0.6156
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 48 of 1582: (4, 1, 47), taking 0.02 seconds to get val score of 0.6107
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 49 of 1582: (4, 1, 48), taking 0.02 seconds to get val score of 0.6089
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 50 of 1582: (4, 1, 49), taking 0.01 seconds to get val score of 0.6085
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 51 of 1582: (4, 1, 50), taking 0.01 seconds to get val score of 0.6078
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 52 of 1582: (4, 1, 51), taking 0.04 seconds to get val score of 0.6119
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 53 of 1582: (4, 1, 52), taking 0.03 seconds to get val score of 0.6111
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 54 of 1582: (4, 1, 53), taking 0.03 seconds to get val score of 0.6089
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 55 of 1582: (4, 1, 54), taking 0.03 seconds to get val score of 0.6085
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 56 of 1582: (4, 1, 55), taking 0.02 seconds to get val score of 0.6022
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 57 of 1582: (4, 1, 56), taking 0.02 seconds to get val score of 0.5996
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 58 of 1582: (4, 1, 57), taking 0.01 seconds to get val score of 0.5974
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 59 of 1582: (4, 1, 58), taking 0.02 seconds to get val score of 0.5974
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 60 of 1582: (4, 1, 59), taking 0.02 seconds to get val score of 0.5959
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 61 of 1582: (4, 1, 60), taking 0.02 seconds to get val score of 0.5926
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 62 of 1582: (4, 1, 61), taking 0.03 seconds to get val score of 0.5922
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 63 of 1582: (4, 1, 62), taking 0.05 seconds to get val score of 0.5941
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 64 of 1582: (4, 1, 63), taking 0.03 seconds to get val score of 0.5933
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 65 of 1582: (4, 1, 64), taking 0.02 seconds to get val score of 0.5926
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 66 of 1582: (4, 1, 65), taking 0.03 seconds to get val score of 0.5896
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 67 of 1582: (4, 1, 66), taking 0.03 seconds to get val score of 0.59
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 68 of 1582: (4, 1, 67), taking 0.04 seconds to get val score of 0.59
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 69 of 1582: (4, 1, 68), taking 0.02 seconds to get val score of 0.5859
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 70 of 1582: (4, 1, 69), taking 0.02 seconds to get val score of 0.5844
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 71 of 1582: (4, 1, 70), taking 0.03 seconds to get val score of 0.5844
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 72 of 1582: (4, 1, 71), taking 0.11 seconds to get val score of 0.5841
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 73 of 1582: (4, 1, 72), taking 0.04 seconds to get val score of 0.5856
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 74 of 1582: (4, 1, 73), taking 0.02 seconds to get val score of 0.5859
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 75 of 1582: (4, 1, 74), taking 0.03 seconds to get val score of 0.5859
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 76 of 1582: (4, 1, 75), taking 0.03 seconds to get val score of 0.5867
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 77 of 1582: (4, 1, 76), taking 0.02 seconds to get val score of 0.5844
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 78 of 1582: (4, 1, 77), taking 0.03 seconds to get val score of 0.583
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 79 of 1582: (4, 1, 78), taking 0.03 seconds to get val score of 0.5826
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 80 of 1582: (4, 1, 79), taking 0.07 seconds to get val score of 0.5833
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 81 of 1582: (4, 1, 80), taking 0.02 seconds to get val score of 0.5826
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 82 of 1582: (4, 1, 81), taking 0.02 seconds to get val score of 0.5833
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 83 of 1582: (4, 1, 82), taking 0.02 seconds to get val score of 0.583
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 84 of 1582: (4, 1, 83), taking 0.04 seconds to get val score of 0.5811
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 85 of 1582: (4, 1, 84), taking 0.05 seconds to get val score of 0.5807
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 86 of 1582: (4, 1, 85), taking 0.02 seconds to get val score of 0.5826
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 87 of 1582: (4, 1, 86), taking 0.02 seconds to get val score of 0.5815
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 88 of 1582: (4, 1, 87), taking 0.02 seconds to get val score of 0.5815
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 89 of 1582: (4, 1, 88), taking 0.04 seconds to get val score of 0.5793
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 90 of 1582: (4, 1, 89), taking 0.02 seconds to get val score of 0.5796
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 91 of 1582: (4, 1, 90), taking 0.03 seconds to get val score of 0.58
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 92 of 1582: (4, 1, 91), taking 0.03 seconds to get val score of 0.58
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 93 of 1582: (4, 1, 92), taking 0.05 seconds to get val score of 0.5804
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 94 of 1582: (4, 1, 93), taking 0.02 seconds to get val score of 0.5804
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 95 of 1582: (4, 1, 94), taking 0.03 seconds to get val score of 0.5804
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 96 of 1582: (4, 1, 95), taking 0.03 seconds to get val score of 0.58
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 97 of 1582: (4, 1, 96), taking 0.03 seconds to get val score of 0.5781
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 98 of 1582: (4, 1, 97), taking 0.03 seconds to get val score of 0.5778
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 99 of 1582: (4, 1, 98), taking 0.02 seconds to get val score of 0.577
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 100 of 1582: (4, 1, 99), taking 0.04 seconds to get val score of 0.577
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 101 of 1582: (4, 1, 100), taking 0.05 seconds to get val score of 0.5756
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 102 of 1582: (4, 1, 101), taking 0.02 seconds to get val score of 0.5752
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 103 of 1582: (4, 1, 102), taking 0.03 seconds to get val score of 0.5763
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 104 of 1582: (4, 1, 103), taking 0.03 seconds to get val score of 0.5785
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 105 of 1582: (4, 1, 104), taking 0.05 seconds to get val score of 0.5789
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 106 of 1582: (4, 1, 105), taking 0.06 seconds to get val score of 0.5781
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 107 of 1582: (4, 1, 106), taking 0.03 seconds to get val score of 0.577
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 108 of 1582: (4, 1, 107), taking 0.02 seconds to get val score of 0.5767
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 109 of 1582: (4, 1, 108), taking 0.03 seconds to get val score of 0.5767
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 110 of 1582: (4, 1, 109), taking 0.02 seconds to get val score of 0.5763
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 111 of 1582: (4, 1, 110), taking 0.02 seconds to get val score of 0.5752
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 112 of 1582: (4, 1, 111), taking 0.03 seconds to get val score of 0.5756
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 113 of 1582: (4, 1, 112), taking 0.02 seconds to get val score of 0.5756
#         Current best combo: (4, 1, 5) with val score 0.7722
#
# Best combo after this hyperparameter: (4, 1, 5) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: alpha (index: 0)
#
# Trained and Tested combination 114 of 1582: (0, 1, 5), taking 0.03 seconds to get val score of 0.7707
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 115 of 1582: (1, 1, 5), taking 0.02 seconds to get val score of 0.7707
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 116 of 1582: (2, 1, 5), taking 0.04 seconds to get val score of 0.7707
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 117 of 1582: (3, 1, 5), taking 0.13 seconds to get val score of 0.7707
#         Current best combo: (4, 1, 5) with val score 0.7722
# Already Trained and Tested combination (4, 1, 5), which had val score of 0.7722
#         Current best combo: (4, 1, 5) with val score 0.7722.
#         Has trained 117 of 1582 combinations so far
# Trained and Tested combination 118 of 1582: (5, 1, 5), taking 0.02 seconds to get val score of 0.7711
#         Current best combo: (4, 1, 5) with val score 0.7722
# Trained and Tested combination 119 of 1582: (6, 1, 5), taking 0.01 seconds to get val score of 0.7778
#         Current best combo: (6, 1, 5) with val score 0.7778
#
# Best combo after this hyperparameter: (6, 1, 5) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: fit_prior (index: 1)
#
# Trained and Tested combination 120 of 1582: (6, 0, 5), taking 0.01 seconds to get val score of 0.747
#         Current best combo: (6, 1, 5) with val score 0.7778
# Already Trained and Tested combination (6, 1, 5), which had val score of 0.7778
#         Current best combo: (6, 1, 5) with val score 0.7778.
#         Has trained 120 of 1582 combinations so far
#
# Best combo after this hyperparameter: (6, 1, 5) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 0 (alpha) ROUND 2
#
# Round 2
# Hyperparameter: features (index: 2)
#
# Trained and Tested combination 121 of 1582: (6, 1, 0), taking 0.02 seconds to get val score of 0.7667
#         Current best combo: (6, 1, 5) with val score 0.7778
# Trained and Tested combination 122 of 1582: (6, 1, 1), taking 0.03 seconds to get val score of 0.7793
#         Current best combo: (6, 1, 1) with val score 0.7793
# Trained and Tested combination 123 of 1582: (6, 1, 2), taking 0.01 seconds to get val score of 0.7763
#         Current best combo: (6, 1, 1) with val score 0.7793
# Trained and Tested combination 124 of 1582: (6, 1, 3), taking 0.01 seconds to get val score of 0.7759
#         Current best combo: (6, 1, 1) with val score 0.7793
# Trained and Tested combination 125 of 1582: (6, 1, 4), taking 0.04 seconds to get val score of 0.7733
#         Current best combo: (6, 1, 1) with val score 0.7793
# Already Trained and Tested combination (6, 1, 5), which had val score of 0.7778
#         Current best combo: (6, 1, 1) with val score 0.7793.
#         Has trained 125 of 1582 combinations so far
# Trained and Tested combination 126 of 1582: (6, 1, 6), taking 0.01 seconds to get val score of 0.7744
#         Current best combo: (6, 1, 1) with val score 0.7793
# Trained and Tested combination 127 of 1582: (6, 1, 7), taking 0.01 seconds to get val score of 0.7785
#         Current best combo: (6, 1, 1) with val score 0.7793
# Trained and Tested combination 128 of 1582: (6, 1, 8), taking 0.01 seconds to get val score of 0.7785
#         Current best combo: (6, 1, 1) with val score 0.7793
# Trained and Tested combination 129 of 1582: (6, 1, 9), taking 0.01 seconds to get val score of 0.7763
#         Current best combo: (6, 1, 1) with val score 0.7793
# Trained and Tested combination 130 of 1582: (6, 1, 10), taking 0.08 seconds to get val score of 0.7789
#         Current best combo: (6, 1, 1) with val score 0.7793
# Trained and Tested combination 131 of 1582: (6, 1, 11), taking 0.01 seconds to get val score of 0.7748
#         Current best combo: (6, 1, 1) with val score 0.7793
# Trained and Tested combination 132 of 1582: (6, 1, 12), taking 0.06 seconds to get val score of 0.7778
#         Current best combo: (6, 1, 1) with val score 0.7793
# Trained and Tested combination 133 of 1582: (6, 1, 13), taking 0.02 seconds to get val score of 0.7804
#         Current best combo: (6, 1, 13) with val score 0.7804
# Trained and Tested combination 134 of 1582: (6, 1, 14), taking 0.07 seconds to get val score of 0.78
#         Current best combo: (6, 1, 13) with val score 0.7804
# Trained and Tested combination 135 of 1582: (6, 1, 15), taking 0.01 seconds to get val score of 0.7785
#         Current best combo: (6, 1, 13) with val score 0.7804
# Trained and Tested combination 136 of 1582: (6, 1, 16), taking 0.01 seconds to get val score of 0.7833
#         Current best combo: (6, 1, 16) with val score 0.7833
# Trained and Tested combination 137 of 1582: (6, 1, 17), taking 0.02 seconds to get val score of 0.7837
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 138 of 1582: (6, 1, 18), taking 0.01 seconds to get val score of 0.7822
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 139 of 1582: (6, 1, 19), taking 0.01 seconds to get val score of 0.783
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 140 of 1582: (6, 1, 20), taking 0.02 seconds to get val score of 0.7822
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 141 of 1582: (6, 1, 21), taking 0.08 seconds to get val score of 0.7752
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 142 of 1582: (6, 1, 22), taking 0.02 seconds to get val score of 0.7759
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 143 of 1582: (6, 1, 23), taking 0.02 seconds to get val score of 0.777
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 144 of 1582: (6, 1, 24), taking 0.01 seconds to get val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 145 of 1582: (6, 1, 25), taking 0.02 seconds to get val score of 0.7778
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 146 of 1582: (6, 1, 26), taking 0.02 seconds to get val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 147 of 1582: (6, 1, 27), taking 0.01 seconds to get val score of 0.7789
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 148 of 1582: (6, 1, 28), taking 0.02 seconds to get val score of 0.78
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 149 of 1582: (6, 1, 29), taking 0.03 seconds to get val score of 0.78
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 150 of 1582: (6, 1, 30), taking 0.03 seconds to get val score of 0.7756
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 151 of 1582: (6, 1, 31), taking 0.02 seconds to get val score of 0.7752
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 152 of 1582: (6, 1, 32), taking 0.01 seconds to get val score of 0.7767
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 153 of 1582: (6, 1, 33), taking 0.03 seconds to get val score of 0.7793
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 154 of 1582: (6, 1, 34), taking 0.03 seconds to get val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 155 of 1582: (6, 1, 35), taking 0.07 seconds to get val score of 0.7752
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 156 of 1582: (6, 1, 36), taking 0.01 seconds to get val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 157 of 1582: (6, 1, 37), taking 0.02 seconds to get val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 158 of 1582: (6, 1, 38), taking 0.02 seconds to get val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 159 of 1582: (6, 1, 39), taking 0.04 seconds to get val score of 0.7815
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 160 of 1582: (6, 1, 40), taking 0.05 seconds to get val score of 0.7804
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 161 of 1582: (6, 1, 41), taking 0.04 seconds to get val score of 0.7811
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 162 of 1582: (6, 1, 42), taking 0.02 seconds to get val score of 0.7819
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 163 of 1582: (6, 1, 43), taking 0.02 seconds to get val score of 0.7804
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 164 of 1582: (6, 1, 44), taking 0.01 seconds to get val score of 0.78
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 165 of 1582: (6, 1, 45), taking 0.01 seconds to get val score of 0.78
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 166 of 1582: (6, 1, 46), taking 0.06 seconds to get val score of 0.7819
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 167 of 1582: (6, 1, 47), taking 0.08 seconds to get val score of 0.7826
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 168 of 1582: (6, 1, 48), taking 0.02 seconds to get val score of 0.7833
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 169 of 1582: (6, 1, 49), taking 0.06 seconds to get val score of 0.783
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 170 of 1582: (6, 1, 50), taking 0.02 seconds to get val score of 0.7811
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 171 of 1582: (6, 1, 51), taking 0.02 seconds to get val score of 0.7796
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 172 of 1582: (6, 1, 52), taking 0.02 seconds to get val score of 0.7811
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 173 of 1582: (6, 1, 53), taking 0.05 seconds to get val score of 0.7822
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 174 of 1582: (6, 1, 54), taking 0.04 seconds to get val score of 0.7837
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 175 of 1582: (6, 1, 55), taking 0.07 seconds to get val score of 0.7826
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 176 of 1582: (6, 1, 56), taking 0.08 seconds to get val score of 0.7826
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 177 of 1582: (6, 1, 57), taking 0.02 seconds to get val score of 0.7811
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 178 of 1582: (6, 1, 58), taking 0.02 seconds to get val score of 0.7807
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 179 of 1582: (6, 1, 59), taking 0.02 seconds to get val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 180 of 1582: (6, 1, 60), taking 0.02 seconds to get val score of 0.7807
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 181 of 1582: (6, 1, 61), taking 0.02 seconds to get val score of 0.7815
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 182 of 1582: (6, 1, 62), taking 0.02 seconds to get val score of 0.7815
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 183 of 1582: (6, 1, 63), taking 0.03 seconds to get val score of 0.7793
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 184 of 1582: (6, 1, 64), taking 0.02 seconds to get val score of 0.7793
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 185 of 1582: (6, 1, 65), taking 0.02 seconds to get val score of 0.78
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 186 of 1582: (6, 1, 66), taking 0.03 seconds to get val score of 0.78
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 187 of 1582: (6, 1, 67), taking 0.05 seconds to get val score of 0.78
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 188 of 1582: (6, 1, 68), taking 0.02 seconds to get val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 189 of 1582: (6, 1, 69), taking 0.02 seconds to get val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 190 of 1582: (6, 1, 70), taking 0.02 seconds to get val score of 0.7789
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 191 of 1582: (6, 1, 71), taking 0.02 seconds to get val score of 0.7789
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 192 of 1582: (6, 1, 72), taking 0.06 seconds to get val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 193 of 1582: (6, 1, 73), taking 0.02 seconds to get val score of 0.7793
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 194 of 1582: (6, 1, 74), taking 0.02 seconds to get val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 195 of 1582: (6, 1, 75), taking 0.03 seconds to get val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 196 of 1582: (6, 1, 76), taking 0.05 seconds to get val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 197 of 1582: (6, 1, 77), taking 0.04 seconds to get val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 198 of 1582: (6, 1, 78), taking 0.02 seconds to get val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 199 of 1582: (6, 1, 79), taking 0.02 seconds to get val score of 0.777
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 200 of 1582: (6, 1, 80), taking 0.02 seconds to get val score of 0.7759
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 201 of 1582: (6, 1, 81), taking 0.02 seconds to get val score of 0.7763
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 202 of 1582: (6, 1, 82), taking 0.05 seconds to get val score of 0.7759
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 203 of 1582: (6, 1, 83), taking 0.02 seconds to get val score of 0.7744
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 204 of 1582: (6, 1, 84), taking 0.02 seconds to get val score of 0.7759
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 205 of 1582: (6, 1, 85), taking 0.02 seconds to get val score of 0.7759
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 206 of 1582: (6, 1, 86), taking 0.03 seconds to get val score of 0.7759
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 207 of 1582: (6, 1, 87), taking 0.03 seconds to get val score of 0.777
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 208 of 1582: (6, 1, 88), taking 0.02 seconds to get val score of 0.7759
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 209 of 1582: (6, 1, 89), taking 0.08 seconds to get val score of 0.7767
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 210 of 1582: (6, 1, 90), taking 0.03 seconds to get val score of 0.777
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 211 of 1582: (6, 1, 91), taking 0.05 seconds to get val score of 0.7774
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 212 of 1582: (6, 1, 92), taking 0.04 seconds to get val score of 0.7774
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 213 of 1582: (6, 1, 93), taking 0.04 seconds to get val score of 0.7774
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 214 of 1582: (6, 1, 94), taking 0.04 seconds to get val score of 0.7774
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 215 of 1582: (6, 1, 95), taking 0.02 seconds to get val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 216 of 1582: (6, 1, 96), taking 0.02 seconds to get val score of 0.7778
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 217 of 1582: (6, 1, 97), taking 0.03 seconds to get val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 218 of 1582: (6, 1, 98), taking 0.03 seconds to get val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 219 of 1582: (6, 1, 99), taking 0.16 seconds to get val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 220 of 1582: (6, 1, 100), taking 0.02 seconds to get val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 221 of 1582: (6, 1, 101), taking 0.02 seconds to get val score of 0.777
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 222 of 1582: (6, 1, 102), taking 0.02 seconds to get val score of 0.777
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 223 of 1582: (6, 1, 103), taking 0.08 seconds to get val score of 0.7778
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 224 of 1582: (6, 1, 104), taking 0.02 seconds to get val score of 0.7767
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 225 of 1582: (6, 1, 105), taking 0.04 seconds to get val score of 0.7774
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 226 of 1582: (6, 1, 106), taking 0.03 seconds to get val score of 0.7778
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 227 of 1582: (6, 1, 107), taking 0.02 seconds to get val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 228 of 1582: (6, 1, 108), taking 0.07 seconds to get val score of 0.7774
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 229 of 1582: (6, 1, 109), taking 0.04 seconds to get val score of 0.7774
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 230 of 1582: (6, 1, 110), taking 0.04 seconds to get val score of 0.7774
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 231 of 1582: (6, 1, 111), taking 0.03 seconds to get val score of 0.777
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 232 of 1582: (6, 1, 112), taking 0.03 seconds to get val score of 0.7767
#         Current best combo: (6, 1, 17) with val score 0.7837
#
# Best combo after this hyperparameter: (6, 1, 17) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: alpha (index: 0)
#
# Trained and Tested combination 233 of 1582: (0, 1, 17), taking 0.01 seconds to get val score of 0.6648
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 234 of 1582: (1, 1, 17), taking 0.03 seconds to get val score of 0.6648
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 235 of 1582: (2, 1, 17), taking 0.03 seconds to get val score of 0.6648
#         Current best combo: (6, 1, 17) with val score 0.7837
# Trained and Tested combination 236 of 1582: (3, 1, 17), taking 0.01 seconds to get val score of 0.6648
#         Current best combo: (6, 1, 17) with val score 0.7837
# Already Trained and Tested combination (4, 1, 17), which had val score of 0.6656
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 236 of 1582 combinations so far
# Trained and Tested combination 237 of 1582: (5, 1, 17), taking 0.01 seconds to get val score of 0.6826
#         Current best combo: (6, 1, 17) with val score 0.7837
# Already Trained and Tested combination (6, 1, 17), which had val score of 0.7837
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 237 of 1582 combinations so far
#
# Best combo after this hyperparameter: (6, 1, 17) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: fit_prior (index: 1)
#
# Trained and Tested combination 238 of 1582: (6, 0, 17), taking 0.02 seconds to get val score of 0.777
#         Current best combo: (6, 1, 17) with val score 0.7837
# Already Trained and Tested combination (6, 1, 17), which had val score of 0.7837
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
#
# Best combo after this hyperparameter: (6, 1, 17) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 0 (alpha) ROUND 3
#
# Round 3
# Hyperparameter: features (index: 2)
#
# Already Trained and Tested combination (6, 1, 0), which had val score of 0.7667
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 1), which had val score of 0.7793
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 2), which had val score of 0.7763
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 3), which had val score of 0.7759
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 4), which had val score of 0.7733
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 5), which had val score of 0.7778
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 6), which had val score of 0.7744
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 7), which had val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 8), which had val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 9), which had val score of 0.7763
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 10), which had val score of 0.7789
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 11), which had val score of 0.7748
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 12), which had val score of 0.7778
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 13), which had val score of 0.7804
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 14), which had val score of 0.78
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 15), which had val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 16), which had val score of 0.7833
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 17), which had val score of 0.7837
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 18), which had val score of 0.7822
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 19), which had val score of 0.783
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 20), which had val score of 0.7822
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 21), which had val score of 0.7752
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 22), which had val score of 0.7759
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 23), which had val score of 0.777
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 24), which had val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 25), which had val score of 0.7778
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 26), which had val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 27), which had val score of 0.7789
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 28), which had val score of 0.78
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 29), which had val score of 0.78
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 30), which had val score of 0.7756
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 31), which had val score of 0.7752
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 32), which had val score of 0.7767
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 33), which had val score of 0.7793
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 34), which had val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 35), which had val score of 0.7752
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 238 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 36), which had val score of 0.7781
# ...
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 48), which had val score of 0.7833
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 49), which had val score of 0.783
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 50), which had val score of 0.7811
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 51), which had val score of 0.7796
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 52), which had val score of 0.7811
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 53), which had val score of 0.7822
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 54), which had val score of 0.7837
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 55), which had val score of 0.7826
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 56), which had val score of 0.7826
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 57), which had val score of 0.7811
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 58), which had val score of 0.7807
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 59), which had val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 60), which had val score of 0.7807
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 61), which had val score of 0.7815
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 62), which had val score of 0.7815
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 63), which had val score of 0.7793
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 64), which had val score of 0.7793
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 65), which had val score of 0.78
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 66), which had val score of 0.78
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 67), which had val score of 0.78
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 68), which had val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 69), which had val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 70), which had val score of 0.7789
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 71), which had val score of 0.7789
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 72), which had val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 73), which had val score of 0.7793
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 74), which had val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 75), which had val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 76), which had val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 77), which had val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 78), which had val score of 0.7785
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 79), which had val score of 0.777
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 80), which had val score of 0.7759
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 81), which had val score of 0.7763
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 82), which had val score of 0.7759
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 83), which had val score of 0.7744
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 84), which had val score of 0.7759
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 85), which had val score of 0.7759
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 86), which had val score of 0.7759
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 87), which had val score of 0.777
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 88), which had val score of 0.7759
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 89), which had val score of 0.7767
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 90), which had val score of 0.777
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 91), which had val score of 0.7774
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 92), which had val score of 0.7774
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 93), which had val score of 0.7774
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 94), which had val score of 0.7774
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 95), which had val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 96), which had val score of 0.7778
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 97), which had val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 98), which had val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 99), which had val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 100), which had val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 101), which had val score of 0.777
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 102), which had val score of 0.777
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 103), which had val score of 0.7778
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 104), which had val score of 0.7767
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 105), which had val score of 0.7774
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 106), which had val score of 0.7778
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 107), which had val score of 0.7781
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 108), which had val score of 0.7774
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 109), which had val score of 0.7774
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 110), which had val score of 0.7774
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 111), which had val score of 0.777
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 112), which had val score of 0.7767
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
#
# Best combo after this hyperparameter: (6, 1, 17) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: alpha (index: 0)
#
# Already Trained and Tested combination (0, 1, 17), which had val score of 0.6648
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (1, 1, 17), which had val score of 0.6648
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (2, 1, 17), which had val score of 0.6648
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (3, 1, 17), which had val score of 0.6648
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (4, 1, 17), which had val score of 0.6656
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (5, 1, 17), which had val score of 0.6826
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
# Already Trained and Tested combination (6, 1, 17), which had val score of 0.7837
#         Current best combo: (6, 1, 17) with val score 0.7837.
#         Has trained 244 of 1582 combinations so far
#
# Best combo after this hyperparameter: (6, 1, 17) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.7837037037037037
# Max Test Score:
#  0.775926
# Max Combo Index:
#  (6, 1, 17) out of [7, 2, 113] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'alpha': 100, 'fit_prior': True, 'features': 17}
# Max Combo Features:
#  (29667, 59920, 41191, 9639, 11997, 14175, 66664, 7149, 6603, 32996, 3710, 4587, 14700, 25279, 27675, 67128, 66157, 67050, 68180, 7075, 59749, 20338, 28574, 35861, 36130, 3061, 22106, 11721, 13444, 9404, 14989, 567, 27004, 6826, 36615, 34203, 16127, 6771, 4193, 37572, 66519, 2160, 27889, 1762, 36120, 67094, 35137, 36623, 3677, 3863, 67659, 2359, 63650, 112, 67892, 37744, 60303, 68047, 9072, 17942, 9372, 27745, 6450, 13095, 5563, 40128, 2491, 34703, 13142, 57787, 64230, 49708, 4501, 17577, 44387, 13454, 59415, 6308, 23378, 43389, 13877, 56288, 12469, 67781, 50832, 66239, 47800, 52938, 66841, 5607, 3414, 52187, 32465, 45854, 65820, 8584, 31185, 2038, 1574, 3094, 500, 29750, 50043, 13792, 42802, 23414, 27046, 62724, 389, 13727, 1651, 67637, 2688, 67361, 23131, 9050, 16198, 17050, 44471, 15432, 3403, 29971, 1663, 39524, 10971, 16331, 16037, 41662, 34860, 30159, 15118, 17674, 39435, 26704, 2567, 67494, 6882, 12746, 7300, 58670, 29441, 36203, 14524, 68147, 18304, 29592, 48456, 6638, 15998, 29601, 898, 43055, 18791, 51366, 1120, 11229, 5082, 51794, 2522, 49870, 30337, 35352, 11926, 21109, 14423, 1774, 19240, 48631, 58751, 43307, 18584, 2060, 111, 3315, 10330, 4875, 710, 17607, 31239, 27581)
# % Combos Checked: 244 out of 1582 which is 15.423514999999998%
