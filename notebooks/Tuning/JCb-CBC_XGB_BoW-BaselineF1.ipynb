# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'cbc'
FEATURE_IMPORTANCE_ORDERING = 'xgb'
PREPROCESSING = 'Baseline'
TUNER = 'jiaochengb-f1'
FEATURE_ENGINEERING = 'bow'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
from scipy.sparse import load_npz

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/PrivatePackages" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
else:
    py_file_location = '../../PrivatePackages'
    home_directory = '../../'

sys.path.append(os.path.abspath(py_file_location))

from Tuners import JiaoChengB_F1

import pandas as pd
# Out:
# Collecting catboost
#   Downloading catboost-1.2.3-cp310-cp310-manylinux2014_x86_64.whl (98.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.3

# %%
## Parameters that are same for every script

SEED = 2608

TASK_TYPE = 'Classification' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = True # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from catboost import CatBoostClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {

    'n_estimators': (25, 50, 100, 200),
    'max_depth': (2, 4, 8, 16),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bylevel': (0.4, 0.55, 0.7, 0.85, 1),
    'reg_lambda': (0.01, 0.1, 1),
    'learning_rate': (0.001, 0.01, 0.1, 1),

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
      'random_state': 19260817,
      'verbose': False,
      'max_bin': 64
      }

# what order to tune hyperparameters in (JiaoCheng specific)
tuning_order = ['features',
                'max_depth',
                'colsample_bylevel',
                'subsample',
                'n_estimators',
                'reg_lambda',
                'learning_rate']

# what order to tune hyperparameters in (JiaoCheng specific)
default_hyperparameter_values = {
                                'features': 0,
                                'n_estimators': 50,
                                'max_depth': 4,
                                'subsample': 0.7,
                                'colsample_bylevel': 0.7,
                                'learning_rate': 0.01,
                                'reg_lambda': 0.01
                                }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_x = load_npz(home_directory + f'data/curated/baseline/train_{FEATURE_ENGINEERING}_x.npz')
val_x = load_npz(home_directory + f'data/curated/baseline/val_{FEATURE_ENGINEERING}_x.npz')
test_x = load_npz(home_directory + f'data/curated/baseline/test_{FEATURE_ENGINEERING}_x.npz')

with open(home_directory + 'data/curated/baseline/train_y.pkl', 'rb') as f:
    train_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/val_y.pkl', 'rb') as f:
    val_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/test_y.pkl', 'rb') as f:
    test_y = pickle.load(f)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = JiaoChengB_F1.JiaoChengB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'catboost.core.CatBoostClassifier'>, which is a Classification model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# Successfully read in tuning result of 267 rows, for 267.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# FEATURE_INDEX: 0 (features) ROUND 1
#
# Round 1
# Hyperparameter: features (index: 6)
#
# As new Best Combo (1, 1, 2, 2, 0, 1, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 0), which had val score of 0.7527
#         Current best combo: (1, 1, 2, 2, 0, 1, 0) with val score 0.7527.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 1), which had val score of 0.7519
#         Current best combo: (1, 1, 2, 2, 0, 1, 0) with val score 0.7527.
#         Has trained 267 of 542400 combinations so far
# As new Best Combo (1, 1, 2, 2, 0, 1, 2) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 2), which had val score of 0.753
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.753.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 3), which had val score of 0.7515
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.753.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 4), which had val score of 0.7517
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.753.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 5), which had val score of 0.7529
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.753.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 6), which had val score of 0.7527
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.753.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 7), which had val score of 0.7521
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.753.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 8), which had val score of 0.7521
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.753.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 9), which had val score of 0.7454
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.753.
#         Has trained 267 of 542400 combinations so far
# As new Best Combo (1, 1, 2, 2, 0, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 10), which had val score of 0.755
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 11), which had val score of 0.7516
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 12), which had val score of 0.7446
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 13), which had val score of 0.7472
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 14), which had val score of 0.7493
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 15), which had val score of 0.7494
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 16), which had val score of 0.7497
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 17), which had val score of 0.7495
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 18), which had val score of 0.738
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 19), which had val score of 0.7475
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 20), which had val score of 0.7395
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 21), which had val score of 0.751
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 22), which had val score of 0.7501
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 23), which had val score of 0.7457
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 24), which had val score of 0.7462
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 25), which had val score of 0.7479
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 26), which had val score of 0.7445
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 27), which had val score of 0.7471
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 28), which had val score of 0.7483
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 29), which had val score of 0.7497
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 30), which had val score of 0.7339
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 31), which had val score of 0.7406
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 32), which had val score of 0.7294
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 33), which had val score of 0.7347
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 34), which had val score of 0.7382
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 35), which had val score of 0.7286
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 36), which had val score of 0.7405
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 37), which had val score of 0.7329
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 38), which had val score of 0.7309
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 39), which had val score of 0.736
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 40), which had val score of 0.7444
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 41), which had val score of 0.7353
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 42), which had val score of 0.7382
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 43), which had val score of 0.734
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 44), which had val score of 0.73
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 45), which had val score of 0.7331
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 46), which had val score of 0.7318
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 47), which had val score of 0.738
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 48), which had val score of 0.7344
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 49), which had val score of 0.7291
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 50), which had val score of 0.7401
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 51), which had val score of 0.7303
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 52), which had val score of 0.7344
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 53), which had val score of 0.7299
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 54), which had val score of 0.7327
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 55), which had val score of 0.7317
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 56), which had val score of 0.7364
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 57), which had val score of 0.732
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 58), which had val score of 0.7343
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 59), which had val score of 0.7366
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 60), which had val score of 0.7356
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 61), which had val score of 0.7338
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 62), which had val score of 0.7273
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 63), which had val score of 0.7305
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 64), which had val score of 0.7255
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 65), which had val score of 0.7271
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 66), which had val score of 0.7252
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 67), which had val score of 0.7299
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 68), which had val score of 0.7343
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 69), which had val score of 0.728
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 70), which had val score of 0.7283
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 71), which had val score of 0.7255
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 72), which had val score of 0.7352
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 73), which had val score of 0.7282
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 74), which had val score of 0.7281
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 75), which had val score of 0.7223
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 76), which had val score of 0.7259
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 77), which had val score of 0.7274
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 78), which had val score of 0.7319
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 79), which had val score of 0.7306
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 80), which had val score of 0.7259
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 81), which had val score of 0.7247
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 82), which had val score of 0.7286
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 83), which had val score of 0.7213
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 84), which had val score of 0.7252
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 85), which had val score of 0.7312
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 86), which had val score of 0.7309
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 87), which had val score of 0.7283
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 88), which had val score of 0.7181
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 89), which had val score of 0.7299
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 90), which had val score of 0.7279
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 91), which had val score of 0.7314
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 92), which had val score of 0.7204
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 93), which had val score of 0.7295
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 94), which had val score of 0.7273
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 95), which had val score of 0.7365
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 96), which had val score of 0.7339
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 97), which had val score of 0.7204
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 98), which had val score of 0.7213
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 99), which had val score of 0.7361
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 100), which had val score of 0.7275
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 101), which had val score of 0.7262
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 102), which had val score of 0.7235
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 103), which had val score of 0.7206
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 104), which had val score of 0.723
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 105), which had val score of 0.724
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 106), which had val score of 0.7264
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 107), which had val score of 0.7196
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 108), which had val score of 0.7262
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 109), which had val score of 0.7221
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 110), which had val score of 0.7211
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 111), which had val score of 0.7228
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 112), which had val score of 0.7242
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 1, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (1, 0, 2, 2, 0, 1, 10), which had val score of 0.6838
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 10), which had val score of 0.755
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 0, 1, 10), which had val score of 0.7546
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.755.
#         Has trained 267 of 542400 combinations so far
# As new Best Combo (1, 3, 2, 2, 0, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 2, 2, 0, 1, 10), which had val score of 0.7611
#         Current best combo: (1, 3, 2, 2, 0, 1, 10) with val score 0.7611.
#         Has trained 267 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 0, 1, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: colsample_bylevel (index: 3)
#
# Already Trained and Tested combination (1, 3, 2, 0, 0, 1, 10), which had val score of 0.755
#         Current best combo: (1, 3, 2, 2, 0, 1, 10) with val score 0.7611.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 2, 1, 0, 1, 10), which had val score of 0.7565
#         Current best combo: (1, 3, 2, 2, 0, 1, 10) with val score 0.7611.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 0, 1, 10), which had val score of 0.7611
#         Current best combo: (1, 3, 2, 2, 0, 1, 10) with val score 0.7611.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 2, 3, 0, 1, 10), which had val score of 0.7568
#         Current best combo: (1, 3, 2, 2, 0, 1, 10) with val score 0.7611.
#         Has trained 267 of 542400 combinations so far
# As new Best Combo (1, 3, 2, 4, 0, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 2, 4, 0, 1, 10), which had val score of 0.7648
#         Current best combo: (1, 3, 2, 4, 0, 1, 10) with val score 0.7648.
#         Has trained 267 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 4, 0, 1, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: subsample (index: 2)
#
# As new Best Combo (1, 3, 0, 4, 0, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 0, 4, 0, 1, 10), which had val score of 0.7671
#         Current best combo: (1, 3, 0, 4, 0, 1, 10) with val score 0.7671.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 1, 4, 0, 1, 10), which had val score of 0.7634
#         Current best combo: (1, 3, 0, 4, 0, 1, 10) with val score 0.7671.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 2, 4, 0, 1, 10), which had val score of 0.7648
#         Current best combo: (1, 3, 0, 4, 0, 1, 10) with val score 0.7671.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 3, 4, 0, 1, 10), which had val score of 0.7634
#         Current best combo: (1, 3, 0, 4, 0, 1, 10) with val score 0.7671.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 4, 4, 0, 1, 10), which had val score of 0.761
#         Current best combo: (1, 3, 0, 4, 0, 1, 10) with val score 0.7671.
#         Has trained 267 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 0, 4, 0, 1, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 3, 0, 4, 0, 1, 10), which had val score of 0.7633
#         Current best combo: (1, 3, 0, 4, 0, 1, 10) with val score 0.7671.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 0, 1, 10), which had val score of 0.7671
#         Current best combo: (1, 3, 0, 4, 0, 1, 10) with val score 0.7671.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (2, 3, 0, 4, 0, 1, 10), which had val score of 0.7638
#         Current best combo: (1, 3, 0, 4, 0, 1, 10) with val score 0.7671.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 0, 1, 10), which had val score of 0.7668
#         Current best combo: (1, 3, 0, 4, 0, 1, 10) with val score 0.7671.
#         Has trained 267 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 0, 4, 0, 1, 10) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: reg_lambda (index: 4)
#
# Already Trained and Tested combination (1, 3, 0, 4, 0, 1, 10), which had val score of 0.7671
#         Current best combo: (1, 3, 0, 4, 0, 1, 10) with val score 0.7671.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 1, 1, 10), which had val score of 0.7631
#         Current best combo: (1, 3, 0, 4, 0, 1, 10) with val score 0.7671.
#         Has trained 267 of 542400 combinations so far
# As new Best Combo (1, 3, 0, 4, 2, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 0, 4, 2, 1, 10), which had val score of 0.7672
#         Current best combo: (1, 3, 0, 4, 2, 1, 10) with val score 0.7672.
#         Has trained 267 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 0, 4, 2, 1, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: learning_rate (index: 5)
#
# Already Trained and Tested combination (1, 3, 0, 4, 2, 0, 10), which had val score of 0.7649
#         Current best combo: (1, 3, 0, 4, 2, 1, 10) with val score 0.7672.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 1, 10), which had val score of 0.7672
#         Current best combo: (1, 3, 0, 4, 2, 1, 10) with val score 0.7672.
#         Has trained 267 of 542400 combinations so far
# As new Best Combo (1, 3, 0, 4, 2, 2, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 10), which had val score of 0.7795
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 3, 10), which had val score of 0.7765
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 0, 4, 2, 2, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 0 (features) ROUND 2
#
# Round 2
# Hyperparameter: features (index: 6)
#
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 0), which had val score of 0.7646
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 1), which had val score of 0.7578
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 2), which had val score of 0.7687
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 3), which had val score of 0.7691
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 4), which had val score of 0.7648
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 5), which had val score of 0.7729
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 6), which had val score of 0.7702
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 7), which had val score of 0.7753
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 8), which had val score of 0.7705
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 9), which had val score of 0.7737
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 10), which had val score of 0.7795
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 11), which had val score of 0.775
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 12), which had val score of 0.7713
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 13), which had val score of 0.776
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 14), which had val score of 0.7733
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 15), which had val score of 0.7749
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 16), which had val score of 0.7789
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 17), which had val score of 0.7771
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 18), which had val score of 0.7771
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 19), which had val score of 0.7766
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 20), which had val score of 0.7786
#         Current best combo: (1, 3, 0, 4, 2, 2, 10) with val score 0.7795.
#         Has trained 267 of 542400 combinations so far
# As new Best Combo (1, 3, 0, 4, 2, 2, 21) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 21), which had val score of 0.7859
#         Current best combo: (1, 3, 0, 4, 2, 2, 21) with val score 0.7859.
#         Has trained 267 of 542400 combinations so far
# As new Best Combo (1, 3, 0, 4, 2, 2, 22) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 22), which had val score of 0.7876
#         Current best combo: (1, 3, 0, 4, 2, 2, 22) with val score 0.7876.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 23), which had val score of 0.7807
#         Current best combo: (1, 3, 0, 4, 2, 2, 22) with val score 0.7876.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 24), which had val score of 0.7797
#         Current best combo: (1, 3, 0, 4, 2, 2, 22) with val score 0.7876.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 25), which had val score of 0.7804
#         Current best combo: (1, 3, 0, 4, 2, 2, 22) with val score 0.7876.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 26), which had val score of 0.7839
#         Current best combo: (1, 3, 0, 4, 2, 2, 22) with val score 0.7876.
#         Has trained 267 of 542400 combinations so far
# As new Best Combo (1, 3, 0, 4, 2, 2, 27) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 27), which had val score of 0.7892
#         Current best combo: (1, 3, 0, 4, 2, 2, 27) with val score 0.7892.
#         Has trained 267 of 542400 combinations so far
# As new Best Combo (1, 3, 0, 4, 2, 2, 28) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 28), which had val score of 0.7893
#         Current best combo: (1, 3, 0, 4, 2, 2, 28) with val score 0.7893.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 29), which had val score of 0.7859
#         Current best combo: (1, 3, 0, 4, 2, 2, 28) with val score 0.7893.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 30), which had val score of 0.7853
#         Current best combo: (1, 3, 0, 4, 2, 2, 28) with val score 0.7893.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 31), which had val score of 0.7857
#         Current best combo: (1, 3, 0, 4, 2, 2, 28) with val score 0.7893.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 32), which had val score of 0.7878
#         Current best combo: (1, 3, 0, 4, 2, 2, 28) with val score 0.7893.
#         Has trained 267 of 542400 combinations so far
# As new Best Combo (1, 3, 0, 4, 2, 2, 33) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 33), which had val score of 0.7894
#         Current best combo: (1, 3, 0, 4, 2, 2, 33) with val score 0.7894.
#         Has trained 267 of 542400 combinations so far
# As new Best Combo (1, 3, 0, 4, 2, 2, 34) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 34), which had val score of 0.7944
#         Current best combo: (1, 3, 0, 4, 2, 2, 34) with val score 0.7944.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 35), which had val score of 0.7824
#         Current best combo: (1, 3, 0, 4, 2, 2, 34) with val score 0.7944.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 36), which had val score of 0.7824
#         Current best combo: (1, 3, 0, 4, 2, 2, 34) with val score 0.7944.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 37), which had val score of 0.786
#         Current best combo: (1, 3, 0, 4, 2, 2, 34) with val score 0.7944.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 38), which had val score of 0.7881
#         Current best combo: (1, 3, 0, 4, 2, 2, 34) with val score 0.7944.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 39), which had val score of 0.7904
#         Current best combo: (1, 3, 0, 4, 2, 2, 34) with val score 0.7944.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 40), which had val score of 0.7933
#         Current best combo: (1, 3, 0, 4, 2, 2, 34) with val score 0.7944.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 41), which had val score of 0.7876
#         Current best combo: (1, 3, 0, 4, 2, 2, 34) with val score 0.7944.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 42), which had val score of 0.7907
#         Current best combo: (1, 3, 0, 4, 2, 2, 34) with val score 0.7944.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 43), which had val score of 0.7892
#         Current best combo: (1, 3, 0, 4, 2, 2, 34) with val score 0.7944.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 44), which had val score of 0.7907
#         Current best combo: (1, 3, 0, 4, 2, 2, 34) with val score 0.7944.
#         Has trained 267 of 542400 combinations so far
# As new Best Combo (1, 3, 0, 4, 2, 2, 45) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 45), which had val score of 0.7968
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 46), which had val score of 0.7929
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 47), which had val score of 0.7852
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 48), which had val score of 0.7933
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 49), which had val score of 0.7882
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 50), which had val score of 0.7825
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 51), which had val score of 0.7878
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 52), which had val score of 0.7823
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 53), which had val score of 0.7909
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 54), which had val score of 0.7851
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 55), which had val score of 0.7926
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 56), which had val score of 0.7857
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 57), which had val score of 0.7881
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 58), which had val score of 0.7873
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 59), which had val score of 0.7953
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 60), which had val score of 0.7861
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 61), which had val score of 0.7918
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 62), which had val score of 0.7907
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 63), which had val score of 0.7829
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 64), which had val score of 0.7893
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 65), which had val score of 0.7893
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 66), which had val score of 0.7911
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 67), which had val score of 0.7887
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# ...
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 76), which had val score of 0.7907
#         Current best combo: (1, 3, 0, 4, 2, 2, 45) with val score 0.7968.
#         Has trained 267 of 542400 combinations so far
# As new Best Combo (1, 3, 0, 4, 2, 2, 77) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 77), which had val score of 0.7986
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 78), which had val score of 0.7856
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 79), which had val score of 0.7849
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 80), which had val score of 0.7829
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 81), which had val score of 0.7817
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 82), which had val score of 0.7809
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 83), which had val score of 0.788
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 84), which had val score of 0.7866
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 85), which had val score of 0.786
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 86), which had val score of 0.7862
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 87), which had val score of 0.7828
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 88), which had val score of 0.7768
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 89), which had val score of 0.7827
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 90), which had val score of 0.7855
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 91), which had val score of 0.7913
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 92), which had val score of 0.7918
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 93), which had val score of 0.7801
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 94), which had val score of 0.7869
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 95), which had val score of 0.7905
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 96), which had val score of 0.7922
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 97), which had val score of 0.7885
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 98), which had val score of 0.7937
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 99), which had val score of 0.7826
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 100), which had val score of 0.7931
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 101), which had val score of 0.784
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 102), which had val score of 0.7843
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 103), which had val score of 0.7914
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 104), which had val score of 0.7872
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 105), which had val score of 0.7869
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 106), which had val score of 0.7885
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 107), which had val score of 0.7794
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 108), which had val score of 0.7745
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 109), which had val score of 0.7818
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 110), which had val score of 0.7905
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 111), which had val score of 0.7958
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 112), which had val score of 0.7884
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 0, 4, 2, 2, 77) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (1, 0, 0, 4, 2, 2, 77), which had val score of 0.7598
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 0, 4, 2, 2, 77), which had val score of 0.7695
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 2, 0, 4, 2, 2, 77), which had val score of 0.7837
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 77), which had val score of 0.7986
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 0, 4, 2, 2, 77) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: colsample_bylevel (index: 3)
#
# Already Trained and Tested combination (1, 3, 0, 0, 2, 2, 77), which had val score of 0.7958
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 1, 2, 2, 77), which had val score of 0.7873
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 2, 2, 2, 77), which had val score of 0.7824
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 3, 2, 2, 77), which had val score of 0.7815
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 77), which had val score of 0.7986
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 0, 4, 2, 2, 77) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 77), which had val score of 0.7986
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 1, 4, 2, 2, 77), which had val score of 0.7985
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 2, 4, 2, 2, 77), which had val score of 0.7893
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 3, 4, 2, 2, 77), which had val score of 0.7859
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 4, 4, 2, 2, 77), which had val score of 0.7942
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 0, 4, 2, 2, 77) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 3, 0, 4, 2, 2, 77), which had val score of 0.78
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 2, 77), which had val score of 0.7986
#         Current best combo: (1, 3, 0, 4, 2, 2, 77) with val score 0.7986.
#         Has trained 267 of 542400 combinations so far
# As new Best Combo (2, 3, 0, 4, 2, 2, 77) was read in, best_clf is set to None
# Already Trained and Tested combination (2, 3, 0, 4, 2, 2, 77), which had val score of 0.8062
#         Current best combo: (2, 3, 0, 4, 2, 2, 77) with val score 0.8062.
#         Has trained 267 of 542400 combinations so far
# As new Best Combo (3, 3, 0, 4, 2, 2, 77) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 77), which had val score of 0.8184
#         Current best combo: (3, 3, 0, 4, 2, 2, 77) with val score 0.8184.
#         Has trained 267 of 542400 combinations so far
#
# Best combo after this hyperparameter: (3, 3, 0, 4, 2, 2, 77) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: reg_lambda (index: 4)
#
# Already Trained and Tested combination (3, 3, 0, 4, 0, 2, 77), which had val score of 0.803
#         Current best combo: (3, 3, 0, 4, 2, 2, 77) with val score 0.8184.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 1, 2, 77), which had val score of 0.81
#         Current best combo: (3, 3, 0, 4, 2, 2, 77) with val score 0.8184.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 77), which had val score of 0.8184
#         Current best combo: (3, 3, 0, 4, 2, 2, 77) with val score 0.8184.
#         Has trained 267 of 542400 combinations so far
#
# Best combo after this hyperparameter: (3, 3, 0, 4, 2, 2, 77) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: learning_rate (index: 5)
#
# Already Trained and Tested combination (3, 3, 0, 4, 2, 0, 77), which had val score of 0.764
#         Current best combo: (3, 3, 0, 4, 2, 2, 77) with val score 0.8184.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 1, 77), which had val score of 0.7778
#         Current best combo: (3, 3, 0, 4, 2, 2, 77) with val score 0.8184.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 77), which had val score of 0.8184
#         Current best combo: (3, 3, 0, 4, 2, 2, 77) with val score 0.8184.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 3, 77), which had val score of 0.8115
#         Current best combo: (3, 3, 0, 4, 2, 2, 77) with val score 0.8184.
#         Has trained 267 of 542400 combinations so far
#
# Best combo after this hyperparameter: (3, 3, 0, 4, 2, 2, 77) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 0 (features) ROUND 3
#
# Round 3
# Hyperparameter: features (index: 6)
#
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 0), which had val score of 0.7604
#         Current best combo: (3, 3, 0, 4, 2, 2, 77) with val score 0.8184.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 1), which had val score of 0.7619
#         Current best combo: (3, 3, 0, 4, 2, 2, 77) with val score 0.8184.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 2), which had val score of 0.7613
#         Current best combo: (3, 3, 0, 4, 2, 2, 77) with val score 0.8184.
#         Has trained 267 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 2, 3), which had val score of 0.7621
#         Current best combo: (3, 3, 0, 4, 2, 2, 77) with val score 0.8184.
#         Has trained 267 of 542400 combinations so far
