# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'svc(rbf)'
FEATURE_IMPORTANCE_ORDERING = 'xgb'
PREPROCESSING = 'Baseline'
TUNER = 'jiaochengb-balaccu'
FEATURE_ENGINEERING = 'tfidf'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
from scipy.sparse import load_npz

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/PrivatePackages" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
else:
    py_file_location = '../../PrivatePackages'
    home_directory = '../../'

sys.path.append(os.path.abspath(py_file_location))

from Tuners import JiaoChengB_BalAccu

import pandas as pd

# %%
## Parameters that are same for every script

SEED = 2608

TASK_TYPE = 'Classification' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = False # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import SVC as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'decision_function_shape': 'ovr',
                                    'random_state': 42,
                                    'kernel': 'poly'
                                    }

tuning_order = [
    'C',
    'max_iter',
    'gamma',
    'tol',
]

default_hyperparameter_values = {'C': 1, 'tol': 0.001, 'max_iter': 800, 'gamma': 'auto'}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_x = load_npz(home_directory + f'data/curated/baseline/train_{FEATURE_ENGINEERING}_x.npz')
val_x = load_npz(home_directory + f'data/curated/baseline/val_{FEATURE_ENGINEERING}_x.npz')
test_x = load_npz(home_directory + f'data/curated/baseline/test_{FEATURE_ENGINEERING}_x.npz')

with open(home_directory + 'data/curated/baseline/train_y.pkl', 'rb') as f:
    train_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/val_y.pkl', 'rb') as f:
    val_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/test_y.pkl', 'rb') as f:
    test_y = pickle.load(f)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = JiaoChengB_BalAccu.JiaoChengB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}')
# Out:
# Streaming output truncated to the last 5000 lines.
# feature combo ningxiang score                                             0.054853
# Train accu                                                                0.274286
# Val accu                                                                  0.272593
# Test accu                                                                 0.272222
# Train balanced_accu                                                            NaN
# Val balanced_accu                                                              NaN
# Test balanced_accu                                                             NaN
# Train f1                                                                   0.18934
# Val f1                                                                    0.189135
# Test f1                                                                   0.184935
# Train precision                                                            0.76324
# Val precision                                                             0.740459
# Test precision                                                            0.766352
# Train recall                                                              0.274286
# Val recall                                                                0.272593
# Test recall                                                               0.272222
# Time                                                                          0.02
# verbose                                                                      False
# decision_function_shape                                                        ovr
# random_state                                                                  42.0
# kernel                                                                        poly
# n_columns                                                                     10.0
# features_combo_index                                                           0.0
# Train balanced_accuracy                                                   0.524923
# Val balanced_accuracy                                                     0.520476
# Test balanced_accuracy                                                    0.524405
# Train AP                                                                  0.231194
# Val AP                                                                    0.229542
# Test AP                                                                   0.230999
# Train AUC                                                                 0.524923
# Val AUC                                                                   0.520476
# Test AUC                                                                  0.524405
# Precedence                                                                   246.0
# Name: 246, dtype: object)
# Error message: ('3414', '29667', '887', '14524', '6603', '67869', '15936', '63974', '66808', '3426')
# Error Importing this Row: (247, C                                                                              1.0
# degree                                                                         1.0
# tol                                                                          0.001
# max_iter                                                                     100.0
# gamma                                                                         auto
# features                         [3414, 29667, 887, 14524, 6603, 67869, 15936, ...
# feature combo ningxiang score                                             0.054853
# Train accu                                                                0.224365
# Val accu                                                                  0.220741
# Test accu                                                                 0.228148
# Train balanced_accu                                                            NaN
# Val balanced_accu                                                              NaN
# Test balanced_accu                                                             NaN
# Train f1                                                                  0.087164
# Val f1                                                                    0.084903
# Test f1                                                                   0.094237
# Train precision                                                           0.629149
# Val precision                                                             0.351272
# Test precision                                                            0.749585
# Train recall                                                              0.224365
# Val recall                                                                0.220741
# Test recall                                                               0.228148
# Time                                                                          0.04
# verbose                                                                      False
# decision_function_shape                                                        ovr
# random_state                                                                  42.0
# kernel                                                                        poly
# n_columns                                                                     10.0
# features_combo_index                                                           0.0
# Train balanced_accuracy                                                   0.499592
# Val balanced_accuracy                                                       0.4925
# Test balanced_accuracy                                                    0.502619
# Train AP                                                                  0.222081
# Val AP                                                                     0.21966
# Test AP                                                                   0.223131
# Train AUC                                                                 0.499592
# Val AUC                                                                     0.4925
# Test AUC                                                                  0.502619
# Precedence                                                                   247.0
# Name: 247, dtype: object)
# Error message: ('3414', '29667', '887', '14524', '6603', '67869', '15936', '63974', '66808', '3426')
# Error Importing this Row: (248, C                                                                              1.0
# degree                                                                         1.0
# tol                                                                          0.001
# max_iter                                                                     200.0
# gamma                                                                         auto
# features                         [3414, 29667, 887, 14524, 6603, 67869, 15936, ...
# feature combo ningxiang score                                             0.054853
# Train accu                                                                0.226587
# Val accu                                                                  0.222222
# Test accu                                                                  0.23037
# Train balanced_accu                                                            NaN
# Val balanced_accu                                                              NaN
# Test balanced_accu                                                             NaN
# Train f1                                                                  0.093472
# Val f1                                                                    0.088561
# Test f1                                                                   0.099367
# Train precision                                                           0.634451
# Val precision                                                             0.437718
# Test precision                                                            0.744095
# Train recall                                                              0.226587
# Val recall                                                                0.222222
# Test recall                                                                0.23037
# Time                                                                          0.07
# verbose                                                                      False
# decision_function_shape                                                        ovr
# random_state                                                                  42.0
# kernel                                                                        poly
# n_columns                                                                     10.0
# features_combo_index                                                           0.0
# Train balanced_accuracy                                                   0.499362
# Val balanced_accuracy                                                     0.492857
# Test balanced_accuracy                                                    0.503452
# Train AP                                                                  0.222002
# Val AP                                                                    0.219781
# Test AP                                                                   0.223422
# Train AUC                                                                 0.499362
# Val AUC                                                                   0.492857
# Test AUC                                                                  0.503452
# Precedence                                                                   248.0
# Name: 248, dtype: object)
# Error message: ('3414', '29667', '887', '14524', '6603', '67869', '15936', '63974', '66808', '3426')
# Error Importing this Row: (249, C                                                                              1.0
# degree                                                                         1.0
# tol                                                                          0.001
# max_iter                                                                     400.0
# gamma                                                                         auto
# features                         [3414, 29667, 887, 14524, 6603, 67869, 15936, ...
# feature combo ningxiang score                                             0.054853
# Train accu                                                                0.218333
# Val accu                                                                  0.217778
# Test accu                                                                 0.224074
# Train balanced_accu                                                            NaN
# Val balanced_accu                                                              NaN
# Test balanced_accu                                                             NaN
# Train f1                                                                  0.109948
# Val f1                                                                    0.111897
# Test f1                                                                   0.121034
# Train precision                                                           0.397785
# Val precision                                                             0.395386
# Test precision                                                            0.451046
# Train recall                                                              0.218333
# Val recall                                                                0.217778
# Test recall                                                               0.224074
# Time                                                                          0.15
# verbose                                                                      False
# decision_function_shape                                                        ovr
# random_state                                                                  42.0
# kernel                                                                        poly
# n_columns                                                                     10.0
# features_combo_index                                                           0.0
# Train balanced_accuracy                                                   0.461913
# Val balanced_accuracy                                                     0.458452
# Test balanced_accuracy                                                    0.465476
# Train AP                                                                  0.209869
# Val AP                                                                    0.208831
# Test AP                                                                    0.21096
# Train AUC                                                                 0.461913
# Val AUC                                                                   0.458452
# Test AUC                                                                  0.465476
# Precedence                                                                   249.0
# Name: 249, dtype: object)
# Error message: ('3414', '29667', '887', '14524', '6603', '67869', '15936', '63974', '66808', '3426')
# Error Importing this Row: (250, C                                                                              1.0
# degree                                                                         1.0
# tol                                                                          0.001
# max_iter                                                                    1600.0
# gamma                                                                         auto
# features                         [3414, 29667, 887, 14524, 6603, 67869, 15936, ...
# feature combo ningxiang score                                             0.054853
# Train accu                                                                 0.22119
# Val accu                                                                   0.22037
# Test accu                                                                 0.220741
# Train balanced_accu                                                            NaN
# Val balanced_accu                                                              NaN
# Test balanced_accu                                                             NaN
# Train f1                                                                   0.08315
# Val f1                                                                    0.082855
# Test f1                                                                   0.082968
# Train precision                                                           0.338777
# Val precision                                                             0.288194
# Test precision                                                            0.308201
# Train recall                                                               0.22119
# Val recall                                                                 0.22037
# Test recall                                                               0.220741
# Time                                                                          0.81
# verbose                                                                      False
# decision_function_shape                                                        ovr
# random_state                                                                  42.0
# kernel                                                                        poly
# n_columns                                                                     10.0
# features_combo_index                                                           0.0
# Train balanced_accuracy                                                   0.495255
# Val balanced_accuracy                                                     0.493452
# Test balanced_accuracy                                                    0.494286
# Train AP                                                                  0.220594
# Val AP                                                                    0.219982
# Test AP                                                                   0.220265
# Train AUC                                                                 0.495255
# Val AUC                                                                   0.493452
# Test AUC                                                                  0.494286
# Precedence                                                                   250.0
# Name: 250, dtype: object)
# Error message: ('3414', '29667', '887', '14524', '6603', '67869', '15936', '63974', '66808', '3426')
# Error Importing this Row: (251, C                                                                              1.0
# degree                                                                         1.0
# tol                                                                          0.001
# max_iter                                                                     800.0
# gamma                                                                        scale
# features                         [3414, 29667, 887, 14524, 6603, 67869, 15936, ...
# feature combo ningxiang score                                             0.054853
# Train accu                                                                0.220476
# Val accu                                                                  0.221111
# Test accu                                                                 0.223704
# Train balanced_accu                                                            NaN
# Val balanced_accu                                                              NaN
# Test balanced_accu                                                             NaN
# Train f1                                                                  0.100516
# Val f1                                                                    0.104859
# Test f1                                                                   0.106943
# Train precision                                                           0.409884
# Val precision                                                             0.421832
# Test precision                                                            0.456548
# Train recall                                                              0.220476
# Val recall                                                                0.221111
# Test recall                                                               0.223704
# Time                                                                          0.31
# verbose                                                                      False
# decision_function_shape                                                        ovr
# random_state                                                                  42.0
# kernel                                                                        poly
# n_columns                                                                     10.0
# features_combo_index                                                           0.0
# Train balanced_accuracy                                                   0.476939
# Val balanced_accuracy                                                     0.474286
# Test balanced_accuracy                                                    0.478929
# Train AP                                                                  0.214544
# Val AP                                                                      0.2137
# Test AP                                                                   0.215184
# Train AUC                                                                 0.476939
# Val AUC                                                                   0.474286
# Test AUC                                                                  0.478929
# Precedence                                                                   251.0
# Name: 251, dtype: object)
# Error message: ('3414', '29667', '887', '14524', '6603', '67869', '15936', '63974', '66808', '3426')
# Error Importing this Row: (252, C                                                                              1.0
# degree                                                                         1.0
# tol                                                                         0.0001
# max_iter                                                                     800.0
# gamma                                                                         auto
# features                         [3414, 29667, 887, 14524, 6603, 67869, 15936, ...
# feature combo ningxiang score                                             0.054853
# Train accu                                                                0.218333
# Val accu                                                                  0.217778
# Test accu                                                                 0.224074
# Train balanced_accu                                                            NaN
# Val balanced_accu                                                              NaN
# Test balanced_accu                                                             NaN
# Train f1                                                                  0.109948
# Val f1                                                                    0.111897
# Test f1                                                                   0.121034
# Train precision                                                           0.397785
# Val precision                                                             0.395386
# Test precision                                                            0.451046
# Train recall                                                              0.218333
# Val recall                                                                0.217778
# Test recall                                                               0.224074
# Time                                                                          0.32
# verbose                                                                      False
# decision_function_shape                                                        ovr
# random_state                                                                  42.0
# kernel                                                                        poly
# n_columns                                                                     10.0
# features_combo_index                                                           0.0
# Train balanced_accuracy                                                   0.461913
# Val balanced_accuracy                                                     0.458452
# Test balanced_accuracy                                                    0.465476
# Train AP                                                                  0.209869
# Val AP                                                                    0.208831
# Test AP                                                                    0.21096
# Train AUC                                                                 0.461913
# Val AUC                                                                   0.458452
# Test AUC                                                                  0.465476
# Precedence                                                                   252.0
# Name: 252, dtype: object)
# Error message: ('3414', '29667', '887', '14524', '6603', '67869', '15936', '63974', '66808', '3426')
# Error Importing this Row: (253, C                                                                              1.0
# degree                                                                         1.0
# tol                                                                           0.01
# max_iter                                                                     800.0
# gamma                                                                         auto
# features                         [3414, 29667, 887, 14524, 6603, 67869, 15936, ...
# feature combo ningxiang score                                             0.054853
# Train accu                                                                0.218333
# Val accu                                                                  0.217778
# Test accu                                                                 0.224074
# Train balanced_accu                                                            NaN
# Val balanced_accu                                                              NaN
# Test balanced_accu                                                             NaN
# Train f1                                                                  0.109948
# Val f1                                                                    0.111897
# Test f1                                                                   0.121034
# Train precision                                                           0.397785
# Val precision                                                             0.395386
# Test precision                                                            0.451046
# Train recall                                                              0.218333
# Val recall                                                                0.217778
# Test recall                                                               0.224074
# Time                                                                          0.31
# verbose                                                                      False
# decision_function_shape                                                        ovr
# random_state                                                                  42.0
# kernel                                                                        poly
# n_columns                                                                     10.0
# features_combo_index                                                           0.0
# Train balanced_accuracy                                                   0.461913
# Val balanced_accuracy                                                     0.458452
# Test balanced_accuracy                                                    0.465476
# Train AP                                                                  0.209869
# Val AP                                                                    0.208831
# Test AP                                                                    0.21096
# Train AUC                                                                 0.461913
# Val AUC                                                                   0.458452
# Test AUC                                                                  0.465476
# Precedence                                                                   253.0
# Name: 253, dtype: object)
# Error message: ('3414', '29667', '887', '14524', '6603', '67869', '15936', '63974', '66808', '3426')
# Error Importing this Row: (254, C                                                                              1.0
# degree                                                                         1.0
# tol                                                                            0.1
# max_iter                                                                     800.0
# gamma                                                                         auto
# features                         [3414, 29667, 887, 14524, 6603, 67869, 15936, ...
# feature combo ningxiang score                                             0.054853
# Train accu                                                                0.218333
# Val accu                                                                  0.217778
# Test accu                                                                 0.224074
# Train balanced_accu                                                            NaN
# Val balanced_accu                                                              NaN
# Test balanced_accu                                                             NaN
# Train f1                                                                  0.109948
# Val f1                                                                    0.111897
# Test f1                                                                   0.121034
# Train precision                                                           0.397785
# Val precision                                                             0.395386
# Test precision                                                            0.451046
# Train recall                                                              0.218333
# Val recall                                                                0.217778
# Test recall                                                               0.224074
# Time                                                                          0.32
# verbose                                                                      False
# decision_function_shape                                                        ovr
# random_state                                                                  42.0
# kernel                                                                        poly
# n_columns                                                                     10.0
# features_combo_index                                                           0.0
# Train balanced_accuracy                                                   0.461913
# Val balanced_accuracy                                                     0.458452
# Test balanced_accuracy                                                    0.465476
# Train AP                                                                  0.209869
# Val AP                                                                    0.208831
# Test AP                                                                    0.21096
# Train AUC                                                                 0.461913
# Val AUC                                                                   0.458452
# Test AUC                                                                  0.465476
# Precedence                                                                   254.0
# Name: 254, dtype: object)
# Error message: ('3414', '29667', '887', '14524', '6603', '67869', '15936', '63974', '66808', '3426')
# Error Importing this Row: (255, C                                                                              1.0
# degree                                                                         1.0
# tol                                                                            1.0
# max_iter                                                                     800.0
# gamma                                                                         auto
# features                         [3414, 29667, 887, 14524, 6603, 67869, 15936, ...
# feature combo ningxiang score                                             0.054853
# Train accu                                                                0.218333
# Val accu                                                                  0.217778
# Test accu                                                                 0.224074
# Train balanced_accu                                                            NaN
# Val balanced_accu                                                              NaN
# Test balanced_accu                                                             NaN
# Train f1                                                                  0.109948
# Val f1                                                                    0.111897
# Test f1                                                                   0.121034
# Train precision                                                           0.397785
# Val precision                                                             0.395386
# Test precision                                                            0.451046
# Train recall                                                              0.218333
# Val recall                                                                0.217778
# Test recall                                                               0.224074
# Time                                                                          0.31
# verbose                                                                      False
# decision_function_shape                                                        ovr
# random_state                                                                  42.0
# kernel                                                                        poly
# n_columns                                                                     10.0
# features_combo_index                                                           0.0
# Train balanced_accuracy                                                   0.461913
# Val balanced_accuracy                                                     0.458452
# Test balanced_accuracy                                                    0.465476
# Train AP                                                                  0.209869
# Val AP                                                                    0.208831
# Test AP                                                                    0.21096
# Train AUC                                                                 0.461913
# Val AUC                                                                   0.458452
# Test AUC                                                                  0.465476
# Precedence                                                                   255.0
# Name: 255, dtype: object)
# Error message: ('3414', '29667', '887', '14524', '6603', '67869', '15936', '63974', '66808', '3426')
# Error Importing this Row: (256, C                                                                              1.0
# degree                                                                         1.0
# tol                                                                           10.0
# max_iter                                                                     800.0
# gamma                                                                         auto
# features                         [3414, 29667, 887, 14524, 6603, 67869, 15936, ...
# feature combo ningxiang score                                             0.054853
# Train accu                                                                0.222222
# Val accu                                                                  0.222222
# Test accu                                                                 0.222222
# Train balanced_accu                                                            NaN
# Val balanced_accu                                                              NaN
# Test balanced_accu                                                             NaN
# Train f1                                                                  0.080808
# Val f1                                                                    0.080808
# Test f1                                                                   0.080808
# Train precision                                                           0.049383
# Val precision                                                             0.049383
# Test precision                                                            0.049383
# Train recall                                                              0.222222
# Val recall                                                                0.222222
# Test recall                                                               0.222222
# Time                                                                          0.01
# verbose                                                                      False
# decision_function_shape                                                        ovr
# random_state                                                                  42.0
# kernel                                                                        poly
# n_columns                                                                     10.0
# features_combo_index                                                           0.0
# Train balanced_accuracy                                                        0.5
# Val balanced_accuracy                                                          0.5
# Test balanced_accuracy                                                         0.5
# Train AP                                                                  0.222222
# Val AP                                                                    0.222222
# Test AP                                                                   0.222222
# Train AUC                                                                      0.5
# Val AUC                                                                        0.5
# Test AUC                                                                       0.5
# Precedence                                                                   256.0
# Name: 256, dtype: object)
# Error message: ('3414', '29667', '887', '14524', '6603', '67869', '15936', '63974', '66808', '3426')
# Error Importing this Row: (257, C                                                                              1.0
# degree                                                                         1.0
# tol                                                                          0.001
# max_iter                                                                     800.0
# gamma                                                                         auto
# features                         [3414, 29667, 887, 14524, 6603, 67869, 15936, ...
# feature combo ningxiang score                                             0.054853
# Train accu                                                                0.218333
# Val accu                                                                  0.217778
# Test accu                                                                 0.224074
# Train balanced_accu                                                            NaN
# Val balanced_accu                                                              NaN
# Test balanced_accu                                                             NaN
# Train f1                                                                  0.109948
# Val f1                                                                    0.111897
# Test f1                                                                   0.121034
# Train precision                                                           0.397785
# Val precision                                                             0.395386
# Test precision                                                            0.451046
# Train recall                                                              0.218333
# Val recall                                                                0.217778
# Test recall                                                               0.224074
# Time                                                                          0.55
# verbose                                                                      False
# decision_function_shape                                                        ovr
# random_state                                                                  42.0
# kernel                                                                        poly
# n_columns                                                                     10.0
# features_combo_index                                                           0.0
# Train balanced_accuracy                                                   0.461913
# Val balanced_accuracy                                                     0.458452
# Test balanced_accuracy                                                    0.465476
# Train AP                                                                  0.209869
# Val AP                                                                    0.208831
# Test AP                                                                    0.21096
# Train AUC                                                                 0.461913
# Val AUC                                                                   0.458452
# Test AUC                                                                  0.465476
# Precedence                                                                     0.0
# Name: 257, dtype: object)
# Error message: ('3414', '29667', '887', '14524', '6603', '67869', '15936', '63974', '66808', '3426', '66664', '29750', '41191', '55340', '12469', '67858', '66575', '65072', '16037', '1740')
# Error Importing this Row: (258, C                                                                              1.0
# degree                                                                         1.0
# tol                                                                          0.001
# max_iter                                                                     800.0
# gamma                                                                         auto
# features                         [3414, 29667, 887, 14524, 6603, 67869, 15936, ...
# feature combo ningxiang score                                             0.091189
# Train accu                                                                0.221508
# Val accu                                                                  0.221111
# Test accu                                                                 0.222222
# Train balanced_accu                                                            NaN
# Val balanced_accu                                                              NaN
# Test balanced_accu                                                             NaN
# Train f1                                                                  0.082551
# Val f1                                                                    0.082432
# Test f1                                                                   0.083416
# Train precision                                                           0.343416
# Val precision                                                             0.308312
# Test precision                                                            0.438088
# Train recall                                                              0.221508
# Val recall                                                                0.221111
# Test recall                                                               0.222222
# Time                                                                          0.55
# verbose                                                                      False
# decision_function_shape                                                        ovr
# random_state                                                                  42.0
# kernel                                                                        poly
# n_columns                                                                     20.0
# features_combo_index                                                           1.0
# Train balanced_accuracy                                                   0.496607
# Val balanced_accuracy                                                     0.495714
# Test balanced_accuracy                                                    0.497619
# Train AP                                                                  0.221056
# Val AP                                                                    0.220751
# Test AP                                                                   0.221402
# Train AUC                                                                 0.496607
# Val AUC                                                                   0.495714
# Test AUC                                                                  0.497619
# Precedence                                                                     1.0
# Name: 258, dtype: object)
# Error message: ('3414', '29667', '887', '14524', '6603', '67869', '15936', '63974', '66808', '3426', '66664', '29750', '41191', '55340', '12469', '67858', '66575', '65072', '16037', '1740', '13507', '2688', '2215', '52187', '23378', '6233', '10403', '37744', '14712', '32284')
# Error Importing this Row: (259, C                                                                              1.0
# degree                                                                         1.0
# tol                                                                          0.001
# max_iter                                                                     800.0
# gamma                                                                         auto
# features                         [3414, 29667, 887, 14524, 6603, 67869, 15936, ...
# feature combo ningxiang score                                             0.119589
# Train accu                                                                0.223413
# Val accu                                                                  0.221481
# Test accu                                                                 0.224444
# Train balanced_accu                                                            NaN
# Val balanced_accu                                                              NaN
# Test balanced_accu                                                             NaN
# Train f1                                                                  0.086457
# Val f1                                                                    0.082543
# Test f1                                                                   0.088612
# Train precision                                                           0.533733
# Val precision                                                             0.340783
# Test precision                                                            0.583985
# Train recall                                                              0.223413
# Val recall                                                                0.221481
# Test recall                                                               0.224444
# Time                                                                          0.59
# verbose                                                                      False
# decision_function_shape                                                        ovr
# random_state                                                                  42.0
# kernel                                                                        poly
# n_columns                                                                     30.0
# features_combo_index                                                           2.0
# Train balanced_accuracy                                                   0.497832
# Val balanced_accuracy                                                     0.496548
# Test balanced_accuracy                                                    0.498452
# Train AP                                                                  0.221475
# Val AP                                                                    0.221035
# Test AP                                                                   0.221689
# Train AUC                                                                 0.497832
# Val AUC                                                                   0.496548
# Test AUC                                                                  0.498452
# Precedence                                                                     2.0
# Name: 259, dtype: object)
# Error message: ('3414', '29667', '887', '14524', '6603', '67869', '15936', '63974', '66808', '3426', '66664', '29750', '41191', '55340', '12469', '67858', '66575', '65072', '16037', '1740', '13507', '2688', '2215', '52187', '23378', '6233', '10403', '37744', '14712', '32284', '1674', '45854', '3216', '2359', '30255', '34377', '8995', '5290', '15598', '6860')
# Error Importing this Row: (260, C                                                                              1.0
# degree                                                                         1.0
# tol                                                                          0.001
# max_iter                                                                     800.0
# ...
# Val f1                                                                    0.733479
# Test f1                                                                   0.728813
# Train precision                                                           0.741294
# Val precision                                                             0.732012
# Test precision                                                            0.724886
# Train recall                                                                  0.78
# Val recall                                                                0.775926
# Test recall                                                               0.771852
# Time                                                                          1.71
# verbose                                                                      False
# decision_function_shape                                                        ovr
# random_state                                                                  42.0
# kernel                                                                        poly
# n_columns                                                                    410.0
# features_combo_index                                                          40.0
# Train balanced_accuracy                                                   0.576173
# Val balanced_accuracy                                                     0.563095
# Test balanced_accuracy                                                      0.5575
# Train AP                                                                  0.282918
# Val AP                                                                    0.270186
# Test AP                                                                   0.263721
# Train AUC                                                                 0.576173
# Val AUC                                                                   0.563095
# Test AUC                                                                    0.5575
# Precedence                                                                   108.0
# Name: 365, dtype: object)
# Error message: ('3414', '29667', '887', '14524', '6603', '67869', '15936', '63974', '66808', '3
', '25085', '2214', '1', '66797', '6167', '27869', '66508', '28537', '58031', '2655', '61071', '1884', '34036', '17566', '67682', '3499', '66886', '66441', '31317', '31394', '34541', '46915', '37735', '21316', '67671', '27771', '22655', '14207', '9695', '9964', '56288', '24880', '1994', '8125', '41662', '9639', '52270', '41418', '16342', '167', '9595', '9532', '57030', '28246', '5180', '66663', '1120', '1441', '14911', '67903', '59415', '42466', '1907', '35352', '17912', '35861', '28536', '4852', '14495', '64229', '10971', '4908', '2436', '29196', '8584', '9855', '13142', '3238', '27675', '14423', '10853', '5401', '33484', '46270', '11401', '25246', '32973', '58438', '18071', '8343', '11573', '3315', '37179', '17607', '16957', '4501', '8790', '29912', '55176', '66774', '389', '21010', '1297', '60742', '14186', '26905', '15233', '4523', '10341', '17270', '41982', '2060', '15127', '12100', '66063', '31700', '36384', '5729', '20728', '61735', '32886', '26779', '49043', '21148', '56533', '29601', '19795', '55655', '25887', '67438', '31060', '17050', '5618', '50803', '40283', '60093', '4314', '59253', '67880')
# Error Importing this Row: (367, C                                                                              1.0
# degree                                                                         6.0
# tol                                                                          0.001
# max_iter                                                                    1600.0
# gamma                                                                         auto
# features                         [3414, 29667, 887, 14524, 6603, 67869, 15936, ...
# feature combo ningxiang score                                             0.675742
# Train accu                                                                0.805635
# Val accu                                                                   0.75963
# Test accu                                                                 0.766296
# Train balanced_accu                                                            NaN
# Val balanced_accu                                                              NaN
# Test balanced_accu                                                             NaN
# Train f1                                                                  0.817644
# Val f1                                                                    0.771326
# Test f1                                                                   0.777106
# Train precision                                                           0.849955
# Val precision                                                             0.792338
# Test precision                                                            0.796203
# Train recall                                                              0.805635
# Val recall                                                                 0.75963
# Test recall                                                               0.766296
# Time                                                                         14.75
# verbose                                                                      False
# decision_function_shape                                                        ovr
# random_state                                                                  42.0
# kernel                                                                        poly
# n_columns                                                                    410.0
# features_combo_index                                                          40.0
# Train balanced_accuracy                                                   0.808724
# Val balanced_accuracy                                                     0.715714
# Test balanced_accuracy                                                     0.72119
# Train AP                                                                  0.482365
# Val AP                                                                    0.379888
# Test AP                                                                   0.387584
# Train AUC                                                                 0.808724
# Val AUC                                                                   0.715714
# Test AUC                                                                   0.72119
# Precedence                                                                   110.0
# Name: 367, dtype: object)
# Successfully read in tuning result of 368 rows, for 0.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#         Current best combo: (4, 0, 1, 4, 0, 6) with val score 0.5055
# Trained and Tested combination 36 of 361584: (4, 0, 1, 4, 0, 35), taking 3.5 seconds to get val score of 0.4946
#         Current best combo: (4, 0, 1, 4, 0, 6) with val score 0.5055
# Trained and Tested combination 37 of 361584: (4, 0, 1, 4, 0, 36), taking 4.42 seconds to get val score of 0.4705
#         Current best combo: (4, 0, 1, 4, 0, 6) with val score 0.5055
# Trained and Tested combination 38 of 361584: (4, 0, 1, 4, 0, 37), taking 3.8 seconds to get val score of 0.4852
#         Current best combo: (4, 0, 1, 4, 0, 6) with val score 0.5055
# Trained and Tested combination 39 of 361584: (4, 0, 1, 4, 0, 38), taking 4.06 seconds to get val score of 0.5115
#         Current best combo: (4, 0, 1, 4, 0, 38) with val score 0.5115
# Trained and Tested combination 40 of 361584: (4, 0, 1, 4, 0, 39), taking 4.83 seconds to get val score of 0.4958
#         Current best combo: (4, 0, 1, 4, 0, 38) with val score 0.5115
# Trained and Tested combination 41 of 361584: (4, 0, 1, 4, 0, 40), taking 4.51 seconds to get val score of 0.5831
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 71 of 361584: (4, 0, 1, 4, 0, 70), taking 9.65 seconds to get val score of 0.5045
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 72 of 361584: (4, 0, 1, 4, 0, 71), taking 9.47 seconds to get val score of 0.5664
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 73 of 361584: (4, 0, 1, 4, 0, 72), taking 10.3 seconds to get val score of 0.493
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 74 of 361584: (4, 0, 1, 4, 0, 73), taking 10.19 seconds to get val score of 0.5569
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 75 of 361584: (4, 0, 1, 4, 0, 74), taking 10.03 seconds to get val score of 0.5455
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 76 of 361584: (4, 0, 1, 4, 0, 75), taking 11.0 seconds to get val score of 0.4994
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 77 of 361584: (4, 0, 1, 4, 0, 76), taking 10.34 seconds to get val score of 0.5031
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 78 of 361584: (4, 0, 1, 4, 0, 77), taking 10.63 seconds to get val score of 0.5367
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 79 of 361584: (4, 0, 1, 4, 0, 78), taking 9.94 seconds to get val score of 0.5021
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 80 of 361584: (4, 0, 1, 4, 0, 79), taking 10.81 seconds to get val score of 0.5508
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 81 of 361584: (4, 0, 1, 4, 0, 80), taking 11.01 seconds to get val score of 0.5095
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 82 of 361584: (4, 0, 1, 4, 0, 81), taking 11.0 seconds to get val score of 0.5101
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 83 of 361584: (4, 0, 1, 4, 0, 82), taking 10.86 seconds to get val score of 0.5307
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 84 of 361584: (4, 0, 1, 4, 0, 83), taking 10.85 seconds to get val score of 0.529
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 85 of 361584: (4, 0, 1, 4, 0, 84), taking 11.52 seconds to get val score of 0.5388
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 86 of 361584: (4, 0, 1, 4, 0, 85), taking 11.34 seconds to get val score of 0.5033
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 87 of 361584: (4, 0, 1, 4, 0, 86), taking 11.24 seconds to get val score of 0.5051
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 88 of 361584: (4, 0, 1, 4, 0, 87), taking 11.48 seconds to get val score of 0.572
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 89 of 361584: (4, 0, 1, 4, 0, 88), taking 12.31 seconds to get val score of 0.5255
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 90 of 361584: (4, 0, 1, 4, 0, 89), taking 11.89 seconds to get val score of 0.5042
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 91 of 361584: (4, 0, 1, 4, 0, 90), taking 11.59 seconds to get val score of 0.5244
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 92 of 361584: (4, 0, 1, 4, 0, 91), taking 11.47 seconds to get val score of 0.5558
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 93 of 361584: (4, 0, 1, 4, 0, 92), taking 11.95 seconds to get val score of 0.5354
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
#
# Best combo after this hyperparameter: (4, 0, 1, 4, 0, 40) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: degree (index: 1)
#
# Already Trained and Tested combination (4, 0, 1, 4, 0, 40), which had val score of 0.5831
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831.
#         Has trained 93 of 361584 combinations so far
# Trained and Tested combination 94 of 361584: (4, 1, 1, 4, 0, 40), taking 4.16 seconds to get val score of 0.5008
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 95 of 361584: (4, 2, 1, 4, 0, 40), taking 4.74 seconds to get val score of 0.4988
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 96 of 361584: (4, 3, 1, 4, 0, 40), taking 4.91 seconds to get val score of 0.4992
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 97 of 361584: (4, 4, 1, 4, 0, 40), taking 4.95 seconds to get val score of 0.4989
#         Current best combo: (4, 0, 1, 4, 0, 40) with val score 0.5831
# Trained and Tested combination 98 of 361584: (4, 5, 1, 4, 0, 40), taking 5.04 seconds to get val score of 0.6856
#         Current best combo: (4, 5, 1, 4, 0, 40) with val score 0.6856
# Trained and Tested combination 99 of 361584: (4, 6, 1, 4, 0, 40), taking 4.94 seconds to get val score of 0.6811
#         Current best combo: (4, 5, 1, 4, 0, 40) with val score 0.6856
# Trained and Tested combination 100 of 361584: (4, 7, 1, 4, 0, 40), taking 4.94 seconds to get val score of 0.676
#         Current best combo: (4, 5, 1, 4, 0, 40) with val score 0.6856
# Trained and Tested combination 101 of 361584: (4, 8, 1, 4, 0, 40), taking 5.87 seconds to get val score of 0.6708
#         Current best combo: (4, 5, 1, 4, 0, 40) with val score 0.6856
#
# Best combo after this hyperparameter: (4, 5, 1, 4, 0, 40) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: C (index: 0)
#
# Trained and Tested combination 102 of 361584: (0, 5, 1, 4, 0, 40), taking 5.55 seconds to get val score of 0.6856
#         Current best combo: (4, 5, 1, 4, 0, 40) with val score 0.6856
# Trained and Tested combination 103 of 361584: (1, 5, 1, 4, 0, 40), taking 5.31 seconds to get val score of 0.6856
#         Current best combo: (4, 5, 1, 4, 0, 40) with val score 0.6856
# Trained and Tested combination 104 of 361584: (2, 5, 1, 4, 0, 40), taking 5.04 seconds to get val score of 0.6856
#         Current best combo: (4, 5, 1, 4, 0, 40) with val score 0.6856
# Trained and Tested combination 105 of 361584: (3, 5, 1, 4, 0, 40), taking 4.91 seconds to get val score of 0.6856
#         Current best combo: (4, 5, 1, 4, 0, 40) with val score 0.6856
# Already Trained and Tested combination (4, 5, 1, 4, 0, 40), which had val score of 0.6856
#         Current best combo: (4, 5, 1, 4, 0, 40) with val score 0.6856.
#         Has trained 105 of 361584 combinations so far
# Trained and Tested combination 106 of 361584: (5, 5, 1, 4, 0, 40), taking 4.94 seconds to get val score of 0.6856
#         Current best combo: (4, 5, 1, 4, 0, 40) with val score 0.6856
#
# Best combo after this hyperparameter: (4, 5, 1, 4, 0, 40) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_iter (index: 3)
#
# Trained and Tested combination 107 of 361584: (4, 5, 1, 0, 0, 40), taking 0.31 seconds to get val score of 0.5394
#         Current best combo: (4, 5, 1, 4, 0, 40) with val score 0.6856
# Trained and Tested combination 108 of 361584: (4, 5, 1, 1, 0, 40), taking 0.59 seconds to get val score of 0.554
#         Current best combo: (4, 5, 1, 4, 0, 40) with val score 0.6856
# Trained and Tested combination 109 of 361584: (4, 5, 1, 2, 0, 40), taking 1.22 seconds to get val score of 0.5631
#         Current best combo: (4, 5, 1, 4, 0, 40) with val score 0.6856
# Trained and Tested combination 110 of 361584: (4, 5, 1, 3, 0, 40), taking 2.44 seconds to get val score of 0.5946
#         Current best combo: (4, 5, 1, 4, 0, 40) with val score 0.6856
# Already Trained and Tested combination (4, 5, 1, 4, 0, 40), which had val score of 0.6856
#         Current best combo: (4, 5, 1, 4, 0, 40) with val score 0.6856.
#         Has trained 110 of 361584 combinations so far
# Trained and Tested combination 111 of 361584: (4, 5, 1, 5, 0, 40), taking 10.03 seconds to get val score of 0.7157
#         Current best combo: (4, 5, 1, 5, 0, 40) with val score 0.7157
#
# Best combo after this hyperparameter: (4, 5, 1, 5, 0, 40) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: gamma (index: 4)
#
# Already Trained and Tested combination (4, 5, 1, 5, 0, 40), which had val score of 0.7157
#         Current best combo: (4, 5, 1, 5, 0, 40) with val score 0.7157.
#         Has trained 111 of 361584 combinations so far
# Trained and Tested combination 112 of 361584: (4, 5, 1, 5, 1, 40), taking 8.37 seconds to get val score of 0.5029
#         Current best combo: (4, 5, 1, 5, 0, 40) with val score 0.7157
#
# Best combo after this hyperparameter: (4, 5, 1, 5, 0, 40) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: tol (index: 2)
#
# Trained and Tested combination 113 of 361584: (4, 5, 0, 5, 0, 40), taking 10.49 seconds to get val score of 0.7157
#         Current best combo: (4, 5, 1, 5, 0, 40) with val score 0.7157
# Already Trained and Tested combination (4, 5, 1, 5, 0, 40), which had val score of 0.7157
#         Current best combo: (4, 5, 1, 5, 0, 40) with val score 0.7157.
#         Has trained 113 of 361584 combinations so far
# Trained and Tested combination 114 of 361584: (4, 5, 2, 5, 0, 40), taking 9.92 seconds to get val score of 0.7157
#         Current best combo: (4, 5, 1, 5, 0, 40) with val score 0.7157
# Trained and Tested combination 115 of 361584: (4, 5, 3, 5, 0, 40), taking 10.39 seconds to get val score of 0.7157
#         Current best combo: (4, 5, 1, 5, 0, 40) with val score 0.7157
# Trained and Tested combination 116 of 361584: (4, 5, 4, 5, 0, 40), taking 11.42 seconds to get val score of 0.7157
#         Current best combo: (4, 5, 1, 5, 0, 40) with val score 0.7157
# Trained and Tested combination 117 of 361584: (4, 5, 5, 5, 0, 40), taking 0.02 seconds to get val score of 0.5
#         Current best combo: (4, 5, 1, 5, 0, 40) with val score 0.7157
#
# Best combo after this hyperparameter: (4, 5, 1, 5, 0, 40) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 0 (features) ROUND 2
#
# Round 2
# Hyperparameter: features (index: 5)
#
# Trained and Tested combination 118 of 361584: (4, 5, 1, 5, 0, 0), taking 0.93 seconds to get val score of 0.4998
#         Current best combo: (4, 5, 1, 5, 0, 40) with val score 0.7157
# Trained and Tested combination 119 of 361584: (4, 5, 1, 5, 0, 1), taking 1.07 seconds to get val score of 0.4998
#         Current best combo: (4, 5, 1, 5, 0, 40) with val score 0.7157
# Trained and Tested combination 120 of 361584: (4, 5, 1, 5, 0, 2), taking 1.23 seconds to get val score of 0.4998
#         Current best combo: (4, 5, 1, 5, 0, 40) with val score 0.7157
# Trained and Tested combination 121 of 361584: (4, 5, 1, 5, 0, 3), taking 1.76 seconds to get val score of 0.5001
#         Current best combo: (4, 5, 1, 5, 0, 40) with val score 0.7157
# Trained and Tested combination 122 of 361584: (4, 5, 1, 5, 0, 4), taking 1.58 seconds to get val score of 0.6571
#         Current best combo: (4, 5, 1, 5, 0, 40) with val score 0.7157
# Trained and Tested combination 123 of 361584: (4, 5, 1, 5, 0, 5), taking 1.66 seconds to get val score of 0.6605
#         Current best combo: (4, 5, 1, 5, 0, 40) with val score 0.7157
# Trained and Tested combination
#         Current best combo: (4, 5, 1, 5, 0, 34) with val score 0.7186
# Trained and Tested combination 157 of 361584: (4, 5, 1, 5, 0, 39), taking 9.68 seconds to get val score of 0.7161
#         Current best combo: (4, 5, 1, 5, 0, 34) with val score 0.7186
# Already Trained and Tested combination (4, 5, 1, 5, 0, 40), which had val score of 0.7157
#         Current best combo: (4, 5, 1, 5, 0, 34) with val score 0.7186.
#         Has trained 157 of 361584 combinations so far
# Trained and Tested combination 158 of 361584: (4, 5, 1, 5, 0, 41), taking 10.55 seconds to get val score of 0.7138
#         Current best combo: (4, 5, 1, 5, 0, 34) with val score 0.7186
# Trained and Tested combination 159 of 361584: (4, 5, 1, 5, 0, 42), taking 11.74 seconds to get val score of 0.715
#         Current best combo: (4, 5, 1, 5, 0, 34) with val score 0.7186
# Trained and Tested combination 160 of 361584: (4, 5, 1, 5, 0, 43), taking 11.19 seconds to get val score of 0.7139
#         Current best combo: (4, 5, 1, 5, 0, 34) with val score 0.7186
# Trained and Tested combination 161 of 361584: (4, 5, 1, 5, 0, 44), taking 11.57 seconds to get val score of 0.7161
#         Current best combo: (4, 5, 1, 5, 0, 34) with val score 0.7186
# Trained and Tested combination 162 of 361584: (4, 5, 1, 5, 0, 45), taking 12.21 seconds to get val score of 0.7135
#         Current best combo: (4, 5, 1, 5, 0, 34) with val score 0.7186
# Trained and Tested combination 163 of 361584: (4, 5, 1, 5, 0, 46), taking 13.36 seconds to get val score of 0.7142
#         Current best combo: (4, 5, 1, 5, 0, 34) with val score 0.7186
# Trained and Tested combination 164 of 361584: (4, 5, 1, 5, 0, 47), taking 12.49 seconds to get val score of 0.7131
#         Current best combo: (4, 5, 1, 5, 0, 34) with val score 0.7186
# Trained and Tested combination 165 of 361584: (4, 5, 1, 5, 0, 48), taking 13.18 seconds to get val score of 0.7169
#         Current best combo: (4, 5, 1, 5, 0, 34) with val score 0.7186
# Trained and Tested combination 166 of 361584: (4, 5, 1, 5, 0, 49), taking 13.23 seconds to get val score of 0.7188
#         Current best combo: (4, 5, 1, 5, 0, 49) with val score 0.7188
# Trained and Tested combination 167 of 361584: (4, 5, 1, 5, 0, 50), taking 13.62 seconds to get val score of 0.7204
#         Current best combo: (4, 5, 1, 5, 0, 50) with val score 0.7204
# Trained and Tested combination 168 of 361584: (4, 5, 1, 5, 0, 51), taking 14.32 seconds to get val score of 0.719
#         Current best combo: (4, 5, 1, 5, 0, 50) with val score 0.7204
# Trained and Tested combination 169 of 361584: (4, 5, 1, 5, 0, 52), taking 15.09 seconds to get val score of 0.7235
#         Current best combo: (4, 5, 1, 5, 0, 52) with val score 0.7235
# Trained and Tested combination 170 of 361584: (4, 5, 1, 5, 0, 53), taking 15.07 seconds to get val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 171 of 361584: (4, 5, 1, 5, 0, 54), taking 15.71 seconds to get val score of 0.7218
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 172 of 361584: (4, 5, 1, 5, 0, 55), taking 15.8 seconds to get val score of 0.7221
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 173 of 361584: (4, 5, 1, 5, 0, 56), taking 15.97 seconds to get val score of 0.7218
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 174 of 361584: (4, 5, 1, 5, 0, 57), taking 16.93 seconds to get val score of 0.7213
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 175 of 361584: (4, 5, 1, 5, 0, 58), taking 18.02 seconds to get val score of 0.7215
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 176 of 361584: (4, 5, 1, 5, 0, 59), taking 17.63 seconds to get val score of 0.7213
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 177 of 361584: (4, 5, 1, 5, 0, 60), taking 17.97 seconds to get val score of 0.7232
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 178 of 361584: (4, 5, 1, 5, 0, 61), taking 19.03 seconds to get val score of 0.7199
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 179 of 361584: (4, 5, 1, 5, 0, 62), taking 18.97 seconds to get val score of 0.7208
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 180 of 361584: (4, 5, 1, 5, 0, 63), taking 19.84 seconds to get val score of 0.7211
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 181 of 361584: (4, 5, 1, 5, 0, 64), taking 19.85 seconds to get val score of 0.7211
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 182 of 361584: (4, 5, 1, 5, 0, 65), taking 20.18 seconds to get val score of 0.7213
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 183 of 361584: (4, 5, 1, 5, 0, 66), taking 19.82 seconds to get val score of 0.7196
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 217 of 361584: (4, 8, 1, 5, 0, 53), taking 14.7 seconds to get val score of 0.7233
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
#
# Best combo after this hyperparameter: (4, 5, 1, 5, 0, 53) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: C (index: 0)
#
# Trained and Tested combination 218 of 361584: (0, 5, 1, 5, 0, 53), taking 14.75 seconds to get val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 219 of 361584: (1, 5, 1, 5, 0, 53), taking 14.98 seconds to get val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 220 of 361584: (2, 5, 1, 5, 0, 53), taking 14.83 seconds to get val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 221 of 361584: (3, 5, 1, 5, 0, 53), taking 14.81 seconds to get val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Already Trained and Tested combination (4, 5, 1, 5, 0, 53), which had val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 221 of 361584 combinations so far
# Trained and Tested combination 222 of 361584: (5, 5, 1, 5, 0, 53), taking 14.95 seconds to get val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
#
# Best combo after this hyperparameter: (4, 5, 1, 5, 0, 53) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_iter (index: 3)
#
# Trained and Tested combination 223 of 361584: (4, 5, 1, 0, 0, 53), taking 0.54 seconds to get val score of 0.5214
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 224 of 361584: (4, 5, 1, 1, 0, 53), taking 0.85 seconds to get val score of 0.5232
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 225 of 361584: (4, 5, 1, 2, 0, 53), taking 1.75 seconds to get val score of 0.5387
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 226 of 361584: (4, 5, 1, 3, 0, 53), taking 3.51 seconds to get val score of 0.5811
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 227 of 361584: (4, 5, 1, 4, 0, 53), taking 7.02 seconds to get val score of 0.6842
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Already Trained and Tested combination (4, 5, 1, 5, 0, 53), which had val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 227 of 361584 combinations so far
#
# Best combo after this hyperparameter: (4, 5, 1, 5, 0, 53) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: gamma (index: 4)
#
# Already Trained and Tested combination (4, 5, 1, 5, 0, 53), which had val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 227 of 361584 combinations so far
# Trained and Tested combination 228 of 361584: (4, 5, 1, 5, 1, 53), taking 11.72 seconds to get val score of 0.5137
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
#
# Best combo after this hyperparameter: (4, 5, 1, 5, 0, 53) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: tol (index: 2)
#
# Trained and Tested combination 229 of 361584: (4, 5, 0, 5, 0, 53), taking 15.61 seconds to get val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Already Trained and Tested combination (4, 5, 1, 5, 0, 53), which had val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 229 of 361584 combinations so far
# Trained and Tested combination 230 of 361584: (4, 5, 2, 5, 0, 53), taking 15.01 seconds to get val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 231 of 361584: (4, 5, 3, 5, 0, 53), taking 14.79 seconds to get val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 232 of 361584: (4, 5, 4, 5, 0, 53), taking 15.37 seconds to get val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
# Trained and Tested combination 233 of 361584: (4, 5, 5, 5, 0, 53), taking 0.03 seconds to get val score of 0.5
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237
#
# Best combo after this hyperparameter: (4, 5, 1, 5, 0, 53) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 0 (features) ROUND 3
#
# Round 3
# Hyperparameter: features (index: 5)
#
# Already Trained and Tested combination (4, 5, 1, 5, 0, 0), which had val score of 0.4998
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 1), which had val score of 0.4998
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 2), which had val score of 0.4998
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 3), which had val score of 0.5001
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 4), which had val score of 0.6571
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 5), which had val score of 0.6605
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 6), which had val score of 0.6607
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 7), which had val score of 0.6664
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 8), which had val score of 0.6718
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 9), which had val score of 0.5
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 10), which had val score of 0.5
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 11), which had val score of 0.5005
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 12), which had val score of 0.5005
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 13), which had val score of 0.5005
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 14), which had val score of 0.5005
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 15), which had val score of 0.5002
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 16), which had val score of 0.6868
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 17), which had val score of 0.6917
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 18), which had val score of 0.6948
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 19), which had val score of 0.6963
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 20), which had val score of 0.6987
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 21), which had val score of 0.6995
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 22), which had val score of 0.701
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 23), which had val score of 0.7023
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 24), which had val score of 0.7045
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 25), which had val score of 0.7081
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 26), which had val score of 0.7115
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 27), which had val score of 0.7112
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 28), which had val score of 0.7133
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 29), which had val score of 0.7135
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 30), which had val score of 0.7146
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 31), which had val score of 0.713
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 32), which had val score of 0.714
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 233 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 33), which had val score of 0.7157
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
# ...
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 54), which had val score of 0.7218
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 55), which had val score of 0.7221
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 56), which had val score of 0.7218
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 57), which had val score of 0.7213
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 58), which had val score of 0.7215
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 59), which had val score of 0.7213
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 60), which had val score of 0.7232
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 61), which had val score of 0.7199
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 62), which had val score of 0.7208
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 63), which had val score of 0.7211
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 64), which had val score of 0.7211
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 65), which had val score of 0.7213
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 66), which had val score of 0.7196
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 67), which had val score of 0.7211
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 68), which had val score of 0.721
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 69), which had val score of 0.7208
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 70), which had val score of 0.7204
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 71), which had val score of 0.7193
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 72), which had val score of 0.7199
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 73), which had val score of 0.7204
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 74), which had val score of 0.7206
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 75), which had val score of 0.7194
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 76), which had val score of 0.7192
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 77), which had val score of 0.7189
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 78), which had val score of 0.7194
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 79), which had val score of 0.7188
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 80), which had val score of 0.7193
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 81), which had val score of 0.7174
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 82), which had val score of 0.7185
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 83), which had val score of 0.7185
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 84), which had val score of 0.7185
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 85), which had val score of 0.7187
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 86), which had val score of 0.7189
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 87), which had val score of 0.7185
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 88), which had val score of 0.7185
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 89), which had val score of 0.7193
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 90), which had val score of 0.719
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 91), which had val score of 0.719
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 92), which had val score of 0.7193
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
#
# Best combo after this hyperparameter: (4, 5, 1, 5, 0, 53) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: degree (index: 1)
#
# Already Trained and Tested combination (4, 0, 1, 5, 0, 53), which had val score of 0.587
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 1, 1, 5, 0, 53), which had val score of 0.5024
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 2, 1, 5, 0, 53), which had val score of 0.499
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 3, 1, 5, 0, 53), which had val score of 0.5025
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 4, 1, 5, 0, 53), which had val score of 0.5004
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 53), which had val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 6, 1, 5, 0, 53), which had val score of 0.7227
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 7, 1, 5, 0, 53), which had val score of 0.7224
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 8, 1, 5, 0, 53), which had val score of 0.7233
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
#
# Best combo after this hyperparameter: (4, 5, 1, 5, 0, 53) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: C (index: 0)
#
# Already Trained and Tested combination (0, 5, 1, 5, 0, 53), which had val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (1, 5, 1, 5, 0, 53), which had val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (2, 5, 1, 5, 0, 53), which had val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (3, 5, 1, 5, 0, 53), which had val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 53), which had val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (5, 5, 1, 5, 0, 53), which had val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
#
# Best combo after this hyperparameter: (4, 5, 1, 5, 0, 53) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_iter (index: 3)
#
# Already Trained and Tested combination (4, 5, 1, 0, 0, 53), which had val score of 0.5214
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 1, 0, 53), which had val score of 0.5232
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 2, 0, 53), which had val score of 0.5387
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 3, 0, 53), which had val score of 0.5811
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 4, 0, 53), which had val score of 0.6842
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 0, 53), which had val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
#
# Best combo after this hyperparameter: (4, 5, 1, 5, 0, 53) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: gamma (index: 4)
#
# Already Trained and Tested combination (4, 5, 1, 5, 0, 53), which had val score of 0.7237
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
# Already Trained and Tested combination (4, 5, 1, 5, 1, 53), which had val score of 0.5137
#         Current best combo: (4, 5, 1, 5, 0, 53) with val score 0.7237.
#         Has trained 257 of 361584 combinations so far
#
# Best combo after this hyperparameter: (4, 5, 1, 5, 0, 53) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.7236904761904762
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-8eb19a2f5b4f> in <cell line: 3>()
#       1 # begin tuning ... (or continue training)
#       2
# ----> 3 tuner.tune()
#
# /content/drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/PrivatePackages/Tuners/JiaoChengB_BalAccu.py in tune(self, key_stats_only)
#     394
#     395         # Display final information
# --> 396         self.view_best_combo_and_score()
#     397
#     398
#
# /content/drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/PrivatePackages/Tuners/JiaoChengB_BalAccu.py in view_best_combo_and_score(self)
#     705         if self.clf_type == 'Classification':
#     706             max_val_id = self.tuning_result['Val balanced_accu'].idxmax()
# --> 707             print('Max Test Score: \n', self.tuning_result.iloc[max_val_id]['Test balanced_accu'])
#     708
#     709         elif self.clf_type == 'Regression':
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1620             key = item_from_zerodim(key)
#    1621             if not is_integer(key):
# -> 1622                 raise TypeError("Cannot index by location index with a non-integer key")
#    1623
#    1624             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
max_val_id = tuner.tuning_result['Val balanced_accuracy'].idxmax()
tuner.tuning_result.iloc[max_val_id]['Test balanced_accuracy']
# Out:
# 0.720476
