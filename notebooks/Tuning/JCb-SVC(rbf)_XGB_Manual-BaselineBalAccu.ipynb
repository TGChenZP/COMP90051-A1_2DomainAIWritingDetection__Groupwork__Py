# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'svc(rbf)'
FEATURE_IMPORTANCE_ORDERING = 'None'
PREPROCESSING = 'TextFeatures'
TUNER = 'jiaochengb-balaccu'
FEATURE_ENGINEERING = 'Manual'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle
from scipy.sparse import load_npz

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/PrivatePackages" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
else:
    py_file_location = '../../PrivatePackages'
    home_directory = '../../'

sys.path.append(os.path.abspath(py_file_location))

from Tuners import JiaoChengB_BalAccu

import pandas as pd

# %%
## Parameters that are same for every script

SEED = 2608

TASK_TYPE = 'Classification' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = False # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import SVC as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'decision_function_shape': 'ovr',
                                    'random_state': 42,
                                    'kernel': 'poly'
                                    }

tuning_order = [
    'C',
    'max_iter',
    'gamma',
    'tol',
]

default_hyperparameter_values = {'C': 1, 'tol': 0.001, 'max_iter': 800, 'gamma': 'auto'}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
data1 = pd.read_csv('../../data/curated/comp90051-2024s1-project-1/data1_additional.csv')
data2 = pd.read_csv('../../data/curated/comp90051-2024s1-project-1/data2_additional.csv')
future = pd.read_csv('../../data/curated/comp90051-2024s1-project-1/data1_additional.csv')

# %%
from sklearn.model_selection import train_test_split

train_ix_1, val_test_ix_1 = train_test_split(range(len(data1)), test_size=0.3, random_state=SEED, stratify = data1['label'])
train_ix_2, val_test_ix_2 = train_test_split(range(len(data2)), test_size=0.3, random_state=SEED, stratify = data2['label'])
val_ix_1, test_ix_1 = train_test_split(val_test_ix_1, test_size=0.5, random_state=SEED, stratify = [data1.iloc[i]['label'] for i in val_test_ix_1])
val_ix_2, test_ix_2 = train_test_split(val_test_ix_2, test_size=0.5, random_state=SEED, stratify = [data2.iloc[i]['label'] for i in val_test_ix_2])

# split data according to the index from train_test_split
train_data_1 = data1.iloc[train_ix_1]
val_data_1 = data1.iloc[val_ix_1]
test_data_1 = data1.iloc[test_ix_1]
train_data_2 = data2.iloc[train_ix_2]
val_data_2 = data2.iloc[val_ix_2]
test_data_2 = data2.iloc[test_ix_2]

# combine the data
train_data = pd.concat([train_data_1, train_data_2])
val_data = pd.concat([val_data_1, val_data_2])
test_data = pd.concat([test_data_1, test_data_2])

# %%
train_x = train_data[['perplexity', 'burstiness', 'length', 'domain', 'unique_word_ratio']]
train_y = train_data['label']
val_x = val_data[['perplexity', 'burstiness', 'length', 'domain', 'unique_word_ratio']]
val_y = val_data['label']
test_x = test_data[['perplexity', 'burstiness', 'length', 'domain', 'unique_word_ratio']]
test_y = test_data['label']

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = JiaoChengB_BalAccu.JiaoChengB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.SVC'>, which is a Classification model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# ---
# ---
# ---
# Error message: nan
# Error Importing this Row: (32, C                                 NaN
# tol                               NaN
# max_iter                          NaN
# gamma                             NaN
# Train accu                   0.777857
# Val accu                     0.778148
# Test accu                    0.777778
# Train balanced_accu          0.500561
# Val balanced_accu            0.500833
# Test balanced_accu                0.5
# Train f1                     0.681193
# Val f1                       0.681437
# Test f1                      0.680556
# Train precision              0.732073
# Val precision                0.827385
# Test precision               0.604938
# Train recall                 0.777857
# Val recall                   0.778148
# Test recall                  0.777778
# Time                             0.13
# verbose                           NaN
# decision_function_shape           NaN
# random_state               19260817.0
# kernel                            NaN
# Train AP                     0.222721
# Val AP                       0.223519
# Test AP                      0.222222
# Train AUC                    0.500561
# Val AUC                      0.500833
# Test AUC                          0.5
# Precedence                        0.0
# n_estimators                    100.0
# max_depth                         3.0
# subsample                         0.7
# colsample_bytree                  0.7
# learning_rate                    0.01
# reg_alpha                        0.01
# n_jobs                           -1.0
# warnings                         none
# Name: 32, dtype: object)
# Error message: nan
# Error Importing this Row: (33, C                                 NaN
# tol                               NaN
# max_iter                          NaN
# gamma                             NaN
# Train accu                       0.84
# Val accu                     0.827778
# Test accu                    0.836667
# Train balanced_accu           0.65926
# Val balanced_accu              0.6375
# Test balanced_accu            0.65631
# Train f1                     0.811148
# Val f1                       0.794881
# Test f1                      0.807991
# Train precision               0.84312
# Val precision                0.824774
# Test precision               0.836075
# Train recall                     0.84
# Val recall                   0.827778
# Test recall                  0.836667
# Time                             0.42
# verbose                           NaN
# decision_function_shape           NaN
# random_state               19260817.0
# kernel                            NaN
# Train AP                     0.435514
# Val AP                       0.395091
# Test AP                      0.424676
# Train AUC                     0.65926
# Val AUC                        0.6375
# Test AUC                      0.65631
# Precedence                        1.0
# n_estimators                    100.0
# max_depth                         6.0
# subsample                         0.7
# colsample_bytree                  0.7
# learning_rate                    0.01
# reg_alpha                        0.01
# n_jobs                           -1.0
# warnings                         none
# Name: 33, dtype: object)
# Error message: nan
# Error Importing this Row: (34, C                                 NaN
# tol                               NaN
# max_iter                          NaN
# gamma                             NaN
# Train accu                    0.84746
# Val accu                     0.832963
# Test accu                    0.837778
# Train balanced_accu          0.677704
# Val balanced_accu            0.651548
# Test balanced_accu           0.661786
# Train f1                     0.822849
# Val f1                       0.803888
# Test f1                      0.810854
# Train precision              0.849776
# Val precision                0.829483
# Test precision               0.835454
# Train recall                  0.84746
# Val recall                   0.832963
# Test recall                  0.837778
# Time                             0.21
# verbose                           NaN
# decision_function_shape           NaN
# random_state               19260817.0
# kernel                            NaN
# Train AP                      0.46106
# Val AP                       0.412967
# Test AP                      0.428948
# Train AUC                    0.677704
# Val AUC                      0.651548
# Test AUC                     0.661786
# Precedence                        2.0
# n_estimators                    100.0
# max_depth                        12.0
# subsample                         0.7
# colsample_bytree                  0.7
# learning_rate                    0.01
# reg_alpha                        0.01
# n_jobs                           -1.0
# warnings                         none
# Name: 34, dtype: object)
# Error message: nan
# Error Importing this Row: (35, C                                 NaN
# tol                               NaN
# max_iter                          NaN
# gamma                             NaN
# Train accu                   0.847619
# Val accu                     0.833704
# Test accu                    0.837778
# Train balanced_accu          0.677551
# Val balanced_accu            0.652024
# Test balanced_accu           0.661786
# Train f1                     0.822893
# Val f1                       0.804508
# Test f1                      0.810854
# Train precision              0.850292
# Val precision                0.831092
# Test precision               0.835454
# Train recall                 0.847619
# Val recall                   0.833704
# Test recall                  0.837778
# Time                             0.37
# verbose                           NaN
# decision_function_shape           NaN
# random_state               19260817.0
# kernel                            NaN
# Train AP                     0.461587
# Val AP                       0.415167
# Test AP                      0.428948
# Train AUC                    0.677551
# Val AUC                      0.652024
# Test AUC                     0.661786
# Precedence                        3.0
# n_estimators                    100.0
# max_depth                        24.0
# subsample                         0.7
# colsample_bytree                  0.7
# learning_rate                    0.01
# reg_alpha                        0.01
# n_jobs                           -1.0
# warnings                         none
# Name: 35, dtype: object)
# Error message: nan
# Error Importing this Row: (36, C                                 NaN
# tol                               NaN
# max_iter                          NaN
# gamma                             NaN
# Train accu                   0.847619
# Val accu                     0.833704
# Test accu                    0.837778
# Train balanced_accu          0.677551
# Val balanced_accu            0.652024
# Test balanced_accu           0.661786
# Train f1                     0.822893
# Val f1                       0.804508
# Test f1                      0.810854
# Train precision              0.850292
# Val precision                0.831092
# Test precision               0.835454
# Train recall                 0.847619
# Val recall                   0.833704
# Test recall                  0.837778
# Time                             0.43
# verbose                           NaN
# decision_function_shape           NaN
# random_state               19260817.0
# kernel                            NaN
# Train AP                     0.461587
# Val AP                       0.415167
# Test AP                      0.428948
# Train AUC                    0.677551
# Val AUC                      0.652024
# Test AUC                     0.661786
# Precedence                        4.0
# n_estimators                    100.0
# max_depth                        48.0
# subsample                         0.7
# colsample_bytree                  0.7
# learning_rate                    0.01
# reg_alpha                        0.01
# n_jobs                           -1.0
# warnings                         none
# Name: 36, dtype: object)
# Error message: nan
# Error Importing this Row: (37, C                                 NaN
# tol                               NaN
# max_iter                          NaN
# gamma                             NaN
# Train accu                   0.847619
# Val accu                     0.833704
# Test accu                    0.837778
# Train balanced_accu          0.677551
# Val balanced_accu            0.652024
# Test balanced_accu           0.661786
# Train f1                     0.822893
# Val f1                       0.804508
# Test f1                      0.810854
# Train precision              0.850292
# Val precision                0.831092
# Test precision               0.835454
# Train recall                 0.847619
# Val recall                   0.833704
# Test recall                  0.837778
# Time                             0.29
# verbose                           NaN
# decision_function_shape           NaN
# random_state               19260817.0
# kernel                            NaN
# Train AP                     0.461587
# Val AP                       0.415167
# Test AP                      0.428948
# Train AUC                    0.677551
# Val AUC                      0.652024
# Test AUC                     0.661786
# Precedence                        5.0
# n_estimators                    100.0
# max_depth                        96.0
# subsample                         0.7
# colsample_bytree                  0.7
# learning_rate                    0.01
# reg_alpha                        0.01
# n_jobs                           -1.0
# warnings                         none
# Name: 37, dtype: object)
# Error message: nan
# Error Importing this Row: (38, C                                 NaN
# tol                               NaN
# max_iter                          NaN
# gamma                             NaN
# Train accu                   0.847619
# Val accu                     0.833704
# Test accu                    0.837778
# Train balanced_accu          0.677551
# Val balanced_accu            0.652024
# Test balanced_accu           0.661786
# Train f1                     0.822893
# Val f1                       0.804508
# Test f1                      0.810854
# Train precision              0.850292
# Val precision                0.831092
# Test precision               0.835454
# Train recall                 0.847619
# Val recall                   0.833704
# Test recall                  0.837778
# Time                             0.43
# verbose                           NaN
# decision_function_shape           NaN
# random_state               19260817.0
# kernel                            NaN
# Train AP                     0.461587
# Val AP                       0.415167
# Test AP                      0.428948
# Train AUC                    0.677551
# Val AUC                      0.652024
# Test AUC                     0.661786
# Precedence                        6.0
# n_estimators                    100.0
# max_depth                       192.0
# subsample                         0.7
# colsample_bytree                  0.7
# learning_rate                    0.01
# reg_alpha                        0.01
# n_jobs                           -1.0
# warnings                         none
# Name: 38, dtype: object)
# Error message: nan
# Error Importing this Row: (39, C                                 NaN
# tol                               NaN
# max_iter                          NaN
# gamma                             NaN
# Train accu                   0.847619
# Val accu                     0.833704
# Test accu                    0.837778
# Train balanced_accu          0.677551
# Val balanced_accu            0.652024
# Test balanced_accu           0.661786
# Train f1                     0.822893
# Val f1                       0.804508
# Test f1                      0.810854
# Train precision              0.850292
# Val precision                0.831092
# Test precision               0.835454
# Train recall                 0.847619
# Val recall                   0.833704
# Test recall                  0.837778
# Time                             0.76
# verbose                           NaN
# decision_function_shape           NaN
# random_state               19260817.0
# kernel                            NaN
# Train AP                     0.461587
# Val AP                       0.415167
# Test AP                      0.428948
# Train AUC                    0.677551
# Val AUC                      0.652024
# Test AUC                     0.661786
# Precedence                        7.0
# n_estimators                    100.0
# max_depth                        24.0
# subsample                         0.4
# colsample_bytree                  0.7
# learning_rate                    0.01
# reg_alpha                        0.01
# n_jobs                           -1.0
# warnings                         none
# Name: 39, dtype: object)
# Error message: nan
# Error Importing this Row: (40, C                                 NaN
# tol                               NaN
# max_iter                          NaN
# gamma                             NaN
# Train accu                   0.847619
# Val accu                     0.833704
# Test accu                    0.837778
# Train balanced_accu          0.677551
# Val balanced_accu            0.652024
# Test balanced_accu           0.661786
# Train f1                     0.822893
# Val f1                       0.804508
# Test f1                      0.810854
# Train precision              0.850292
# Val precision                0.831092
# Test precision               0.835454
# Train recall                 0.847619
# Val recall                   0.833704
# Test recall                  0.837778
# Time                             0.48
# verbose                           NaN
# decision_function_shape           NaN
# random_state               19260817.0
# kernel                            NaN
# Train AP                     0.461587
# Val AP                       0.415167
# Test AP                      0.428948
# Train AUC                    0.677551
# Val AUC                      0.652024
# Test AUC                     0.661786
# Precedence                        8.0
# n_estimators                    100.0
# max_depth                        24.0
# subsample                        0.55
# colsample_bytree                  0.7
# learning_rate                    0.01
# reg_alpha                        0.01
# n_jobs                           -1.0
# warnings                         none
# Name: 40, dtype: object)
# Error message: nan
# Error Importing this Row: (41, C                                 NaN
# tol                               NaN
# max_iter                          NaN
# gamma                             NaN
# Train accu                   0.847619
# Val accu                     0.833704
# Test accu                    0.837778
# Train balanced_accu          0.677551
# Val balanced_accu            0.652024
# Test balanced_accu           0.661786
# Train f1                     0.822893
# Val f1                       0.804508
# Test f1                      0.810854
# Train precision              0.850292
# Val precision                0.831092
# Test precision               0.835454
# Train recall                 0.847619
# Val recall                   0.833704
# Test recall                  0.837778
# Time                             0.47
# verbose                           NaN
# decision_function_shape           NaN
# random_state               19260817.0
# kernel                            NaN
# Train AP                     0.461587
# Val AP                       0.415167
# Test AP                      0.428948
# Train AUC                    0.677551
# Val AUC                      0.652024
# Test AUC                     0.661786
# Precedence                        9.0
# n_estimators                    100.0
# max_depth                        24.0
# subsample                        0.85
# colsample_bytree                  0.7
# learning_rate                    0.01
# reg_alpha                        0.01
# n_jobs                           -1.0
# warnings                         none
# Name: 41, dtype: object)
# Successfully read in tuning result of 42 rows, for 32.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Default combo: [4, 1, 4, 0]
#
#
# FEATURE_INDEX: 0 (C) ROUND 1
#
# Round 1
# Hyperparameter: C (index: 0)
#
# As new Best Combo (0, 1, 4, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 1, 4, 0), which had val score of 0.4467
#         Current best combo: (0, 1, 4, 0) with val score 0.4467.
#         Has trained 32 of 432 combinations so far
# As new Best Combo (1, 1, 4, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 4, 0), which had val score of 0.5375
#         Current best combo: (1, 1, 4, 0) with val score 0.5375.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (2, 1, 4, 0), which had val score of 0.446
#         Current best combo: (1, 1, 4, 0) with val score 0.5375.
#         Has trained 32 of 432 combinations so far
# As new Best Combo (3, 1, 4, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 1, 4, 0), which had val score of 0.5704
#         Current best combo: (3, 1, 4, 0) with val score 0.5704.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0), which had val score of 0.5704
#         Current best combo: (3, 1, 4, 0) with val score 0.5704.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (5, 1, 4, 0), which had val score of 0.5671
#         Current best combo: (3, 1, 4, 0) with val score 0.5704.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 4, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_iter (index: 2)
#
# Already Trained and Tested combination (3, 1, 0, 0), which had val score of 0.5452
#         Current best combo: (3, 1, 4, 0) with val score 0.5704.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 1, 0), which had val score of 0.4398
#         Current best combo: (3, 1, 4, 0) with val score 0.5704.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0), which had val score of 0.5662
#         Current best combo: (3, 1, 4, 0) with val score 0.5704.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 3, 0), which had val score of 0.448
#         Current best combo: (3, 1, 4, 0) with val score 0.5704.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 4, 0), which had val score of 0.5704
#         Current best combo: (3, 1, 4, 0) with val score 0.5704.
#         Has trained 32 of 432 combinations so far
# As new Best Combo (3, 1, 5, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: gamma (index: 3)
#
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 1), which had val score of 0.5295
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: tol (index: 1)
#
# Already Trained and Tested combination (3, 0, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 2, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 3, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 4, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 5, 5, 0), which had val score of 0.5
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 0 (C) ROUND 2
#
# Round 2
# Hyperparameter: C (index: 0)
#
# Already Trained and Tested combination (0, 1, 5, 0), which had val score of 0.5545
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (1, 1, 5, 0), which had val score of 0.5425
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (2, 1, 5, 0), which had val score of 0.4423
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (5, 1, 5, 0), which had val score of 0.5712
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_iter (index: 2)
#
# Already Trained and Tested combination (3, 1, 0, 0), which had val score of 0.5452
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 1, 0), which had val score of 0.4398
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0), which had val score of 0.5662
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 3, 0), which had val score of 0.448
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 4, 0), which had val score of 0.5704
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: gamma (index: 3)
#
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 1), which had val score of 0.5295
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: tol (index: 1)
#
# Already Trained and Tested combination (3, 0, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 2, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 3, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 4, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 5, 5, 0), which had val score of 0.5
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 1 (max_iter) ROUND 1
#
# Round 1
# Hyperparameter: max_iter (index: 2)
#
# Already Trained and Tested combination (4, 1, 0, 0), which had val score of 0.5452
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 1, 1, 0), which had val score of 0.4398
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 1, 2, 0), which had val score of 0.5662
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 1, 3, 0), which had val score of 0.448
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0), which had val score of 0.5704
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: gamma (index: 3)
#
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 1), which had val score of 0.5295
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: tol (index: 1)
#
# Already Trained and Tested combination (3, 0, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 2, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 3, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 4, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 5, 5, 0), which had val score of 0.5
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: C (index: 0)
#
# Already Trained and Tested combination (0, 1, 5, 0), which had val score of 0.5545
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (1, 1, 5, 0), which had val score of 0.5425
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (2, 1, 5, 0), which had val score of 0.4423
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (5, 1, 5, 0), which had val score of 0.5712
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 1 (max_iter) ROUND 2
#
# Round 2
# Hyperparameter: max_iter (index: 2)
#
# Already Trained and Tested combination (3, 1, 0, 0), which had val score of 0.5452
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 1, 0), which had val score of 0.4398
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0), which had val score of 0.5662
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 3, 0), which had val score of 0.448
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 4, 0), which had val score of 0.5704
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: gamma (index: 3)
#
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 1), which had val score of 0.5295
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: tol (index: 1)
#
# Already Trained and Tested combination (3, 0, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 2, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 3, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 4, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 5, 5, 0), which had val score of 0.5
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: C (index: 0)
#
# Already Trained and Tested combination (0, 1, 5, 0), which had val score of 0.5545
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (1, 1, 5, 0), which had val score of 0.5425
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (2, 1, 5, 0), which had val score of 0.4423
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (5, 1, 5, 0), which had val score of 0.5712
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 2 (gamma) ROUND 1
#
# Round 1
# Hyperparameter: gamma (index: 3)
#
# Already Trained and Tested combination (4, 1, 4, 0), which had val score of 0.5704
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 1, 4, 1), which had val score of 0.5433
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: tol (index: 1)
#
# Already Trained and Tested combination (3, 0, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 2, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 3, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 4, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 5, 5, 0), which had val score of 0.5
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: C (index: 0)
#
# Already Trained and Tested combination (0, 1, 5, 0), which had val score of 0.5545
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (1, 1, 5, 0), which had val score of 0.5425
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (2, 1, 5, 0), which had val score of 0.4423
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (5, 1, 5, 0), which had val score of 0.5712
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_iter (index: 2)
#
# Already Trained and Tested combination (3, 1, 0, 0), which had val score of 0.5452
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 1, 0), which had val score of 0.4398
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0), which had val score of 0.5662
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 3, 0), which had val score of 0.448
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 4, 0), which had val score of 0.5704
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 2 (gamma) ROUND 2
#
# Round 2
# Hyperparameter: gamma (index: 3)
#
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 1), which had val score of 0.5295
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: tol (index: 1)
#
# Already Trained and Tested combination (3, 0, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 2, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 3, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 4, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 5, 5, 0), which had val score of 0.5
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: C (index: 0)
#
# Already Trained and Tested combination (0, 1, 5, 0), which had val score of 0.5545
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (1, 1, 5, 0), which had val score of 0.5425
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (2, 1, 5, 0), which had val score of 0.4423
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (5, 1, 5, 0), which had val score of 0.5712
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_iter (index: 2)
#
# Already Trained and Tested combination (3, 1, 0, 0), which had val score of 0.5452
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 1, 0), which had val score of 0.4398
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0), which had val score of 0.5662
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 3, 0), which had val score of 0.448
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 4, 0), which had val score of 0.5704
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 3 (tol) ROUND 1
#
# Round 1
# Hyperparameter: tol (index: 1)
#
# Already Trained and Tested combination (4, 0, 4, 0), which had val score of 0.5704
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 1, 4, 0), which had val score of 0.5704
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 2, 4, 0), which had val score of 0.5704
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 3, 4, 0), which had val score of 0.5704
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 4, 4, 0), which had val score of 0.5704
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 5, 4, 0), which had val score of 0.5
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: C (index: 0)
#
# Already Trained and Tested combination (0, 1, 5, 0), which had val score of 0.5545
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (1, 1, 5, 0), which had val score of 0.5425
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (2, 1, 5, 0), which had val score of 0.4423
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (5, 1, 5, 0), which had val score of 0.5712
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_iter (index: 2)
#
# Already Trained and Tested combination (3, 1, 0, 0), which had val score of 0.5452
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 1, 0), which had val score of 0.4398
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0), which had val score of 0.5662
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 3, 0), which had val score of 0.448
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 4, 0), which had val score of 0.5704
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: gamma (index: 3)
#
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 1), which had val score of 0.5295
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 3 (tol) ROUND 2
#
# Round 2
# Hyperparameter: tol (index: 1)
#
# Already Trained and Tested combination (3, 0, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 2, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 3, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 4, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 5, 5, 0), which had val score of 0.5
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: C (index: 0)
#
# Already Trained and Tested combination (0, 1, 5, 0), which had val score of 0.5545
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (1, 1, 5, 0), which had val score of 0.5425
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (2, 1, 5, 0), which had val score of 0.4423
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (4, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (5, 1, 5, 0), which had val score of 0.5712
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_iter (index: 2)
#
# Already Trained and Tested combination (3, 1, 0, 0), which had val score of 0.5452
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 1, 0), which had val score of 0.4398
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0), which had val score of 0.5662
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 3, 0), which had val score of 0.448
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 4, 0), which had val score of 0.5704
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: gamma (index: 3)
#
# Already Trained and Tested combination (3, 1, 5, 0), which had val score of 0.5898
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
# Already Trained and Tested combination (3, 1, 5, 1), which had val score of 0.5295
#         Current best combo: (3, 1, 5, 0) with val score 0.5898.
#         Has trained 32 of 432 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 5, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.589762
# Max Test Score:
#  0.661786
# Max Combo Index:
#  (3, 1, 5, 0) out of [6, 6, 6, 2] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 0.1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto'}
# % Combos Checked: 32 out of 432 which is 7.407407000000001%

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.model_selection import train_test_split
import json

with open('../../models/tmp_models/jiaochengb-balaccu_svc(rbf)_xgb_tfidf_Baseline.pickle', 'rb') as f:
    clf = pickle.load(f)
# with open('../models/xgb_tfidf_feature_importance_ordering_Baseline.pickle', 'rb') as f:
#     feature_importance_ordering = pickle.load(f)
    

data1 = []
with open('../../data/raw/comp90051-2024s1-project-1/domain1_train_data.json', 'r') as f:
    for line in f:
        data1.append(json.loads(line))

data2 = []
with open('../../data/raw/comp90051-2024s1-project-1/domain2_train_data.json', 'r') as f:
    for line in f:
        data2.append(json.loads(line))

data_test = []
with open('../../data/raw/comp90051-2024s1-project-1/test_data.json', 'r') as f:
    for line in f:
        data_test.append(json.loads(line))

future_tfidf = load_npz('../../data/curated/baseline/future_tfidf_x.npz')

# create domain labels for data
for i in range(len(data1)):
    data1[i]['domain'] = 1
for i in range(len(data2)):
    data2[i]['domain'] = 2

label1 = [instance['label'] for instance in data1]
label2 = [instance['label'] for instance in data2]

train_ix_1, val_test_ix_1 = train_test_split(range(len(data1)), test_size=0.3, random_state=SEED, stratify = label1)
train_ix_2, val_test_ix_2 = train_test_split(range(len(data2)), test_size=0.3, random_state=SEED, stratify = label2)
val_ix_1, test_ix_1 = train_test_split(val_test_ix_1, test_size=0.5, random_state=SEED, stratify = [data1[i]['label'] for i in val_test_ix_1])
val_ix_2, test_ix_2 = train_test_split(val_test_ix_2, test_size=0.5, random_state=SEED, stratify = [data2[i]['label'] for i in val_test_ix_2])

# split data according to the index from train_test_split
train_data_1 = [data1[i] for i in train_ix_1]
val_data_1 = [data1[i] for i in val_ix_1]
test_data_1 = [data1[i] for i in test_ix_1]
train_data_2 = [data2[i] for i in train_ix_2]
val_data_2 = [data2[i] for i in val_ix_2]
test_data_2 = [data2[i] for i in test_ix_2]

# combine the data
train_data = train_data_1 + train_data_2
val_data = val_data_1 + val_data_2
test_data = test_data_1 + test_data_2

train_label = [instance['label'] for instance in train_data]
val_label = [instance['label'] for instance in val_data]
test_label = [instance['label'] for instance in test_data]


train_domain = [instance['domain'] for instance in train_data]
val_domain = [instance['domain'] for instance in val_data]
test_domain = [instance['domain'] for instance in test_data]

val_pred = clf.predict(val_x)
test_pred = clf.predict(test_x)

print(balanced_accuracy_score(val_y, val_pred), balanced_accuracy_score(test_y, test_pred))

print()

val_dom1_pred = [val_pred[i] for i in range(len(val_pred)) if val_domain[i] == 1]
val_dom2_pred = [val_pred[i] for i in range(len(val_pred)) if val_domain[i] == 2]
val_dom1_true = [val_label[i] for i in range(len(val_label)) if val_domain[i] == 1]
val_dom2_true = [val_label[i] for i in range(len(val_label)) if val_domain[i] == 2]

test_dom1_pred = [test_pred[i] for i in range(len(test_pred)) if test_domain[i] == 1]
test_dom2_pred = [test_pred[i] for i in range(len(test_pred)) if test_domain[i] == 2]
test_dom1_true = [test_label[i] for i in range(len(test_label)) if test_domain[i] == 1]
test_dom2_true = [test_label[i] for i in range(len(test_label)) if test_domain[i] == 2]


print(balanced_accuracy_score(val_dom1_true, val_dom1_pred), balanced_accuracy_score(val_dom2_true, val_dom2_pred), \
      (balanced_accuracy_score(val_dom1_true, val_dom1_pred) + balanced_accuracy_score(val_dom2_true, val_dom2_pred)) / 2, balanced_accuracy_score(val_label, val_pred))
print(balanced_accuracy_score(test_dom1_true, test_dom1_pred), balanced_accuracy_score(test_dom2_true, test_dom2_pred), \
        (balanced_accuracy_score(test_dom1_true, test_dom1_pred) + balanced_accuracy_score(test_dom2_true, test_dom2_pred)) / 2, balanced_accuracy_score(test_label, test_pred))

future_predict = clf.predict(future_tfidf)
predictions = pd.DataFrame({'id': range(len(future_predict)), 'class': future_predict})
predictions.to_csv('../..//predictions/jiaochengb-balaccu_svm_tfidf_Baseline.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 64
#      61 val_domain = [instance['domain'] for instance in val_data]
#      62 test_domain = [instance['domain'] for instance in test_data]
# ---> 64 val_pred = clf.predict(val_x)
#      65 test_pred = clf.predict(test_x)
#      67 print(balanced_accuracy_score(val_y, val_pred), balanced_accuracy_score(test_y, test_pred))
#
# File /Applications/anaconda3/envs/COMP90051/lib/python3.9/site-packages/sklearn/svm/_base.py:814, in BaseSVC.predict(self, X)
#     812     y = np.argmax(self.decision_function(X), axis=1)
#     813 else:
# --> 814     y = super().predict(X)
#     815 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File /Applications/anaconda3/envs/COMP90051/lib/python3.9/site-packages/sklearn/svm/_base.py:429, in BaseLibSVM.predict(self, X)
#     413 def predict(self, X):
#     414     """Perform regression on samples in X.
#     415
#     416     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
#     427         The predicted values.
#     428     """
# --> 429     X = self._validate_for_predict(X)
#     430     predict = self._sparse_predict if self._sparse else self._dense_predict
#     431     return predict(X)
#
# File /Applications/anaconda3/envs/COMP90051/lib/python3.9/site-packages/sklearn/svm/_base.py:607, in BaseLibSVM._validate_for_predict(self, X)
#     604 check_is_fitted(self)
#     606 if not callable(self.kernel):
# --> 607     X = self._validate_data(
#     608         X,
#     609         accept_sparse="csr",
#     610         dtype=np.float64,
#     611         order="C",
#     612         accept_large_sparse=False,
#     613         reset=False,
#     614     )
#     616 if self._sparse and not sp.issparse(X):
#     617     X = sp.csr_matrix(X)
#
# File /Applications/anaconda3/envs/COMP90051/lib/python3.9/site-packages/sklearn/base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File /Applications/anaconda3/envs/COMP90051/lib/python3.9/site-packages/sklearn/base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 5 features, but SVC is expecting 68213 features as input.
