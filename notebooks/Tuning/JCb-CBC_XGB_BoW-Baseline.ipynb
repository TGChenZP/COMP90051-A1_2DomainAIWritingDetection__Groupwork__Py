# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'cbc'
FEATURE_IMPORTANCE_ORDERING = 'xgb'
PREPROCESSING = 'Baseline'
TUNER = 'jiaochengb'
FEATURE_ENGINEERING = 'bow'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
from scipy.sparse import load_npz

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/PrivatePackages" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
else:
    py_file_location = '../../PrivatePackages'
    home_directory = '../../'

sys.path.append(os.path.abspath(py_file_location))

from Tuners import JiaoChengB

import pandas as pd
# Out:
# Collecting catboost
#   Downloading catboost-1.2.3-cp310-cp310-manylinux2014_x86_64.whl (98.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.3

# %%
## Parameters that are same for every script

SEED = 2608

TASK_TYPE = 'Classification' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = True # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from catboost import CatBoostClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {

    'n_estimators': (25, 50, 100, 200),
    'max_depth': (2, 4, 8, 16),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bylevel': (0.4, 0.55, 0.7, 0.85, 1),
    'reg_lambda': (0.01, 0.1, 1),
    'learning_rate': (0.001, 0.01, 0.1, 1),

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
      'random_state': 19260817,
      'verbose': False,
      'max_bin': 64
      }

# what order to tune hyperparameters in (JiaoCheng specific)
tuning_order = ['features',
                'max_depth',
                'colsample_bylevel',
                'subsample',
                'n_estimators',
                'reg_lambda',
                'learning_rate']

# what order to tune hyperparameters in (JiaoCheng specific)
default_hyperparameter_values = {
                                'features': 0,
                                'n_estimators': 50,
                                'max_depth': 4,
                                'subsample': 0.7,
                                'colsample_bylevel': 0.7,
                                'learning_rate': 0.01,
                                'reg_lambda': 0.01
                                }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_x = load_npz(home_directory + f'data/curated/baseline/train_{FEATURE_ENGINEERING}_x.npz')
val_x = load_npz(home_directory + f'data/curated/baseline/val_{FEATURE_ENGINEERING}_x.npz')
test_x = load_npz(home_directory + f'data/curated/baseline/test_{FEATURE_ENGINEERING}_x.npz')

with open(home_directory + 'data/curated/baseline/train_y.pkl', 'rb') as f:
    train_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/val_y.pkl', 'rb') as f:
    val_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/test_y.pkl', 'rb') as f:
    test_y = pickle.load(f)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = JiaoChengB.JiaoChengB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'catboost.core.CatBoostClassifier'>, which is a Classification model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# Successfully read in tuning result of 573 rows, for 211.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# FEATURE_INDEX: 0 (features) ROUND 1
#
# Round 1
# Hyperparameter: features (index: 6)
#
# As new Best Combo (1, 1, 2, 2, 0, 1, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 0), which had val score of 0.7933
#         Current best combo: (1, 1, 2, 2, 0, 1, 0) with val score 0.7933.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 1), which had val score of 0.7922
#         Current best combo: (1, 1, 2, 2, 0, 1, 0) with val score 0.7933.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (1, 1, 2, 2, 0, 1, 2) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 2), which had val score of 0.7937
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.7937.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 3), which had val score of 0.7926
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.7937.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 4), which had val score of 0.7933
#         Current best combo: (1, 1, 2, 2, 0, 1, 2) with val score 0.7937.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (1, 1, 2, 2, 0, 1, 5) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 5), which had val score of 0.7941
#         Current best combo: (1, 1, 2, 2, 0, 1, 5) with val score 0.7941.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 6), which had val score of 0.7933
#         Current best combo: (1, 1, 2, 2, 0, 1, 5) with val score 0.7941.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 7), which had val score of 0.7926
#         Current best combo: (1, 1, 2, 2, 0, 1, 5) with val score 0.7941.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 8), which had val score of 0.7926
#         Current best combo: (1, 1, 2, 2, 0, 1, 5) with val score 0.7941.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 9), which had val score of 0.7926
#         Current best combo: (1, 1, 2, 2, 0, 1, 5) with val score 0.7941.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (1, 1, 2, 2, 0, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 10), which had val score of 0.7959
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.7959.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 11), which had val score of 0.7919
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.7959.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 12), which had val score of 0.7941
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.7959.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 13), which had val score of 0.7944
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.7959.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 14), which had val score of 0.793
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.7959.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 15), which had val score of 0.7911
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.7959.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 16), which had val score of 0.793
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.7959.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 17), which had val score of 0.7937
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.7959.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 18), which had val score of 0.7915
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.7959.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 19), which had val score of 0.7933
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.7959.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 20), which had val score of 0.7919
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.7959.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 21), which had val score of 0.7952
#         Current best combo: (1, 1, 2, 2, 0, 1, 10) with val score 0.7959.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (1, 1, 2, 2, 0, 1, 22) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 22), which had val score of 0.7974
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 23), which had val score of 0.7956
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 24), which had val score of 0.7974
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 25), which had val score of 0.797
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 26), which had val score of 0.7956
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 27), which had val score of 0.797
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 28), which had val score of 0.7956
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 29), which had val score of 0.7944
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 30), which had val score of 0.7893
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 31), which had val score of 0.7941
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 32), which had val score of 0.7904
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 33), which had val score of 0.7922
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 34), which had val score of 0.793
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 35), which had val score of 0.7911
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 36), which had val score of 0.7933
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 37), which had val score of 0.7941
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 38), which had val score of 0.7919
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 39), which had val score of 0.7941
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 40), which had val score of 0.7948
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 41), which had val score of 0.7919
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 42), which had val score of 0.793
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 43), which had val score of 0.79
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 44), which had val score of 0.7885
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 45), which had val score of 0.7911
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 46), which had val score of 0.7919
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 47), which had val score of 0.7944
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 48), which had val score of 0.7937
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 49), which had val score of 0.7885
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 50), which had val score of 0.7933
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 51), which had val score of 0.7896
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 52), which had val score of 0.7893
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 53), which had val score of 0.7911
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 54), which had val score of 0.7919
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 55), which had val score of 0.7904
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 56), which had val score of 0.7922
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 57), which had val score of 0.7915
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 58), which had val score of 0.793
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 59), which had val score of 0.7937
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 60), which had val score of 0.7941
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 61), which had val score of 0.7915
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 62), which had val score of 0.7885
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 63), which had val score of 0.7933
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 64), which had val score of 0.79
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 65), which had val score of 0.7911
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 66), which had val score of 0.7889
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 67), which had val score of 0.7911
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 68), which had val score of 0.7922
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 69), which had val score of 0.7896
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 70), which had val score of 0.7907
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 71), which had val score of 0.7907
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 72), which had val score of 0.793
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 73), which had val score of 0.7893
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 74), which had val score of 0.7911
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 75), which had val score of 0.7852
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 76), which had val score of 0.7885
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 77), which had val score of 0.7915
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 78), which had val score of 0.79
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 79), which had val score of 0.7915
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 80), which had val score of 0.7885
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 81), which had val score of 0.7904
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 82), which had val score of 0.7919
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 83), which had val score of 0.7874
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 84), which had val score of 0.7896
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 85), which had val score of 0.7922
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 86), which had val score of 0.7911
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 87), which had val score of 0.79
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 88), which had val score of 0.7863
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 89), which had val score of 0.7878
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 90), which had val score of 0.7922
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 91), which had val score of 0.79
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 92), which had val score of 0.7859
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 93), which had val score of 0.7919
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 94), which had val score of 0.7893
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 95), which had val score of 0.793
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 96), which had val score of 0.793
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 97), which had val score of 0.7874
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 98), which had val score of 0.7889
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 99), which had val score of 0.7956
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 100), which had val score of 0.7889
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 101), which had val score of 0.7896
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 102), which had val score of 0.7893
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 103), which had val score of 0.787
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 104), which had val score of 0.7893
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 105), which had val score of 0.7878
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 106), which had val score of 0.7893
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 107), which had val score of 0.787
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 108), which had val score of 0.7896
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 109), which had val score of 0.7863
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 110), which had val score of 0.7885
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 111), which had val score of 0.7859
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 112), which had val score of 0.7889
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 1, 22) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (1, 0, 2, 2, 0, 1, 22), which had val score of 0.7752
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 1, 22), which had val score of 0.7974
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 0, 1, 22), which had val score of 0.7948
#         Current best combo: (1, 1, 2, 2, 0, 1, 22) with val score 0.7974.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (1, 3, 2, 2, 0, 1, 22) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 2, 2, 0, 1, 22), which had val score of 0.8011
#         Current best combo: (1, 3, 2, 2, 0, 1, 22) with val score 0.8011.
#         Has trained 573 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 2, 0, 1, 22) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: colsample_bylevel (index: 3)
#
# Already Trained and Tested combination (1, 3, 2, 0, 0, 1, 22), which had val score of 0.7974
#         Current best combo: (1, 3, 2, 2, 0, 1, 22) with val score 0.8011.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (1, 3, 2, 1, 0, 1, 22) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 3, 2, 1, 0, 1, 22), which had val score of 0.8015
#         Current best combo: (1, 3, 2, 1, 0, 1, 22) with val score 0.8015.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 0, 1, 22), which had val score of 0.8011
#         Current best combo: (1, 3, 2, 1, 0, 1, 22) with val score 0.8015.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 2, 3, 0, 1, 22), which had val score of 0.7996
#         Current best combo: (1, 3, 2, 1, 0, 1, 22) with val score 0.8015.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 2, 4, 0, 1, 22), which had val score of 0.7996
#         Current best combo: (1, 3, 2, 1, 0, 1, 22) with val score 0.8015.
#         Has trained 573 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 1, 0, 1, 22) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (1, 3, 0, 1, 0, 1, 22), which had val score of 0.7985
#         Current best combo: (1, 3, 2, 1, 0, 1, 22) with val score 0.8015.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 1, 1, 0, 1, 22), which had val score of 0.8015
#         Current best combo: (1, 3, 2, 1, 0, 1, 22) with val score 0.8015.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 2, 1, 0, 1, 22), which had val score of 0.8015
#         Current best combo: (1, 3, 2, 1, 0, 1, 22) with val score 0.8015.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 3, 1, 0, 1, 22), which had val score of 0.7978
#         Current best combo: (1, 3, 2, 1, 0, 1, 22) with val score 0.8015.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 4, 1, 0, 1, 22), which had val score of 0.7959
#         Current best combo: (1, 3, 2, 1, 0, 1, 22) with val score 0.8015.
#         Has trained 573 of 542400 combinations so far
#
# Best combo after this hyperparameter: (1, 3, 2, 1, 0, 1, 22) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 3, 2, 1, 0, 1, 22), which had val score of 0.7952
#         Current best combo: (1, 3, 2, 1, 0, 1, 22) with val score 0.8015.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (1, 3, 2, 1, 0, 1, 22), which had val score of 0.8015
#         Current best combo: (1, 3, 2, 1, 0, 1, 22) with val score 0.8015.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (2, 3, 2, 1, 0, 1, 22) was read in, best_clf is set to None
# Already Trained and Tested combination (2, 3, 2, 1, 0, 1, 22), which had val score of 0.8041
#         Current best combo: (2, 3, 2, 1, 0, 1, 22) with val score 0.8041.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (3, 3, 2, 1, 0, 1, 22) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 2, 1, 0, 1, 22), which had val score of 0.8052
#         Current best combo: (3, 3, 2, 1, 0, 1, 22) with val score 0.8052.
#         Has trained 573 of 542400 combinations so far
#
# Best combo after this hyperparameter: (3, 3, 2, 1, 0, 1, 22) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: reg_lambda (index: 4)
#
# Already Trained and Tested combination (3, 3, 2, 1, 0, 1, 22), which had val score of 0.8052
#         Current best combo: (3, 3, 2, 1, 0, 1, 22) with val score 0.8052.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (3, 3, 2, 1, 1, 1, 22) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 2, 1, 1, 1, 22), which had val score of 0.8067
#         Current best combo: (3, 3, 2, 1, 1, 1, 22) with val score 0.8067.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 2, 1, 22), which had val score of 0.8037
#         Current best combo: (3, 3, 2, 1, 1, 1, 22) with val score 0.8067.
#         Has trained 573 of 542400 combinations so far
#
# Best combo after this hyperparameter: (3, 3, 2, 1, 1, 1, 22) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: learning_rate (index: 5)
#
# Already Trained and Tested combination (3, 3, 2, 1, 1, 0, 22), which had val score of 0.7989
#         Current best combo: (3, 3, 2, 1, 1, 1, 22) with val score 0.8067.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 1, 22), which had val score of 0.8067
#         Current best combo: (3, 3, 2, 1, 1, 1, 22) with val score 0.8067.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (3, 3, 2, 1, 1, 2, 22) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 22), which had val score of 0.8185
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 3, 22), which had val score of 0.7993
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
#
# Best combo after this hyperparameter: (3, 3, 2, 1, 1, 2, 22) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 0 (features) ROUND 2
#
# Round 2
# Hyperparameter: features (index: 6)
#
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 0), which had val score of 0.7867
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 1), which had val score of 0.787
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 2), which had val score of 0.7837
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 3), which had val score of 0.7815
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 4), which had val score of 0.7867
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 5), which had val score of 0.7944
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 6), which had val score of 0.7993
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 7), which had val score of 0.7959
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 8), which had val score of 0.8004
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 9), which had val score of 0.8056
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 10), which had val score of 0.8041
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 11), which had val score of 0.8089
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 12), which had val score of 0.8037
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 13), which had val score of 0.8085
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 14), which had val score of 0.8093
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 15), which had val score of 0.807
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 16), which had val score of 0.8074
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 17), which had val score of 0.8041
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 18), which had val score of 0.8126
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 19), which had val score of 0.81
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 20), which had val score of 0.8133
#         Current best combo: (3, 3, 2, 1, 1, 2, 22) with val score 0.8185.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (3, 3, 2, 1, 1, 2, 21) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 21), which had val score of 0.8189
#         Current best combo: (3, 3, 2, 1, 1, 2, 21) with val score 0.8189.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 22), which had val score of 0.8185
#         Current best combo: (3, 3, 2, 1, 1, 2, 21) with val score 0.8189.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (3, 3, 2, 1, 1, 2, 23) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 23), which had val score of 0.8204
#         Current best combo: (3, 3, 2, 1, 1, 2, 23) with val score 0.8204.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 24), which had val score of 0.8167
#         Current best combo: (3, 3, 2, 1, 1, 2, 23) with val score 0.8204.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 25), which had val score of 0.8148
#         Current best combo: (3, 3, 2, 1, 1, 2, 23) with val score 0.8204.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 26), which had val score of 0.8141
#         Current best combo: (3, 3, 2, 1, 1, 2, 23) with val score 0.8204.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 27), which had val score of 0.8181
#         Current best combo: (3, 3, 2, 1, 1, 2, 23) with val score 0.8204.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 28), which had val score of 0.8193
#         Current best combo: (3, 3, 2, 1, 1, 2, 23) with val score 0.8204.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (3, 3, 2, 1, 1, 2, 29) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 29), which had val score of 0.8259
#         Current best combo: (3, 3, 2, 1, 1, 2, 29) with val score 0.8259.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 30), which had val score of 0.82
#         Current best combo: (3, 3, 2, 1, 1, 2, 29) with val score 0.8259.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 31), which had val score of 0.8137
#         Current best combo: (3, 3, 2, 1, 1, 2, 29) with val score 0.8259.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (3, 3, 2, 1, 1, 2, 32) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 32), which had val score of 0.8281
#         Current best combo: (3, 3, 2, 1, 1, 2, 32) with val score 0.8281.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 33), which had val score of 0.8252
#         Current best combo: (3, 3, 2, 1, 1, 2, 32) with val score 0.8281.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (3, 3, 2, 1, 1, 2, 34) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 34), which had val score of 0.8296
#         Current best combo: (3, 3, 2, 1, 1, 2, 34) with val score 0.8296.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (3, 3, 2, 1, 1, 2, 35) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 35), which had val score of 0.8326
#         Current best combo: (3, 3, 2, 1, 1, 2, 35) with val score 0.8326.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 36), which had val score of 0.8219
#         Current best combo: (3, 3, 2, 1, 1, 2, 35) with val score 0.8326.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 37), which had val score of 0.8248
#         Current best combo: (3, 3, 2, 1, 1, 2, 35) with val score 0.8326.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 38), which had val score of 0.8222
#         Current best combo: (3, 3, 2, 1, 1, 2, 35) with val score 0.8326.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 39), which had val score of 0.8237
#         Current best combo: (3, 3, 2, 1, 1, 2, 35) with val score 0.8326.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 40), which had val score of 0.8267
#         Current best combo: (3, 3, 2, 1, 1, 2, 35) with val score 0.8326.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 41), which had val score of 0.8307
#         Current best combo: (3, 3, 2, 1, 1, 2, 35) with val score 0.8326.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 42), which had val score of 0.8281
#         Current best combo: (3, 3, 2, 1, 1, 2, 35) with val score 0.8326.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 43), which had val score of 0.8293
#         Current best combo: (3, 3, 2, 1, 1, 2, 35) with val score 0.8326.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 44), which had val score of 0.827
#         Current best combo: (3, 3, 2, 1, 1, 2, 35) with val score 0.8326.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 45), which had val score of 0.823
#         Current best combo: (3, 3, 2, 1, 1, 2, 35) with val score 0.8326.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 46), which had val score of 0.823
#         Current best combo: (3, 3, 2, 1, 1, 2, 35) with val score 0.8326.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (3, 3, 2, 1, 1, 2, 47) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 47), which had val score of 0.833
#         Current best combo: (3, 3, 2, 1, 1, 2, 47) with val score 0.833.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 48), which had val score of 0.827
#         Current best combo: (3, 3, 2, 1, 1, 2, 47) with val score 0.833.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 49), which had val score of 0.8256
#         Current best combo: (3, 3, 2, 1, 1, 2, 47) with val score 0.833.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 50), which had val score of 0.8252
#         Current best combo: (3, 3, 2, 1, 1, 2, 47) with val score 0.833.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 51), which had val score of 0.8267
#         Current best combo: (3, 3, 2, 1, 1, 2, 47) with val score 0.833.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 52), which had val score of 0.827
#         Current best combo: (3, 3, 2, 1, 1, 2, 47) with val score 0.833.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 53), which had val score of 0.8259
#         Current best combo: (3, 3, 2, 1, 1, 2, 47) with val score 0.833.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 54), which had val score of 0.8263
#         Current best combo: (3, 3, 2, 1, 1, 2, 47) with val score 0.833.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 55), which had val score of 0.8248
#         Current best combo: (3, 3, 2, 1, 1, 2, 47) with val score 0.833.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 56), which had val score of 0.8222
#         Current best combo: (3, 3, 2, 1, 1, 2, 47) with val score 0.833.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 57), which had val score of 0.8252
#         Current best combo: (3, 3, 2, 1, 1, 2, 47) with val score 0.833.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 58), which had val score of 0.8293
#         Current best combo: (3, 3, 2, 1, 1, 2, 47) with val score 0.833.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 59), which had val score of 0.8267
#         Current best combo: (3, 3, 2, 1, 1, 2, 47) with val score 0.833.
#         Has trained 573 of 542400 combinations so far
# As new Best Combo (3, 3, 2, 1, 1, 2, 60) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 60), which had val score of 0.8363
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 61), which had val score of 0.8248
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 62), which had val score of 0.8311
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 63), which had val score of 0.8189
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 64), which had val score of 0.8259
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 65), which had val score of 0.8244
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 66), which had val score of 0.8281
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 67), which had val score of 0.8259
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 68), which had val score of 0.8159
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 69), which had val score of 0.8285
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 70), which had val score of 0.8307
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 71), which had val score of 0.8207
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 72), which had val score of 0.8263
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 73), which had val score of 0.8226
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 74), which had val score of 0.8233
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 75), which had val score of 0.8293
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 76), which had val score of 0.8211
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 77), which had val score of 0.8326
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 78), which had val score of 0.8285
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 1, 2, 79), which had val score of 0.8322
#         Current best combo: (3, 3, 2, 1, 1, 2, 60) with val score 0.8363.
#         Has trained 573 of 542400 combinations so far
