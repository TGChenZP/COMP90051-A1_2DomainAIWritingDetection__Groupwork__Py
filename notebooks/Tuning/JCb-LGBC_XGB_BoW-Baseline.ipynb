# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'lgbc'
FEATURE_IMPORTANCE_ORDERING = 'xgb'
PREPROCESSING = 'Baseline'
TUNER = 'jiaochengb'
FEATURE_ENGINEERING = 'bow'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os
import pickle
import numpy as np
from scipy.sparse import load_npz

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/PrivatePackages" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
else:
    py_file_location = '../../PrivatePackages'
    home_directory = '../../'

sys.path.append(os.path.abspath(py_file_location))

from Tuners import JiaoChengB

import pandas as pd

# %%
## Parameters that are same for every script

SEED = 2608

TASK_TYPE = 'Classification' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = True # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from lightgbm import LGBMClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
    'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'reg_alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 19260817,
                                    'n_jobs': -1,
                                    'warnings': 'none'
                                    }

tuning_order = [
    'features',
    'max_depth',
    'subsample',
    'colsample_bytree',
    'n_estimators',
    'reg_alpha',
    'learning_rate',
]

default_hyperparameter_values = {'n_estimators': 100, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.01, 'learning_rate': 0.01, 'features': 0}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_x = load_npz(home_directory + f'data/curated/baseline/train_{FEATURE_ENGINEERING}_x.npz')
val_x = load_npz(home_directory + f'data/curated/baseline/val_{FEATURE_ENGINEERING}_x.npz')
test_x = load_npz(home_directory + f'data/curated/baseline/test_{FEATURE_ENGINEERING}_x.npz')

train_x.data = train_x.data.astype(np.float64)
val_x.data = val_x.data.astype(np.float64)
test_x.data = test_x.data.astype(np.float64)

with open(home_directory + 'data/curated/baseline/train_y.pkl', 'rb') as f:
    train_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/val_y.pkl', 'rb') as f:
    val_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/test_y.pkl', 'rb') as f:
    test_y = pickle.load(f)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = JiaoChengB.JiaoChengB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'lightgbm.sklearn.LGBMClassifier'>, which is a Classification model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 77), which had val score of 0.8648
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
#
# Best combo after this hyperparameter: (5, 2, 2, 2, 4, 1, 77) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: features (index: 6)
#
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 0), which had val score of 0.7874
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 1), which had val score of 0.7826
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 2), which had val score of 0.7837
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 3), which had val score of 0.7863
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 4), which had val score of 0.7856
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 5), which had val score of 0.7944
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 6), which had val score of 0.79
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 7), which had val score of 0.7933
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 8), which had val score of 0.7941
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 9), which had val score of 0.7907
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 10), which had val score of 0.8037
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 11), which had val score of 0.8015
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 12), which had val score of 0.8022
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 13), which had val score of 0.8026
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 14), which had val score of 0.8096
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 15), which had val score of 0.8096
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 16), which had val score of 0.8093
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 17), which had val score of 0.81
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 18), which had val score of 0.8081
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 19), which had val score of 0.8089
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 20), which had val score of 0.813
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 21), which had val score of 0.8222
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 22), which had val score of 0.82
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 23), which had val score of 0.8181
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 24), which had val score of 0.8215
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 25), which had val score of 0.827
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 26), which had val score of 0.823
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 27), which had val score of 0.8241
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 28), which had val score of 0.8241
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 29), which had val score of 0.8289
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 30), which had val score of 0.833
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 31), which had val score of 0.83
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 32), which had val score of 0.8326
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 33), which had val score of 0.8344
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 34), which had val score of 0.8319
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 35), which had val score of 0.8319
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 36), which had val score of 0.833
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 37), which had val score of 0.8378
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 38), which had val score of 0.8378
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 39), which had val score of 0.8407
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 40), which had val score of 0.8437
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 41), which had val score of 0.8411
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 42), which had val score of 0.8385
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 43), which had val score of 0.8459
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 44), which had val score of 0.8422
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 45), which had val score of 0.8444
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 46), which had val score of 0.8463
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 47), which had val score of 0.8493
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 48), which had val score of 0.8489
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 49), which had val score of 0.8496
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 50), which had val score of 0.8522
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 51), which had val score of 0.8548
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 52), which had val score of 0.8507
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 53), which had val score of 0.8541
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 54), which had val score of 0.8533
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 55), which had val score of 0.8526
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 56), which had val score of 0.8504
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 57), which had val score of 0.8537
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 58), which had val score of 0.8544
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 59), which had val score of 0.8596
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 60), which had val score of 0.857
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 61), which had val score of 0.8526
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 62), which had val score of 0.8556
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 63), which had val score of 0.8541
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 64), which had val score of 0.8607
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 65), which had val score of 0.8537
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 66), which had val score of 0.8615
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 67), which had val score of 0.8533
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 68), which had val score of 0.8574
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 69), which had val score of 0.8581
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 70), which had val score of 0.8544
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 71), which had val score of 0.863
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 72), which had val score of 0.8607
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 73), which had val score of 0.8593
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 74), which had val score of 0.8596
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 75), which had val score of 0.8574
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 76), which had val score of 0.8637
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 77), which had val score of 0.8648
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 78), which had val score of 0.8589
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 79), which had val score of 0.8578
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 80), which had val score of 0.8611
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 81), which had val score of 0.8622
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 82), which had val score of 0.8593
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 83), which had val score of 0.8589
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 84), which had val score of 0.8589
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 85), which had val score of 0.8644
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 86), which had val score of 0.8578
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 87), which had val score of 0.8585
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 88), which had val score of 0.8607
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 89), which had val score of 0.8585
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 90), which had val score of 0.8626
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 91), which had val score of 0.8563
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 92), which had val score of 0.857
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 93), which had val score of 0.86
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 94), which had val score of 0.8585
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 95), which had val score of 0.8596
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 96), which had val score of 0.8615
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 97), which had val score of 0.86
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 98), which had val score of 0.8581
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 99), which had val score of 0.8611
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 100), which had val score of 0.8563
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 101), which had val score of 0.8596
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 102), which had val score of 0.8589
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 103), which had val score of 0.8559
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 104), which had val score of 0.86
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 105), which had val score of 0.8578
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 106), which had val score of 0.8585
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 107), which had val score of 0.8574
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 108), which had val score of 0.8581
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 109), which had val score of 0.8622
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 110), which had val score of 0.8552
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 111), which had val score of 0.8574
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 112), which had val score of 0.8615
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
#
# Best combo after this hyperparameter: (5, 2, 2, 2, 4, 1, 77) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (5, 0, 2, 2, 4, 1, 77), which had val score of 0.8344
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 1, 2, 2, 4, 1, 77), which had val score of 0.8567
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 77), which had val score of 0.8648
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 3, 2, 2, 4, 1, 77), which had val score of 0.8596
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 1, 77), which had val score of 0.863
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 5, 2, 2, 4, 1, 77), which had val score of 0.863
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
# Already Trained and Tested combination (5, 6, 2, 2, 4, 1, 77), which had val score of 0.863
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 291 of 3559500 combinations so far
#
# Best combo after this hyperparameter: (5, 2, 2, 2, 4, 1, 77) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 3 (colsample_bytree) ROUND 1
#
# Round 1
# Hyperparameter: colsample_bytree (index: 3)
#
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 2800, number of negative: 9800
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001222 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 134
# [LightGBM] [Info] Number of data points in the train set: 12600, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.222222 -> initscore=-1.252763
# [LightGBM] [Info] Start training from score -1.252763
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Trained and Tested combination 292 of 3559500: (2, 2, 2, 0, 3, 2, 0), taking 0.19 seconds to get val score of 0.7778
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 2800, number of negative: 9800
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001308 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 134
# [LightGBM] [Info] Number of data points in the train set: 12600, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.222222 -> initscore=-1.252763
# [LightGBM] [Info] Start training from score -1.252763
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Trained and Tested combination 293 of 3559500: (2, 2, 2, 1, 3, 2, 0), taking 0.15 seconds to get val score of 0.7796
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648
# Already Trained and Tested combination (2, 2, 2, 2, 3, 2, 0), which had val score of 0.7793
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 293 of 3559500 combinations so far
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 2800, number of negative: 9800
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001395 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 134
# [LightGBM] [Info] Number of data points in the train set: 12600, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.222222 -> initscore=-1.252763
# [LightGBM] [Info] Start training from score -1.252763
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Trained and Tested combination 294 of 3559500: (2, 2, 2, 3, 3, 2, 0), taking 0.14 seconds to get val score of 0.7878
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 2800, number of negative: 9800
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001318 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 134
# [LightGBM] [Info] Number of data points in the train set: 12600, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.222222 -> initscore=-1.252763
# [LightGBM] [Info] Start training from score -1.252763
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: warnings
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Trained and Tested combination 295 of 3559500: (2, 2, 2, 4, 3, 2, 0), taking 0.16 seconds to get val score of 0.7915
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648
#
# Best combo after this hyperparameter: (5, 2, 2, 2, 4, 1, 77) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 2, 2, 2, 4, 1, 77), which had val score of 0.8144
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 1, 77), which had val score of 0.8285
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (2, 2, 2, 2, 4, 1, 77), which had val score of 0.8393
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 4, 1, 77), which had val score of 0.8481
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (4, 2, 2, 2, 4, 1, 77), which had val score of 0.8567
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 77), which had val score of 0.8648
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
#
# Best combo after this hyperparameter: (5, 2, 2, 2, 4, 1, 77) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: reg_alpha (index: 5)
#
# Already Trained and Tested combination (5, 2, 2, 2, 4, 0, 77), which had val score of 0.8585
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 77), which had val score of 0.8648
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 2, 77), which had val score of 0.8581
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 3, 77), which had val score of 0.8596
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 4, 77), which had val score of 0.8622
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 5, 77), which had val score of 0.8326
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
#
# Best combo after this hyperparameter: (5, 2, 2, 2, 4, 1, 77) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: learning_rate (index: 4)
#
# Already Trained and Tested combination (5, 2, 2, 2, 0, 1, 77), which had val score of 0.7778
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 1, 1, 77), which had val score of 0.7778
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 2, 1, 77), which had val score of 0.7778
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 3, 1, 77), which had val score of 0.8359
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 77), which had val score of 0.8648
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
#
# Best combo after this hyperparameter: (5, 2, 2, 2, 4, 1, 77) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: features (index: 6)
#
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 0), which had val score of 0.7874
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 1), which had val score of 0.7826
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 2), which had val score of 0.7837
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 3), which had val score of 0.7863
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 4), which had val score of 0.7856
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 5), which had val score of 0.7944
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 6), which had val score of 0.79
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 7), which had val score of 0.7933
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 8), which had val score of 0.7941
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 9), which had val score of 0.7907
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 10), which had val score of 0.8037
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 11), which had val score of 0.8015
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 12), which had val score of 0.8022
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 13), which had val score of 0.8026
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 295 of 3559500 combinations so far
# ...
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 95), which had val score of 0.8596
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 96), which had val score of 0.8615
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 97), which had val score of 0.86
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 98), which had val score of 0.8581
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 99), which had val score of 0.8611
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 100), which had val score of 0.8563
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 101), which had val score of 0.8596
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 102), which had val score of 0.8589
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 103), which had val score of 0.8559
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 104), which had val score of 0.86
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 105), which had val score of 0.8578
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 106), which had val score of 0.8585
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 107), which had val score of 0.8574
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 108), which had val score of 0.8581
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 109), which had val score of 0.8622
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 110), which had val score of 0.8552
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 111), which had val score of 0.8574
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 112), which had val score of 0.8615
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
#
# Best combo after this hyperparameter: (5, 2, 2, 2, 4, 1, 77) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (5, 0, 2, 2, 4, 1, 77), which had val score of 0.8344
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 1, 2, 2, 4, 1, 77), which had val score of 0.8567
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 77), which had val score of 0.8648
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 3, 2, 2, 4, 1, 77), which had val score of 0.8596
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 4, 1, 77), which had val score of 0.863
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 5, 2, 2, 4, 1, 77), which had val score of 0.863
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 6, 2, 2, 4, 1, 77), which had val score of 0.863
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
#
# Best combo after this hyperparameter: (5, 2, 2, 2, 4, 1, 77) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (5, 2, 0, 2, 4, 1, 77), which had val score of 0.8648
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 1, 2, 4, 1, 77), which had val score of 0.8648
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 77), which had val score of 0.8648
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 3, 2, 4, 1, 77), which had val score of 0.8648
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 4, 2, 4, 1, 77), which had val score of 0.8648
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
#
# Best combo after this hyperparameter: (5, 2, 2, 2, 4, 1, 77) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: colsample_bytree (index: 3)
#
# Already Trained and Tested combination (5, 2, 2, 0, 4, 1, 77), which had val score of 0.8585
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 1, 4, 1, 77), which had val score of 0.857
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 77), which had val score of 0.8648
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 3, 4, 1, 77), which had val score of 0.8593
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 4, 4, 1, 77), which had val score of 0.8552
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
#
# Best combo after this hyperparameter: (5, 2, 2, 2, 4, 1, 77) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 2, 2, 2, 4, 1, 77), which had val score of 0.8144
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 1, 77), which had val score of 0.8285
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (2, 2, 2, 2, 4, 1, 77), which had val score of 0.8393
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 4, 1, 77), which had val score of 0.8481
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (4, 2, 2, 2, 4, 1, 77), which had val score of 0.8567
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 77), which had val score of 0.8648
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
#
# Best combo after this hyperparameter: (5, 2, 2, 2, 4, 1, 77) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: reg_alpha (index: 5)
#
# Already Trained and Tested combination (5, 2, 2, 2, 4, 0, 77), which had val score of 0.8585
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 1, 77), which had val score of 0.8648
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 2, 77), which had val score of 0.8581
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 3, 77), which had val score of 0.8596
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 4, 77), which had val score of 0.8622
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 4, 5, 77), which had val score of 0.8326
#         Current best combo: (5, 2, 2, 2, 4, 1, 77) with val score 0.8648.
#         Has trained 309 of 3559500 combinations so far
#
# Best combo after this hyperparameter: (5, 2, 2, 2, 4, 1, 77) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.8648148148148148
# Max Test Score:
#  0.857037
# Max Combo Index:
#  (5, 2, 2, 2, 4, 1, 77) out of [6, 7, 5, 5, 5, 6, 113] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 800, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 77}
# Max Combo Features:
#  (29667, 59920, 41191, 9639, 11997, 14175, 66664, 7149, 6603, 32996, 3710, 4587, 14700, 25279, 27675, 67128, 66157, 67050, 68180, 7075, 59749, 20338, 28574, 35861, 36130, 3061, 22106, 11721, 13444, 9404, 14989, 567, 27004, 6826, 36615, 34203, 16127, 6771, 4193, 37572, 66519, 2160, 27889, 1762, 36120, 67094, 35137, 36623, 3677, 3863, 67659, 2359, 63650, 112, 67892, 37744, 60303, 68047, 9072, 17942, 9372, 27745, 6450, 13095, 5563, 40128, 2491, 34703, 13142, 57787, 64230, 49708, 4501, 17577, 44387, 13454, 59415, 6308, 23378, 43389, 13877, 56288, 12469, 67781, 50832, 66239, 47800, 52938, 66841, 5607, 3414, 52187, 32465, 45854, 65820, 8584, 31185, 2038, 1574, 3094, 500, 29750, 50043, 13792, 42802, 23414, 27046, 62724, 389, 13727, 1651, 67637, 2688, 67361, 23131, 9050, 16198, 17050, 44471, 15432, 3403, 29971, 1663, 39524, 10971, 16331, 16037, 41662, 34860, 30159, 15118, 17674, 39435, 26704, 2567, 67494, 6882, 12746, 7300, 58670, 29441, 36203, 14524, 68147, 18304, 29592, 48456, 6638, 15998, 29601, 898, 43055, 18791, 51366, 1120, 11229, 5082, 51794, 2522, 49870, 30337, 35352, 11926, 21109, 14423, 1774, 19240, 48631, 58751, 43307, 18584, 2060, 111, 3315, 10330, 4875, 710, 17607, 31239, 27581, 1629, 16422, 22771, 66508,