# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'xgbc'
FEATURE_IMPORTANCE_ORDERING = 'xgb'
PREPROCESSING = 'Baseline'
TUNER = 'jiaochengb'
FEATURE_ENGINEERING = 'tfidf'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle
from scipy.sparse import load_npz 

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/Research - Internet Addiction Part 1/PrivatePackages" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/Research - Internet Addiction Part 1/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
else:
    py_file_location = '../../PrivatePackages'
    home_directory = '../../'

sys.path.append(os.path.abspath(py_file_location))

from Tuners import JiaoChengB

import pandas as pd

# %%
## Parameters that are same for every script

SEED = 2608

TASK_TYPE = 'Classification' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = True # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from xgboost import XGBClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
        'n_estimators': (25, 50, 100, 200, 400, 800),
        'max_depth': (3, 6, 12, 24, 48, 96, 192),
        'subsample': (0.4, 0.55, 0.7, 0.85, 1),
        'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
        'gamma': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
        'eta': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    'n_jobs': -1
                                    }

tuning_order = [
    'features',
    'max_depth',
    'subsample',
    'colsample_bytree',
    'n_estimators',
    'gamma',
    'eta',
]

default_hyperparameter_values = {'n_estimators': 100, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.01, 'eta': 0.01, 'features': 0}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_x = load_npz(home_directory + f'data/curated/baseline/train_{FEATURE_ENGINEERING}_x.npz')
val_x = load_npz(home_directory + f'data/curated/baseline/val_{FEATURE_ENGINEERING}_x.npz')
test_x = load_npz(home_directory + f'data/curated/baseline/test_{FEATURE_ENGINEERING}_x.npz')

with open(home_directory + 'data/curated/baseline/train_y.pkl', 'rb') as f:
    train_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/val_y.pkl', 'rb') as f:
    val_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/test_y.pkl', 'rb') as f:
    test_y = pickle.load(f)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = JiaoChengB.JiaoChengB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'xgboost.sklearn.XGBClassifier'>, which is a Classification model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# FEATURE_INDEX: 0 (n_estimators) ROUND 1
#
# Round 1
# Hyperparameter: features (index: 6)
#
# Trained and Tested combination 1 of 2929500: (2, 2, 2, 2, 3, 2, 0), taking 2.59 seconds to get val score of 0.7781
#         Current best combo: (2, 2, 2, 2, 3, 2, 0) with val score 0.7781
# Trained and Tested combination 2 of 2929500: (2, 2, 2, 2, 3, 2, 1), taking 3.24 seconds to get val score of 0.783
#         Current best combo: (2, 2, 2, 2, 3, 2, 1) with val score 0.783
# Trained and Tested combination 3 of 2929500: (2, 2, 2, 2, 3, 2, 2), taking 1.85 seconds to get val score of 0.7896
#         Current best combo: (2, 2, 2, 2, 3, 2, 2) with val score 0.7896
# Trained and Tested combination 4 of 2929500: (2, 2, 2, 2, 3, 2, 3), taking 1.69 seconds to get val score of 0.7896
#         Current best combo: (2, 2, 2, 2, 3, 2, 2) with val score 0.7896
# Trained and Tested combination 5 of 2929500: (2, 2, 2, 2, 3, 2, 4), taking 1.93 seconds to get val score of 0.7911
#         Current best combo: (2, 2, 2, 2, 3, 2, 4) with val score 0.7911
# Trained and Tested combination 6 of 2929500: (2, 2, 2, 2, 3, 2, 5), taking 2.12 seconds to get val score of 0.7889
#         Current best combo: (2, 2, 2, 2, 3, 2, 4) with val score 0.7911
# Trained and Tested combination 7 of 2929500: (2, 2, 2, 2, 3, 2, 6), taking 2.58 seconds to get val score of 0.7893
#         Current best combo: (2, 2, 2, 2, 3, 2, 4) with val score 0.7911
# Trained and Tested combination 8 of 2929500: (2, 2, 2, 2, 3, 2, 7), taking 3.0 seconds to get val score of 0.793
#         Current best combo: (2, 2, 2, 2, 3, 2, 7) with val score 0.793
# Trained and Tested combination 9 of 2929500: (2, 2, 2, 2, 3, 2, 8), taking 3.25 seconds to get val score of 0.793
#         Current best combo: (2, 2, 2, 2, 3, 2, 7) with val score 0.793
# Trained and Tested combination 10 of 2929500: (2, 2, 2, 2, 3, 2, 9), taking 5.66 seconds to get val score of 0.7944
#         Current best combo: (2, 2, 2, 2, 3, 2, 9) with val score 0.7944
# Trained and Tested combination 11 of 2929500: (2, 2, 2, 2, 3, 2, 10), taking 6.1 seconds to get val score of 0.793
#         Current best combo: (2, 2, 2, 2, 3, 2, 9) with val score 0.7944
# Trained and Tested combination 12 of 2929500: (2, 2, 2, 2, 3, 2, 11), taking 7.5 seconds to get val score of 0.7941
#         Current best combo: (2, 2, 2, 2, 3, 2, 9) with val score 0.7944
# Trained and Tested combination 13 of 2929500: (2, 2, 2, 2, 3, 2, 12), taking 7.28 seconds to get val score of 0.7948
#         Current best combo: (2, 2, 2, 2, 3, 2, 12) with val score 0.7948
# Trained and Tested combination 14 of 2929500: (2, 2, 2, 2, 3, 2, 13), taking 9.04 seconds to get val score of 0.7948
#         Current best combo: (2, 2, 2, 2, 3, 2, 12) with val score 0.7948
# Trained and Tested combination 15 of 2929500: (2, 2, 2, 2, 3, 2, 14), taking 5.9 seconds to get val score of 0.7933
#         Current best combo: (2, 2, 2, 2, 3, 2, 12) with val score 0.7948
# Trained and Tested combination 16 of 2929500: (2, 2, 2, 2, 3, 2, 15), taking 9.22 seconds to get val score of 0.7933
#         Current best combo: (2, 2, 2, 2, 3, 2, 12) with val score 0.7948
# Trained and Tested combination 17 of 2929500: (2, 2, 2, 2, 3, 2, 16), taking 7.47 seconds to get val score of 0.7919
#         Current best combo: (2, 2, 2, 2, 3, 2, 12) with val score 0.7948
# Trained and Tested combination 18 of 2929500: (2, 2, 2, 2, 3, 2, 17), taking 10.51 seconds to get val score of 0.7941
#         Current best combo: (2, 2, 2, 2, 3, 2, 12) with val score 0.7948
# Trained and Tested combination 19 of 2929500: (2, 2, 2, 2, 3, 2, 18), taking 9.5 seconds to get val score of 0.7959
#         Current best combo: (2, 2, 2, 2, 3, 2, 18) with val score 0.7959
# Trained and Tested combination 20 of 2929500: (2, 2, 2, 2, 3, 2, 19), taking 9.79 seconds to get val score of 0.793
#         Current best combo: (2, 2, 2, 2, 3, 2, 18) with val score 0.7959
# Trained and Tested combination 21 of 2929500: (2, 2, 2, 2, 3, 2, 20), taking 11.35 seconds to get val score of 0.7952
#         Current best combo: (2, 2, 2, 2, 3, 2, 18) with val score 0.7959
# Trained and Tested combination 22 of 2929500: (2, 2, 2, 2, 3, 2, 21), taking 11.2 seconds to get val score of 0.7959
#         Current best combo: (2, 2, 2, 2, 3, 2, 18) with val score 0.7959
# Trained and Tested combination 23 of 2929500: (2, 2, 2, 2, 3, 2, 22), taking 10.01 seconds to get val score of 0.7937
#         Current best combo: (2, 2, 2, 2, 3, 2, 18) with val score 0.7959
# Trained and Tested combination 24 of 2929500: (2, 2, 2, 2, 3, 2, 23), taking 12.01 seconds to get val score of 0.7963
#         Current best combo: (2, 2, 2, 2, 3, 2, 23) with val score 0.7963
# Trained and Tested combination 25 of 2929500: (2, 2, 2, 2, 3, 2, 24), taking 10.88 seconds to get val score of 0.7952
#         Current best combo: (2, 2, 2, 2, 3, 2, 23) with val score 0.7963
# Trained and Tested combination 26 of 2929500: (2, 2, 2, 2, 3, 2, 25), taking 13.11 seconds to get val score of 0.7952
#         Current best combo: (2, 2, 2, 2, 3, 2, 23) with val score 0.7963
# Trained and Tested combination 27 of 2929500: (2, 2, 2, 2, 3, 2, 26), taking 11.83 seconds to get val score of 0.7944
#         Current best combo: (2, 2, 2, 2, 3, 2, 23) with val score 0.7963
# Trained and Tested combination 28 of 2929500: (2, 2, 2, 2, 3, 2, 27), taking 13.57 seconds to get val score of 0.7985
#         Current best combo: (2, 2, 2, 2, 3, 2, 27) with val score 0.7985
# Trained and Tested combination 29 of 2929500: (2, 2, 2, 2, 3, 2, 28), taking 12.57 seconds to get val score of 0.7989
#         Current best combo: (2, 2, 2, 2, 3, 2, 28) with val score 0.7989
# Trained and Tested combination 30 of 2929500: (2, 2, 2, 2, 3, 2, 29), taking 12.17 seconds to get val score of 0.8004
#         Current best combo: (2, 2, 2, 2, 3, 2, 29) with val score 0.8004
# Trained and Tested combination 31 of 2929500: (2, 2, 2, 2, 3, 2, 30), taking 12.66 seconds to get val score of 0.7989
#         Current best combo: (2, 2, 2, 2, 3, 2, 29) with val score 0.8004
# Trained and Tested combination 32 of 2929500: (2, 2, 2, 2, 3, 2, 31), taking 13.16 seconds to get val score of 0.7963
#         Current best combo: (2, 2, 2, 2, 3, 2, 29) with val score 0.8004
# Trained and Tested combination 33 of 2929500: (2, 2, 2, 2, 3, 2, 32), taking 14.06 seconds to get val score of 0.7996
#         Current best combo: (2, 2, 2, 2, 3, 2, 29) with val score 0.8004
# Trained and Tested combination 34 of 2929500: (2, 2, 2, 2, 3, 2, 33), taking 14.34 seconds to get val score of 0.8004
#         Current best combo: (2, 2, 2, 2, 3, 2, 29) with val score 0.8004
# Trained and Tested combination 35 of 2929500: (2, 2, 2, 2, 3, 2, 34), taking 17.87 seconds to get val score of 0.7985
#         Current best combo: (2, 2, 2, 2, 3, 2, 29) with val score 0.8004
# Trained and Tested combination 36 of 2929500: (2, 2, 2, 2, 3, 2, 35), taking 15.65 seconds to get val score of 0.7963
#         Current best combo: (2, 2, 2, 2, 3, 2, 29) with val score 0.8004
# Trained and Tested combination 37 of 2929500: (2, 2, 2, 2, 3, 2, 36), taking 16.62 seconds to get val score of 0.7985
#         Current best combo: (2, 2, 2, 2, 3, 2, 29) with val score 0.8004
# Trained and Tested combination 38 of 2929500: (2, 2, 2, 2, 3, 2, 37), taking 16.82 seconds to get val score of 0.7993
#         Current best combo: (2, 2, 2, 2, 3, 2, 29) with val score 0.8004
# Trained and Tested combination 39 of 2929500: (2, 2, 2, 2, 3, 2, 38), taking 16.86 seconds to get val score of 0.7978
#         Current best combo: (2, 2, 2, 2, 3, 2, 29) with val score 0.8004
# Trained and Tested combination 40 of 2929500: (2, 2, 2, 2, 3, 2, 39), taking 17.78 seconds to get val score of 0.7985
#         Current best combo: (2, 2, 2, 2, 3, 2, 29) with val score 0.8004
# Trained and Tested combination 41 of 2929500: (2, 2, 2, 2, 3, 2, 40), taking 17.38 seconds to get val score of 0.7981
#         Current best combo: (2, 2, 2, 2, 3, 2, 29) with val score 0.8004
# Trained and Tested combination 42 of 2929500: (2, 2, 2, 2, 3, 2, 41), taking 18.28 seconds to get val score of 0.8004
#         Current best combo: (2, 2, 2, 2, 3, 2, 29) with val score 0.8004
# Trained and Tested combination 43 of 2929500: (2, 2, 2, 2, 3, 2, 42), taking 23.02 seconds to get val score of 0.8
#         Current best combo: (2, 2, 2, 2, 3, 2, 29) with val score 0.8004
# Trained and Tested combination 44 of 2929500: (2, 2, 2, 2, 3, 2, 43), taking 20.4 seconds to get val score of 0.7996
#         Current best combo: (2, 2, 2, 2, 3, 2, 29) with val score 0.8004
# Trained and Tested combination 45 of 2929500: (2, 2, 2, 2, 3, 2, 44), taking 23.17 seconds to get val score of 0.797
#         Current best combo: (2, 2, 2, 2, 3, 2, 29) with val score 0.8004
# Trained and Tested combination 46 of 2929500: (2, 2, 2, 2, 3, 2, 45), taking 22.29 seconds to get val score of 0.7989
#         Current best combo: (2, 2, 2, 2, 3, 2, 29) with val score 0.8004
# Trained and Tested combination 47 of 2929500: (2, 2, 2, 2, 3, 2, 46), taking 19.48 seconds to get val score of 0.8011
#         Current best combo: (2, 2, 2, 2, 3, 2, 46) with val score 0.8011
# Trained and Tested combination 48 of 2929500: (2, 2, 2, 2, 3, 2, 47), taking 19.02 seconds to get val score of 0.7974
#         Current best combo: (2, 2, 2, 2, 3, 2, 46) with val score 0.8011
# Trained and Tested combination 49 of 2929500: (2, 2, 2, 2, 3, 2, 48), taking 20.86 seconds to get val score of 0.8019
#         Current best combo: (2, 2, 2, 2, 3, 2, 48) with val score 0.8019
# Trained and Tested combination 50 of 2929500: (2, 2, 2, 2, 3, 2, 49), taking 26.38 seconds to get val score of 0.7963
#         Current best combo: (2, 2, 2, 2, 3, 2, 48) with val score 0.8019
# Trained and Tested combination 51 of 2929500: (2, 2, 2, 2, 3, 2, 50), taking 24.89 seconds to get val score of 0.7989
#         Current best combo: (2, 2, 2, 2, 3, 2, 48) with val score 0.8019
# Trained and Tested combination 52 of 2929500: (2, 2, 2, 2, 3, 2, 51), taking 22.43 seconds to get val score of 0.8015
#         Current best combo: (2, 2, 2, 2, 3, 2, 48) with val score 0.8019
# Trained and Tested combination 53 of 2929500: (2, 2, 2, 2, 3, 2, 52), taking 23.82 seconds to get val score of 0.8
#         Current best combo: (2, 2, 2, 2, 3, 2, 48) with val score 0.8019
# Trained and Tested combination 54 of 2929500: (2, 2, 2, 2, 3, 2, 53), taking 25.25 seconds to get val score of 0.8037
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 55 of 2929500: (2, 2, 2, 2, 3, 2, 54), taking 25.79 seconds to get val score of 0.8004
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 56 of 2929500: (2, 2, 2, 2, 3, 2, 55), taking 28.92 seconds to get val score of 0.8026
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 57 of 2929500: (2, 2, 2, 2, 3, 2, 56), taking 30.59 seconds to get val score of 0.8004
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 58 of 2929500: (2, 2, 2, 2, 3, 2, 57), taking 27.47 seconds to get val score of 0.8
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 59 of 2929500: (2, 2, 2, 2, 3, 2, 58), taking 29.1 seconds to get val score of 0.8019
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 60 of 2929500: (2, 2, 2, 2, 3, 2, 59), taking 25.91 seconds to get val score of 0.8011
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 61 of 2929500: (2, 2, 2, 2, 3, 2, 60), taking 28.5 seconds to get val score of 0.7985
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 62 of 2929500: (2, 2, 2, 2, 3, 2, 61), taking 25.18 seconds to get val score of 0.803
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 63 of 2929500: (2, 2, 2, 2, 3, 2, 62), taking 26.24 seconds to get val score of 0.8033
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 64 of 2929500: (2, 2, 2, 2, 3, 2, 63), taking 27.82 seconds to get val score of 0.7974
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 65 of 2929500: (2, 2, 2, 2, 3, 2, 64), taking 27.37 seconds to get val score of 0.8
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 66 of 2929500: (2, 2, 2, 2, 3, 2, 65), taking 28.31 seconds to get val score of 0.7981
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 67 of 2929500: (2, 2, 2, 2, 3, 2, 66), taking 29.11 seconds to get val score of 0.803
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 68 of 2929500: (2, 2, 2, 2, 3, 2, 67), taking 33.35 seconds to get val score of 0.7989
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 69 of 2929500: (2, 2, 2, 2, 3, 2, 68), taking 37.94 seconds to get val score of 0.8015
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 70 of 2929500: (2, 2, 2, 2, 3, 2, 69), taking 31.13 seconds to get val score of 0.7996
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 71 of 2929500: (2, 2, 2, 2, 3, 2, 70), taking 32.05 seconds to get val score of 0.7985
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 72 of 2929500: (2, 2, 2, 2, 3, 2, 71), taking 31.27 seconds to get val score of 0.7993
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 73 of 2929500: (2, 2, 2, 2, 3, 2, 72), taking 31.27 seconds to get val score of 0.7996
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 74 of 2929500: (2, 2, 2, 2, 3, 2, 73), taking 32.01 seconds to get val score of 0.8004
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 75 of 2929500: (2, 2, 2, 2, 3, 2, 74), taking 37.77 seconds to get val score of 0.7956
#         Current best combo: (2, 2, 2, 2, 3, 2, 53) with val score 0.8037
# Trained and Tested combination 76 of 2929500: (2, 2, 2, 2, 3, 2, 75), taking 41.71 seconds to get val score of 0.8041
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 77 of 2929500: (2, 2, 2, 2, 3, 2, 76), taking 36.72 seconds to get val score of 0.8007
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 78 of 2929500: (2, 2, 2, 2, 3, 2, 77), taking 36.94 seconds to get val score of 0.8004
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 79 of 2929500: (2, 2, 2, 2, 3, 2, 78), taking 39.79 seconds to get val score of 0.8037
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 80 of 2929500: (2, 2, 2, 2, 3, 2, 79), taking 37.14 seconds to get val score of 0.8004
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 81 of 2929500: (2, 2, 2, 2, 3, 2, 80), taking 40.69 seconds to get val score of 0.8019
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 82 of 2929500: (2, 2, 2, 2, 3, 2, 81), taking 54.84 seconds to get val score of 0.7978
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 83 of 2929500: (2, 2, 2, 2, 3, 2, 82), taking 51.14 seconds to get val score of 0.8015
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 84 of 2929500: (2, 2, 2, 2, 3, 2, 83), taking 52.82 seconds to get val score of 0.7978
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 85 of 2929500: (2, 2, 2, 2, 3, 2, 84), taking 62.57 seconds to get val score of 0.8015
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 86 of 2929500: (2, 2, 2, 2, 3, 2, 85), taking 56.01 seconds to get val score of 0.803
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 87 of 2929500: (2, 2, 2, 2, 3, 2, 86), taking 47.68 seconds to get val score of 0.8
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 88 of 2929500: (2, 2, 2, 2, 3, 2, 87), taking 54.44 seconds to get val score of 0.8007
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 89 of 2929500: (2, 2, 2, 2, 3, 2, 88), taking 62.26 seconds to get val score of 0.7989
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 90 of 2929500: (2, 2, 2, 2, 3, 2, 89), taking 53.04 seconds to get val score of 0.8015
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 91 of 2929500: (2, 2, 2, 2, 3, 2, 90), taking 53.84 seconds to get val score of 0.8015
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 92 of 2929500: (2, 2, 2, 2, 3, 2, 91), taking 51.2 seconds to get val score of 0.7967
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 93 of 2929500: (2, 2, 2, 2, 3, 2, 92), taking 53.84 seconds to get val score of 0.8011
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
#
# Best combo after this hyperparameter: (2, 2, 2, 2, 3, 2, 75) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_depth (index: 1)
#
# Trained and Tested combination 94 of 2929500: (2, 0, 2, 2, 3, 2, 75), taking 2.58 seconds to get val score of 0.7778
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Trained and Tested combination 95 of 2929500: (2, 1, 2, 2, 3, 2, 75), taking 11.56 seconds to get val score of 0.79
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041
# Already Trained and Tested combination (2, 2, 2, 2, 3, 2, 75), which had val score of 0.8041
#         Current best combo: (2, 2, 2, 2, 3, 2, 75) with val score 0.8041.
#         Has trained 95 of 2929500 combinations so far
# Trained and Tested combination 96 of 2929500: (2, 3, 2, 2, 3, 2, 75), taking 99.07 seconds to get val score of 0.8052
#         Current best combo: (2, 3, 2, 2, 3, 2, 75) with val score 0.8052
# Trained and Tested combination 97 of 2929500: (2, 4, 2, 2, 3, 2, 75), taking 234.88 seconds to get val score of 0.8033
#         Current best combo: (2, 3, 2, 2, 3, 2, 75) with val score 0.8052
# Trained and Tested combination 98 of 2929500: (2, 5, 2, 2, 3, 2, 75), taking 209.34 seconds to get val score of 0.8048
#         Current best combo: (2, 3, 2, 2, 3, 2, 75) with val score 0.8052
# Trained and Tested combination 99 of 2929500: (2, 6, 2, 2, 3, 2, 75), taking 219.22 seconds to get val score of 0.8048
#         Current best combo: (2, 3, 2, 2, 3, 2, 75) with val score 0.8052
#
# Best combo after this hyperparameter: (2, 3, 2, 2, 3, 2, 75) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: subsample (index: 2)
#
# Trained and Tested combination 100 of 2929500: (2, 3, 0, 2, 3, 2, 75), taking 64.34 seconds to get val score of 0.7985
#         Current best combo: (2, 3, 2, 2, 3, 2, 75) with val score 0.8052
# Trained and Tested combination 101 of 2929500: (2, 3, 1, 2, 3, 2, 75), taking 67.38 seconds to get val score of 0.8015
#         Current best combo: (2, 3, 2, 2, 3, 2, 75) with val score 0.8052
# Already Trained and Tested combination (2, 3, 2, 2, 3, 2, 75), which had val score of 0.8052
#         Current best combo: (2, 3, 2, 2, 3, 2, 75) with val score 0.8052.
#         Has trained 101 of 2929500 combinations so far
# Trained and Tested combination 102 of 2929500: (2, 3, 3, 2, 3, 2, 75), taking 136.67 seconds to get val score of 0.807
#         Current best combo: (2, 3, 3, 2, 3, 2, 75) with val score 0.807
# Trained and Tested combination 103 of 2929500: (2, 3, 4, 2, 3, 2, 75), taking 156.04 seconds to get val score of 0.8093
#         Current best combo: (2, 3, 4, 2, 3, 2, 75) with val score 0.8093
#
# Best combo after this hyperparameter: (2, 3, 4, 2, 3, 2, 75) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: colsample_bytree (index: 3)
#
# Trained and Tested combination 104 of 2929500: (2, 3, 4, 0, 3, 2, 75), taking 63.95 seconds to get val score of 0.7952
#         Current best combo: (2, 3, 4, 2, 3, 2, 75) with val score 0.8093
# Trained and Tested combination 105 of 2929500: (2, 3, 4, 1, 3, 2, 75), taking 61.84 seconds to get val score of 0.8026
#         Current best combo: (2, 3, 4, 2, 3, 2, 75) with val score 0.8093
# Already Trained and Tested combination (2, 3, 4, 2, 3, 2, 75), which had val score of 0.8093
#         Current best combo: (2, 3, 4, 2, 3, 2, 75) with val score 0.8093.
#         Has trained 105 of 2929500 combinations so far
# Trained and Tested combination 106 of 2929500: (2, 3, 4, 3, 3, 2, 75), taking 97.96 seconds to get val score of 0.8119
#         Current best combo: (2, 3, 4, 3, 3, 2, 75) with val score 0.8119
# Trained and Tested combination 107 of 2929500: (2, 3, 4, 4, 3, 2, 75), taking 129.05 seconds to get val score of 0.8163
#         Current best combo: (2, 3, 4, 4, 3, 2, 75) with val score 0.8163
#
# Best combo after this hyperparameter: (2, 3, 4, 4, 3, 2, 75) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: n_estimators (index: 0)
#
# Trained and Tested combination 108 of 2929500: (0, 3, 4, 4, 3, 2, 75), taking 33.37 seconds to get val score of 0.7778
#         Current best combo: (2, 3, 4, 4, 3, 2, 75) with val score 0.8163
# Trained and Tested combination 109 of 2929500: (1, 3, 4, 4, 3, 2, 75), taking 65.39 seconds to get val score of 0.7826
#         Current best combo: (2, 3, 4, 4, 3, 2, 75) with val score 0.8163
# Already Trained and Tested combination (2, 3, 4, 4, 3, 2, 75), which had val score of 0.8163
#         Current best combo: (2, 3, 4, 4, 3, 2, 75) with val score 0.8163.
#         Has trained 109 of 2929500 combinations so far
# Trained and Tested combination 110 of 2929500: (3, 3, 4, 4, 3, 2, 75), taking 233.73 seconds to get val score of 0.8315
#         Current best combo: (3, 3, 4, 4, 3, 2, 75) with val score 0.8315
# Trained and Tested combination 111 of 2929500: (4, 3, 4, 4, 3, 2, 75), taking 354.8 seconds to get val score of 0.8422
#         Current best combo: (4, 3, 4, 4, 3, 2, 75) with val score 0.8422
# Trained and Tested combination 112 of 2929500: (5, 3, 4, 4, 3, 2, 75), taking 367.37 seconds to get val score of 0.8489
#         Current best combo: (5, 3, 4, 4, 3, 2, 75) with val score 0.8489
#
# Best combo after this hyperparameter: (5, 3, 4, 4, 3, 2, 75) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: gamma (index: 4)
#
# Trained and Tested combination 113 of 2929500: (5, 3, 4, 4, 0, 2, 75), taking 371.11 seconds to get val score of 0.8481
#         Current best combo: (5, 3, 4, 4, 3, 2, 75) with val score 0.8489
# Trained and Tested combination 114 of 2929500: (5, 3, 4, 4, 1, 2, 75), taking 372.53 seconds to get val score of 0.8481
#         Current best combo: (5, 3, 4, 4, 3, 2, 75) with val score 0.8489
# Trained and Tested combination 115 of 2929500: (5, 3, 4, 4, 2, 2, 75), taking 367.95 seconds to get val score of 0.8511
#         Current best combo: (5, 3, 4, 4, 2, 2, 75) with val score 0.8511
# Already Trained and Tested combination (5, 3, 4, 4, 3, 2, 75), which had val score of 0.8489
#         Current best combo: (5, 3, 4, 4, 2, 2, 75) with val score 0.8511.
#         Has trained 115 of 2929500 combinations so far
# Trained and Tested combination 116 of 2929500: (5, 3, 4, 4, 4, 2, 75), taking 356.0 seconds to get val score of 0.8485
#         Current best combo: (5, 3, 4, 4, 2, 2, 75) with val score 0.8511
#
# Best combo after this hyperparameter: (5, 3, 4, 4, 2, 2, 75) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: eta (index: 5)
#
# Trained and Tested combination 117 of 2929500: (5, 3, 4, 4, 2, 0, 75), taking 652.76 seconds to get val score of 0.7778
#         Current best combo: (5, 3, 4, 4, 2, 2, 75) with val score 0.8511
# Trained and Tested combination 118 of 2929500: (5, 3, 4, 4, 2, 1, 75), taking 744.83 seconds to get val score of 0.8015
#         Current best combo: (5, 3, 4, 4, 2, 2, 75) with val score 0.8511
# Already Trained and Tested combination (5, 3, 4, 4, 2, 2, 75), which had val score of 0.8511
#         Current best combo: (5, 3, 4, 4, 2, 2, 75) with val score 0.8511.
#         Has trained 118 of 2929500 combinations so far
# Trained and Tested combination 119 of 2929500: (5, 3, 4, 4, 2, 3, 75), taking 117.41 seconds to get val score of 0.8607
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 120 of 2929500: (5, 3, 4, 4, 2, 4, 75), taking 24.71 seconds to get val score of 0.8452
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 121 of 2929500: (5, 3, 4, 4, 2, 5, 75), taking 4.95 seconds to get val score of 0.767
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
#
# Best combo after this hyperparameter: (5, 3, 4, 4, 2, 3, 75) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 0 (n_estimators) ROUND 2
#
# Round 2
# Hyperparameter: features (index: 6)
#
# Trained and Tested combination 122 of 2929500: (5, 3, 4, 4, 2, 3, 0), taking 3.99 seconds to get val score of 0.7696
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 123 of 2929500: (5, 3, 4, 4, 2, 3, 1), taking 8.62 seconds to get val score of 0.7733
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 124 of 2929500: (5, 3, 4, 4, 2, 3, 2), taking 11.15 seconds to get val score of 0.7752
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 125 of 2929500: (5, 3, 4, 4, 2, 3, 3), taking 13.06 seconds to get val score of 0.7767
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 126 of 2929500: (5, 3, 4, 4, 2, 3, 4), taking 15.34 seconds to get val score of 0.7741
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 127 of 2929500: (5, 3, 4, 4, 2, 3, 5), taking 14.55 seconds to get val score of 0.7789
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 128 of 2929500: (5, 3, 4, 4, 2, 3, 6), taking 17.39 seconds to get val score of 0.7844
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 129 of 2929500: (5, 3, 4, 4, 2, 3, 7), taking 20.13 seconds to get val score of 0.7819
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 130 of 2929500: (5, 3, 4, 4, 2, 3, 8), taking 23.17 seconds to get val score of 0.7896
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 131 of 2929500: (5, 3, 4, 4, 2, 3, 9), taking 25.5 seconds to get val score of 0.7948
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 132 of 2929500: (5, 3, 4, 4, 2, 3, 10), taking 27.47 seconds to get val score of 0.7996
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 133 of 2929500: (5, 3, 4, 4, 2, 3, 11), taking 28.63 seconds to get val score of 0.7978
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 134 of 2929500: (5, 3, 4, 4, 2, 3, 12), taking 32.38 seconds to get val score of 0.8078
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 135 of 2929500: (5, 3, 4, 4, 2, 3, 13), taking 34.97 seconds to get val score of 0.8144
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 136 of 2929500: (5, 3, 4, 4, 2, 3, 14), taking 34.51 seconds to get val score of 0.8133
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 137 of 2929500: (5, 3, 4, 4, 2, 3, 15), taking 34.89 seconds to get val score of 0.8174
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 138 of 2929500: (5, 3, 4, 4, 2, 3, 16), taking 39.23 seconds to get val score of 0.8119
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 139 of 2929500: (5, 3, 4, 4, 2, 3, 17), taking 40.83 seconds to get val score of 0.82
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 140 of 2929500: (5, 3, 4, 4, 2, 3, 18), taking 41.66 seconds to get val score of 0.8167
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 141 of 2929500: (5, 3, 4, 4, 2, 3, 19), taking 40.9 seconds to get val score of 0.8178
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 142 of 2929500: (5, 3, 4, 4, 2, 3, 20), taking 45.09 seconds to get val score of 0.8163
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 143 of 2929500: (5, 3, 4, 4, 2, 3, 21), taking 46.49 seconds to get val score of 0.8156
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 144 of 2929500: (5, 3, 4, 4, 2, 3, 22), taking 47.11 seconds to get val score of 0.8215
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 145 of 2929500: (5, 3, 4, 4, 2, 3, 23), taking 46.81 seconds to get val score of 0.8207
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 146 of 2929500: (5, 3, 4, 4, 2, 3, 24), taking 52.87 seconds to get val score of 0.8211
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 147 of 2929500: (5, 3, 4, 4, 2, 3, 25), taking 53.92 seconds to get val score of 0.8204
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 148 of 2929500: (5, 3, 4, 4, 2, 3, 26), taking 54.58 seconds to get val score of 0.8174
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 149 of 2929500: (5, 3, 4, 4, 2, 3, 27), taking 53.49 seconds to get val score of 0.827
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 150 of 2929500: (5, 3, 4, 4, 2, 3, 28), taking 56.72 seconds to get val score of 0.84
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 151 of 2929500: (5, 3, 4, 4, 2, 3, 29), taking 58.28 seconds to get val score of 0.8378
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 152 of 2929500: (5, 3, 4, 4, 2, 3, 30), taking 58.77 seconds to get val score of 0.8367
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 153 of 2929500: (5, 3, 4, 4, 2, 3, 31), taking 57.2 seconds to get val score of 0.8352
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 154 of 2929500: (5, 3, 4, 4, 2, 3, 32), taking 61.7 seconds to get val score of 0.8348
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 155 of 2929500: (5, 3, 4, 4, 2, 3, 33), taking 63.62 seconds to get val score of 0.8393
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 156 of 2929500: (5, 3, 4, 4, 2, 3, 34), taking 64.23 seconds to get val score of 0.8433
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 157 of 2929500: (5, 3, 4, 4, 2, 3, 35), taking 63.74 seconds to get val score of 0.8407
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 158 of 2929500: (5, 3, 4, 4, 2, 3, 36), taking 68.01 seconds to get val score of 0.8415
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 159 of 2929500: (5, 3, 4, 4, 2, 3, 37), taking 68.94 seconds to get val score of 0.8396
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 160 of 2929500: (5, 3, 4, 4, 2, 3, 38), taking 69.96 seconds to get val score of 0.84
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 161 of 2929500: (5, 3, 4, 4, 2, 3, 39), taking 67.5 seconds to get val score of 0.8441
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 162 of 2929500: (5, 3, 4, 4, 2, 3, 40), taking 72.8 seconds to get val score of 0.8419
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 163 of 2929500: (5, 3, 4, 4, 2, 3, 41), taking 74.64 seconds to get val score of 0.843
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 164 of 2929500: (5, 3, 4, 4, 2, 3, 42), taking 74.44 seconds to get val score of 0.8474
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 165 of 2929500: (5, 3, 4, 4, 2, 3, 43), taking 73.17 seconds to get val score of 0.8485
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 166 of 2929500: (5, 3, 4, 4, 2, 3, 44), taking 77.38 seconds to get val score of 0.8478
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 167 of 2929500: (5, 3, 4, 4, 2, 3, 45), taking 78.41 seconds to get val score of 0.8504
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 168 of 2929500: (5, 3, 4, 4, 2, 3, 46), taking 80.67 seconds to get val score of 0.8489
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 169 of 2929500: (5, 3, 4, 4, 2, 3, 47), taking 78.82 seconds to get val score of 0.8481
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 170 of 2929500: (5, 3, 4, 4, 2, 3, 48), taking 84.49 seconds to get val score of 0.8504
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 171 of 2929500: (5, 3, 4, 4, 2, 3, 49), taking 83.82 seconds to get val score of 0.8504
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 172 of 2929500: (5, 3, 4, 4, 2, 3, 50), taking 85.55 seconds to get val score of 0.8489
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 173 of 2929500: (5, 3, 4, 4, 2, 3, 51), taking 81.62 seconds to get val score of 0.8526
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 174 of 2929500: (5, 3, 4, 4, 2, 3, 52), taking 87.51 seconds to get val score of 0.8574
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 175 of 2929500: (5, 3, 4, 4, 2, 3, 53), taking 85.59 seconds to get val score of 0.8581
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 176 of 2929500: (5, 3, 4, 4, 2, 3, 54), taking 87.73 seconds to get val score of 0.8522
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 177 of 2929500: (5, 3, 4, 4, 2, 3, 55), taking 86.18 seconds to get val score of 0.8515
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 178 of 2929500: (5, 3, 4, 4, 2, 3, 56), taking 99.84 seconds to get val score of 0.8559
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 179 of 2929500: (5, 3, 4, 4, 2, 3, 57), taking 93.64 seconds to get val score of 0.8556
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 180 of 2929500: (5, 3, 4, 4, 2, 3, 58), taking 102.05 seconds to get val score of 0.8593
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 181 of 2929500: (5, 3, 4, 4, 2, 3, 59), taking 91.41 seconds to get val score of 0.8522
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 182 of 2929500: (5, 3, 4, 4, 2, 3, 60), taking 93.16 seconds to get val score of 0.8559
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 183 of 2929500: (5, 3, 4, 4, 2, 3, 61), taking 91.56 seconds to get val score of 0.8567
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 184 of 2929500: (5, 3, 4, 4, 2, 3, 62), taking 92.81 seconds to get val score of 0.857
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 185 of 2929500: (5, 3, 4, 4, 2, 3, 63), taking 90.2 seconds to get val score of 0.857
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 186 of 2929500: (5, 3, 4, 4, 2, 3, 64), taking 94.33 seconds to get val score of 0.8567
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 187 of 2929500: (5, 3, 4, 4, 2, 3, 65), taking 96.64 seconds to get val score of 0.8552
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 188 of 2929500: (5, 3, 4, 4, 2, 3, 66), taking 97.02 seconds to get val score of 0.8585
#         Current best combo: (5, 3, 4, 4, 2, 3, 75) with val score 0.8607
# Trained and Tested combination 189 of 2929500: (5, 3, 4, 4, 2, 3, 67), taking 94.48 seconds to get val score of 0.8619
#         Current best combo: (5, 3, 4, 4, 2, 3, 67) with val score 0.8619
# Trained and Tested combination 190 of 2929500: (5, 3, 4, 4, 2, 3, 68), taking 100.85 seconds to get val score of 0.8559
#         Current best combo: (5, 3, 4, 4, 2, 3, 67) with val score 0.8619
# Trained and Tested combination 191 of 2929500: (5, 3, 4, 4, 2, 3, 69), taking 99.88 seconds to get val score of 0.8593
#         Current best combo: (5, 3, 4, 4, 2, 3, 67) with val score 0.8619
# Trained and Tested combination 192 of 2929500: (5, 3, 4, 4, 2, 3, 70), taking 101.29 seconds to get val score of 0.8619
#         Current best combo: (5, 3, 4, 4, 2, 3, 67) with val score 0.8619
# Trained and Tested combination 193 of 2929500: (5, 3, 4, 4, 2, 3, 71), taking 97.34 seconds to get val score of 0.8593
#         Current best combo: (5, 3, 4, 4, 2, 3, 67) with val score 0.8619
# Trained and Tested combination 194 of 2929500: (5, 3, 4, 4, 2, 3, 72), taking 103.46 seconds to get val score of 0.863
#         Current best combo: (5, 3, 4, 4, 2, 3, 72) with val score 0.863
# Trained and Tested combination 195 of 2929500: (5, 3, 4, 4, 2, 3, 73), taking 106.48 seconds to get val score of 0.8626
#         Current best combo: (5, 3, 4, 4, 2, 3, 72) with val score 0.863
# Trained and Tested combination 196 of 2929500: (5, 3, 4, 4, 2, 3, 74), taking 144.74 seconds to get val score of 0.8633
#         Current best combo: (5, 3, 4, 4, 2, 3, 74) with val score 0.8633
# Already Trained and Tested combination (5, 3, 4, 4, 2, 3, 75), which had val score of 0.8607
#         Current best combo: (5, 3, 4, 4, 2, 3, 74) with val score 0.8633.
#         Has trained 196 of 2929500 combinations so far
# Trained and Tested combination 197 of 2929500: (5, 3, 4, 4, 2, 3, 76), taking 137.34 seconds to get val score of 0.8626
#         Current best combo: (5, 3, 4, 4, 2, 3, 74) with val score 0.8633
# Trained and Tested combination 198 of 2929500: (5, 3, 4, 4, 2, 3, 77), taking 124.68 seconds to get val score of 0.8596
#         Current best combo: (5, 3, 4, 4, 2, 3, 74) with val score 0.8633
# Trained and Tested combination 199 of 2929500: (5, 3, 4, 4, 2, 3, 78), taking 125.64 seconds to get val score of 0.863
#         Current best combo: (5, 3, 4, 4, 2, 3, 74) with val score 0.8633
# Trained and Tested combination 200 of 2929500: (5, 3, 4, 4, 2, 3, 79), taking 113.95 seconds to get val score of 0.8611
#         Current best combo: (5, 3, 4, 4, 2, 3, 74) with val score 0.8633
# Trained and Tested combination 201 of 2929500: (5, 3, 4, 4, 2, 3, 80), taking 140.46 seconds to get val score of 0.857
#         Current best combo: (5, 3, 4, 4, 2, 3, 74) with val score 0.8633
# Trained and Tested combination 202 of 2929500: (5, 3, 4, 4, 2, 3, 81), taking 148.1 seconds to get val score of 0.8633
#         Current best combo: (5, 3, 4, 4, 2, 3, 74) with val score 0.8633
# Trained and Tested combination 203 of 2929500: (5, 3, 4, 4, 2, 3, 82), taking 143.88 seconds to get val score of 0.8596
#         Current best combo: (5, 3, 4, 4, 2, 3, 74) with val score 0.8633
# Trained and Tested combination 204 of 2929500: (5, 3, 4, 4, 2, 3, 83), taking 139.12 seconds to get val score of 0.8637
#         Current best combo: (5, 3, 4, 4, 2, 3, 83) with val score 0.8637
# Trained and Tested combination 205 of 2929500: (5, 3, 4, 4, 2, 3, 84), taking 173.48 seconds to get val score of 0.8656
#         Current best combo: (5, 3, 4, 4, 2, 3, 84) with val score 0.8656
# Trained and Tested combination 206 of 2929500: (5, 3, 4, 4, 2, 3, 85), taking 130.25 seconds to get val score of 0.8615
#         Current best combo: (5, 3, 4, 4, 2, 3, 84) with val score 0.8656
# Trained and Tested combination 207 of 2929500: (5, 3, 4, 4, 2, 3, 86), taking 125.37 seconds to get val score of 0.8622
#         Current best combo: (5, 3, 4, 4, 2, 3, 84) with val score 0.8656
# Trained and Tested combination 208 of 2929500: (5, 3, 4, 4, 2, 3, 87), taking 119.53 seconds to get val score of 0.8611
#         Current best combo: (5, 3, 4, 4, 2, 3, 84) with val score 0.8656
# Trained and Tested combination 209 of 2929500: (5, 3, 4, 4, 2, 3, 88), taking 128.48 seconds to get val score of 0.8641
#         Current best combo: (5, 3, 4, 4, 2, 3, 84) with val score 0.8656
# Trained and Tested combination 210 of 2929500: (5, 3, 4, 4, 2, 3, 89), taking 159.32 seconds to get val score of 0.863
#         Current best combo: (5, 3, 4, 4, 2, 3, 84) with val score 0.8656
# Trained and Tested combination 211 of 2929500: (5, 3, 4, 4, 2, 3, 90), taking 230.29 seconds to get val score of 0.863
#         Current best combo: (5, 3, 4, 4, 2, 3, 84) with val score 0.8656
# Trained and Tested combination 212 of 2929500: (5, 3, 4, 4, 2, 3, 91), taking 213.41 seconds to get val score of 0.8622
#         Current best combo: (5, 3, 4, 4, 2, 3, 84) with val score 0.8656
# Trained and Tested combination 213 of 2929500: (5, 3, 4, 4, 2, 3, 92), taking 213.25 seconds to get val score of 0.8626
#         Current best combo: (5, 3, 4, 4, 2, 3, 84) with val score 0.8656
#
# Best combo after this hyperparameter: (5, 3, 4, 4, 2, 3, 84) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_depth (index: 1)
#
# Trained and Tested combination 214 of 2929500: (5, 0, 4, 4, 2, 3, 84), taking 23.84 seconds to get val score of 0.8426
#         Current best combo: (5, 3, 4, 4, 2, 3, 84) with val score 0.8656
# Trained and Tested combination 215 of 2929500: (5, 1, 4, 4, 2, 3, 84), taking 55.04 seconds to get val score of 0.8541
#         Current best combo: (5, 3, 4, 4, 2, 3, 84) with val score 0.8656
# Trained and Tested combination 216 of 2929500: (5, 2, 4, 4, 2, 3, 84), taking 112.63 seconds to get val score of 0.8626
#         Current best combo: (5, 3, 4, 4, 2, 3, 84) with val score 0.8656
# Already Trained and Tested combination (5, 3, 4, 4, 2, 3, 84), which had val score of 0.8656
#         Current best combo: (5, 3, 4, 4, 2, 3, 84) with val score 0.8656.
#         Has trained 216 of 2929500 combinations so far
# Trained and Tested combination 217 of 2929500: (5, 4, 4, 4, 2, 3, 84), taking 178.87 seconds to get val score of 0.8644
#         Current best combo: (5, 3, 4, 4, 2, 3, 84) with val score 0.8656
# Trained and Tested combination 218 of 2929500: (5, 5, 4, 4, 2, 3, 84), taking 263.09 seconds to get val score of 0.8604
#         Current best combo: (5, 3, 4, 4, 2, 3, 84) with val score 0.8656
# Trained and Tested combination 219 of 2929500: (5, 6, 4, 4, 2, 3, 84), taking 215.82 seconds to get val score of 0.8607
#         Current best combo: (5, 3, 4, 4, 2, 3, 84) with val score 0.8656
#
# Best combo after this hyperparameter: (5, 3, 4, 4, 2, 3, 84) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: subsample (index: 2)
#
# Trained and Tested combination 220 of 2929500: (5, 3, 0, 4, 2, 3, 84), taking 131.73 seconds to get val score of 0.8696
#         Current best combo: (5, 3, 0, 4, 2, 3, 84) with val score 0.8696
# Trained and Tested combination 221 of 2929500: (5, 3, 1, 4, 2, 3, 84), taking 144.09 seconds to get val score of 0.8641
#         Current best combo: (5, 3, 0, 4, 2, 3, 84) with val score 0.8696
# Trained and Tested combination 222 of 2929500: (5, 3, 2, 4, 2, 3, 84), taking 148.99 seconds to get val score of 0.8574
#         Current best combo: (5, 3, 0, 4, 2, 3, 84) with val score 0.8696
# Trained and Tested combination 223 of 2929500: (5, 3, 3, 4, 2, 3, 84), taking 163.82 seconds to get val score of 0.8607
#         Current best combo: (5, 3, 0, 4, 2, 3, 84) with val score 0.8696
# Already Trained and Tested combination (5, 3, 4, 4, 2, 3, 84), which had val score of 0.8656
#         Current best combo: (5, 3, 0, 4, 2, 3, 84) with val score 0.8696.
#         Has trained 223 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 3, 0, 4, 2, 3, 84) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: colsample_bytree (index: 3)
#
# Trained and Tested combination 224 of 2929500: (5, 3, 0, 0, 2, 3, 84), taking 93.69 seconds to get val score of 0.8615
#         Current best combo: (5, 3, 0, 4, 2, 3, 84) with val score 0.8696
# Trained and Tested combination 225 of 2929500: (5, 3, 0, 1, 2, 3, 84), taking 108.08 seconds to get val score of 0.8615
#         Current best combo: (5, 3, 0, 4, 2, 3, 84) with val score 0.8696
# Trained and Tested combination 226 of 2929500: (5, 3, 0, 2, 2, 3, 84), taking 105.37 seconds to get val score of 0.8611
#         Current best combo: (5, 3, 0, 4, 2, 3, 84) with val score 0.8696
# Trained and Tested combination 227 of 2929500: (5, 3, 0, 3, 2, 3, 84), taking 121.37 seconds to get val score of 0.8633
#         Current best combo: (5, 3, 0, 4, 2, 3, 84) with val score 0.8696
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 84), which had val score of 0.8696
#         Current best combo: (5, 3, 0, 4, 2, 3, 84) with val score 0.8696.
#         Has trained 227 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 3, 0, 4, 2, 3, 84) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Trained and Tested combination 228 of 2929500: (0, 3, 0, 4, 2, 3, 84), taking 16.01 seconds to get val score of 0.8363
#         Current best combo: (5, 3, 0, 4, 2, 3, 84) with val score 0.8696
# Trained and Tested combination 229 of 2929500: (1, 3, 0, 4, 2, 3, 84), taking 28.41 seconds to get val score of 0.8411
#         Current best combo: (5, 3, 0, 4, 2, 3, 84) with val score 0.8696
# Trained and Tested combination 230 of 2929500: (2, 3, 0, 4, 2, 3, 84), taking 46.05 seconds to get val score of 0.8526
#         Current best combo: (5, 3, 0, 4, 2, 3, 84) with val score 0.8696
# ...
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 73), which had val score of 0.86
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 74), which had val score of 0.8581
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 75), which had val score of 0.8622
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 76), which had val score of 0.8593
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 77), which had val score of 0.8611
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 78), which had val score of 0.8589
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 79), which had val score of 0.86
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 80), which had val score of 0.8622
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 81), which had val score of 0.8704
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 82), which had val score of 0.8604
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 83), which had val score of 0.8615
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 84), which had val score of 0.8696
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 85), which had val score of 0.86
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 86), which had val score of 0.8607
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 87), which had val score of 0.8615
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 88), which had val score of 0.8619
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 89), which had val score of 0.8585
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 90), which had val score of 0.8667
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 91), which had val score of 0.8589
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 92), which had val score of 0.8589
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 3, 0, 4, 2, 3, 81) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (5, 0, 0, 4, 2, 3, 81), which had val score of 0.8456
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 1, 0, 4, 2, 3, 81), which had val score of 0.8585
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 2, 0, 4, 2, 3, 81), which had val score of 0.863
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 81), which had val score of 0.8704
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 4, 0, 4, 2, 3, 81), which had val score of 0.8548
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 5, 0, 4, 2, 3, 81), which had val score of 0.8648
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 2, 3, 81), which had val score of 0.8648
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 3, 0, 4, 2, 3, 81) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 81), which had val score of 0.8704
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 1, 4, 2, 3, 81), which had val score of 0.8574
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 2, 4, 2, 3, 81), which had val score of 0.8567
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 3, 4, 2, 3, 81), which had val score of 0.8615
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 4, 2, 3, 81), which had val score of 0.8633
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 3, 0, 4, 2, 3, 81) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: colsample_bytree (index: 3)
#
# Already Trained and Tested combination (5, 3, 0, 0, 2, 3, 81), which had val score of 0.8574
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 2, 3, 81), which had val score of 0.8559
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 2, 2, 3, 81), which had val score of 0.8581
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 3, 2, 3, 81), which had val score of 0.863
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 81), which had val score of 0.8704
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 3, 0, 4, 2, 3, 81) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 3, 0, 4, 2, 3, 81), which had val score of 0.8278
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 2, 3, 81), which had val score of 0.8426
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (2, 3, 0, 4, 2, 3, 81), which had val score of 0.8515
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (3, 3, 0, 4, 2, 3, 81), which had val score of 0.8596
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 2, 3, 81), which had val score of 0.8641
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 81), which had val score of 0.8704
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 3, 0, 4, 2, 3, 81) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: gamma (index: 4)
#
# Already Trained and Tested combination (5, 3, 0, 4, 0, 3, 81), which had val score of 0.8678
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 1, 3, 81), which had val score of 0.8678
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 3, 81), which had val score of 0.8704
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 3, 3, 81), which had val score of 0.8619
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 4, 3, 81), which had val score of 0.86
#         Current best combo: (5, 3, 0, 4, 2, 3, 81) with val score 0.8704.
#         Has trained 388 of 2929500 combinations so far
#
# Best combo after this hyperparameter: (5, 3, 0, 4, 2, 3, 81) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.8703703703703703
# Max Test Score:
#  0.859259
# Max Combo Index:
#  (5, 3, 0, 4, 2, 3, 81) out of [6, 7, 5, 5, 5, 6, 93] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.0001, 'eta': 0.1, 'features': 81}
# Max Combo Features:
#  (3414, 29667, 887, 14524, 6603, 67869, 15936, 63974, 66808, 3426, 66664, 29750, 41191, 55340, 12469, 67858, 66575, 65072, 16037, 1740, 13507, 2688, 2215, 52187, 23378, 6233, 10403, 37744, 14712, 32284, 1674, 45854, 3216, 2359, 30255, 34377, 8995, 5290, 15598, 6860, 3403, 46916, 17969, 13664, 32363, 36120, 40128, 36203, 51794, 55739, 3907, 15310, 11612, 9426, 567, 44892, 22090, 30337, 18791, 24916, 31782, 50216, 50215, 35702, 7824, 11463, 42186, 52031, 55970, 49708, 6092, 16198, 40946, 11229, 50463, 33791, 13877, 21818, 67106, 24711, 62981, 45306, 19094, 57360, 10927, 48377, 4654, 8387, 13044, 5192, 31387, 2181, 38937, 6276, 42062, 36443, 21494, 4522, 16137, 775, 67394, 8778, 68147, 1396, 3995, 27108, 67483, 599, 2325, 11358, 5027, 1275, 60996, 200, 8670, 67659, 1663, 6826, 2038, 14989, 5563, 7910, 13802, 6308, 62561, 3863, 28574, 8973, 67781, 12746, 112, 1219, 58670, 4587, 6882, 68058, 66841, 43634, 21109, 42225, 16422, 66519, 4631, 14637, 12935, 21486, 8200, 2522, 2491, 24897, 29971, 67361, 19494, 1629, 10500, 67991, 13980, 7690, 42802, 67715, 31538, 35098, 49870, 7194, 44224, 3621, 23830, 66239, 9748, 3644, 4017, 7933, 46987, 15432, 11293, 55573, 2082, 34542, 753, 47462, 7625, 3094, 40333, 41027, 8530, 9105, 36130, 665, 54450, 63408, 7041, 20921, 3360, 7365, 26712, 13727, 34703, 10716, 2414, 7476, 13454, 11347, 2104, 41268, 50294, 3973, 1961, 60910, 39435, 17673, 13350, 7311, 5071, 2006, 4742, 4083, 742, 13230, 7399, 22771, 32440, 3072, 51366, 22478, 444, 68047, 3940, 886, 4875, 2832, 67128, 36530, 8050, 23837, 63142, 6716, 25175, 6450, 38996, 2654, 3061, 478, 30264, 37833, 55177, 9737, 29835, 1751, 45689, 22673, 60660, 3896, 25504, 5950, 67150, 11905, 710, 45465, 12620, 67947, 2788, 61818, 47222, 5496, 35, 1074, 67327, 1440, 67747, 33058, 26453, 22089, 3039, 12311, 29120, 18304, 38360, 24618, 9854, 27383, 67427, 25085, 2214, 1, 66797, 6167, 27869, 66508, 28537, 58031, 2655, 61071, 1884, 34036, 17566, 67682, 3499, 66886, 66441, 31317, 31394, 34541, 46915, 37735, 21316, 67671, 27771, 22655, 14207, 9695, 9964, 56288, 24880, 1994, 8125, 41662, 9639, 52270, 41418, 16342, 167, 9595, 9532, 57030, 28246, 5180, 66663, 1120, 1441, 14911, 67903, 59415, 42466, 1907, 35352, 17912, 35861, 28536, 4852, 14495, 64229, 10971, 4908, 2436, 29196, 8584, 9855, 13142, 3238, 27675, 14423, 10853, 5401, 33484, 46270, 11401, 25246, 32973, 58438, 18071, 8343, 11573, 3315, 37179, 17607, 16957, 4501, 8790, 29912, 55176, 66774, 389, 21010, 1297, 60742, 14186, 26905, 15233, 4523, 10341, 17270, 41982, 2060, 15127, 12100, 66063, 31700, 36384, 5729, 20728, 61735, 32886, 26779, 49043, 21148, 56533, 29601, 19795, 55655, 25887, 67438, 31060, 17050, 5618, 50803, 40283, 60093, 4314, 59253, 67880, 1374, 10820, 42887, 40536, 66652, 1574, 12354, 67571, 6059, 7713, 19576, 57605, 14085, 24028, 51132, 40621, 9318, 66530, 67050, 65820, 4192, 49539, 8801, 28157, 19190, 16138, 43055, 15332, 38700, 22644, 17166, 9372, 46109, 60825, 65071, 4962, 11023, 48869, 30494, 997, 2984, 998, 5082, 39106, 22381, 17165, 4411, 32527, 3775, 27266, 42143, 58194, 1142, 1851, 59254, 39514, 28494, 7475, 67216, 48631, 10178, 66408, 65392, 19219, 17040, 8855, 50383, 7801, 3643, 26226, 33723, 14084, 37572, 9072, 17773, 44970, 44470, 11142, 16474, 25949, 32731, 36615, 5840, 6936, 68102, 61242, 4764, 24415, 39524, 67758, 4412, 34940, 21646, 8017, 31318, 29518, 45535, 14595, 5607, 11997, 18168, 39348, 1107, 52783, 16116, 24991, 19240, 5508, 27967, 62560, 52706, 10330, 66430, 39523, 20177, 51049, 37493, 14127, 31618, 27868, 39021, 45305, 12713, 13010, 13561, 32810, 65906, 6222, 11808, 10145, 30420, 16978, 23071, 21985, 23356, 67549, 40367, 15629, 34778, 1773, 22286, 53529, 1840, 36936, 35953, 22695, 3753, 28635, 28831, 67007, 30077, 19597, 43307, 57869, 49376, 14258, 68069, 100, 13769, 19897, 3314, 7689, 19392, 7075, 7410, 8724, 54356, 1551, 4302, 1662, 13239, 8072, 10070, 4457, 16787, 1108, 54516, 10392, 18934, 25514, 4291, 66885, 21297, 41106, 3510, 34628, 41349, 16331, 18080, 6715, 21591, 11721 ...
# % Combos Checked: 388 out of 2929500 which is 0.013245%
