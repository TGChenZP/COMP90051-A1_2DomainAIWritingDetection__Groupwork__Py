# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'rfc'
FEATURE_IMPORTANCE_ORDERING = 'xgb'
PREPROCESSING = 'Baseline'
TUNER = 'jiaochengb'
FEATURE_ENGINEERING = 'tfidf'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os
import pickle
from scipy.sparse import load_npz

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/PrivatePackages" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
else:
    py_file_location = '../../PrivatePackages'
    home_directory = '../../'

sys.path.append(os.path.abspath(py_file_location))

from Tuners import JiaoChengB

import pandas as pd

# %%
## Parameters that are same for every script

SEED = 2608

TASK_TYPE = 'Classification' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = True # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import RandomForestClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_samples': (0.4, 0.55, 0.7, 0.85, 1),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    'n_jobs': -1
                                    }

tuning_order = [
    'features',
    'max_depth',
    'max_samples',
    'max_features',
    'n_estimators',
    'ccp_alpha',
]

default_hyperparameter_values = {'n_estimators': 100, 'max_depth': 12, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.01, 'features': 0}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_x = load_npz(home_directory + f'data/curated/baseline/train_{FEATURE_ENGINEERING}_x.npz')
val_x = load_npz(home_directory + f'data/curated/baseline/val_{FEATURE_ENGINEERING}_x.npz')
test_x = load_npz(home_directory + f'data/curated/baseline/test_{FEATURE_ENGINEERING}_x.npz')

with open(home_directory + 'data/curated/baseline/train_y.pkl', 'rb') as f:
    train_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/val_y.pkl', 'rb') as f:
    val_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/test_y.pkl', 'rb') as f:
    test_y = pickle.load(f)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = JiaoChengB.JiaoChengB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._forest.RandomForestClassifier'>, which is a Classification model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# Trained and Tested combination 139 of 488250: (2, 2, 2, 2, 0, 22), taking 14.18 seconds to get val score of 0.8181
#         Current best combo: (2, 2, 2, 2, 0, 22) with val score 0.8181
# Trained and Tested combination 140 of 488250: (2, 2, 2, 2, 0, 23), taking 14.33 seconds to get val score of 0.8167
#         Current best combo: (2, 2, 2, 2, 0, 22) with val score 0.8181
# Trained and Tested combination 141 of 488250: (2, 2, 2, 2, 0, 24), taking 14.77 seconds to get val score of 0.8152
#         Current best combo: (2, 2, 2, 2, 0, 22) with val score 0.8181
# Already Trained and Tested combination (2, 2, 2, 2, 0, 25), which had val score of 0.8148
#         Current best combo: (2, 2, 2, 2, 0, 22) with val score 0.8181.
#         Has trained 141 of 488250 combinations so far
# Trained and Tested combination 142 of 488250: (2, 2, 2, 2, 0, 26), taking 15.45 seconds to get val score of 0.8189
#         Current best combo: (2, 2, 2, 2, 0, 26) with val score 0.8189
# Trained and Tested combination 143 of 488250: (2, 2, 2, 2, 0, 27), taking 16.73 seconds to get val score of 0.8156
#         Current best combo: (2, 2, 2, 2, 0, 26) with val score 0.8189
# Trained and Tested combination 144 of 488250: (2, 2, 2, 2, 0, 28), taking 19.42 seconds to get val score of 0.8204
#         Current best combo: (2, 2, 2, 2, 0, 28) with val score 0.8204
# Trained and Tested combination 145 of 488250: (2, 2, 2, 2, 0, 29), taking 18.75 seconds to get val score of 0.8215
#         Current best combo: (2, 2, 2, 2, 0, 29) with val score 0.8215
# Trained and Tested combination 146 of 488250: (2, 2, 2, 2, 0, 30), taking 19.56 seconds to get val score of 0.8178
#         Current best combo: (2, 2, 2, 2, 0, 29) with val score 0.8215
# Trained and Tested combination 147 of 488250: (2, 2, 2, 2, 0, 31), taking 22.89 seconds to get val score of 0.8219
#         Current best combo: (2, 2, 2, 2, 0, 31) with val score 0.8219
# Trained and Tested combination 148 of 488250: (2, 2, 2, 2, 0, 32), taking 20.5 seconds to get val score of 0.82
#         Current best combo: (2, 2, 2, 2, 0, 31) with val score 0.8219
# Trained and Tested combination 149 of 488250: (2, 2, 2, 2, 0, 33), taking 23.04 seconds to get val score of 0.8207
#         Current best combo: (2, 2, 2, 2, 0, 31) with val score 0.8219
# Trained and Tested combination 150 of 488250: (2, 2, 2, 2, 0, 34), taking 21.92 seconds to get val score of 0.8189
#         Current best combo: (2, 2, 2, 2, 0, 31) with val score 0.8219
# Trained and Tested combination 151 of 488250: (2, 2, 2, 2, 0, 35), taking 23.79 seconds to get val score of 0.8204
#         Current best combo: (2, 2, 2, 2, 0, 31) with val score 0.8219
# Trained and Tested combination 152 of 488250: (2, 2, 2, 2, 0, 36), taking 24.96 seconds to get val score of 0.8237
#         Current best combo: (2, 2, 2, 2, 0, 36) with val score 0.8237
# Trained and Tested combination 153 of 488250: (2, 2, 2, 2, 0, 37), taking 24.43 seconds to get val score of 0.8248
#         Current best combo: (2, 2, 2, 2, 0, 37) with val score 0.8248
# Trained and Tested combination 154 of 488250: (2, 2, 2, 2, 0, 38), taking 27.88 seconds to get val score of 0.8226
#         Current best combo: (2, 2, 2, 2, 0, 37) with val score 0.8248
# Trained and Tested combination 155 of 488250: (2, 2, 2, 2, 0, 39), taking 26.33 seconds to get val score of 0.8244
#         Current best combo: (2, 2, 2, 2, 0, 37) with val score 0.8248
# Trained and Tested combination 156 of 488250: (2, 2, 2, 2, 0, 40), taking 28.23 seconds to get val score of 0.8181
#         Current best combo: (2, 2, 2, 2, 0, 37) with val score 0.8248
# Trained and Tested combination 157 of 488250: (2, 2, 2, 2, 0, 41), taking 28.57 seconds to get val score of 0.8207
#         Current best combo: (2, 2, 2, 2, 0, 37) with val score 0.8248
# Trained and Tested combination 158 of 488250: (2, 2, 2, 2, 0, 42), taking 29.74 seconds to get val score of 0.8252
#         Current best combo: (2, 2, 2, 2, 0, 42) with val score 0.8252
# Trained and Tested combination 159 of 488250: (2, 2, 2, 2, 0, 43), taking 30.84 seconds to get val score of 0.8193
#         Current best combo: (2, 2, 2, 2, 0, 42) with val score 0.8252
# Trained and Tested combination 160 of 488250: (2, 2, 2, 2, 0, 44), taking 34.16 seconds to get val score of 0.8189
#         Current best combo: (2, 2, 2, 2, 0, 42) with val score 0.8252
# Trained and Tested combination 161 of 488250: (2, 2, 2, 2, 0, 45), taking 32.54 seconds to get val score of 0.8215
#         Current best combo: (2, 2, 2, 2, 0, 42) with val score 0.8252
# Trained and Tested combination 162 of 488250: (2, 2, 2, 2, 0, 46), taking 32.86 seconds to get val score of 0.8219
#         Current best combo: (2, 2, 2, 2, 0, 42) with val score 0.8252
# Trained and Tested combination 163 of 488250: (2, 2, 2, 2, 0, 47), taking 35.07 seconds to get val score of 0.8237
#         Current best combo: (2, 2, 2, 2, 0, 42) with val score 0.8252
# Trained and Tested combination 164 of 488250: (2, 2, 2, 2, 0, 48), taking 34.39 seconds to get val score of 0.8233
#         Current best combo: (2, 2, 2, 2, 0, 42) with val score 0.8252
# Trained and Tested combination 165 of 488250: (2, 2, 2, 2, 0, 49), taking 38.74 seconds to get val score of 0.8222
#         Current best combo: (2, 2, 2, 2, 0, 42) with val score 0.8252
# Trained and Tested combination 166 of 488250: (2, 2, 2, 2, 0, 50), taking 35.62 seconds to get val score of 0.8244
#         Current best combo: (2, 2, 2, 2, 0, 42) with val score 0.8252
# Trained and Tested combination 167 of 488250: (2, 2, 2, 2, 0, 51), taking 39.05 seconds to get val score of 0.8244
#         Current best combo: (2, 2, 2, 2, 0, 42) with val score 0.8252
# Trained and Tested combination 168 of 488250: (2, 2, 2, 2, 0, 52), taking 40.48 seconds to get val score of 0.8226
#         Current best combo: (2, 2, 2, 2, 0, 42) with val score 0.8252
# Trained and Tested combination 169 of 488250: (2, 2, 2, 2, 0, 53), taking 43.29 seconds to get val score of 0.823
#         Current best combo: (2, 2, 2, 2, 0, 42) with val score 0.8252
# Trained and Tested combination 170 of 488250: (2, 2, 2, 2, 0, 54), taking 40.88 seconds to get val score of 0.8248
#         Current best combo: (2, 2, 2, 2, 0, 42) with val score 0.8252
# Trained and Tested combination 171 of 488250: (2, 2, 2, 2, 0, 55), taking 42.1 seconds to get val score of 0.8274
#         Current best combo: (2, 2, 2, 2, 0, 55) with val score 0.8274
# Trained and Tested combination 172 of 488250: (2, 2, 2, 2, 0, 56), taking 43.12 seconds to get val score of 0.8248
#         Current best combo: (2, 2, 2, 2, 0, 55) with val score 0.8274
# Trained and Tested combination 173 of 488250: (2, 2, 2, 2, 0, 57), taking 48.38 seconds to get val score of 0.827
#         Current best combo: (2, 2, 2, 2, 0, 55) with val score 0.8274
# Trained and Tested combination 174 of 488250: (2, 2, 2, 2, 0, 58), taking 45.34 seconds to get val score of 0.823
#         Current best combo: (2, 2, 2, 2, 0, 55) with val score 0.8274
# Trained and Tested combination 175 of 488250: (2, 2, 2, 2, 0, 59), taking 47.88 seconds to get val score of 0.8222
#         Current best combo: (2, 2, 2, 2, 0, 55) with val score 0.8274
# Trained and Tested combination 176 of 488250: (2, 2, 2, 2, 0, 60), taking 52.32 seconds to get val score of 0.8248
#         Current best combo: (2, 2, 2, 2, 0, 55) with val score 0.8274
# Trained and Tested combination 177 of 488250: (2, 2, 2, 2, 0, 61), taking 50.27 seconds to get val score of 0.8241
#         Current best combo: (2, 2, 2, 2, 0, 55) with val score 0.8274
# Trained and Tested combination 178 of 488250: (2, 2, 2, 2, 0, 62), taking 50.98 seconds to get val score of 0.827
#         Current best combo: (2, 2, 2, 2, 0, 55) with val score 0.8274
# Trained and Tested combination 179 of 488250: (2, 2, 2, 2, 0, 63), taking 54.65 seconds to get val score of 0.8285
#         Current best combo: (2, 2, 2, 2, 0, 63) with val score 0.8285
# Trained and Tested combination 180 of 488250: (2, 2, 2, 2, 0, 64), taking 56.21 seconds to get val score of 0.823
#         Current best combo: (2, 2, 2, 2, 0, 63) with val score 0.8285
# Trained and Tested combination 181 of 488250: (2, 2, 2, 2, 0, 65), taking 53.85 seconds to get val score of 0.8256
#         Current best combo: (2, 2, 2, 2, 0, 63) with val score 0.8285
# Trained and Tested combination 182 of 488250: (2, 2, 2, 2, 0, 66), taking 56.84 seconds to get val score of 0.8226
#         Current best combo: (2, 2, 2, 2, 0, 63) with val score 0.8285
# Trained and Tested combination 183 of 488250: (2, 2, 2, 2, 0, 67), taking 59.77 seconds to get val score of 0.8244
#         Current best combo: (2, 2, 2, 2, 0, 63) with val score 0.8285
# Trained and Tested combination 184 of 488250: (2, 2, 2, 2, 0, 68), taking 59.28 seconds to get val score of 0.8226
#         Current best combo: (2, 2, 2, 2, 0, 63) with val score 0.8285
# Trained and Tested combination 185 of 488250: (2, 2, 2, 2, 0, 69), taking 58.64 seconds to get val score of 0.8219
#         Current best combo: (2, 2, 2, 2, 0, 63) with val score 0.8285
# Trained and Tested combination 186 of 488250: (2, 2, 2, 2, 0, 70), taking 62.88 seconds to get val score of 0.8244
#         Current best combo: (2, 2, 2, 2, 0, 63) with val score 0.8285
# Trained and Tested combination 187 of 488250: (2, 2, 2, 2, 0, 71), taking 61.46 seconds to get val score of 0.8263
#         Current best combo: (2, 2, 2, 2, 0, 63) with val score 0.8285
# Trained and Tested combination 188 of 488250: (2, 2, 2, 2, 0, 72), taking 63.47 seconds to get val score of 0.8259
#         Current best combo: (2, 2, 2, 2, 0, 63) with val score 0.8285
# Trained and Tested combination 189 of 488250: (2, 2, 2, 2, 0, 73), taking 59.21 seconds to get val score of 0.8289
#         Current best combo: (2, 2, 2, 2, 0, 73) with val score 0.8289
# Trained and Tested combination 190 of 488250: (2, 2, 2, 2, 0, 74), taking 59.31 seconds to get val score of 0.8256
#         Current best combo: (2, 2, 2, 2, 0, 73) with val score 0.8289
# Trained and Tested combination 191 of 488250: (2, 2, 2, 2, 0, 75), taking 61.95 seconds to get val score of 0.8278
#         Current best combo: (2, 2, 2, 2, 0, 73) with val score 0.8289
# Trained and Tested combination 192 of 488250: (2, 2, 2, 2, 0, 76), taking 60.17 seconds to get val score of 0.8252
#         Current best combo: (2, 2, 2, 2, 0, 73) with val score 0.8289
# Trained and Tested combination 193 of 488250: (2, 2, 2, 2, 0, 77), taking 60.92 seconds to get val score of 0.8241
#         Current best combo: (2, 2, 2, 2, 0, 73) with val score 0.8289
# Trained and Tested combination 194 of 488250: (2, 2, 2, 2, 0, 78), taking 63.18 seconds to get val score of 0.8244
#         Current best combo: (2, 2, 2, 2, 0, 73) with val score 0.8289
# Trained and Tested combination 195 of 488250: (2, 2, 2, 2, 0, 79), taking 63.73 seconds to get val score of 0.8244
#         Current best combo: (2, 2, 2, 2, 0, 73) with val score 0.8289
# Trained and Tested combination 196 of 488250: (2, 2, 2, 2, 0, 80), taking 64.04 seconds to get val score of 0.8296
#         Current best combo: (2, 2, 2, 2, 0, 80) with val score 0.8296
# Trained and Tested combination 197 of 488250: (2, 2, 2, 2, 0, 81), taking 64.21 seconds to get val score of 0.8248
#         Current best combo: (2, 2, 2, 2, 0, 80) with val score 0.8296
# Trained and Tested combination 198 of 488250: (2, 2, 2, 2, 0, 82), taking 63.75 seconds to get val score of 0.82
#         Current best combo: (2, 2, 2, 2, 0, 80) with val score 0.8296
# Trained and Tested combination 199 of 488250: (2, 2, 2, 2, 0, 83), taking 67.16 seconds to get val score of 0.8281
#         Current best combo: (2, 2, 2, 2, 0, 80) with val score 0.8296
# Trained and Tested combination 200 of 488250: (2, 2, 2, 2, 0, 84), taking 64.06 seconds to get val score of 0.8285
#         Current best combo: (2, 2, 2, 2, 0, 80) with val score 0.8296
# Trained and Tested combination 201 of 488250: (2, 2, 2, 2, 0, 85), taking 65.66 seconds to get val score of 0.8233
#         Current best combo: (2, 2, 2, 2, 0, 80) with val score 0.8296
# Trained and Tested combination 202 of 488250: (2, 2, 2, 2, 0, 86), taking 66.06 seconds to get val score of 0.8278
#         Current best combo: (2, 2, 2, 2, 0, 80) with val score 0.8296
# Trained and Tested combination 203 of 488250: (2, 2, 2, 2, 0, 87), taking 66.27 seconds to get val score of 0.8256
#         Current best combo: (2, 2, 2, 2, 0, 80) with val score 0.8296
# Trained and Tested combination 204 of 488250: (2, 2, 2, 2, 0, 88), taking 67.23 seconds to get val score of 0.8219
#         Current best combo: (2, 2, 2, 2, 0, 80) with val score 0.8296
# Trained and Tested combination 205 of 488250: (2, 2, 2, 2, 0, 89), taking 67.33 seconds to get val score of 0.823
#         Current best combo: (2, 2, 2, 2, 0, 80) with val score 0.8296
# Trained and Tested combination 206 of 488250: (2, 2, 2, 2, 0, 90), taking 66.78 seconds to get val score of 0.8244
#         Current best combo: (2, 2, 2, 2, 0, 80) with val score 0.8296
# Trained and Tested combination 207 of 488250: (2, 2, 2, 2, 0, 91), taking 68.43 seconds to get val score of 0.8222
#         Current best combo: (2, 2, 2, 2, 0, 80) with val score 0.8296
# Trained and Tested combination 208 of 488250: (2, 2, 2, 2, 0, 92), taking 67.41 seconds to get val score of 0.8233
#         Current best combo: (2, 2, 2, 2, 0, 80) with val score 0.8296
#
# Best combo after this hyperparameter: (2, 2, 2, 2, 0, 80) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_depth (index: 1)
#
# Trained and Tested combination 209 of 488250: (2, 0, 2, 2, 0, 80), taking 10.97 seconds to get val score of 0.7885
#         Current best combo: (2, 2, 2, 2, 0, 80) with val score 0.8296
# Trained and Tested combination 210 of 488250: (2, 1, 2, 2, 0, 80), taking 23.26 seconds to get val score of 0.8115
#         Current best combo: (2, 2, 2, 2, 0, 80) with val score 0.8296
# Already Trained and Tested combination (2, 2, 2, 2, 0, 80), which had val score of 0.8296
#         Current best combo: (2, 2, 2, 2, 0, 80) with val score 0.8296.
#         Has trained 210 of 488250 combinations so far
# Trained and Tested combination 211 of 488250: (2, 3, 2, 2, 0, 80), taking 115.0 seconds to get val score of 0.8319
#         Current best combo: (2, 3, 2, 2, 0, 80) with val score 0.8319
# Trained and Tested combination 212 of 488250: (2, 4, 2, 2, 0, 80), taking 146.56 seconds to get val score of 0.8381
#         Current best combo: (2, 4, 2, 2, 0, 80) with val score 0.8381
# Trained and Tested combination 213 of 488250: (2, 5, 2, 2, 0, 80), taking 161.62 seconds to get val score of 0.8359
#         Current best combo: (2, 4, 2, 2, 0, 80) with val score 0.8381
# Trained and Tested combination 214 of 488250: (2, 6, 2, 2, 0, 80), taking 160.48 seconds to get val score of 0.8381
#         Current best combo: (2, 4, 2, 2, 0, 80) with val score 0.8381
#
# Best combo after this hyperparameter: (2, 4, 2, 2, 0, 80) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_samples (index: 2)
#
# Trained and Tested combination 215 of 488250: (2, 4, 0, 2, 0, 80), taking 84.28 seconds to get val score of 0.8326
#         Current best combo: (2, 4, 2, 2, 0, 80) with val score 0.8381
# Trained and Tested combination 216 of 488250: (2, 4, 1, 2, 0, 80), taking 119.12 seconds to get val score of 0.8344
#         Current best combo: (2, 4, 2, 2, 0, 80) with val score 0.8381
# Already Trained and Tested combination (2, 4, 2, 2, 0, 80), which had val score of 0.8381
#         Current best combo: (2, 4, 2, 2, 0, 80) with val score 0.8381.
#         Has trained 216 of 488250 combinations so far
# Trained and Tested combination 217 of 488250: (2, 4, 3, 2, 0, 80), taking 169.68 seconds to get val score of 0.8367
#         Current best combo: (2, 4, 2, 2, 0, 80) with val score 0.8381
# Trained and Tested combination 218 of 488250: (2, 4, 4, 2, 0, 80), taking 0.34 seconds to get val score of 0.7778
#         Current best combo: (2, 4, 2, 2, 0, 80) with val score 0.8381
#
# Best combo after this hyperparameter: (2, 4, 2, 2, 0, 80) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_features (index: 3)
#
# Trained and Tested combination 219 of 488250: (2, 4, 2, 0, 0, 80), taking 89.05 seconds to get val score of 0.8396
#         Current best combo: (2, 4, 2, 0, 0, 80) with val score 0.8396
# Trained and Tested combination 220 of 488250: (2, 4, 2, 1, 0, 80), taking 114.16 seconds to get val score of 0.8348
#         Current best combo: (2, 4, 2, 0, 0, 80) with val score 0.8396
# Already Trained and Tested combination (2, 4, 2, 2, 0, 80), which had val score of 0.8381
#         Current best combo: (2, 4, 2, 0, 0, 80) with val score 0.8396.
#         Has trained 220 of 488250 combinations so far
# Trained and Tested combination 221 of 488250: (2, 4, 2, 3, 0, 80), taking 174.42 seconds to get val score of 0.8304
#         Current best combo: (2, 4, 2, 0, 0, 80) with val score 0.8396
# Trained and Tested combination 222 of 488250: (2, 4, 2, 4, 0, 80), taking 3.46 seconds to get val score of 0.7989
#         Current best combo: (2, 4, 2, 0, 0, 80) with val score 0.8396
#
# Best combo after this hyperparameter: (2, 4, 2, 0, 0, 80) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Trained and Tested combination 223 of 488250: (0, 4, 2, 0, 0, 80), taking 21.13 seconds to get val score of 0.8404
#         Current best combo: (0, 4, 2, 0, 0, 80) with val score 0.8404
# Trained and Tested combination 224 of 488250: (1, 4, 2, 0, 0, 80), taking 45.14 seconds to get val score of 0.8363
#         Current best combo: (0, 4, 2, 0, 0, 80) with val score 0.8404
# Already Trained and Tested combination (2, 4, 2, 0, 0, 80), which had val score of 0.8396
#         Current best combo: (0, 4, 2, 0, 0, 80) with val score 0.8404.
#         Has trained 224 of 488250 combinations so far
# Trained and Tested combination 225 of 488250: (3, 4, 2, 0, 0, 80), taking 174.38 seconds to get val score of 0.8426
#         Current best combo: (3, 4, 2, 0, 0, 80) with val score 0.8426
# Trained and Tested combination 226 of 488250: (4, 4, 2, 0, 0, 80), taking 347.5 seconds to get val score of 0.84
#         Current best combo: (3, 4, 2, 0, 0, 80) with val score 0.8426
# Trained and Tested combination 227 of 488250: (5, 4, 2, 0, 0, 80), taking 694.24 seconds to get val score of 0.8419
#         Current best combo: (3, 4, 2, 0, 0, 80) with val score 0.8426
#
# Best combo after this hyperparameter: (3, 4, 2, 0, 0, 80) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: ccp_alpha (index: 4)
#
# Already Trained and Tested combination (3, 4, 2, 0, 0, 80), which had val score of 0.8426
#         Current best combo: (3, 4, 2, 0, 0, 80) with val score 0.8426.
#         Has trained 227 of 488250 combinations so far
# Trained and Tested combination 228 of 488250: (3, 4, 2, 0, 1, 80), taking 174.2 seconds to get val score of 0.8426
#         Current best combo: (3, 4, 2, 0, 0, 80) with val score 0.8426
# Trained and Tested combination 229 of 488250: (3, 4, 2, 0, 2, 80), taking 174.61 seconds to get val score of 0.8426
#         Current best combo: (3, 4, 2, 0, 0, 80) with val score 0.8426
# Trained and Tested combination 230 of 488250: (3, 4, 2, 0, 3, 80), taking 175.39 seconds to get val score of 0.7789
#         Current best combo: (3, 4, 2, 0, 0, 80) with val score 0.8426
# Trained and Tested combination 231 of 488250: (3, 4, 2, 0, 4, 80), taking 174.86 seconds to get val score of 0.7778
#         Current best combo: (3, 4, 2, 0, 0, 80) with val score 0.8426
#
# Best combo after this hyperparameter: (3, 4, 2, 0, 0, 80) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 0 (n_estimators) ROUND 3
#
# Round 3
# Hyperparameter: features (index: 5)
#
# Trained and Tested combination 232 of 488250: (3, 4, 2, 0, 0, 0), taking 4.08 seconds to get val score of 0.7559
#         Current best combo: (3, 4, 2, 0, 0, 80) with val score 0.8426
# Trained and Tested combination 233 of 488250: (3, 4, 2, 0, 0, 1), taking 7.02 seconds to get val score of 0.7633
#         Current best combo: (3, 4, 2, 0, 0, 80) with val score 0.8426
# Trained and Tested combination 234 of 488250: (3, 4, 2, 0, 0, 2), taking 6.16 seconds to get val score of 0.77
#         Current best combo: (3, 4, 2, 0, 0, 80) with val score 0.8426
# Trained and Tested combination 235 of 488250: (3, 4, 2, 0, 0, 3), taking 9.45 seconds to get val score of 0.7756
#         Current best combo: (3, 4, 2, 0, 0, 80) with val score 0.8426
# Trained and Tested combination 236 of 488250: (3, 4, 2, 0, 0, 4), taking 11.59 seconds to get val score of 0.7841
#         Current best combo: (3, 4, 2, 0, 0, 80) with val score 0.8426
# Trained and Tested combination
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 303 of 488250: (3, 4, 2, 0, 0, 71), taking 159.87 seconds to get val score of 0.8348
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 304 of 488250: (3, 4, 2, 0, 0, 72), taking 161.09 seconds to get val score of 0.837
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 305 of 488250: (3, 4, 2, 0, 0, 73), taking 163.07 seconds to get val score of 0.8381
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 306 of 488250: (3, 4, 2, 0, 0, 74), taking 165.18 seconds to get val score of 0.8381
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 307 of 488250: (3, 4, 2, 0, 0, 75), taking 166.9 seconds to get val score of 0.84
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 308 of 488250: (3, 4, 2, 0, 0, 76), taking 166.91 seconds to get val score of 0.8393
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 309 of 488250: (3, 4, 2, 0, 0, 77), taking 171.25 seconds to get val score of 0.8315
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 310 of 488250: (3, 4, 2, 0, 0, 78), taking 172.33 seconds to get val score of 0.8381
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 311 of 488250: (3, 4, 2, 0, 0, 79), taking 174.82 seconds to get val score of 0.837
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Already Trained and Tested combination (3, 4, 2, 0, 0, 80), which had val score of 0.8426
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 311 of 488250 combinations so far
# Trained and Tested combination 312 of 488250: (3, 4, 2, 0, 0, 81), taking 176.45 seconds to get val score of 0.8337
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 313 of 488250: (3, 4, 2, 0, 0, 82), taking 178.99 seconds to get val score of 0.8363
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 314 of 488250: (3, 4, 2, 0, 0, 83), taking 180.64 seconds to get val score of 0.8407
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 315 of 488250: (3, 4, 2, 0, 0, 84), taking 181.4 seconds to get val score of 0.8433
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 316 of 488250: (3, 4, 2, 0, 0, 85), taking 182.99 seconds to get val score of 0.8385
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 317 of 488250: (3, 4, 2, 0, 0, 86), taking 183.21 seconds to get val score of 0.8344
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 318 of 488250: (3, 4, 2, 0, 0, 87), taking 183.09 seconds to get val score of 0.8404
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 319 of 488250: (3, 4, 2, 0, 0, 88), taking 185.45 seconds to get val score of 0.837
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 320 of 488250: (3, 4, 2, 0, 0, 89), taking 186.3 seconds to get val score of 0.8381
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 321 of 488250: (3, 4, 2, 0, 0, 90), taking 188.46 seconds to get val score of 0.8378
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 322 of 488250: (3, 4, 2, 0, 0, 91), taking 188.89 seconds to get val score of 0.8422
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 323 of 488250: (3, 4, 2, 0, 0, 92), taking 187.79 seconds to get val score of 0.8374
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
#
# Best combo after this hyperparameter: (3, 4, 2, 0, 0, 52) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: max_depth (index: 1)
#
# Trained and Tested combination 324 of 488250: (3, 0, 2, 0, 0, 52), taking 7.64 seconds to get val score of 0.7926
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 325 of 488250: (3, 1, 2, 0, 0, 52), taking 18.77 seconds to get val score of 0.81
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 326 of 488250: (3, 2, 2, 0, 0, 52), taking 46.39 seconds to get val score of 0.8248
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 327 of 488250: (3, 3, 2, 0, 0, 52), taking 86.91 seconds to get val score of 0.8367
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Already Trained and Tested combination (3, 4, 2, 0, 0, 52), which had val score of 0.8444
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 327 of 488250 combinations so far
# Trained and Tested combination 328 of 488250: (3, 5, 2, 0, 0, 52), taking 122.0 seconds to get val score of 0.8381
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 329 of 488250: (3, 6, 2, 0, 0, 52), taking 124.54 seconds to get val score of 0.8437
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
#
# Best combo after this hyperparameter: (3, 4, 2, 0, 0, 52) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: max_samples (index: 2)
#
# Trained and Tested combination 330 of 488250: (3, 4, 0, 0, 0, 52), taking 63.39 seconds to get val score of 0.8341
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 331 of 488250: (3, 4, 1, 0, 0, 52), taking 90.25 seconds to get val score of 0.8396
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Already Trained and Tested combination (3, 4, 2, 0, 0, 52), which had val score of 0.8444
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 331 of 488250 combinations so far
# Trained and Tested combination 332 of 488250: (3, 4, 3, 0, 0, 52), taking 129.58 seconds to get val score of 0.8419
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 333 of 488250: (3, 4, 4, 0, 0, 52), taking 0.89 seconds to get val score of 0.7778
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
#
# Best combo after this hyperparameter: (3, 4, 2, 0, 0, 52) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: max_features (index: 3)
#
# Already Trained and Tested combination (3, 4, 2, 0, 0, 52), which had val score of 0.8444
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 333 of 488250 combinations so far
# Trained and Tested combination 334 of 488250: (3, 4, 2, 1, 0, 52), taking 148.59 seconds to get val score of 0.8419
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 335 of 488250: (3, 4, 2, 2, 0, 52), taking 184.41 seconds to get val score of 0.8348
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 336 of 488250: (3, 4, 2, 3, 0, 52), taking 224.43 seconds to get val score of 0.8352
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 337 of 488250: (3, 4, 2, 4, 0, 52), taking 3.67 seconds to get val score of 0.8015
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
#
# Best combo after this hyperparameter: (3, 4, 2, 0, 0, 52) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: n_estimators (index: 0)
#
# Trained and Tested combination 338 of 488250: (0, 4, 2, 0, 0, 52), taking 14.2 seconds to get val score of 0.8244
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 339 of 488250: (1, 4, 2, 0, 0, 52), taking 27.92 seconds to get val score of 0.8333
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 340 of 488250: (2, 4, 2, 0, 0, 52), taking 57.65 seconds to get val score of 0.8363
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Already Trained and Tested combination (3, 4, 2, 0, 0, 52), which had val score of 0.8444
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 340 of 488250 combinations so far
# Trained and Tested combination 341 of 488250: (4, 4, 2, 0, 0, 52), taking 222.47 seconds to get val score of 0.84
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 342 of 488250: (5, 4, 2, 0, 0, 52), taking 447.11 seconds to get val score of 0.8407
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
#
# Best combo after this hyperparameter: (3, 4, 2, 0, 0, 52) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: ccp_alpha (index: 4)
#
# Already Trained and Tested combination (3, 4, 2, 0, 0, 52), which had val score of 0.8444
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 342 of 488250 combinations so far
# Trained and Tested combination 343 of 488250: (3, 4, 2, 0, 1, 52), taking 109.68 seconds to get val score of 0.8444
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 344 of 488250: (3, 4, 2, 0, 2, 52), taking 113.29 seconds to get val score of 0.8437
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 345 of 488250: (3, 4, 2, 0, 3, 52), taking 113.53 seconds to get val score of 0.7778
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
# Trained and Tested combination 346 of 488250: (3, 4, 2, 0, 4, 52), taking 110.23 seconds to get val score of 0.7778
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444
#
# Best combo after this hyperparameter: (3, 4, 2, 0, 0, 52) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 0 (n_estimators) ROUND 4
#
# Round 4
# Hyperparameter: features (index: 5)
#
# Already Trained and Tested combination (3, 4, 2, 0, 0, 0), which had val score of 0.7559
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 1), which had val score of 0.7633
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 2), which had val score of 0.77
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 3), which had val score of 0.7756
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 4), which had val score of 0.7841
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 5), which had val score of 0.7904
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 6), which had val score of 0.7881
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 7), which had val score of 0.7915
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 8), which had val score of 0.7959
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 9), which had val score of 0.8119
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 10), which had val score of 0.8107
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 11), which had val score of 0.8126
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 12), which had val score of 0.8107
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 13), which had val score of 0.8159
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 14), which had val score of 0.8137
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 15), which had val score of 0.8141
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 16), which had val score of 0.8211
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 17), which had val score of 0.8152
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 18), which had val score of 0.8185
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 19), which had val score of 0.8219
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 20), which had val score of 0.8248
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 21), which had val score of 0.8252
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 22), which had val score of 0.8244
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 346 of 488250 combinations so far
# ...
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 64), which had val score of 0.8348
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 65), which had val score of 0.8393
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 66), which had val score of 0.843
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 67), which had val score of 0.8374
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 68), which had val score of 0.8404
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 69), which had val score of 0.833
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 70), which had val score of 0.8363
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 71), which had val score of 0.8348
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 72), which had val score of 0.837
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 73), which had val score of 0.8381
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 74), which had val score of 0.8381
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 75), which had val score of 0.84
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 76), which had val score of 0.8393
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 77), which had val score of 0.8315
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 78), which had val score of 0.8381
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 79), which had val score of 0.837
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 80), which had val score of 0.8426
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 81), which had val score of 0.8337
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 82), which had val score of 0.8363
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 83), which had val score of 0.8407
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 84), which had val score of 0.8433
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 85), which had val score of 0.8385
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 86), which had val score of 0.8344
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 87), which had val score of 0.8404
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 88), which had val score of 0.837
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 89), which had val score of 0.8381
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 90), which had val score of 0.8378
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 91), which had val score of 0.8422
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 92), which had val score of 0.8374
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
#
# Best combo after this hyperparameter: (3, 4, 2, 0, 0, 52) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (3, 0, 2, 0, 0, 52), which had val score of 0.7926
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 0, 52), which had val score of 0.81
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 2, 2, 0, 0, 52), which had val score of 0.8248
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 3, 2, 0, 0, 52), which had val score of 0.8367
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 52), which had val score of 0.8444
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 5, 2, 0, 0, 52), which had val score of 0.8381
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 6, 2, 0, 0, 52), which had val score of 0.8437
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
#
# Best combo after this hyperparameter: (3, 4, 2, 0, 0, 52) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_samples (index: 2)
#
# Already Trained and Tested combination (3, 4, 0, 0, 0, 52), which had val score of 0.8341
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 1, 0, 0, 52), which had val score of 0.8396
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 52), which had val score of 0.8444
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 3, 0, 0, 52), which had val score of 0.8419
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 4, 0, 0, 52), which had val score of 0.7778
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
#
# Best combo after this hyperparameter: (3, 4, 2, 0, 0, 52) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_features (index: 3)
#
# Already Trained and Tested combination (3, 4, 2, 0, 0, 52), which had val score of 0.8444
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 1, 0, 52), which had val score of 0.8419
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 0, 52), which had val score of 0.8348
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 0, 52), which had val score of 0.8352
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 4, 0, 52), which had val score of 0.8015
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
#
# Best combo after this hyperparameter: (3, 4, 2, 0, 0, 52) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 4, 2, 0, 0, 52), which had val score of 0.8244
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (1, 4, 2, 0, 0, 52), which had val score of 0.8333
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (2, 4, 2, 0, 0, 52), which had val score of 0.8363
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (3, 4, 2, 0, 0, 52), which had val score of 0.8444
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (4, 4, 2, 0, 0, 52), which had val score of 0.84
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
# Already Trained and Tested combination (5, 4, 2, 0, 0, 52), which had val score of 0.8407
#         Current best combo: (3, 4, 2, 0, 0, 52) with val score 0.8444.
#         Has trained 368 of 488250 combinations so far
#
# Best combo after this hyperparameter: (3, 4, 2, 0, 0, 52) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.8444444444444444
# Max Test Score:
#  0.83
# Max Combo Index:
#  (3, 4, 2, 0, 0, 52) out of [6, 7, 5, 5, 5, 93] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 200, 'max_depth': 48, 'max_samples': 0.7, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 52}
# Max Combo Features:
#  (3414, 29667, 887, 14524, 6603, 67869, 15936, 63974, 66808, 3426, 66664, 29750, 41191, 55340, 12469, 67858, 66575, 65072, 16037, 1740, 13507, 2688, 2215, 52187, 23378, 6233, 10403, 37744, 14712, 32284, 1674, 45854, 3216, 2359, 30255, 34377, 8995, 5290, 15598, 6860, 3403, 46916, 17969, 13664, 32363, 36120, 40128, 36203, 51794, 55739, 3907, 15310, 11612, 9426, 567, 44892, 22090, 30337, 18791, 24916, 31782, 50216, 50215, 35702, 7824, 11463, 42186, 52031, 55970, 49708, 6092, 16198, 40946, 11229, 50463, 33791, 13877, 21818, 67106, 24711, 62981, 45306, 19094, 57360, 10927, 48377, 4654, 8387, 13044, 5192, 31387, 2181, 38937, 6276, 42062, 36443, 21494, 4522, 16137, 775, 67394, 8778, 68147, 1396, 3995, 27108, 67483, 599, 2325, 11358, 5027, 1275, 60996, 200, 8670, 67659, 1663, 6826, 2038, 14989, 5563, 7910, 13802, 6308, 62561, 3863, 28574, 8973, 67781, 12746, 112, 1219, 58670, 4587, 6882, 68058, 66841, 43