# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'logrc'
FEATURE_IMPORTANCE_ORDERING = 'xgb'
PREPROCESSING = 'Baseline'
TUNER = 'jiaochengb'
FEATURE_ENGINEERING = 'bow'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
from scipy.sparse import load_npz

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/PrivatePackages" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
else:
    py_file_location = '../../PrivatePackages'
    home_directory = '../../'

sys.path.append(os.path.abspath(py_file_location))

from Tuners import JiaoChengB

import pandas as pd

# %%
## Parameters that are same for every script

SEED = 2608

TASK_TYPE = 'Classification' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = True # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.linear_model import LogisticRegression as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'penalty': ('l1', 'l2'),
    'tol': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,
                                    'n_jobs': -1,
                                    'verbose': 0,
                                    'multi_class': 'ovr',
                                    'solver': 'liblinear'
                                    }

tuning_order = [
    'features',
    'C',
    'max_iter',
    'penalty',
    'tol'
]

default_hyperparameter_values = {'C': 1, 'max_iter': 800, 'penalty': 'l1', 'tol': 0.001, 'features': 0}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_x = load_npz(home_directory + f'data/curated/baseline/train_{FEATURE_ENGINEERING}_x.npz')
val_x = load_npz(home_directory + f'data/curated/baseline/val_{FEATURE_ENGINEERING}_x.npz')
test_x = load_npz(home_directory + f'data/curated/baseline/test_{FEATURE_ENGINEERING}_x.npz')

with open(home_directory + 'data/curated/baseline/train_y.pkl', 'rb') as f:
    train_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/val_y.pkl', 'rb') as f:
    val_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/test_y.pkl', 'rb') as f:
    test_y = pickle.load(f)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = JiaoChengB.JiaoChengB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'sklearn.linear_model._logistic.LogisticRegression'>, which is a Classification model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# FEATURE_INDEX: 0 (C) ROUND 1
#
# Round 1
# Hyperparameter: features (index: 4)
#
# Trained and Tested combination 1 of 48816: (4, 4, 0, 2, 0), taking 0.02 seconds to get val score of 0.7744
#         Current best combo: (4, 4, 0, 2, 0) with val score 0.7744
# Trained and Tested combination 2 of 48816: (4, 4, 0, 2, 1), taking 0.01 seconds to get val score of 0.7744
#         Current best combo: (4, 4, 0, 2, 0) with val score 0.7744
# Trained and Tested combination 3 of 48816: (4, 4, 0, 2, 2), taking 0.01 seconds to get val score of 0.7781
#         Current best combo: (4, 4, 0, 2, 2) with val score 0.7781
# Trained and Tested combination 4 of 48816: (4, 4, 0, 2, 3), taking 0.01 seconds to get val score of 0.7752
#         Current best combo: (4, 4, 0, 2, 2) with val score 0.7781
# Trained and Tested combination 5 of 48816: (4, 4, 0, 2, 4), taking 0.01 seconds to get val score of 0.7752
#         Current best combo: (4, 4, 0, 2, 2) with val score 0.7781
# Trained and Tested combination 6 of 48816: (4, 4, 0, 2, 5), taking 0.01 seconds to get val score of 0.777
#         Current best combo: (4, 4, 0, 2, 2) with val score 0.7781
# Trained and Tested combination 7 of 48816: (4, 4, 0, 2, 6), taking 0.01 seconds to get val score of 0.777
#         Current best combo: (4, 4, 0, 2, 2) with val score 0.7781
# Trained and Tested combination 8 of 48816: (4, 4, 0, 2, 7), taking 0.02 seconds to get val score of 0.7804
#         Current best combo: (4, 4, 0, 2, 7) with val score 0.7804
# Trained and Tested combination 9 of 48816: (4, 4, 0, 2, 8), taking 0.01 seconds to get val score of 0.7804
#         Current best combo: (4, 4, 0, 2, 7) with val score 0.7804
# Trained and Tested combination 10 of 48816: (4, 4, 0, 2, 9), taking 0.01 seconds to get val score of 0.7807
#         Current best combo: (4, 4, 0, 2, 9) with val score 0.7807
# Trained and Tested combination 11 of 48816: (4, 4, 0, 2, 10), taking 0.02 seconds to get val score of 0.7822
#         Current best combo: (4, 4, 0, 2, 10) with val score 0.7822
# Trained and Tested combination 12 of 48816: (4, 4, 0, 2, 11), taking 0.02 seconds to get val score of 0.7819
#         Current best combo: (4, 4, 0, 2, 10) with val score 0.7822
# Trained and Tested combination 13 of 48816: (4, 4, 0, 2, 12), taking 0.02 seconds to get val score of 0.7874
#         Current best combo: (4, 4, 0, 2, 12) with val score 0.7874
# Trained and Tested combination 14 of 48816: (4, 4, 0, 2, 13), taking 0.02 seconds to get val score of 0.7859
#         Current best combo: (4, 4, 0, 2, 12) with val score 0.7874
# Trained and Tested combination 15 of 48816: (4, 4, 0, 2, 14), taking 0.02 seconds to get val score of 0.7881
#         Current best combo: (4, 4, 0, 2, 14) with val score 0.7881
# Trained and Tested combination 16 of 48816: (4, 4, 0, 2, 15), taking 0.02 seconds to get val score of 0.7893
#         Current best combo: (4, 4, 0, 2, 15) with val score 0.7893
# Trained and Tested combination 17 of 48816: (4, 4, 0, 2, 16), taking 0.02 seconds to get val score of 0.7889
#         Current best combo: (4, 4, 0, 2, 15) with val score 0.7893
# Trained and Tested combination 18 of 48816: (4, 4, 0, 2, 17), taking 0.02 seconds to get val score of 0.7907
#         Current best combo: (4, 4, 0, 2, 17) with val score 0.7907
# Trained and Tested combination 19 of 48816: (4, 4, 0, 2, 18), taking 0.02 seconds to get val score of 0.7907
#         Current best combo: (4, 4, 0, 2, 17) with val score 0.7907
# Trained and Tested combination 20 of 48816: (4, 4, 0, 2, 19), taking 0.02 seconds to get val score of 0.7904
#         Current best combo: (4, 4, 0, 2, 17) with val score 0.7907
# Trained and Tested combination 21 of 48816: (4, 4, 0, 2, 20), taking 0.02 seconds to get val score of 0.7919
#         Current best combo: (4, 4, 0, 2, 20) with val score 0.7919
# Trained and Tested combination 22 of 48816: (4, 4, 0, 2, 21), taking 0.02 seconds to get val score of 0.797
#         Current best combo: (4, 4, 0, 2, 21) with val score 0.797
# Trained and Tested combination 23 of 48816: (4, 4, 0, 2, 22), taking 0.03 seconds to get val score of 0.7967
#         Current best combo: (4, 4, 0, 2, 21) with val score 0.797
# Trained and Tested combination 24 of 48816: (4, 4, 0, 2, 23), taking 0.03 seconds to get val score of 0.7981
#         Current best combo: (4, 4, 0, 2, 23) with val score 0.7981
# Trained and Tested combination 25 of 48816: (4, 4, 0, 2, 24), taking 0.03 seconds to get val score of 0.7967
#         Current best combo: (4, 4, 0, 2, 23) with val score 0.7981
# Trained and Tested combination 26 of 48816: (4, 4, 0, 2, 25), taking 0.04 seconds to get val score of 0.7989
#         Current best combo: (4, 4, 0, 2, 25) with val score 0.7989
# Trained and Tested combination 27 of 48816: (4, 4, 0, 2, 26), taking 0.03 seconds to get val score of 0.797
#         Current best combo: (4, 4, 0, 2, 25) with val score 0.7989
# Trained and Tested combination 28 of 48816: (4, 4, 0, 2, 27), taking 0.03 seconds to get val score of 0.7963
#         Current best combo: (4, 4, 0, 2, 25) with val score 0.7989
# Trained and Tested combination 29 of 48816: (4, 4, 0, 2, 28), taking 0.03 seconds to get val score of 0.8
#         Current best combo: (4, 4, 0, 2, 28) with val score 0.8
# Trained and Tested combination 30 of 48816: (4, 4, 0, 2, 29), taking 0.03 seconds to get val score of 0.8015
#         Current best combo: (4, 4, 0, 2, 29) with val score 0.8015
# Trained and Tested combination 31 of 48816: (4, 4, 0, 2, 30), taking 0.04 seconds to get val score of 0.8022
#         Current best combo: (4, 4, 0, 2, 30) with val score 0.8022
# Trained and Tested combination 32 of 48816: (4, 4, 0, 2, 31), taking 0.04 seconds to get val score of 0.8037
#         Current best combo: (4, 4, 0, 2, 31) with val score 0.8037
# Trained and Tested combination 33 of 48816: (4, 4, 0, 2, 32), taking 0.04 seconds to get val score of 0.8022
#         Current best combo: (4, 4, 0, 2, 31) with val score 0.8037
# Trained and Tested combination 34 of 48816: (4, 4, 0, 2, 33), taking 0.05 seconds to get val score of 0.8044
#         Current best combo: (4, 4, 0, 2, 33) with val score 0.8044
# Trained and Tested combination 35 of 48816: (4, 4, 0, 2, 34), taking 0.07 seconds to get val score of 0.8044
#         Current best combo: (4, 4, 0, 2, 33) with val score 0.8044
# Trained and Tested combination 36 of 48816: (4, 4, 0, 2, 35), taking 0.06 seconds to get val score of 0.8022
#         Current best combo: (4, 4, 0, 2, 33) with val score 0.8044
# Trained and Tested combination 37 of 48816: (4, 4, 0, 2, 36), taking 0.06 seconds to get val score of 0.8048
#         Current best combo: (4, 4, 0, 2, 36) with val score 0.8048
# Trained and Tested combination 38 of 48816: (4, 4, 0, 2, 37), taking 0.05 seconds to get val score of 0.8022
#         Current best combo: (4, 4, 0, 2, 36) with val score 0.8048
# Trained and Tested combination 39 of 48816: (4, 4, 0, 2, 38), taking 0.05 seconds to get val score of 0.8056
#         Current best combo: (4, 4, 0, 2, 38) with val score 0.8056
# Trained and Tested combination 40 of 48816: (4, 4, 0, 2, 39), taking 0.05 seconds to get val score of 0.8041
#         Current best combo: (4, 4, 0, 2, 38) with val score 0.8056
# Trained and Tested combination 41 of 48816: (4, 4, 0, 2, 40), taking 0.05 seconds to get val score of 0.8033
#         Current best combo: (4, 4, 0, 2, 38) with val score 0.8056
# Trained and Tested combination 42 of 48816: (4, 4, 0, 2, 41), taking 0.05 seconds to get val score of 0.8074
#         Current best combo: (4, 4, 0, 2, 41) with val score 0.8074
# Trained and Tested combination 43 of 48816: (4, 4, 0, 2, 42), taking 0.06 seconds to get val score of 0.807
#         Current best combo: (4, 4, 0, 2, 41) with val score 0.8074
# Trained and Tested combination 44 of 48816: (4, 4, 0, 2, 43), taking 0.05 seconds to get val score of 0.8089
#         Current best combo: (4, 4, 0, 2, 43) with val score 0.8089
# Trained and Tested combination 45 of 48816: (4, 4, 0, 2, 44), taking 0.05 seconds to get val score of 0.8096
#         Current best combo: (4, 4, 0, 2, 44) with val score 0.8096
# Trained and Tested combination 46 of 48816: (4, 4, 0, 2, 45), taking 0.07 seconds to get val score of 0.8063
#         Current best combo: (4, 4, 0, 2, 44) with val score 0.8096
# Trained and Tested combination 47 of 48816: (4, 4, 0, 2, 46), taking 0.05 seconds to get val score of 0.807
#         Current best combo: (4, 4, 0, 2, 44) with val score 0.8096
# Trained and Tested combination 48 of 48816: (4, 4, 0, 2, 47), taking 0.06 seconds to get val score of 0.8089
#         Current best combo: (4, 4, 0, 2, 44) with val score 0.8096
# Trained and Tested combination 49 of 48816: (4, 4, 0, 2, 48), taking 0.06 seconds to get val score of 0.8081
#         Current best combo: (4, 4, 0, 2, 44) with val score 0.8096
# Trained and Tested combination 50 of 48816: (4, 4, 0, 2, 49), taking 0.06 seconds to get val score of 0.81
#         Current best combo: (4, 4, 0, 2, 49) with val score 0.81
# Trained and Tested combination 51 of 48816: (4, 4, 0, 2, 50), taking 0.06 seconds to get val score of 0.8111
#         Current best combo: (4, 4, 0, 2, 50) with val score 0.8111
# Trained and Tested combination 52 of 48816: (4, 4, 0, 2, 51), taking 0.07 seconds to get val score of 0.813
#         Current best combo: (4, 4, 0, 2, 51) with val score 0.813
# Trained and Tested combination 53 of 48816: (4, 4, 0, 2, 52), taking 0.07 seconds to get val score of 0.8174
#         Current best combo: (4, 4, 0, 2, 52) with val score 0.8174
# Trained and Tested combination 54 of 48816: (4, 4, 0, 2, 53), taking 0.11 seconds to get val score of 0.8156
#         Current best combo: (4, 4, 0, 2, 52) with val score 0.8174
# Trained and Tested combination 55 of 48816: (4, 4, 0, 2, 54), taking 0.11 seconds to get val score of 0.8174
#         Current best combo: (4, 4, 0, 2, 52) with val score 0.8174
# Trained and Tested combination 56 of 48816: (4, 4, 0, 2, 55), taking 0.1 seconds to get val score of 0.8156
#         Current best combo: (4, 4, 0, 2, 52) with val score 0.8174
# Trained and Tested combination 57 of 48816: (4, 4, 0, 2, 56), taking 0.11 seconds to get val score of 0.8163
#         Current best combo: (4, 4, 0, 2, 52) with val score 0.8174
# Trained and Tested combination 58 of 48816: (4, 4, 0, 2, 57), taking 0.11 seconds to get val score of 0.8137
#         Current best combo: (4, 4, 0, 2, 52) with val score 0.8174
# Trained and Tested combination 59 of 48816: (4, 4, 0, 2, 58), taking 0.11 seconds to get val score of 0.8159
#         Current best combo: (4, 4, 0, 2, 52) with val score 0.8174
# Trained and Tested combination 60 of 48816: (4, 4, 0, 2, 59), taking 0.11 seconds to get val score of 0.8159
#         Current best combo: (4, 4, 0, 2, 52) with val score 0.8174
# Trained and Tested combination 61 of 48816: (4, 4, 0, 2, 60), taking 0.15 seconds to get val score of 0.8156
#         Current best combo: (4, 4, 0, 2, 52) with val score 0.8174
# Trained and Tested combination 62 of 48816: (4, 4, 0, 2, 61), taking 0.14 seconds to get val score of 0.8137
#         Current best combo: (4, 4, 0, 2, 52) with val score 0.8174
# Trained and Tested combination 63 of 48816: (4, 4, 0, 2, 62), taking 0.14 seconds to get val score of 0.8152
#         Current best combo: (4, 4, 0, 2, 52) with val score 0.8174
# Trained and Tested combination 64 of 48816: (4, 4, 0, 2, 63), taking 0.14 seconds to get val score of 0.813
#         Current best combo: (4, 4, 0, 2, 52) with val score 0.8174
# Trained and Tested combination 65 of 48816: (4, 4, 0, 2, 64), taking 0.11 seconds to get val score of 0.8163
#         Current best combo: (4, 4, 0, 2, 52) with val score 0.8174
# Trained and Tested combination 66 of 48816: (4, 4, 0, 2, 65), taking 0.1 seconds to get val score of 0.817
#         Current best combo: (4, 4, 0, 2, 52) with val score 0.8174
# Trained and Tested combination 67 of 48816: (4, 4, 0, 2, 66), taking 0.1 seconds to get val score of 0.8185
#         Current best combo: (4, 4, 0, 2, 66) with val score 0.8185
# Trained and Tested combination 68 of 48816: (4, 4, 0, 2, 67), taking 0.1 seconds to get val score of 0.8133
#         Current best combo: (4, 4, 0, 2, 66) with val score 0.8185
# Trained and Tested combination 69 of 48816: (4, 4, 0, 2, 68), taking 0.11 seconds to get val score of 0.8137
#         Current best combo: (4, 4, 0, 2, 66) with val score 0.8185
# Trained and Tested combination
#         Current best combo: (4, 4, 0, 2, 66) with val score 0.8185
# Trained and Tested combination 106 of 48816: (4, 4, 0, 2, 105), taking 0.23 seconds to get val score of 0.8181
#         Current best combo: (4, 4, 0, 2, 66) with val score 0.8185
# Trained and Tested combination 107 of 48816: (4, 4, 0, 2, 106), taking 0.17 seconds to get val score of 0.8174
#         Current best combo: (4, 4, 0, 2, 66) with val score 0.8185
# Trained and Tested combination 108 of 48816: (4, 4, 0, 2, 107), taking 0.18 seconds to get val score of 0.8189
#         Current best combo: (4, 4, 0, 2, 107) with val score 0.8189
# Trained and Tested combination 109 of 48816: (4, 4, 0, 2, 108), taking 0.19 seconds to get val score of 0.8196
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
# Trained and Tested combination 110 of 48816: (4, 4, 0, 2, 109), taking 0.17 seconds to get val score of 0.8178
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
# Trained and Tested combination 111 of 48816: (4, 4, 0, 2, 110), taking 0.25 seconds to get val score of 0.8193
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
# Trained and Tested combination 112 of 48816: (4, 4, 0, 2, 111), taking 0.2 seconds to get val score of 0.8181
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
# Trained and Tested combination 113 of 48816: (4, 4, 0, 2, 112), taking 0.19 seconds to get val score of 0.8181
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
#
# Best combo after this hyperparameter: (4, 4, 0, 2, 108) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: C (index: 0)
#
# Trained and Tested combination 114 of 48816: (0, 4, 0, 2, 108), taking 0.08 seconds to get val score of 0.7778
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
# Trained and Tested combination 115 of 48816: (1, 4, 0, 2, 108), taking 0.11 seconds to get val score of 0.7763
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
# Trained and Tested combination 116 of 48816: (2, 4, 0, 2, 108), taking 0.11 seconds to get val score of 0.7811
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
# Trained and Tested combination 117 of 48816: (3, 4, 0, 2, 108), taking 0.14 seconds to get val score of 0.8122
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
# Already Trained and Tested combination (4, 4, 0, 2, 108), which had val score of 0.8196
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196.
#         Has trained 117 of 48816 combinations so far
# Trained and Tested combination 118 of 48816: (5, 4, 0, 2, 108), taking 0.19 seconds to get val score of 0.8159
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
#
# Best combo after this hyperparameter: (4, 4, 0, 2, 108) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_iter (index: 1)
#
# Trained and Tested combination 119 of 48816: (4, 0, 0, 2, 108), taking 0.18 seconds to get val score of 0.8196
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
# Trained and Tested combination 120 of 48816: (4, 1, 0, 2, 108), taking 0.17 seconds to get val score of 0.8196
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
# Trained and Tested combination 121 of 48816: (4, 2, 0, 2, 108), taking 0.18 seconds to get val score of 0.8196
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
# Trained and Tested combination 122 of 48816: (4, 3, 0, 2, 108), taking 0.16 seconds to get val score of 0.8196
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
# Already Trained and Tested combination (4, 4, 0, 2, 108), which had val score of 0.8196
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196.
#         Has trained 122 of 48816 combinations so far
# Trained and Tested combination 123 of 48816: (4, 5, 0, 2, 108), taking 0.17 seconds to get val score of 0.8196
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
#
# Best combo after this hyperparameter: (4, 4, 0, 2, 108) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: penalty (index: 2)
#
# Already Trained and Tested combination (4, 4, 0, 2, 108), which had val score of 0.8196
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196.
#         Has trained 123 of 48816 combinations so far
# Trained and Tested combination 124 of 48816: (4, 4, 1, 2, 108), taking 2.63 seconds to get val score of 0.8193
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
#
# Best combo after this hyperparameter: (4, 4, 0, 2, 108) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: tol (index: 3)
#
# Trained and Tested combination 125 of 48816: (4, 4, 0, 0, 108), taking 0.44 seconds to get val score of 0.8193
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
# Trained and Tested combination 126 of 48816: (4, 4, 0, 1, 108), taking 0.29 seconds to get val score of 0.8193
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
# Already Trained and Tested combination (4, 4, 0, 2, 108), which had val score of 0.8196
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196.
#         Has trained 126 of 48816 combinations so far
# Trained and Tested combination 127 of 48816: (4, 4, 0, 3, 108), taking 0.14 seconds to get val score of 0.8193
#         Current best combo: (4, 4, 0, 2, 108) with val score 0.8196
# Trained and Tested combination 128 of 48816: (4, 4, 0, 4, 108), taking 0.16 seconds to get val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 129 of 48816: (4, 4, 0, 5, 108), taking 0.11 seconds to get val score of 0.8041
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
#
# Best combo after this hyperparameter: (4, 4, 0, 4, 108) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 0 (C) ROUND 2
#
# Round 2
# Hyperparameter: features (index: 4)
#
# Trained and Tested combination 130 of 48816: (4, 4, 0, 4, 0), taking 0.01 seconds to get val score of 0.7748
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 131 of 48816: (4, 4, 0, 4, 1), taking 0.01 seconds to get val score of 0.7744
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 132 of 48816: (4, 4, 0, 4, 2), taking 0.01 seconds to get val score of 0.7781
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 133 of 48816: (4, 4, 0, 4, 3), taking 0.01 seconds to get val score of 0.7759
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 134 of 48816: (4, 4, 0, 4, 4), taking 0.02 seconds to get val score of 0.7744
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 135 of 48816: (4, 4, 0, 4, 5), taking 0.01 seconds to get val score of 0.7774
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 136 of 48816: (4, 4, 0, 4, 6), taking 0.02 seconds to get val score of 0.7767
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 137 of 48816: (4, 4, 0, 4, 7), taking 0.02 seconds to get val score of 0.78
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 138 of 48816: (4, 4, 0, 4, 8), taking 0.02 seconds to get val score of 0.7796
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 139 of 48816: (4, 4, 0, 4, 9), taking 0.02 seconds to get val score of 0.7804
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 140 of 48816: (4, 4, 0, 4, 10), taking 0.02 seconds to get val score of 0.7822
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 141 of 48816: (4, 4, 0, 4, 11), taking 0.01 seconds to get val score of 0.7819
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 142 of 48816: (4, 4, 0, 4, 12), taking 0.01 seconds to get val score of 0.7859
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 143 of 48816: (4, 4, 0, 4, 13), taking 0.01 seconds to get val score of 0.7844
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 144 of 48816: (4, 4, 0, 4, 14), taking 0.01 seconds to get val score of 0.7859
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 145 of 48816: (4, 4, 0, 4, 15), taking 0.01 seconds to get val score of 0.7889
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 146 of 48816: (4, 4, 0, 4, 16), taking 0.01 seconds to get val score of 0.79
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 147 of 48816: (4, 4, 0, 4, 17), taking 0.01 seconds to get val score of 0.7878
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 148 of 48816: (4, 4, 0, 4, 18), taking 0.02 seconds to get val score of 0.7881
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 149 of 48816: (4, 4, 0, 4, 19), taking 0.01 seconds to get val score of 0.7911
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 150 of 48816: (4, 4, 0, 4, 20), taking 0.02 seconds to get val score of 0.7922
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 151 of 48816: (4, 4, 0, 4, 21), taking 0.02 seconds to get val score of 0.7956
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 152 of 48816: (4, 4, 0, 4, 22), taking 0.02 seconds to get val score of 0.7952
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 153 of 48816: (4, 4, 0, 4, 23), taking 0.02 seconds to get val score of 0.7959
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 154 of 48816: (4, 4, 0, 4, 24), taking 0.02 seconds to get val score of 0.797
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 155 of 48816: (4, 4, 0, 4, 25), taking 0.02 seconds to get val score of 0.7989
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 156 of 48816: (4, 4, 0, 4, 26), taking 0.02 seconds to get val score of 0.7952
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 157 of 48816: (4, 4, 0, 4, 27), taking 0.02 seconds to get val score of 0.7956
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 158 of 48816: (4, 4, 0, 4, 28), taking 0.02 seconds to get val score of 0.7978
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 159 of 48816: (4, 4, 0, 4, 29), taking 0.03 seconds to get val score of 0.8
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 230 of 48816: (4, 4, 0, 4, 100), taking 0.1 seconds to get val score of 0.8078
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 231 of 48816: (4, 4, 0, 4, 101), taking 0.09 seconds to get val score of 0.8137
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 232 of 48816: (4, 4, 0, 4, 102), taking 0.12 seconds to get val score of 0.8159
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 233 of 48816: (4, 4, 0, 4, 103), taking 0.09 seconds to get val score of 0.8167
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 234 of 48816: (4, 4, 0, 4, 104), taking 0.1 seconds to get val score of 0.8174
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 235 of 48816: (4, 4, 0, 4, 105), taking 0.09 seconds to get val score of 0.8137
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 236 of 48816: (4, 4, 0, 4, 106), taking 0.1 seconds to get val score of 0.8163
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 237 of 48816: (4, 4, 0, 4, 107), taking 0.1 seconds to get val score of 0.8163
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Already Trained and Tested combination (4, 4, 0, 4, 108), which had val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 237 of 48816 combinations so far
# Trained and Tested combination 238 of 48816: (4, 4, 0, 4, 109), taking 0.1 seconds to get val score of 0.8144
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 239 of 48816: (4, 4, 0, 4, 110), taking 0.1 seconds to get val score of 0.8189
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 240 of 48816: (4, 4, 0, 4, 111), taking 0.11 seconds to get val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 241 of 48816: (4, 4, 0, 4, 112), taking 0.12 seconds to get val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
#
# Best combo after this hyperparameter: (4, 4, 0, 4, 108) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: C (index: 0)
#
# Trained and Tested combination 242 of 48816: (0, 4, 0, 4, 108), taking 0.08 seconds to get val score of 0.7778
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 243 of 48816: (1, 4, 0, 4, 108), taking 0.12 seconds to get val score of 0.7763
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 244 of 48816: (2, 4, 0, 4, 108), taking 0.12 seconds to get val score of 0.7767
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 245 of 48816: (3, 4, 0, 4, 108), taking 0.13 seconds to get val score of 0.8144
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Already Trained and Tested combination (4, 4, 0, 4, 108), which had val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 245 of 48816 combinations so far
# Trained and Tested combination 246 of 48816: (5, 4, 0, 4, 108), taking 0.15 seconds to get val score of 0.8178
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
#
# Best combo after this hyperparameter: (4, 4, 0, 4, 108) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_iter (index: 1)
#
# Trained and Tested combination 247 of 48816: (4, 0, 0, 4, 108), taking 0.16 seconds to get val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 248 of 48816: (4, 1, 0, 4, 108), taking 0.17 seconds to get val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 249 of 48816: (4, 2, 0, 4, 108), taking 0.17 seconds to get val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Trained and Tested combination 250 of 48816: (4, 3, 0, 4, 108), taking 0.16 seconds to get val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
# Already Trained and Tested combination (4, 4, 0, 4, 108), which had val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 250 of 48816 combinations so far
# Trained and Tested combination 251 of 48816: (4, 5, 0, 4, 108), taking 0.11 seconds to get val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
#
# Best combo after this hyperparameter: (4, 4, 0, 4, 108) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: penalty (index: 2)
#
# Already Trained and Tested combination (4, 4, 0, 4, 108), which had val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 251 of 48816 combinations so far
# Trained and Tested combination 252 of 48816: (4, 4, 1, 4, 108), taking 0.22 seconds to get val score of 0.8152
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204
#
# Best combo after this hyperparameter: (4, 4, 0, 4, 108) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: tol (index: 3)
#
# Already Trained and Tested combination (4, 4, 0, 0, 108), which had val score of 0.8193
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 252 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 1, 108), which had val score of 0.8193
# ...
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 75), which had val score of 0.8126
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 76), which had val score of 0.8096
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 77), which had val score of 0.8107
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 78), which had val score of 0.8115
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 79), which had val score of 0.8085
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 80), which had val score of 0.8107
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 81), which had val score of 0.81
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 82), which had val score of 0.8126
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 83), which had val score of 0.8122
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 84), which had val score of 0.8122
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 85), which had val score of 0.8111
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 86), which had val score of 0.8119
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 87), which had val score of 0.8148
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 88), which had val score of 0.81
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 89), which had val score of 0.8078
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 90), which had val score of 0.8115
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 91), which had val score of 0.8115
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 92), which had val score of 0.8115
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 93), which had val score of 0.8085
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 94), which had val score of 0.81
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 95), which had val score of 0.8111
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 96), which had val score of 0.8115
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 97), which had val score of 0.8159
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 98), which had val score of 0.8122
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 99), which had val score of 0.8156
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 100), which had val score of 0.8078
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 101), which had val score of 0.8137
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 102), which had val score of 0.8159
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 103), which had val score of 0.8167
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 104), which had val score of 0.8174
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 105), which had val score of 0.8137
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 106), which had val score of 0.8163
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 107), which had val score of 0.8163
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 108), which had val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 109), which had val score of 0.8144
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 110), which had val score of 0.8189
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 111), which had val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 112), which had val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
#
# Best combo after this hyperparameter: (4, 4, 0, 4, 108) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: C (index: 0)
#
# Already Trained and Tested combination (0, 4, 0, 4, 108), which had val score of 0.7778
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (1, 4, 0, 4, 108), which had val score of 0.7763
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (2, 4, 0, 4, 108), which had val score of 0.7767
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (3, 4, 0, 4, 108), which had val score of 0.8144
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 108), which had val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (5, 4, 0, 4, 108), which had val score of 0.8178
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
#
# Best combo after this hyperparameter: (4, 4, 0, 4, 108) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_iter (index: 1)
#
# Already Trained and Tested combination (4, 0, 0, 4, 108), which had val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 1, 0, 4, 108), which had val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 2, 0, 4, 108), which had val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 108), which had val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 108), which had val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 5, 0, 4, 108), which had val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
#
# Best combo after this hyperparameter: (4, 4, 0, 4, 108) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: penalty (index: 2)
#
# Already Trained and Tested combination (4, 4, 0, 4, 108), which had val score of 0.8204
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
# Already Trained and Tested combination (4, 4, 1, 4, 108), which had val score of 0.8152
#         Current best combo: (4, 4, 0, 4, 108) with val score 0.8204.
#         Has trained 267 of 48816 combinations so far
#
# Best combo after this hyperparameter: (4, 4, 0, 4, 108) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.8203703703703704
# Max Test Score:
#  0.802963
# Max Combo Index:
#  (4, 4, 0, 4, 108) out of [6, 6, 2, 6, 113] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 1, 'max_iter': 800, 'penalty': 'l1', 'tol': 0.1, 'features': 108}
# Max Combo Features:
#  (29667, 59920, 41191, 9639, 11997, 14175, 66664, 7149, 6603, 32996, 3710, 4587, 14700, 25279, 27675, 67128, 66157, 67050, 68180, 7075, 59749, 20338, 28574, 35861, 36130, 3061, 22106, 11721, 13444, 9404, 14989, 567, 27004, 6826, 36615, 34203, 16127, 6771, 4193, 37572, 66519, 2160, 27889, 1762, 36120, 67094, 35137, 36623, 3677, 3863, 67659, 2359, 63650, 112, 67892, 37744, 60303, 68047, 9072, 17942, 9372, 27745, 6450, 13095, 5563, 40128, 2491, 34703, 13142, 57787, 64230, 49708, 4501, 17577, 44387, 13454, 59415, 6308, 23378, 43389, 13877, 56288, 12469, 67781, 50832, 66239, 47800, 52938, 66841, 5607, 3414, 52187, 32465, 45854, 65820, 8584, 31185, 2038, 1574, 3094, 500, 29750, 50043, 13792, 42802, 23414, 27046, 62724, 389, 13727, 1651, 67637, 2688, 67361, 23131, 9050, 16198, 17050, 44471, 15432, 3403, 29971, 1663, 39524, 10971, 16331, 16037, 41662, 34860, 30159, 15118, 17674, 39435, 26704, 2567, 67494, 6882, 12746, 7300, 58670, 29441, 36203, 14524, 68147, 18304, 29592, 48456, 6638, 15998, 29601, 898, 43055, 18791, 51366, 1120, 11229, 5082, 51794, 2522, 49870, 30337, 35352, 11926, 21109, 14423, 1774, 19240, 48631, 58751, 43307, 18584, 2060, 111, 3315, 10330, 4875, 710, 17607, 31239, 27581, 1629, 16422, 22771, 66508, 20178, 16474, 13010, 8973, 25246, 3072, 15022, 4083, 3907, 25175, 1429, 38537, 3039, 11893, 67825, 50463, 17566, 66797, 2436, 46601, 7001, 12924, 11786, 22655, 2215, 58438, 12206, 20544, 67106, 60336, 1142, 9726, 64229, 775, 14637, 5401, 14361, 39106, 18484, 34377, 16564, 10842, 55893, 1441, 1219