# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'gnb'
FEATURE_IMPORTANCE_ORDERING = 'xgb'
PREPROCESSING = 'Baseline'
TUNER = 'jiaochengb-f1'
FEATURE_ENGINEERING = 'tfidf'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os
import pickle
from scipy.sparse import load_npz

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/PrivatePackages" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/COMP90051-A1__Groupwork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
else:
    py_file_location = '../../PrivatePackages'
    home_directory = '../../'

sys.path.append(os.path.abspath(py_file_location))

from Tuners import JiaoChengB_F1

import pandas as pd

# %%
## Parameters that are same for every script

SEED = 2608

TASK_TYPE = 'Classification' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = True # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from xgboost import XGBClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'var_smoothing': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    }

tuning_order = [
    'features',
    'var_smoothing'
]

default_hyperparameter_values = {'var_smoothing': 1, 'features': 0}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_x = load_npz(home_directory + f'data/curated/baseline/train_{FEATURE_ENGINEERING}_x.npz')
val_x = load_npz(home_directory + f'data/curated/baseline/val_{FEATURE_ENGINEERING}_x.npz')
test_x = load_npz(home_directory + f'data/curated/baseline/test_{FEATURE_ENGINEERING}_x.npz')

with open(home_directory + 'data/curated/baseline/train_y.pkl', 'rb') as f:
    train_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/val_y.pkl', 'rb') as f:
    val_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/test_y.pkl', 'rb') as f:
    test_y = pickle.load(f)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = JiaoChengB_F1.JiaoChengB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'xgboost.sklearn.XGBClassifier'>, which is a Classification model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# FEATURE_INDEX: 0 (features) ROUND 1
#
# Round 1
# Hyperparameter: features (index: 1)
#
# Trained and Tested combination 1 of 744: (5, 0), taking 2.1 seconds to get val score of 0.7554
#         Current best combo: (5, 0) with val score 0.7554
# Trained and Tested combination 2 of 744: (5, 1), taking 0.41 seconds to get val score of 0.7598
#         Current best combo: (5, 1) with val score 0.7598
# Trained and Tested combination 3 of 744: (5, 2), taking 0.56 seconds to get val score of 0.7705
#         Current best combo: (5, 2) with val score 0.7705
# Trained and Tested combination 4 of 744: (5, 3), taking 0.7 seconds to get val score of 0.7659
#         Current best combo: (5, 2) with val score 0.7705
# Trained and Tested combination 5 of 744: (5, 4), taking 0.9 seconds to get val score of 0.7704
#         Current best combo: (5, 2) with val score 0.7705
# Trained and Tested combination 6 of 744: (5, 5), taking 0.99 seconds to get val score of 0.7739
#         Current best combo: (5, 5) with val score 0.7739
# Trained and Tested combination 7 of 744: (5, 6), taking 3.75 seconds to get val score of 0.7838
#         Current best combo: (5, 6) with val score 0.7838
# Trained and Tested combination 8 of 744: (5, 7), taking 1.28 seconds to get val score of 0.7799
#         Current best combo: (5, 6) with val score 0.7838
# Trained and Tested combination 9 of 744: (5, 8), taking 1.46 seconds to get val score of 0.7861
#         Current best combo: (5, 8) with val score 0.7861
# Trained and Tested combination 10 of 744: (5, 9), taking 1.69 seconds to get val score of 0.7967
#         Current best combo: (5, 9) with val score 0.7967
# Trained and Tested combination 11 of 744: (5, 10), taking 1.87 seconds to get val score of 0.7986
#         Current best combo: (5, 10) with val score 0.7986
# Trained and Tested combination 12 of 744: (5, 11), taking 3.15 seconds to get val score of 0.7979
#         Current best combo: (5, 10) with val score 0.7986
# Trained and Tested combination 13 of 744: (5, 12), taking 3.32 seconds to get val score of 0.8008
#         Current best combo: (5, 12) with val score 0.8008
# Trained and Tested combination 14 of 744: (5, 13), taking 2.36 seconds to get val score of 0.8036
#         Current best combo: (5, 13) with val score 0.8036
# Trained and Tested combination 15 of 744: (5, 14), taking 2.52 seconds to get val score of 0.8121
#         Current best combo: (5, 14) with val score 0.8121
# Trained and Tested combination 16 of 744: (5, 15), taking 2.81 seconds to get val score of 0.803
#         Current best combo: (5, 14) with val score 0.8121
# Trained and Tested combination 17 of 744: (5, 16), taking 5.15 seconds to get val score of 0.8088
#         Current best combo: (5, 14) with val score 0.8121
# Trained and Tested combination 18 of 744: (5, 17), taking 3.0 seconds to get val score of 0.8091
#         Current best combo: (5, 14) with val score 0.8121
# Trained and Tested combination 19 of 744: (5, 18), taking 3.15 seconds to get val score of 0.801
#         Current best combo: (5, 14) with val score 0.8121
# Trained and Tested combination 20 of 744: (5, 19), taking 5.86 seconds to get val score of 0.8072
#         Current best combo: (5, 14) with val score 0.8121
# Trained and Tested combination 21 of 744: (5, 20), taking 3.54 seconds to get val score of 0.7981
#         Current best combo: (5, 14) with val score 0.8121
# Trained and Tested combination 22 of 744: (5, 21), taking 3.68 seconds to get val score of 0.8043
#         Current best combo: (5, 14) with val score 0.8121
# Trained and Tested combination 23 of 744: (5, 22), taking 6.38 seconds to get val score of 0.8118
#         Current best combo: (5, 14) with val score 0.8121
# Trained and Tested combination 24 of 744: (5, 23), taking 4.03 seconds to get val score of 0.8053
#         Current best combo: (5, 14) with val score 0.8121
# Trained and Tested combination 25 of 744: (5, 24), taking 6.74 seconds to get val score of 0.8053
#         Current best combo: (5, 14) with val score 0.8121
# Trained and Tested combination 26 of 744: (5, 25), taking 4.34 seconds to get val score of 0.8074
#         Current best combo: (5, 14) with val score 0.8121
# Trained and Tested combination 27 of 744: (5, 26), taking 5.71 seconds to get val score of 0.8076
#         Current best combo: (5, 14) with val score 0.8121
# Trained and Tested combination 28 of 744: (5, 27), taking 5.94 seconds to get val score of 0.8109
#         Current best combo: (5, 14) with val score 0.8121
# Trained and Tested combination 29 of 744: (5, 28), taking 5.01 seconds to get val score of 0.8135
#         Current best combo: (5, 28) with val score 0.8135
# Trained and Tested combination 30 of 744: (5, 29), taking 7.62 seconds to get val score of 0.8113
#         Current best combo: (5, 28) with val score 0.8135
# Trained and Tested combination 31 of 744: (5, 30), taking 10.23 seconds to get val score of 0.8062
#         Current best combo: (5, 28) with val score 0.8135
# Trained and Tested combination 32 of 744: (5, 31), taking 5.42 seconds to get val score of 0.8084
#         Current best combo: (5, 28) with val score 0.8135
# Trained and Tested combination 33 of 744: (5, 32), taking 8.04 seconds to get val score of 0.8106
#         Current best combo: (5, 28) with val score 0.8135
# Trained and Tested combination 34 of 744: (5, 33), taking 5.91 seconds to get val score of 0.8104
#         Current best combo: (5, 28) with val score 0.8135
# Trained and Tested combination 35 of 744: (5, 34), taking 8.45 seconds to get val score of 0.8122
#         Current best combo: (5, 28) with val score 0.8135
# Trained and Tested combination 36 of 744: (5, 35), taking 6.45 seconds to get val score of 0.8119
#         Current best combo: (5, 28) with val score 0.8135
# Trained and Tested combination 37 of 744: (5, 36), taking 8.46 seconds to get val score of 0.809
#         Current best combo: (5, 28) with val score 0.8135
# Trained and Tested combination 38 of 744: (5, 37), taking 9.0 seconds to get val score of 0.8104
#         Current best combo: (5, 28) with val score 0.8135
# Trained and Tested combination 39 of 744: (5, 38), taking 6.81 seconds to get val score of 0.8163
#         Current best combo: (5, 38) with val score 0.8163
# Trained and Tested combination 40 of 744: (5, 39), taking 9.35 seconds to get val score of 0.8127
#         Current best combo: (5, 38) with val score 0.8163
# Trained and Tested combination 41 of 744: (5, 40), taking 9.45 seconds to get val score of 0.8135
#         Current best combo: (5, 38) with val score 0.8163
# Trained and Tested combination 42 of 744: (5, 41), taking 7.11 seconds to get val score of 0.8142
#         Current best combo: (5, 38) with val score 0.8163
# Trained and Tested combination 43 of 744: (5, 42), taking 9.78 seconds to get val score of 0.8114
#         Current best combo: (5, 38) with val score 0.8163
# Trained and Tested combination 44 of 744: (5, 43), taking 12.35 seconds to get val score of 0.8195
#         Current best combo: (5, 43) with val score 0.8195
# Trained and Tested combination 45 of 744: (5, 44), taking 10.18 seconds to get val score of 0.8173
#         Current best combo: (5, 43) with val score 0.8195
# Trained and Tested combination 46 of 744: (5, 45), taking 8.29 seconds to get val score of 0.8165
#         Current best combo: (5, 43) with val score 0.8195
# Trained and Tested combination 47 of 744: (5, 46), taking 9.87 seconds to get val score of 0.8149
#         Current best combo: (5, 43) with val score 0.8195
# Trained and Tested combination 48 of 744: (5, 47), taking 10.57 seconds to get val score of 0.8184
#         Current best combo: (5, 43) with val score 0.8195
# Trained and Tested combination 49 of 744: (5, 48), taking 10.87 seconds to get val score of 0.8227
#         Current best combo: (5, 48) with val score 0.8227
# Trained and Tested combination 50 of 744: (5, 49), taking 11.18 seconds to get val score of 0.8105
#         Current best combo: (5, 48) with val score 0.8227
# Trained and Tested combination 51 of 744: (5, 50), taking 9.62 seconds to get val score of 0.817
#         Current best combo: (5, 48) with val score 0.8227
# Trained and Tested combination 52 of 744: (5, 51), taking 10.46 seconds to get val score of 0.82
#         Current best combo: (5, 48) with val score 0.8227
# Trained and Tested combination 53 of 744: (5, 52), taking 11.64 seconds to get val score of 0.828
#         Current best combo: (5, 52) with val score 0.828
# Trained and Tested combination 54 of 744: (5, 53), taking 12.8 seconds to get val score of 0.8263
#         Current best combo: (5, 52) with val score 0.828
# Trained and Tested combination 55 of 744: (5, 54), taking 12.59 seconds to get val score of 0.8222
#         Current best combo: (5, 52) with val score 0.828
# Trained and Tested combination 56 of 744: (5, 55), taking 12.23 seconds to get val score of 0.8187
#         Current best combo: (5, 52) with val score 0.828
# Trained and Tested combination 57 of 744: (5, 56), taking 12.48 seconds to get val score of 0.827
#         Current best combo: (5, 52) with val score 0.828
# Trained and Tested combination 58 of 744: (5, 57), taking 12.44 seconds to get val score of 0.8216
#         Current best combo: (5, 52) with val score 0.828
# Trained and Tested combination 59 of 744: (5, 58), taking 12.8 seconds to get val score of 0.8283
#         Current best combo: (5, 58) with val score 0.8283
# Trained and Tested combination 60 of 744: (5, 59), taking 12.5 seconds to get val score of 0.8258
#         Current best combo: (5, 58) with val score 0.8283
# Trained and Tested combination 61 of 744: (5, 60), taking 12.83 seconds to get val score of 0.8253
#         Current best combo: (5, 58) with val score 0.8283
# Trained and Tested combination 62 of 744: (5, 61), taking 13.26 seconds to get val score of 0.8231
#         Current best combo: (5, 58) with val score 0.8283
# Trained and Tested combination 63 of 744: (5, 62), taking 15.56 seconds to get val score of 0.8263
#         Current best combo: (5, 58) with val score 0.8283
# Trained and Tested combination 64 of 744: (5, 63), taking 13.48 seconds to get val score of 0.8295
#         Current best combo: (5, 63) with val score 0.8295
# Trained and Tested combination 65 of 744: (5, 64), taking 13.87 seconds to get val score of 0.8314
#         Current best combo: (5, 64) with val score 0.8314
# Trained and Tested combination 66 of 744: (5, 65), taking 13.59 seconds to get val score of 0.8248
#         Current best combo: (5, 64) with val score 0.8314
# Trained and Tested combination 67 of 744: (5, 66), taking 14.06 seconds to get val score of 0.8318
#         Current best combo: (5, 66) with val score 0.8318
# Trained and Tested combination 68 of 744: (5, 67), taking 13.8 seconds to get val score of 0.8309
#         Current best combo: (5, 66) with val score 0.8318
# Trained and Tested combination 69 of 744: (5, 68), taking 14.08 seconds to get val score of 0.8317
#         Current best combo: (5, 66) with val score 0.8318
# Trained and Tested combination 70 of 744: (5, 69), taking 15.84 seconds to get val score of 0.8301
#         Current best combo: (5, 66) with val score 0.8318
# Trained and Tested combination 71 of 744: (5, 70), taking 17.21 seconds to get val score of 0.8287
#         Current best combo: (5, 66) with val score 0.8318
# Trained and Tested combination 72 of 744: (5, 71), taking 14.97 seconds to get val score of 0.8208
#         Current best combo: (5, 66) with val score 0.8318
# Trained and Tested combination 73 of 744: (5, 72), taking 14.82 seconds to get val score of 0.8326
#         Current best combo: (5, 72) with val score 0.8326
# Trained and Tested combination 74 of 744: (5, 73), taking 15.24 seconds to get val score of 0.827
#         Current best combo: (5, 72) with val score 0.8326
# Trained and Tested combination 75 of 744: (5, 74), taking 15.82 seconds to get val score of 0.8287
#         Current best combo: (5, 72) with val score 0.8326
# Trained and Tested combination 76 of 744: (5, 75), taking 16.22 seconds to get val score of 0.8258
#         Current best combo: (5, 72) with val score 0.8326
# Trained and Tested combination 77 of 744: (5, 76), taking 15.46 seconds to get val score of 0.8331
#         Current best combo: (5, 76) with val score 0.8331
# Trained and Tested combination 78 of 744: (5, 77), taking 17.8 seconds to get val score of 0.8245
#         Current best combo: (5, 76) with val score 0.8331
# Trained and Tested combination 79 of 744: (5, 78), taking 17.9 seconds to get val score of 0.828
#         Current best combo: (5, 76) with val score 0.8331
# Trained and Tested combination 80 of 744: (5, 79), taking 15.4 seconds to get val score of 0.8281
#         Current best combo: (5, 76) with val score 0.8331
# Trained and Tested combination 81 of 744: (5, 80), taking 16.03 seconds to get val score of 0.8266
#         Current best combo: (5, 76) with val score 0.8331
# Trained and Tested combination 82 of 744: (5, 81), taking 15.97 seconds to get val score of 0.8259
#         Current best combo: (5, 76) with val score 0.8331
# Trained and Tested combination 83 of 744: (5, 82), taking 18.18 seconds to get val score of 0.825
#         Current best combo: (5, 76) with val score 0.8331
# Trained and Tested combination 84 of 744: (5, 83), taking 18.6 seconds to get val score of 0.8312
#         Current best combo: (5, 76) with val score 0.8331
# Trained and Tested combination 85 of 744: (5, 84), taking 16.46 seconds to get val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 86 of 744: (5, 85), taking 18.81 seconds to get val score of 0.8282
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 87 of 744: (5, 86), taking 16.94 seconds to get val score of 0.829
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 88 of 744: (5, 87), taking 16.96 seconds to get val score of 0.8326
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 89 of 744: (5, 88), taking 19.13 seconds to get val score of 0.8253
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 90 of 744: (5, 89), taking 19.2 seconds to get val score of 0.8261
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 91 of 744: (5, 90), taking 17.36 seconds to get val score of 0.8233
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 92 of 744: (5, 91), taking 19.7 seconds to get val score of 0.8297
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 93 of 744: (5, 92), taking 17.81 seconds to get val score of 0.8297
#         Current best combo: (5, 84) with val score 0.8388
#
# Best combo after this hyperparameter: (5, 84) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: var_smoothing (index: 0)
#
# Trained and Tested combination 94 of 744: (0, 84), taking 16.49 seconds to get val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 95 of 744: (1, 84), taking 18.79 seconds to get val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 96 of 744: (2, 84), taking 18.92 seconds to get val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 97 of 744: (3, 84), taking 16.76 seconds to get val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 98 of 744: (4, 84), taking 18.89 seconds to get val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388
# Already Trained and Tested combination (5, 84), which had val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 98 of 744 combinations so far
# Trained and Tested combination 99 of 744: (6, 84), taking 16.64 seconds to get val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 100 of 744: (7, 84), taking 16.69 seconds to get val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388
#
# Best combo after this hyperparameter: (5, 84) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 0 (features) ROUND 2
#
# Round 2
# Hyperparameter: features (index: 1)
#
# Already Trained and Tested combination (5, 0), which had val score of 0.7554
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 1), which had val score of 0.7598
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 2), which had val score of 0.7705
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 3), which had val score of 0.7659
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 4), which had val score of 0.7704
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 5), which had val score of 0.7739
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 6), which had val score of 0.7838
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 7), which had val score of 0.7799
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 8), which had val score of 0.7861
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 9), which had val score of 0.7967
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 10), which had val score of 0.7986
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 11), which had val score of 0.7979
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 12), which had val score of 0.8008
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 13), which had val score of 0.8036
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 14), which had val score of 0.8121
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 15), which had val score of 0.803
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 16), which had val score of 0.8088
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 17), which had val score of 0.8091
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 18), which had val score of 0.801
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 19), which had val score of 0.8072
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 20), which had val score of 0.7981
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 21), which had val score of 0.8043
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 22), which had val score of 0.8118
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 23), which had val score of 0.8053
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 24), which had val score of 0.8053
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 25), which had val score of 0.8074
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 26), which had val score of 0.8076
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 27), which had val score of 0.8109
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 28), which had val score of 0.8135
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 29), which had val score of 0.8113
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 30), which had val score of 0.8062
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 31), which had val score of 0.8084
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 32), which had val score of 0.8106
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 33), which had val score of 0.8104
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 34), which had val score of 0.8122
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 35), which had val score of 0.8119
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 36), which had val score of 0.809
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 37), which had val score of 0.8104
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 38), which had val score of 0.8163
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 39), which had val score of 0.8127
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 40), which had val score of 0.8135
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 41), which had val score of 0.8142
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 42), which had val score of 0.8114
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 43), which had val score of 0.8195
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 44), which had val score of 0.8173
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 45), which had val score of 0.8165
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 46), which had val score of 0.8149
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 47), which had val score of 0.8184
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 48), which had val score of 0.8227
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 49), which had val score of 0.8105
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 50), which had val score of 0.817
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 51), which had val score of 0.82
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 52), which had val score of 0.828
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 53), which had val score of 0.8263
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 54), which had val score of 0.8222
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 55), which had val score of 0.8187
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 56), which had val score of 0.827
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 57), which had val score of 0.8216
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 58), which had val score of 0.8283
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 59), which had val score of 0.8258
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 60), which had val score of 0.8253
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 61), which had val score of 0.8231
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 62), which had val score of 0.8263
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 63), which had val score of 0.8295
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 64), which had val score of 0.8314
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 65), which had val score of 0.8248
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 66), which had val score of 0.8318
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 67), which had val score of 0.8309
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 68), which had val score of 0.8317
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 69), which had val score of 0.8301
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 70), which had val score of 0.8287
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 71), which had val score of 0.8208
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 72), which had val score of 0.8326
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 73), which had val score of 0.827
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 74), which had val score of 0.8287
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 75), which had val score of 0.8258
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 76), which had val score of 0.8331
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 77), which had val score of 0.8245
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 78), which had val score of 0.828
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 79), which had val score of 0.8281
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 80), which had val score of 0.8266
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 81), which had val score of 0.8259
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 82), which had val score of 0.825
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 83), which had val score of 0.8312
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 84), which had val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 85), which had val score of 0.8282
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 86), which had val score of 0.829
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 87), which had val score of 0.8326
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 88), which had val score of 0.8253
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 89), which had val score of 0.8261
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 90), which had val score of 0.8233
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 91), which had val score of 0.8297
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 92), which had val score of 0.8297
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
#
# Best combo after this hyperparameter: (5, 84) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: var_smoothing (index: 0)
#
# Already Trained and Tested combination (0, 84), which had val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (1, 84), which had val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (2, 84), which had val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (3, 84), which had val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (4, 84), which had val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (5, 84), which had val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (6, 84), which had val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
# Already Trained and Tested combination (7, 84), which had val score of 0.8388
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 100 of 744 combinations so far
#
# Best combo after this hyperparameter: (5, 84) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# FEATURE_INDEX: 1 (var_smoothing) ROUND 1
#
# Round 1
# Hyperparameter: var_smoothing (index: 0)
#
# Trained and Tested combination 101 of 744: (0, 0), taking 0.27 seconds to get val score of 0.7554
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 102 of 744: (1, 0), taking 0.29 seconds to get val score of 0.7554
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 103 of 744: (2, 0), taking 0.26 seconds to get val score of 0.7554
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 104 of 744: (3, 0), taking 0.31 seconds to get val score of 0.7554
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 105 of 744: (4, 0), taking 2.73 seconds to get val score of 0.7554
#         Current best combo: (5, 84) with val score 0.8388
# Already Trained and Tested combination (5, 0), which had val score of 0.7554
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 105 of 744 combinations so far
# Trained and Tested combination 106 of 744: (6, 0), taking 0.27 seconds to get val score of 0.7554
#         Current best combo: (5, 84) with val score 0.8388
# Trained and Tested combination 107 of 744: (7, 0), taking 0.27 seconds to get val score of 0.7554
#         Current best combo: (5, 84) with val score 0.8388
#
# Best combo after this hyperparameter: (5, 84) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: features (index: 1)
#
# Already Trained and Tested combination (5, 0), which had val score of 0.7554
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 1), which had val score of 0.7598
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 2), which had val score of 0.7705
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 3), which had val score of 0.7659
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 4), which had val score of 0.7704
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 5), which had val score of 0.7739
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 6), which had val score of 0.7838
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 7), which had val score of 0.7799
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 8), which had val score of 0.7861
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 9), which had val score of 0.7967
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 10), which had val score of 0.7986
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 11), which had val score of 0.7979
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 12), which had val score of 0.8008
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 13), which had val score of 0.8036
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 14), which had val score of 0.8121
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 15), which had val score of 0.803
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 16), which had val score of 0.8088
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 17), which had val score of 0.8091
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 18), which had val score of 0.801
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 19), which had val score of 0.8072
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 20), which had val score of 0.7981
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 21), which had val score of 0.8043
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 22), which had val score of 0.8118
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 23), which had val score of 0.8053
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 24), which had val score of 0.8053
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 25), which had val score of 0.8074
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 26), which had val score of 0.8076
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 27), which had val score of 0.8109
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 28), which had val score of 0.8135
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 29), which had val score of 0.8113
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 30), which had val score of 0.8062
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 31), which had val score of 0.8084
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 32), which had val score of 0.8106
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 33), which had val score of 0.8104
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 34), which had val score of 0.8122
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 35), which had val score of 0.8119
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 36), which had val score of 0.809
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 37), which had val score of 0.8104
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 38), which had val score of 0.8163
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 39), which had val score of 0.8127
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 40), which had val score of 0.8135
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 41), which had val score of 0.8142
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 42), which had val score of 0.8114
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 43), which had val score of 0.8195
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 44), which had val score of 0.8173
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 45), which had val score of 0.8165
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 46), which had val score of 0.8149
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 47), which had val score of 0.8184
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 48), which had val score of 0.8227
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 49), which had val score of 0.8105
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 50), which had val score of 0.817
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 51), which had val score of 0.82
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 52), which had val score of 0.828
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 53), which had val score of 0.8263
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 54), which had val score of 0.8222
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 55), which had val score of 0.8187
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 56), which had val score of 0.827
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 57), which had val score of 0.8216
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# ...
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 32), which had val score of 0.8106
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 33), which had val score of 0.8104
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 34), which had val score of 0.8122
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 35), which had val score of 0.8119
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 36), which had val score of 0.809
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 37), which had val score of 0.8104
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 38), which had val score of 0.8163
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 39), which had val score of 0.8127
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 40), which had val score of 0.8135
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 41), which had val score of 0.8142
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 42), which had val score of 0.8114
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 43), which had val score of 0.8195
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 44), which had val score of 0.8173
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 45), which had val score of 0.8165
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 46), which had val score of 0.8149
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 47), which had val score of 0.8184
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 48), which had val score of 0.8227
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 49), which had val score of 0.8105
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 50), which had val score of 0.817
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 51), which had val score of 0.82
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 52), which had val score of 0.828
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 53), which had val score of 0.8263
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 54), which had val score of 0.8222
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 55), which had val score of 0.8187
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 56), which had val score of 0.827
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 57), which had val score of 0.8216
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 58), which had val score of 0.8283
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 59), which had val score of 0.8258
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 60), which had val score of 0.8253
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 61), which had val score of 0.8231
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 62), which had val score of 0.8263
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 63), which had val score of 0.8295
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 64), which had val score of 0.8314
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5, 65), which had val score of 0.8248
#         Current best combo: (5, 84) with val score 0.8388.
#         Has trained 107 of 744 combinations so far
# Already Trained and Tested combination (5,