# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'gnb'
FEATURE_IMPORTANCE_ORDERING = 'xgb'
PREPROCESSING = 'Baseline'
TUNER = 'jiaochengb'
FEATURE_ENGINEERING = 'tfidf'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle
from scipy.sparse import load_npz 

if COLAB_ENVIRONMENT:
    py_file_location = "./drive/MyDrive/LAB/Research - Internet Addiction Part 1/PrivatePackages" # my private packages are stored here
    home_directory = './drive/MyDrive/LAB/Research - Internet Addiction Part 1/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
else:
    py_file_location = '../../PrivatePackages'
    home_directory = '../../'

sys.path.append(os.path.abspath(py_file_location))

from Tuners import JiaoChengB

import pandas as pd

# %%
## Parameters that are same for every script

SEED = 2608

TASK_TYPE = 'Classification' # this task is a classification task

TUNE_FEATURES_AS_HYPERPARAMETERS = True # we have decided to tune features as hp

# %% [markdown]
# ---

# %%
# model to use to tune
from xgboost import XGBClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'var_smoothing': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    }

tuning_order = [
    'features',
    'var_smoothing'
]

default_hyperparameter_values = {'var_smoothing': 1, 'features': 0}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_x = load_npz(home_directory + f'data/curated/baseline/train_{FEATURE_ENGINEERING}_x.npz')
val_x = load_npz(home_directory + f'data/curated/baseline/val_{FEATURE_ENGINEERING}_x.npz')
test_x = load_npz(home_directory + f'data/curated/baseline/test_{FEATURE_ENGINEERING}_x.npz')

with open(home_directory + 'data/curated/baseline/train_y.pkl', 'rb') as f:
    train_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/val_y.pkl', 'rb') as f:
    val_y = pickle.load(f)
with open(home_directory + 'data/curated/baseline/test_y.pkl', 'rb') as f:
    test_y = pickle.load(f)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = JiaoChengB.JiaoChengB()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{FEATURE_IMPORTANCE_ORDERING}_{FEATURE_ENGINEERING}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'xgboost.sklearn.XGBClassifier'>, which is a Classification model
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# FEATURE_INDEX: 0 (var_smoothing) ROUND 1
#
# Round 1
# Hyperparameter: features (index: 1)
# Trained and Tested combination 1 of 744: (5, 0), taking 4.4 seconds to get val score of 0.7844
#         Current best combo: (5, 0) with val score 0.7844
# Trained and Tested combination 2 of 744: (5, 1), taking 3.03 seconds to get val score of 0.7863
#         Current best combo: (5, 1) with val score 0.7863
# Trained and Tested combination 3 of 744: (5, 2), taking 2.35 seconds to get val score of 0.793
#         Current best combo: (5, 2) with val score 0.793
# Trained and Tested combination 4 of 744: (5, 3), taking 3.67 seconds to get val score of 0.7878
#         Current best combo: (5, 2) with val score 0.793
# Trained and Tested combination 5 of 744: (5, 4), taking 2.61 seconds to get val score of 0.7911
#         Current best combo: (5, 2) with val score 0.793
# Trained and Tested combination 6 of 744: (5, 5), taking 4.04 seconds to get val score of 0.7919
#         Current best combo: (5, 2) with val score 0.793
# Trained and Tested combination 7 of 744: (5, 6), taking 4.12 seconds to get val score of 0.8004
#         Current best combo: (5, 6) with val score 0.8004
# Trained and Tested combination 8 of 744: (5, 7), taking 4.59 seconds to get val score of 0.7959
#         Current best combo: (5, 6) with val score 0.8004
# Trained and Tested combination 9 of 744: (5, 8), taking 3.79 seconds to get val score of 0.8052
#         Current best combo: (5, 8) with val score 0.8052
# Trained and Tested combination 10 of 744: (5, 9), taking 3.28 seconds to get val score of 0.8096
#         Current best combo: (5, 9) with val score 0.8096
# Trained and Tested combination 11 of 744: (5, 10), taking 3.36 seconds to get val score of 0.8115
#         Current best combo: (5, 10) with val score 0.8115
# Trained and Tested combination 12 of 744: (5, 11), taking 4.1 seconds to get val score of 0.8119
#         Current best combo: (5, 11) with val score 0.8119
# Trained and Tested combination 13 of 744: (5, 12), taking 5.67 seconds to get val score of 0.8141
#         Current best combo: (5, 12) with val score 0.8141
# Trained and Tested combination 14 of 744: (5, 13), taking 4.45 seconds to get val score of 0.8156
#         Current best combo: (5, 13) with val score 0.8156
# Trained and Tested combination 15 of 744: (5, 14), taking 5.18 seconds to get val score of 0.8233
#         Current best combo: (5, 14) with val score 0.8233
# Trained and Tested combination 16 of 744: (5, 15), taking 2.56 seconds to get val score of 0.8159
#         Current best combo: (5, 14) with val score 0.8233
# Trained and Tested combination 17 of 744: (5, 16), taking 4.37 seconds to get val score of 0.8222
#         Current best combo: (5, 14) with val score 0.8233
# Trained and Tested combination 18 of 744: (5, 17), taking 4.63 seconds to get val score of 0.8207
#         Current best combo: (5, 14) with val score 0.8233
# Trained and Tested combination 19 of 744: (5, 18), taking 3.29 seconds to get val score of 0.8133
#         Current best combo: (5, 14) with val score 0.8233
# Trained and Tested combination 20 of 744: (5, 19), taking 3.36 seconds to get val score of 0.8185
#         Current best combo: (5, 14) with val score 0.8233
# Trained and Tested combination 21 of 744: (5, 20), taking 8.85 seconds to get val score of 0.8104
#         Current best combo: (5, 14) with val score 0.8233
# Trained and Tested combination 22 of 744: (5, 21), taking 7.72 seconds to get val score of 0.8167
#         Current best combo: (5, 14) with val score 0.8233
# Trained and Tested combination 23 of 744: (5, 22), taking 7.21 seconds to get val score of 0.8241
#         Current best combo: (5, 22) with val score 0.8241
# Trained and Tested combination 24 of 744: (5, 23), taking 7.61 seconds to get val score of 0.8193
#         Current best combo: (5, 22) with val score 0.8241
# Trained and Tested combination 25 of 744: (5, 24), taking 7.06 seconds to get val score of 0.8178
#         Current best combo: (5, 22) with val score 0.8241
# Trained and Tested combination 26 of 744: (5, 25), taking 7.06 seconds to get val score of 0.8193
#         Current best combo: (5, 22) with val score 0.8241
# Trained and Tested combination 27 of 744: (5, 26), taking 8.32 seconds to get val score of 0.8207
#         Current best combo: (5, 22) with val score 0.8241
# Trained and Tested combination 28 of 744: (5, 27), taking 7.62 seconds to get val score of 0.8211
#         Current best combo: (5, 22) with val score 0.8241
# Trained and Tested combination 29 of 744: (5, 28), taking 7.15 seconds to get val score of 0.8252
#         Current best combo: (5, 28) with val score 0.8252
# Trained and Tested combination 30 of 744: (5, 29), taking 8.78 seconds to get val score of 0.8237
#         Current best combo: (5, 28) with val score 0.8252
# Trained and Tested combination 31 of 744: (5, 30), taking 8.11 seconds to get val score of 0.817
#         Current best combo: (5, 28) with val score 0.8252
# Trained and Tested combination 32 of 744: (5, 31), taking 7.11 seconds to get val score of 0.8211
#         Current best combo: (5, 28) with val score 0.8252
# Trained and Tested combination 33 of 744: (5, 32), taking 7.1 seconds to get val score of 0.8211
#         Current best combo: (5, 28) with val score 0.8252
# Trained and Tested combination 34 of 744: (5, 33), taking 5.8 seconds to get val score of 0.8222
#         Current best combo: (5, 28) with val score 0.8252
# Trained and Tested combination 35 of 744: (5, 34), taking 5.65 seconds to get val score of 0.8248
#         Current best combo: (5, 28) with val score 0.8252
# Trained and Tested combination 36 of 744: (5, 35), taking 7.2 seconds to get val score of 0.8241
#         Current best combo: (5, 28) with val score 0.8252
# Trained and Tested combination 37 of 744: (5, 36), taking 12.95 seconds to get val score of 0.8204
#         Current best combo: (5, 28) with val score 0.8252
# Trained and Tested combination 38 of 744: (5, 37), taking 13.69 seconds to get val score of 0.8219
#         Current best combo: (5, 28) with val score 0.8252
# Trained and Tested combination 39 of 744: (5, 38), taking 12.79 seconds to get val score of 0.8293
#         Current best combo: (5, 38) with val score 0.8293
